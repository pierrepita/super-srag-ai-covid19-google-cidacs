# %%
import pandas as pd
import pyspark.sql.functions as F
from pyspark.sql.types import *

# %%
pd.set_option("display.max_rows", 101)
pd.set_option("display.max_columns", 101)

# %% [markdown]
# <hr />

# %% [markdown]
# ### reading preprocessed dataframes

# %%
srag_2019 = spark.read.parquet('gs://ai-covid19-datalake/standard/srag/pp_interm_srag_2019_v3_new_attr')

# %%
srag_2020 = spark.read.parquet('gs://ai-covid19-datalake/standard/srag/pp_interm_srag_2020_v3_new_attr')

# %%
srag_2021 = spark.read.parquet('gs://ai-covid19-datalake/standard/srag/pp_interm_srag_2021_v3_new_attr')

# %%
gmr = spark.read.csv('gs://ai-covid19-datalake/standard/google-mobility/pp_google-mobility_report-28-05-2021.csv', header=True, inferSchema=True)

# %%
ibge = spark.read.csv('gs://ai-covid19-datalake/standard/ibge-data/pp_ibge-municipality-to-code-28-05-2021.csv', header=True, inferSchema=True)

# %%
inmet = spark.read.csv('gs://ai-covid19-datalake/standard/inmet-data/pp_inmet_meteorological_data-01012019-a-28052021', header=True, inferSchema=True)

# %%
epi_weeks = spark.read.csv('gs://ai-covid19-datalake/raw/epidemiological-data/epi_weeks.csv', header=True, inferSchema=True)

# %% [markdown]
# <hr />

# %% [markdown]
# # Preparing srag to receive the new information from UF's and Epidemiological Weeks

# %%
# # dropping duplicate columns
# def dropDupeDfCols(df):
#     newcols = []
#     dupcols = []

#     for i in range(len(df.columns)):
#         if df.columns[i] not in newcols:
#             newcols.append(df.columns[i])
#         else:
#             dupcols.append(i)

#     df = df.toDF(*[str(i) for i in range(len(df.columns))])
#     for dupcol in dupcols:
#         df = df.drop(str(dupcol))

#     return df.toDF(*newcols)

# %%
# srag_2019 = dropDupeDfCols(srag_2019)
# srag_2020 = dropDupeDfCols(srag_2020)
# srag_2021 = dropDupeDfCols(srag_2021)

# %%
srag_2019 = srag_2019.withColumn('ANO', F.lit('2019'))
srag_2020 = srag_2020.withColumn('ANO', F.lit('2020'))
srag_2021 = srag_2021.withColumn('ANO', F.lit('2021'))

# %%
def get_epi_week_year(epi_week, year):
    return str(epi_week) + '-' + str(year)
udf_get_epi_week_year = F.udf(get_epi_week_year, StringType())

# %%
# adding 'epi_week_year' tag
srag_2019 = srag_2019.withColumn('epi_week_year', udf_get_epi_week_year(F.col('SEM_PRI'), F.col('ANO')))
srag_2020 = srag_2020.withColumn('epi_week_year', udf_get_epi_week_year(F.col('SEM_PRI'), F.col('ANO')))
srag_2021 = srag_2021.withColumn('epi_week_year', udf_get_epi_week_year(F.col('SEM_PRI'), F.col('ANO')))

# %%
# padding
srag_2019 = srag_2019.withColumn('epi_week_year', F.lpad(F.col('epi_week_year'), 7, '0'))
srag_2020 = srag_2020.withColumn('epi_week_year', F.lpad(F.col('epi_week_year'), 7, '0'))
srag_2021 = srag_2021.withColumn('epi_week_year', F.lpad(F.col('epi_week_year'), 7, '0'))

# %%
def get_uf(cod_mun_res):
    return str(cod_mun_res)[:2]
udf_get_uf = F.udf(get_uf, StringType())

# %%
srag_2019 = srag_2019.withColumn('UF', udf_get_uf(F.col('CO_MUN_NOT')))
srag_2020 = srag_2020.withColumn('UF', udf_get_uf(F.col('CO_MUN_NOT')))
srag_2021 = srag_2021.withColumn('UF', udf_get_uf(F.col('CO_MUN_NOT')))

# %% [markdown]
# # Google Mobility Report with state codes by epi_weeks

# %% [markdown]
# ###  adding epidemiological weeks

# %%
# converting date type variables
gmr = gmr.withColumn('date', F.to_date(F.col('date'), 'dd/MM/yyyy'))
epi_weeks = epi_weeks.withColumn('date', F.to_date(F.col('date'), 'dd/MM/yyyy'))

# %%
# find the date from 7 or 14 days before
epi_weeks = epi_weeks.withColumn('date_7_days_early', F.date_sub(F.col('date'), 7))
epi_weeks = epi_weeks.withColumn('date_14_days_early', F.date_sub(F.col('date'), 14))

# %%
# finding the epi_week number from 1 or 2 weeks before
def find_one_or_two_epi_weeks(n_weeks, col):
    return col - n_weeks
udf_find_one_or_two_epi_weeks = F.udf(find_one_or_two_epi_weeks, IntegerType())

# %%
epi_weeks = epi_weeks.withColumn('epi_week_7_days_early', udf_find_one_or_two_epi_weeks(F.lit(1), F.col('epi_week')))
epi_weeks = epi_weeks.withColumn('epi_week_14_days_early', udf_find_one_or_two_epi_weeks(F.lit(2), F.col('epi_week')))

# %%
# creating the epi_week tag for the new found early epi_weeks
def set_epi_week_year(col1, col2):
    string = str(col1) + '-' + str(col2)
    return string
udf_set_epi_week_year = F.udf(set_epi_week_year, StringType())

# %%
epi_weeks = epi_weeks.withColumn('epi_week_year_7_days_early', udf_set_epi_week_year(F.col('epi_week_7_days_early'), F.col('epi_year')))
epi_weeks = epi_weeks.withColumn('epi_week_year_14_early', udf_set_epi_week_year(F.col('epi_week_14_days_early'), F.col('epi_year')))

# %%
# make sure to erase inexistent epi_week
epi_weeks = epi_weeks.withColumn('epi_week_year_7_days_early', F.when((F.col('epi_week_7_days_early') < 1), None).otherwise(F.col('epi_week_year_7_days_early')))
epi_weeks = epi_weeks.withColumn('epi_week_7_days_early', F.when((F.col('epi_week_7_days_early') < 1), None).otherwise(F.col('epi_week_7_days_early')))

epi_weeks = epi_weeks.withColumn('epi_week_year_14_early', F.when((F.col('epi_week_14_days_early') < 1), None).otherwise(F.col('epi_week_year_14_early')))
epi_weeks = epi_weeks.withColumn('epi_week_14_days_early', F.when((F.col('epi_week_14_days_early') < 1), None).otherwise(F.col('epi_week_14_days_early')))

# %%
# joining using the actual date
epi_weeks_actual = epi_weeks.select(['date', 'epi_week', 'epi_year', 'epi_week_year'])
gmr = gmr.join(epi_weeks_actual, 'date', 'left')

# %%
# joining using date from 7 days before
epi_weeks_7 = epi_weeks.select(['date_7_days_early', 'epi_week_7_days_early', 'epi_week_year_7_days_early'])
gmr = gmr.join(epi_weeks_7, F.date_add(gmr.date, 7) == epi_weeks.date_7_days_early, 'left')

# %%
# joining using date from 14 days before
epi_weeks_14 = epi_weeks.select(['date_14_days_early', 'epi_week_14_days_early', 'epi_week_year_14_early'])
gmr = gmr.join(epi_weeks_14, F.date_add(gmr.date, 14) == epi_weeks.date_14_days_early, 'left')

# %%
epi_weeks.limit(10).toPandas()
# Out:
#          date  epi_week  epi_year epi_week_year date_7_days_early  \
# 0  2018-12-30         1      2019        1-2019        2018-12-23
# 1  2018-12-31         1      2019        1-2019        2018-12-24
# 2  2019-01-01         1      2019        1-2019        2018-12-25
# 3  2019-01-02         1      2019        1-2019        2018-12-26
# 4  2019-01-03         1      2019        1-2019        2018-12-27
# 5  2019-01-04         1      2019        1-2019        2018-12-28
# 6  2019-01-05         1      2019        1-2019        2018-12-29
# 7  2019-01-06         2      2019        2-2019        2018-12-30
# 8  2019-01-07         2      2019        2-2019        2018-12-31
# 9  2019-01-08         2      2019        2-2019        2019-01-01
#
#   date_14_days_early  epi_week_7_days_early epi_week_14_days_early  \
# 0         2018-12-16                    NaN                   None
# 1         2018-12-17                    NaN                   None
# 2         2018-12-18                    NaN                   None
# 3         2018-12-19                    NaN                   None
# 4         2018-12-20                    NaN                   None
# 5         2018-12-21                    NaN                   None
# 6         2018-12-22                    NaN                   None
# 7         2018-12-23                    1.0                   None
# 8         2018-12-24                    1.0                   None
# 9         2018-12-25                    1.0                   None
#
#   epi_week_year_7_days_early epi_week_year_14_early
# 0                       None                   None
# 1                       None                   None
# 2                       None                   None
# 3                       None                   None
# 4                       None                   None
# 5                       None                   None
# 6                       None                   None
# 7                     1-2019                   None
# 8                     1-2019                   None
# 9                     1-2019                   None

# %%
gmr.limit(5).toPandas()
# Out:
#          date country_region_code country_region sub_region_1 sub_region_2  \
# 0  2020-02-25                  BR         Brazil         ACRE    BRASILEIA
# 1  2020-03-24                  BR         Brazil         ACRE    BRASILEIA
# 2  2020-03-25                  BR         Brazil         ACRE    BRASILEIA
# 3  2020-04-10                  BR         Brazil         ACRE    BRASILEIA
# 4  2020-04-21                  BR         Brazil         ACRE    BRASILEIA
#
#   metro_area iso_3166_2_code census_fips_code                     place_id  \
# 0       None            None             None  ChIJm4g9Bje3fpERnpwI2L71NRQ
# 1       None            None             None  ChIJm4g9Bje3fpERnpwI2L71NRQ
# 2       None            None             None  ChIJm4g9Bje3fpERnpwI2L71NRQ
# 3       None            None             None  ChIJm4g9Bje3fpERnpwI2L71NRQ
# 4       None            None             None  ChIJm4g9Bje3fpERnpwI2L71NRQ
#
#   retail_and_recreation_percent_change_from_baseline  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#   grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                              None
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                              None
#
#   parks_percent_change_from_baseline  \
# 0                               None
# 1                               None
# 2                               None
# 3                               None
# 4                               None
#
#   transit_stations_percent_change_from_baseline  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
#
#    workplaces_percent_change_from_baseline  \
# 0                                      -41
# 1                                      -40
# 2                                      -43
# 3                                      -65
# 4                                      -44
#
#   residential_percent_change_from_baseline  epi_week  epi_year epi_week_year  \
# 0                                     None         9      2020        9-2020
# 1                                     None        13      2020       13-2020
# 2                                     None        13      2020       13-2020
# 3                                     None        15      2020       15-2020
# 4                                     None        17      2020       17-2020
#
#   date_7_days_early  epi_week_7_days_early epi_week_year_7_days_early  \
# 0        2020-03-03                     10                    10-2020
# 1        2020-03-31                     14                    14-2020
# 2        2020-04-01                     14                    14-2020
# 3        2020-04-17                     16                    16-2020
# 4        2020-04-28                     18                    18-2020
#
#   date_14_days_early  epi_week_14_days_early epi_week_year_14_early
# 0         2020-03-10                      11                11-2020
# 1         2020-04-07                      15                15-2020
# 2         2020-04-08                      15                15-2020
# 3         2020-04-24                      17                17-2020
# 4         2020-05-05                      19                19-2020

# %% [markdown]
# ### adding state code

# %%
gmr = gmr.join(ibge.select('UF', 'sub_region_1'), 'sub_region_1', 'left')

# %% [markdown]
# ### aggregating

# %%
gmr1 = gmr.groupBy(['UF', 'epi_week_year']).agg({"residential_percent_change_from_baseline":"avg",
                                          "workplaces_percent_change_from_baseline":"avg",
                                          "transit_stations_percent_change_from_baseline":"avg",
                                          "parks_percent_change_from_baseline":"avg",
                                          "grocery_and_pharmacy_percent_change_from_baseline":"avg",
                                          "retail_and_recreation_percent_change_from_baseline":"avg"})\
                                    .withColumnRenamed('avg(transit_stations_percent_change_from_baseline)', 'gmr_transit_stations_avg')\
                                    .withColumnRenamed('avg(grocery_and_pharmacy_percent_change_from_baseline)', 'gmr_grocery_and_pharmacy_avg')\
                                    .withColumnRenamed('avg(retail_and_recreation_percent_change_from_baseline)', 'gmr_retail_and_recreation_avg')\
                                    .withColumnRenamed('avg(retail_and_recreation_percent_change_from_baseline)', 'gmr_retail_and_recreation_avg')\
                                    .withColumnRenamed('avg(workplaces_percent_change_from_baseline)', 'gmr_workplaces_percent_avg')\
                                    .withColumnRenamed('avg(residential_percent_change_from_baseline)', 'gmr_residential_percent_avg')\
                                    .withColumnRenamed('avg(parks_percent_change_from_baseline)', 'gmr_parks_percent_avg')\
                                    .orderBy('UF')

# %%
gmr7 = gmr.groupBy(['UF', 'epi_week_year_7_days_early']).agg({"residential_percent_change_from_baseline":"avg",
                                          "workplaces_percent_change_from_baseline":"avg",
                                          "transit_stations_percent_change_from_baseline":"avg",
                                          "parks_percent_change_from_baseline":"avg",
                                          "grocery_and_pharmacy_percent_change_from_baseline":"avg",
                                          "retail_and_recreation_percent_change_from_baseline":"avg"})\
                                    .withColumnRenamed('avg(transit_stations_percent_change_from_baseline)', 'gmr_transit_stations_1week_before_avg')\
                                    .withColumnRenamed('avg(grocery_and_pharmacy_percent_change_from_baseline)', 'gmr_grocery_and_pharmacy_1week_before_avg')\
                                    .withColumnRenamed('avg(retail_and_recreation_percent_change_from_baseline)', 'gmr_retail_and_recreation_1week_before_avg')\
                                    .withColumnRenamed('avg(retail_and_recreation_percent_change_from_baseline)', 'gmr_retail_and_recreation_1week_before_avg')\
                                    .withColumnRenamed('avg(workplaces_percent_change_from_baseline)', 'gmr_workplaces_percent_1week_before_avg')\
                                    .withColumnRenamed('avg(residential_percent_change_from_baseline)', 'gmr_residential_percent_1week_before_avg')\
                                    .withColumnRenamed('avg(parks_percent_change_from_baseline)', 'gmr_parks_percent_1week_before_avg')\
                                    .orderBy('UF')

# %%
gmr14 = gmr.groupBy(['UF', 'epi_week_year_14_early']).agg({"residential_percent_change_from_baseline":"avg",
                                          "workplaces_percent_change_from_baseline":"avg",
                                          "transit_stations_percent_change_from_baseline":"avg",
                                          "parks_percent_change_from_baseline":"avg",
                                          "grocery_and_pharmacy_percent_change_from_baseline":"avg",
                                          "retail_and_recreation_percent_change_from_baseline":"avg"})\
                                    .withColumnRenamed('avg(transit_stations_percent_change_from_baseline)', 'gmr_transit_stations_2weeks_avg')\
                                    .withColumnRenamed('avg(grocery_and_pharmacy_percent_change_from_baseline)', 'gmr_grocery_and_pharmacy_2weeks_avg')\
                                    .withColumnRenamed('avg(retail_and_recreation_percent_change_from_baseline)', 'gmr_retail_and_recreation_2weeks_avg')\
                                    .withColumnRenamed('avg(retail_and_recreation_percent_change_from_baseline)', 'gmr_retail_and_recreation_2weeks_avg')\
                                    .withColumnRenamed('avg(workplaces_percent_change_from_baseline)', 'gmr_workplaces_percent_2weeks_avg')\
                                    .withColumnRenamed('avg(residential_percent_change_from_baseline)', 'gmr_residential_percent_2weeks_avg')\
                                    .withColumnRenamed('avg(parks_percent_change_from_baseline)', 'gmr_parks_percent_2weeks_avg')\
                                    .orderBy('UF')

# %% [markdown]
# ##### making some validations

# %%
gmr1.filter((F.col('UF')=='11') &  ((F.col('epi_week_year') == '22-2020') | (F.col('epi_week_year') == '23-2020') | (F.col('epi_week_year') == '24-2020') | (F.col('epi_week_year') == '25-2020')))\
    .orderBy('epi_week_year').limit(5).toPandas()
# Out:
#    UF epi_week_year  gmr_transit_stations_avg  gmr_grocery_and_pharmacy_avg  \
# 0  11       22-2020                -54.500000                      2.830189
# 1  11       23-2020                -53.393939                      9.166667
# 2  11       24-2020                -59.968750                      6.259259
# 3  11       25-2020                -57.714286                      2.000000
#
#    gmr_retail_and_recreation_avg  gmr_workplaces_percent_avg  \
# 0                     -33.387755                   -3.505882
# 1                     -29.020000                   -4.119048
# 2                     -31.900000                   -9.711268
# 3                     -29.877551                   -2.129252
#
#    gmr_residential_percent_avg  gmr_parks_percent_avg
# 0                        10.82             -27.666667
# 1                        10.52             -25.314286
# 2                        12.00             -24.781250
# 3                        11.56             -25.114286

# %%
gmr7.filter((F.col('UF')=='11') &  ((F.col('epi_week_year_7_days_early') == '22-2020') | (F.col('epi_week_year_7_days_early') == '23-2020') | (F.col('epi_week_year_7_days_early') == '24-2020') | (F.col('epi_week_year_7_days_early') == '25-2020')))\
    .orderBy('epi_week_year_7_days_early').limit(5).toPandas()
# Out:
#    UF epi_week_year_7_days_early  gmr_transit_stations_1week_before_avg  \
# 0  11                    22-2020                             -55.187500
# 1  11                    23-2020                             -54.500000
# 2  11                    24-2020                             -53.393939
# 3  11                    25-2020                             -59.968750
#
#    gmr_grocery_and_pharmacy_1week_before_avg  \
# 0                                  -2.277778
# 1                                   2.830189
# 2                                   9.166667
# 3                                   6.259259
#
#    gmr_retail_and_recreation_1week_before_avg  \
# 0                                  -35.673469
# 1                                  -33.387755
# 2                                  -29.020000
# 3                                  -31.900000
#
#    gmr_workplaces_percent_1week_before_avg  \
# 0                                -5.617978
# 1                                -3.505882
# 2                                -4.119048
# 3                                -9.711268
#
#    gmr_residential_percent_1week_before_avg  \
# 0                                 10.469388
# 1                                 10.820000
# 2                                 10.520000
# 3                                 12.000000
#
#    gmr_parks_percent_1week_before_avg
# 0                          -30.558824
# 1                          -27.666667
# 2                          -25.314286
# 3                          -24.781250

# %%
gmr14.filter((F.col('UF')=='11') &  ((F.col('epi_week_year_14_early') == '22-2020') | (F.col('epi_week_year_14_early') == '23-2020') | (F.col('epi_week_year_14_early') == '24-2020') | (F.col('epi_week_year_14_early') == '25-2020')))\
    .orderBy('epi_week_year_14_early').limit(5).toPandas()
# Out:
#    UF epi_week_year_14_early  gmr_transit_stations_2weeks_avg  \
# 0  11                22-2020                       -53.937500
# 1  11                23-2020                       -55.187500
# 2  11                24-2020                       -54.500000
# 3  11                25-2020                       -53.393939
#
#    gmr_grocery_and_pharmacy_2weeks_avg  gmr_retail_and_recreation_2weeks_avg  \
# 0                            -1.611111                            -35.693878
# 1                            -2.277778                            -35.673469
# 2                             2.830189                            -33.387755
# 3                             9.166667                            -29.020000
#
#    gmr_workplaces_percent_2weeks_avg  gmr_residential_percent_2weeks_avg  \
# 0                          -6.586207                           10.000000
# 1                          -5.617978                           10.469388
# 2                          -3.505882                           10.820000
# 3                          -4.119048                           10.520000
#
#    gmr_parks_percent_2weeks_avg
# 0                    -30.575758
# 1                    -30.558824
# 2                    -27.666667
# 3                    -25.314286

# %%
# joining all for 1 week early
gmr7 = gmr7.withColumnRenamed('UF', 'UF7')
cond = [gmr1.UF == gmr7.UF7, gmr1.epi_week_year == gmr7.epi_week_year_7_days_early]
gmr_agg = gmr1.join(gmr7, cond, 'left')

gmr_agg.filter((F.col('UF')=='11') &  ((F.col('epi_week_year') == '22-2020') | (F.col('epi_week_year') == '23-2020') | (F.col('epi_week_year') == '24-2020') | (F.col('epi_week_year') == '25-2020')))\
    .orderBy('epi_week_year').limit(5).toPandas()
# Out:
#    UF epi_week_year  gmr_transit_stations_avg  gmr_grocery_and_pharmacy_avg  \
# 0  11       22-2020                -54.500000                      2.830189
# 1  11       23-2020                -53.393939                      9.166667
# 2  11       24-2020                -59.968750                      6.259259
# 3  11       25-2020                -57.714286                      2.000000
#
#    gmr_retail_and_recreation_avg  gmr_workplaces_percent_avg  \
# 0                     -33.387755                   -3.505882
# 1                     -29.020000                   -4.119048
# 2                     -31.900000                   -9.711268
# 3                     -29.877551                   -2.129252
#
#    gmr_residential_percent_avg  gmr_parks_percent_avg  UF7  \
# 0                        10.82             -27.666667   11
# 1                        10.52             -25.314286   11
# 2                        12.00             -24.781250   11
# 3                        11.56             -25.114286   11
#
#   epi_week_year_7_days_early  gmr_transit_stations_1week_before_avg  \
# 0                    22-2020                             -55.187500
# 1                    23-2020                             -54.500000
# 2                    24-2020                             -53.393939
# 3                    25-2020                             -59.968750
#
#    gmr_grocery_and_pharmacy_1week_before_avg  \
# 0                                  -2.277778
# 1                                   2.830189
# 2                                   9.166667
# 3                                   6.259259
#
#    gmr_retail_and_recreation_1week_before_avg  \
# 0                                  -35.673469
# 1                                  -33.387755
# 2                                  -29.020000
# 3                                  -31.900000
#
#    gmr_workplaces_percent_1week_before_avg  \
# 0                                -5.617978
# 1                                -3.505882
# 2                                -4.119048
# 3                                -9.711268
#
#    gmr_residential_percent_1week_before_avg  \
# 0                                 10.469388
# 1                                 10.820000
# 2                                 10.520000
# 3                                 12.000000
#
#    gmr_parks_percent_1week_before_avg
# 0                          -30.558824
# 1                          -27.666667
# 2                          -25.314286
# 3                          -24.781250

# %%
# joining all for 2 weeks early
gmr14 = gmr14.withColumnRenamed('UF', 'UF14')
cond = [gmr1.UF == gmr14.UF14, gmr1.epi_week_year == gmr14.epi_week_year_14_early]
gmr_agg = gmr_agg.join(gmr14, cond, 'left')

gmr_agg.filter((F.col('UF')=='11') &  ((F.col('epi_week_year') == '22-2020') | (F.col('epi_week_year') == '23-2020') | (F.col('epi_week_year') == '24-2020') | (F.col('epi_week_year') == '25-2020')))\
    .orderBy('epi_week_year').limit(5).toPandas()
# Out:
#    UF epi_week_year  gmr_transit_stations_avg  gmr_grocery_and_pharmacy_avg  \
# 0  11       22-2020                -54.500000                      2.830189
# 1  11       23-2020                -53.393939                      9.166667
# 2  11       24-2020                -59.968750                      6.259259
# 3  11       25-2020                -57.714286                      2.000000
#
#    gmr_retail_and_recreation_avg  gmr_workplaces_percent_avg  \
# 0                     -33.387755                   -3.505882
# 1                     -29.020000                   -4.119048
# 2                     -31.900000                   -9.711268
# 3                     -29.877551                   -2.129252
#
#    gmr_residential_percent_avg  gmr_parks_percent_avg  UF7  \
# 0                        10.82             -27.666667   11
# 1                        10.52             -25.314286   11
# 2                        12.00             -24.781250   11
# 3                        11.56             -25.114286   11
#
#   epi_week_year_7_days_early  gmr_transit_stations_1week_before_avg  \
# 0                    22-2020                             -55.187500
# 1                    23-2020                             -54.500000
# 2                    24-2020                             -53.393939
# 3                    25-2020                             -59.968750
#
#    gmr_grocery_and_pharmacy_1week_before_avg  \
# 0                                  -2.277778
# 1                                   2.830189
# 2                                   9.166667
# 3                                   6.259259
#
#    gmr_retail_and_recreation_1week_before_avg  \
# 0                                  -35.673469
# 1                                  -33.387755
# 2                                  -29.020000
# 3                                  -31.900000
#
#    gmr_workplaces_percent_1week_before_avg  \
# 0                                -5.617978
# 1                                -3.505882
# 2                                -4.119048
# 3                                -9.711268
#
#    gmr_residential_percent_1week_before_avg  \
# 0                                 10.469388
# 1                                 10.820000
# 2                                 10.520000
# 3                                 12.000000
#
#    gmr_parks_percent_1week_before_avg  UF14 epi_week_year_14_early  \
# 0                          -30.558824    11                22-2020
# 1                          -27.666667    11                23-2020
# 2                          -25.314286    11                24-2020
# 3                          -24.781250    11                25-2020
#
#    gmr_transit_stations_2weeks_avg  gmr_grocery_and_pharmacy_2weeks_avg  \
# 0                       -53.937500                            -1.611111
# 1                       -55.187500                            -2.277778
# 2                       -54.500000                             2.830189
# 3                       -53.393939                             9.166667
#
#    gmr_retail_and_recreation_2weeks_avg  gmr_workplaces_percent_2weeks_avg  \
# 0                            -35.693878                          -6.586207
# 1                            -35.673469                          -5.617978
# 2                            -33.387755                          -3.505882
# 3                            -29.020000                          -4.119048
#
#    gmr_residential_percent_2weeks_avg  gmr_parks_percent_2weeks_avg
# 0                           10.000000                    -30.575758
# 1                           10.469388                    -30.558824
# 2                           10.820000                    -27.666667
# 3                           10.520000                    -25.314286

# %%
# casting to string
gmr_agg = gmr_agg.withColumn('UF', F.col('UF').cast('string'))

# %%
# selecting variables of interest
gmr_agg = gmr_agg.select(['UF', 'epi_week_year',
                          'gmr_transit_stations_avg', 'gmr_grocery_and_pharmacy_avg', 'gmr_retail_and_recreation_avg', 'gmr_workplaces_percent_avg', 'gmr_residential_percent_avg', 'gmr_parks_percent_avg',
                          'gmr_transit_stations_1week_before_avg', 'gmr_grocery_and_pharmacy_1week_before_avg', 'gmr_retail_and_recreation_1week_before_avg', 'gmr_workplaces_percent_1week_before_avg', 'gmr_residential_percent_1week_before_avg', 'gmr_parks_percent_1week_before_avg',
                          'gmr_transit_stations_2weeks_avg', 'gmr_grocery_and_pharmacy_2weeks_avg', 'gmr_retail_and_recreation_2weeks_avg', 'gmr_workplaces_percent_2weeks_avg', 'gmr_residential_percent_2weeks_avg', 'gmr_parks_percent_2weeks_avg'])

# %%
# padding 'epi_week_year' col
gmr_agg = gmr_agg.withColumn('epi_week_year', F.lpad(F.col('epi_week_year'), 7, '0'))

# %%
gmr_agg.limit(10).toPandas()
# Out:
#    UF epi_week_year  gmr_transit_stations_avg  gmr_grocery_and_pharmacy_avg  \
# 0  14       30-2020                -44.142857                      7.000000
# 1  15       20-2021                 -6.530612                     55.402439
# 2  15       37-2020                -11.450000                     27.414634
# 3  17       23-2020                -57.000000                      9.571429
# 4  26       07-2020                 -8.526316                     -0.925926
# 5  29       38-2020                -41.812500                     13.540284
# 6  29       08-2021                -28.341969                      7.644860
# 7  32       08-2020                 -0.109756                      3.117647
# 8  41       48-2020                -20.229358                     13.529412
# 9  42       31-2020                -55.453061                    -12.080429
#
#    gmr_retail_and_recreation_avg  gmr_workplaces_percent_avg  \
# 0                     -32.285714                    2.538462
# 1                      11.496241                   16.412844
# 2                       7.296875                    2.766304
# 3                     -25.272727                   -6.549020
# 4                      -0.545455                    6.139535
# 5                     -23.806228                   -0.854545
# 6                     -34.619718                   -9.177298
# 7                      -4.833333                   18.933962
# 8                      -9.408740                    7.981399
# 9                     -34.752604                   -7.491713
#
#    gmr_residential_percent_avg  gmr_parks_percent_avg  \
# 0                    12.285714             -45.714286
# 1                     6.491429               3.163265
# 2                     7.508772              17.457627
# 3                    13.096774             -46.000000
# 4                    -0.038462             -10.272727
# 5                    10.245370             -34.438395
# 6                     7.898876             -48.387755
# 7                    -0.893805             -11.224000
# 8                     4.530120             -32.946429
# 9                    11.841176             -54.762376
#
#    gmr_transit_stations_1week_before_avg  \
# 0                             -42.857143
# 1                               1.166667
# 2                              -2.285714
# 3                             -64.034483
# 4                                    NaN
# 5                             -44.825581
# 6                             -25.602151
# 7                              -8.750000
# 8                             -18.538462
# 9                             -52.137652
#
#    gmr_grocery_and_pharmacy_1week_before_avg  \
# 0                                   5.571429
# 1                                  57.160494
# 2                                  23.933333
# 3                                  -2.628571
# 4                                        NaN
# 5                                  13.649485
# 6                                   4.910377
# 7                                   0.214286
# 8                                  13.388740
# 9                                 -12.149733
#
#    gmr_retail_and_recreation_1week_before_avg  \
# 0                                  -38.142857
# 1                                   11.992424
# 2                                    0.382353
# 3                                  -35.696970
# 4                                         NaN
# 5                                  -27.350365
# 6                                  -27.978799
# 7                                   -5.000000
# 8                                   -9.782946
# 9                                  -34.707572
#
#    gmr_workplaces_percent_1week_before_avg  \
# 0                                -1.692308
# 1                                12.783784
# 2                                -0.185714
# 3                               -11.320755
# 4                                      NaN
# 5                                -6.192593
# 6                               -11.994371
# 7                                 7.166667
# 8                                 8.685284
# 9                                -7.229075
#
#    gmr_residential_percent_1week_before_avg  \
# 0                                 12.714286
# 1                                  6.104651
# 2                                  7.000000
# 3                                 14.566667
# 4                                       NaN
# 5                                  9.843602
# 6                                  6.462604
# 7                                  0.636364
# 8                                  4.791165
# 9                                 11.390029
#
#    gmr_parks_percent_1week_before_avg  gmr_transit_stations_2weeks_avg  \
# 0                          -49.571429                       -42.714286
# 1                           -4.817568                        -0.191919
# 2                           22.444444                       -14.428571
# 3                          -53.666667                       -69.241379
# 4                                 NaN                              NaN
# 5                          -35.166667                       -47.950000
# 6                          -35.345646                       -21.706186
# 7                          -17.952381                              NaN
# 8                          -34.879859                       -16.993846
# 9                          -50.454839                       -49.948617
#
#    gmr_grocery_and_pharmacy_2weeks_avg  gmr_retail_and_recreation_2weeks_avg  \
# 0                            14.285714                            -34.857143
# 1                            67.111111                             17.881890
# 2                            12.666667                             -8.058824
# 3                           -10.428571                            -42.818182
# 4                                  NaN                                   NaN
# 5                            15.066667                            -31.105263
# 6                            10.200935                            -22.259786
# 7                                  NaN                                   NaN
# 8                            14.275401                             -6.875325
# 9                           -11.029333                            -31.389034
#
#    gmr_workplaces_percent_2weeks_avg  gmr_residential_percent_2weeks_avg  \
# 0                          -5.384615                           12.714286
# 1                          13.604072                            5.468208
# 2                          -0.857143                            8.559322
# 3                         -21.315789                           16.133333
# 4                                NaN                                 NaN
# 5                          -9.398438                            9.708333
# 6                          -5.385269                            4.810440
# 7                                NaN                                 NaN
# 8                           9.244681                            4.248000
# 9                          -5.820994                           11.008798
#
#    gmr_parks_percent_2weeks_avg
# 0                    -50.142857
# 1                     -3.153846
# 2                      7.181818
# 3                    -54.235294
# 4                           NaN
# 5                    -55.911765
# 6                    -37.036649
# 7                           NaN
# 8                    -32.176895
# 9                    -52.990164

# %% [markdown]
# ### Joining mobility data for srags

# %% [markdown]
# #### 2019

# %%
print("How much distincts before? ", srag_2019.select('NU_NOTIFIC').distinct().count())
print("How much distincts epi_weeks before? ", srag_2019.select('epi_week_year').distinct().count())
# Out:
# How much distincts before?  48554
# How much distincts epi_weeks before?  53

# %%
srag_2019 = srag_2019.join(gmr_agg, ['UF', 'epi_week_year'], 'left')

# %%
print("How much distincts after? ", srag_2019.select('NU_NOTIFIC').distinct().count())
print("How much distincts epi_weeks after? ", srag_2019.select('epi_week_year').distinct().count())
# Out:
# How much distincts after?  48554
# How much distincts epi_weeks after?  53

# %% [markdown]
# #### 2020

# %%
print("How much distincts before? ", srag_2020.select('NU_NOTIFIC').distinct().count())
print("How much distincts epi_weeks before? ", srag_2020.select('epi_week_year').distinct().count())
# Out:
# How much distincts before?  1193735
# How much distincts epi_weeks before?  53

# %%
srag_2020 = srag_2020.join(gmr_agg, ['UF', 'epi_week_year'], 'left')

# %%
print("How much distincts after? ", srag_2020.select('NU_NOTIFIC').distinct().count())
print("How much distincts epi_weeks after? ", srag_2020.select('epi_week_year').distinct().count())
# Out:
# How much distincts after?  1193735
# How much distincts epi_weeks after?  53

# %% [markdown]
# #### 2021

# %%
print("How much distincts before? ", srag_2021.select('NU_NOTIFIC').distinct().count())
print("How much distincts epi_weeks before? ", srag_2021.select('epi_week_year').distinct().count())
# Out:
# How much distincts before?  868367
# How much distincts epi_weeks before?  21

# %%
srag_2021 = srag_2021.join(gmr_agg, ['UF', 'epi_week_year'], 'left')

# %%
print("How much distincts after? ", srag_2021.select('NU_NOTIFIC').distinct().count())
print("How much distincts epi_weeks after? ", srag_2021.select('epi_week_year').distinct().count())
# Out:
# How much distincts after?  868367
# How much distincts epi_weeks after?  21

# %% [markdown]
# # Meteorological data with state codes by epi_weeks

# %%
inmet.limit(5).toPandas()
# Out:
#   station_id measurement_date  total_daily_precipitation_mm  \
# 0       A601       2020-03-13                           0.0
# 1       A601       2020-03-14                           0.0
# 2       A601       2020-03-15                           0.0
# 3       A601       2020-03-16                           0.0
# 4       A601       2020-03-17                           0.0
#
#    daily_atmospheric_pression_mb  daily_avg_dew_point_temp_c  \
# 0                     1011.91250                   20.683332
# 1                     1012.37085                   21.800000
# 2                     1010.29584                   21.245832
# 3                     1008.62085                   20.470833
# 4                     1009.97080                   21.750000
#
#    max_daily_temp_maxima_diaria_c  daily_avg_temp_c  daily_min_temp_c  \
# 0                            32.7         25.975000              21.2
# 1                            32.9         26.379168              22.3
# 2                            35.0         27.829166              22.5
# 3                            34.3         28.270832              24.4
# 4                            31.6         25.987500              23.1
#
#    daily_avg_relative_air_humidity_percent  \
# 0                                74.416664
# 1                                77.416664
# 2                                70.416664
# 3                                63.750000
# 4                                78.041664
#
#    daily_min_relative_air_humidity_percent  max_gust_wind_ms  \
# 0                                     46.0              10.5
# 1                                     47.0               8.5
# 2                                     37.0               9.8
# 3                                     42.0              10.8
# 4                                     54.0              10.5
#
#    avg_wind_velocity_ms empty    municipality_name    sub_region_1
# 0              1.862500  None  SEROPEDICA-ECOLOGIA  RIO DE JANEIRO
# 1              1.141667  None  SEROPEDICA-ECOLOGIA  RIO DE JANEIRO
# 2              1.933333  None  SEROPEDICA-ECOLOGIA  RIO DE JANEIRO
# 3              2.379167  None  SEROPEDICA-ECOLOGIA  RIO DE JANEIRO
# 4              1.795833  None  SEROPEDICA-ECOLOGIA  RIO DE JANEIRO

# %%
inmet = inmet.join(ibge.select('UF', 'sub_region_1'), 'sub_region_1', 'left')
inmet = inmet.withColumn('UF', F.col('UF').cast('string'))

# %%
inmet = inmet.na.drop(subset=['sub_region_1', 'UF'])

# %%
inmet = inmet.withColumnRenamed('measurement_date', 'date')

# %%
# joining using the actual date
epi_weeks_actual = epi_weeks.select(['date', 'epi_week', 'epi_year', 'epi_week_year'])
inmet = inmet.join(epi_weeks_actual, 'date', 'left')

# %%
# joining using date from 7 days before
epi_weeks_7 = epi_weeks.select(['date_7_days_early', 'epi_week_7_days_early', 'epi_week_year_7_days_early'])
inmet = inmet.join(epi_weeks_7, F.date_add(inmet.date, 7) == epi_weeks.date_7_days_early, 'left')

# %%
# joining using date from 14 days before
epi_weeks_14 = epi_weeks.select(['date_14_days_early', 'epi_week_14_days_early', 'epi_week_year_14_early'])
inmet = inmet.join(epi_weeks_14, F.date_add(inmet.date, 14) == epi_weeks.date_14_days_early, 'left')

# %%
inmet1 = inmet.groupBy(['UF', 'epi_week_year']).agg({"total_daily_precipitation_mm":"avg",
                                          "daily_avg_temp_c":"avg",
                                          "daily_avg_relative_air_humidity_percent":"avg"})\
                                    .withColumnRenamed('avg(total_daily_precipitation_mm)', 'inmet_daily_precipt_avg')\
                                    .withColumnRenamed('avg(daily_avg_temp_c)', 'inmet_temp_c_avg')\
                                    .withColumnRenamed('avg(daily_avg_relative_air_humidity_percent)', 'inmet_relative_air_humidity_avg')\
                                    .orderBy('UF')

# %%
inmet7 = inmet.groupBy(['UF', 'epi_week_year_7_days_early']).agg({"total_daily_precipitation_mm":"avg",
                                          "daily_avg_temp_c":"avg",
                                          "daily_avg_relative_air_humidity_percent":"avg"})\
                                    .withColumnRenamed('avg(total_daily_precipitation_mm)', 'inmet_daily_precipt_1week_before_avg')\
                                    .withColumnRenamed('avg(daily_avg_temp_c)', 'inmet_temp_c_1week_before_avg')\
                                    .withColumnRenamed('avg(daily_avg_relative_air_humidity_percent)', 'inmet_relative_air_humidity_1week_before_avg')\
                                    .orderBy('UF')

# %%
inmet14 = inmet.groupBy(['UF', 'epi_week_year_14_early']).agg({"total_daily_precipitation_mm":"avg",
                                          "daily_avg_temp_c":"avg",
                                          "daily_avg_relative_air_humidity_percent":"avg"})\
                                    .withColumnRenamed('avg(total_daily_precipitation_mm)', 'inmet_daily_precipt_2weeks_before_avg')\
                                    .withColumnRenamed('avg(daily_avg_temp_c)', 'inmet_temp_c_2weeks_before_avg')\
                                    .withColumnRenamed('avg(daily_avg_relative_air_humidity_percent)', 'inmet_relative_air_humidity_2weeks_before_avg')\
                                    .orderBy('UF')

# %% [markdown]
# ##### some validations

# %%
inmet1.filter((F.col('UF')=='11') &  ((F.col('epi_week_year') == '22-2020') | (F.col('epi_week_year') == '23-2020') | (F.col('epi_week_year') == '24-2020') | (F.col('epi_week_year') == '25-2020')))\
    .orderBy('epi_week_year').limit(5).toPandas()
# Out:
#    UF epi_week_year  inmet_temp_c_avg  inmet_relative_air_humidity_avg  \
# 0  11       22-2020         21.964815                        70.026316
# 1  11       23-2020         24.943452                        73.357142
# 2  11       24-2020         25.924702                        70.943453
# 3  11       25-2020         24.491667                        71.193453
#
#    inmet_daily_precipt_avg
# 0                 0.100000
# 1                 0.157143
# 2                 0.157143
# 3                 1.257143

# %%
inmet7.filter((F.col('UF')=='11') &  ((F.col('epi_week_year_7_days_early') == '22-2020') | (F.col('epi_week_year_7_days_early') == '23-2020') | (F.col('epi_week_year_7_days_early') == '24-2020') | (F.col('epi_week_year_7_days_early') == '25-2020')))\
    .orderBy('epi_week_year_7_days_early').limit(5).toPandas()
# Out:
#    UF epi_week_year_7_days_early  inmet_temp_c_1week_before_avg  \
# 0  11                    22-2020                      25.405357
# 1  11                    23-2020                      21.964815
# 2  11                    24-2020                      24.943452
# 3  11                    25-2020                      25.924702
#
#    inmet_relative_air_humidity_1week_before_avg  \
# 0                                     77.420634
# 1                                     70.026316
# 2                                     73.357142
# 3                                     70.943453
#
#    inmet_daily_precipt_1week_before_avg
# 0                              0.571429
# 1                              0.100000
# 2                              0.157143
# 3                              0.157143

# %%
inmet14.filter((F.col('UF')=='11') &  ((F.col('epi_week_year_14_early') == '22-2020') | (F.col('epi_week_year_14_early') == '23-2020') | (F.col('epi_week_year_14_early') == '24-2020') | (F.col('epi_week_year_14_early') == '25-2020')))\
    .orderBy('epi_week_year_14_early').limit(5).toPandas()
# Out:
#    UF epi_week_year_14_early  inmet_temp_c_2weeks_before_avg  \
# 0  11                22-2020                       25.143981
# 1  11                23-2020                       25.405357
# 2  11                24-2020                       21.964815
# 3  11                25-2020                       24.943452
#
#    inmet_relative_air_humidity_2weeks_before_avg  \
# 0                                      80.949696
# 1                                      77.420634
# 2                                      70.026316
# 3                                      73.357142
#
#    inmet_daily_precipt_2weeks_before_avg
# 0                               6.033333
# 1                               0.571429
# 2                               0.100000
# 3                               0.157143

# %% [markdown]
# <hr />

# %%
# joining all for 1 week early
inmet7 = inmet7.withColumnRenamed('UF', 'UF7')
cond = [inmet1.UF == inmet7.UF7, inmet1.epi_week_year == inmet7.epi_week_year_7_days_early]
inmet_agg = inmet1.join(inmet7, cond, 'left')

inmet_agg.filter((F.col('UF')=='11') &  ((F.col('epi_week_year') == '22-2020') | (F.col('epi_week_year') == '23-2020') | (F.col('epi_week_year') == '24-2020') | (F.col('epi_week_year') == '25-2020')))\
    .orderBy('epi_week_year').limit(5).toPandas()
# Out:
#    UF epi_week_year  inmet_temp_c_avg  inmet_relative_air_humidity_avg  \
# 0  11       22-2020         21.964815                        70.026316
# 1  11       23-2020         24.943452                        73.357142
# 2  11       24-2020         25.924702                        70.943453
# 3  11       25-2020         24.491667                        71.193453
#
#    inmet_daily_precipt_avg UF7 epi_week_year_7_days_early  \
# 0                 0.100000  11                    22-2020
# 1                 0.157143  11                    23-2020
# 2                 0.157143  11                    24-2020
# 3                 1.257143  11                    25-2020
#
#    inmet_temp_c_1week_before_avg  \
# 0                      25.405357
# 1                      21.964815
# 2                      24.943452
# 3                      25.924702
#
#    inmet_relative_air_humidity_1week_before_avg  \
# 0                                     77.420634
# 1                                     70.026316
# 2                                     73.357142
# 3                                     70.943453
#
#    inmet_daily_precipt_1week_before_avg
# 0                              0.571429
# 1                              0.100000
# 2                              0.157143
# 3                              0.157143

# %%
# joining all for 2 weeks early
inmet14 = inmet14.withColumnRenamed('UF', 'UF14')
cond = [inmet1.UF == inmet14.UF14, inmet1.epi_week_year == inmet14.epi_week_year_14_early]
inmet_agg = inmet_agg.join(inmet14, cond, 'left')

inmet_agg.filter((F.col('UF')=='11') &  ((F.col('epi_week_year') == '22-2020') | (F.col('epi_week_year') == '23-2020') | (F.col('epi_week_year') == '24-2020') | (F.col('epi_week_year') == '25-2020')))\
    .orderBy('epi_week_year').limit(5).toPandas()
# Out:
#    UF epi_week_year  inmet_temp_c_avg  inmet_relative_air_humidity_avg  \
# 0  11       22-2020         21.964815                        70.026316
# 1  11       23-2020         24.943452                        73.357142
# 2  11       24-2020         25.924702                        70.943453
# 3  11       25-2020         24.491667                        71.193453
#
#    inmet_daily_precipt_avg UF7 epi_week_year_7_days_early  \
# 0                 0.100000  11                    22-2020
# 1                 0.157143  11                    23-2020
# 2                 0.157143  11                    24-2020
# 3                 1.257143  11                    25-2020
#
#    inmet_temp_c_1week_before_avg  \
# 0                      25.405357
# 1                      21.964815
# 2                      24.943452
# 3                      25.924702
#
#    inmet_relative_air_humidity_1week_before_avg  \
# 0                                     77.420634
# 1                                     70.026316
# 2                                     73.357142
# 3                                     70.943453
#
#    inmet_daily_precipt_1week_before_avg UF14 epi_week_year_14_early  \
# 0                              0.571429   11                22-2020
# 1                              0.100000   11                23-2020
# 2                              0.157143   11                24-2020
# 3                              0.157143   11                25-2020
#
#    inmet_temp_c_2weeks_before_avg  \
# 0                       25.143981
# 1                       25.405357
# 2                       21.964815
# 3                       24.943452
#
#    inmet_relative_air_humidity_2weeks_before_avg  \
# 0                                      80.949696
# 1                                      77.420634
# 2                                      70.026316
# 3                                      73.357142
#
#    inmet_daily_precipt_2weeks_before_avg
# 0                               6.033333
# 1                               0.571429
# 2                               0.100000
# 3                               0.157143

# %% [markdown]
# <hr />

# %%
# selecting variables of interest
inmet_agg = inmet_agg.select(['UF', 'epi_week_year',
                          'inmet_temp_c_avg', 'inmet_relative_air_humidity_avg', 'inmet_daily_precipt_avg',
                          'inmet_temp_c_1week_before_avg', 'inmet_relative_air_humidity_1week_before_avg', 'inmet_daily_precipt_1week_before_avg',
                          'inmet_temp_c_2weeks_before_avg', 'inmet_relative_air_humidity_2weeks_before_avg', 'inmet_daily_precipt_2weeks_before_avg'])

# %%
# padding 'epi_week_year' col
inmet_agg = inmet_agg.withColumn('epi_week_year', F.lpad(F.col('epi_week_year'), 7, '0'))

# %% [markdown]
# <hr />

# %% [markdown]
# ### Joining meteorological data for srags

# %% [markdown]
# #### 2019

# %%
print("How much distincts before? ", srag_2019.select('NU_NOTIFIC').distinct().count())
print("How much distincts epi_weeks before? ", srag_2019.select('epi_week_year').distinct().count())
# Out:
# How much distincts before?  48554
# How much distincts epi_weeks before?  53

# %%
srag_2019 = srag_2019.join(inmet_agg, ['UF', 'epi_week_year'], 'left')

# %%
print("How much distincts after? ", srag_2019.select('NU_NOTIFIC').distinct().count())
print("How much distincts epi_weeks after? ", srag_2019.select('epi_week_year').distinct().count())
# Out:
# How much distincts after?  48554
# How much distincts epi_weeks after?  53

# %% [markdown]
# #### 2020

# %%
print("How much distincts before? ", srag_2020.select('NU_NOTIFIC').distinct().count())
print("How much distincts epi_weeks before? ", srag_2020.select('epi_week_year').distinct().count())
# Out:
# How much distincts before?  1193735
# How much distincts epi_weeks before?  53

# %%
srag_2020 = srag_2020.join(inmet_agg, ['UF', 'epi_week_year'], 'left')

# %%
print("How much distincts after? ", srag_2020.select('NU_NOTIFIC').distinct().count())
print("How much distincts epi_weeks after? ", srag_2020.select('epi_week_year').distinct().count())
# Out:
# How much distincts after?  1193735
# How much distincts epi_weeks after?  53

# %% [markdown]
# #### 2021

# %%
print("How much distincts before? ", srag_2021.select('NU_NOTIFIC').distinct().count())
print("How much distincts epi_weeks before? ", srag_2021.select('epi_week_year').distinct().count())
# Out:
# How much distincts before?  868367
# How much distincts epi_weeks before?  21

# %%
srag_2021 = srag_2021.join(inmet_agg, ['UF', 'epi_week_year'], 'left')

# %%
print("How much distincts after? ", srag_2021.select('NU_NOTIFIC').distinct().count())
print("How much distincts epi_weeks after? ", srag_2021.select('epi_week_year').distinct().count())
# Out:
# How much distincts after?  868367
# How much distincts epi_weeks after?  21

# %% [markdown]
# <hr />

# %% [markdown]
# #### writing the last temporary version of srags

# %%
srag_2019.write.parquet('gs://ai-covid19-datalake/standard/srag/pp_interm_srag_2019_v4_super-srag/', mode='overwrite')

# %%
srag_2020.write.parquet('gs://ai-covid19-datalake/standard/srag/pp_interm_srag_2020_v4_super-srag', mode='overwrite')

# %%
srag_2021.write.parquet('gs://ai-covid19-datalake/standard/srag/pp_interm_srag_2021_v4_super-srag', mode='overwrite')

# %% [markdown]
# <hr />

# %%
# # reading temporary files
# srag_2019 = spark.read.parquet('gs://ai-covid19-datalake/standard/srag/pp_interm_srag_2019_v4_super-srag/')
# srag_2020 = spark.read.parquet('gs://ai-covid19-datalake/standard/srag/pp_interm_srag_2020_v4_super-srag')
# srag_2021 = spark.read.parquet('gs://ai-covid19-datalake/standard/srag/pp_interm_srag_2021_v4_super-srag')

# %%
srag_2019 = srag_2019.withColumn('AGE_GROUP', F.when(F.col('AGE_AT_NOTIF') < 1, 1)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 1) & (F.col('AGE_AT_NOTIF') <= 5), 2)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 6) & (F.col('AGE_AT_NOTIF') <= 19), 3)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 20) & (F.col('AGE_AT_NOTIF') <= 29), 4)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 30) & (F.col('AGE_AT_NOTIF') <= 39), 5)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 40) & (F.col('AGE_AT_NOTIF') <= 49), 6)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 50) & (F.col('AGE_AT_NOTIF') <= 59), 7)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 60) & (F.col('AGE_AT_NOTIF') <= 69), 8)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 70) & (F.col('AGE_AT_NOTIF') <= 79), 9)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 80) & (F.col('AGE_AT_NOTIF') <= 89), 10)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 90), 11)\
                                                    .otherwise(12))

# %%
srag_2020 = srag_2020.withColumn('AGE_GROUP', F.when(F.col('AGE_AT_NOTIF') < 1, 1)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 1) & (F.col('AGE_AT_NOTIF') <= 5), 2)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 6) & (F.col('AGE_AT_NOTIF') <= 19), 3)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 20) & (F.col('AGE_AT_NOTIF') <= 29), 4)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 30) & (F.col('AGE_AT_NOTIF') <= 39), 5)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 40) & (F.col('AGE_AT_NOTIF') <= 49), 6)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 50) & (F.col('AGE_AT_NOTIF') <= 59), 7)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 60) & (F.col('AGE_AT_NOTIF') <= 69), 8)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 70) & (F.col('AGE_AT_NOTIF') <= 79), 9)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 80) & (F.col('AGE_AT_NOTIF') <= 89), 10)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 90), 11)\
                                                    .otherwise(12))

# %%
srag_2021 = srag_2021.withColumn('AGE_GROUP', F.when(F.col('AGE_AT_NOTIF') < 1, 1)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 1) & (F.col('AGE_AT_NOTIF') <= 5), 2)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 6) & (F.col('AGE_AT_NOTIF') <= 19), 3)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 20) & (F.col('AGE_AT_NOTIF') <= 29), 4)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 30) & (F.col('AGE_AT_NOTIF') <= 39), 5)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 40) & (F.col('AGE_AT_NOTIF') <= 49), 6)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 50) & (F.col('AGE_AT_NOTIF') <= 59), 7)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 60) & (F.col('AGE_AT_NOTIF') <= 69), 8)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 70) & (F.col('AGE_AT_NOTIF') <= 79), 9)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 80) & (F.col('AGE_AT_NOTIF') <= 89), 10)\
                                                    .when((F.col('AGE_AT_NOTIF') >= 90), 11)\
                                                    .otherwise(12))

# %%
# just for check the header later
srag_2019.limit(1).toPandas()
# Out:
#    UF epi_week_year  NU_NOTIFIC  DT_NOTIFIC SEM_NOT  DT_SIN_PRI SEM_PRI  \
# 0  13       07-2019        2577  2019-02-20       8  2019-02-14       7
#
#   SG_UF_NOT                     ID_REGIONA CO_REGIONA ID_MUNICIP CO_MUN_NOT  \
# 0        AM  ENTORNO DE MANAUS E RIO NEGRO       5584     MANAUS     130260
#
#                 ID_UNIDADE CO_UNI_NOT CS_SEXO     DT_NASC  NU_IDADE_N  \
# 0  UPA 24HS JOSE RODRIGUES    9634738       F  1910-11-21         108
#
#    TP_IDADE  COD_IDADE  CS_GESTANT  CS_RACA CS_ETINIA  CS_ESCOL_N ID_PAIS  \
# 0         3       3108           5        4      None           0  BRASIL
#
#    CO_PAIS SG_UF  CO_RG_RESI ID_MN_RESI  CO_MUN_RES  CS_ZONA  SURTO_SG  \
# 0        1    AM        5584     MANAUS      130260        1         1
#
#    NOSOCOMIAL  AVE_SUINO  FEBRE  TOSSE  GARGANTA  DISPNEIA  DESC_RESP  \
# 0           2          2      1      1         2         1          1
#
#    SATURACAO  DIARREIA  VOMITO  OUTRO_SIN OUTRO_DES  PUERPERA  CARDIOPATI  \
# 0          1         2       2          2      None         2           2
#
#    HEMATOLOGI  SIND_DOWN  HEPATICA  ASMA  DIABETES  ...  DIST_PRI_NOTIFIC_q  \
# 0           2          2         2     2         2  ...                   3
#
#    DIST_PRI_INTERNA_q  DIST_PRI_ENTUTI_q  DIST_PRI_SAIDUTI_q  \
# 0                   1                  6                   6
#
#    DIST_PRI_EVOLUCA_q DIST_PRI_ENCERRA_q  DIST_PRI_RAIOX_q DIST_PRI_TOMO_q  \
# 0                   2                  3                 6               6
#
#    DIST_PRI_COLETA_q DIST_PRI_SOR_q DIST_PRI_PCR_q DIST_PRI_TRA_q  \
# 0                  6              6              6              6
#
#   DIST_PRI_IF_q SYMP_GROUP1 SYMP_GROUP2 SYMP_GROUP3  SYMP_GROUP4  RF_GROUP1  \
# 0             6           4           8           1            9          1
#
#   RF_GROUP2 RF_GROUP3  RF_GROUP4   ANO gmr_transit_stations_avg  \
# 0         1         1          1  2019                     None
#
#   gmr_grocery_and_pharmacy_avg  gmr_retail_and_recreation_avg  \
# 0                         None                           None
#
#   gmr_workplaces_percent_avg  gmr_residential_percent_avg  \
# 0                       None                         None
#
#    gmr_parks_percent_avg gmr_transit_stations_1week_before_avg  \
# 0                   None                                  None
#
#   gmr_grocery_and_pharmacy_1week_before_avg  \
# 0                                      None
#
#    gmr_retail_and_recreation_1week_before_avg  \
# 0                                        None
#
#    gmr_workplaces_percent_1week_before_avg  \
# 0                                     None
#
#   gmr_residential_percent_1week_before_avg gmr_parks_percent_1week_before_avg  \
# 0                                     None                               None
#
#    gmr_transit_stations_2weeks_avg gmr_grocery_and_pharmacy_2weeks_avg  \
# 0                             None                                None
#
#   gmr_retail_and_recreation_2weeks_avg gmr_workplaces_percent_2weeks_avg  \
# 0                                 None                              None
#
#   gmr_residential_percent_2weeks_avg gmr_parks_percent_2weeks_avg  \
# 0                               None                         None
#
#   inmet_temp_c_avg inmet_relative_air_humidity_avg inmet_daily_precipt_avg  \
# 0        26.103136                       86.341099               15.366667
#
#   inmet_temp_c_1week_before_avg inmet_relative_air_humidity_1week_before_avg  \
# 0                     26.241688                                    85.106318
#
#   inmet_daily_precipt_1week_before_avg inmet_temp_c_2weeks_before_avg  \
# 0                             7.678571                        26.6344
#
#   inmet_relative_air_humidity_2weeks_before_avg  \
# 0                                     83.187601
#
#   inmet_daily_precipt_2weeks_before_avg AGE_GROUP
# 0                              7.942169        11
#
# [1 rows x 215 columns]

# %%
# just for check the header later
srag_2020.limit(1).toPandas()
# Out:
#    UF epi_week_year   NU_NOTIFIC  DT_NOTIFIC  SEM_NOT  DT_SIN_PRI  SEM_PRI  \
# 0  13       11-2020  25769820812  2020-03-27       13  2020-03-13       11
#
#   SG_UF_NOT                     ID_REGIONA  CO_REGIONA ID_MUNICIP  CO_MUN_NOT  \
# 0        AM  ENTORNO DE MANAUS E RIO NEGRO        5584     MANAUS      130260
#
#                              ID_UNIDADE  CO_UNI_NOT CS_SEXO     DT_NASC  \
# 0  HOSPITAL PRONTO SOCORRO 28 DE AGOSTO     2013649       F  1979-02-27
#
#    NU_IDADE_N  TP_IDADE COD_IDADE  CS_GESTANT  CS_RACA CS_ETINIA CS_ESCOL_N  \
# 0          41         3      3041           5        4      None       None
#
#   ID_PAIS  CO_PAIS SG_UF            ID_RG_RESI  CO_RG_RESI ID_MN_RESI  \
# 0  BRASIL        1    AM  RIO NEGRO E SOLIMOES        5588      COARI
#
#    CO_MUN_RES  CS_ZONA  SURTO_SG  NOSOCOMIAL  AVE_SUINO  FEBRE  TOSSE  \
# 0      130120        1         1           2          2      1      1
#
#    GARGANTA  DISPNEIA  DESC_RESP  SATURACAO DIARREIA VOMITO OUTRO_SIN  \
# 0         1         2          1          2     None   None      None
#
#   OUTRO_DES  PUERPERA FATOR_RISC  CARDIOPATI  HEMATOLOGI  SIND_DOWN  HEPATICA  \
# 0      None         2          S           2           2          2         2
#
#    ...  DIST_PRI_NOTIFIC_q  DIST_PRI_INTERNA_q  DIST_PRI_ENTUTI_q  \
# 0  ...                   5                   5                  6
#
#    DIST_PRI_SAIDUTI_q  DIST_PRI_EVOLUCA_q  DIST_PRI_ENCERRA_q  \
# 0                   6                   3                   3
#
#    DIST_PRI_RAIOX_q DIST_PRI_TOMO_q  DIST_PRI_COLETA_q DIST_PRI_SOR_q  \
# 0                 5               6                  5              6
#
#    DIST_PRI_PCR_q DIST_PRI_TRA_q DIST_PRI_IF_q SYMP_GROUP1 SYMP_GROUP2  \
# 0               5              6             6           8           3
#
#   SYMP_GROUP3 SYMP_GROUP4 RF_GROUP1  RF_GROUP2 RF_GROUP3 RF_GROUP4   ANO  \
# 0           1           1         1          1         5         5  2020
#
#   gmr_transit_stations_avg gmr_grocery_and_pharmacy_avg  \
# 0                 0.363636                         1.75
#
#   gmr_retail_and_recreation_avg gmr_workplaces_percent_avg  \
# 0                     -2.172414                  19.591837
#
#    gmr_residential_percent_avg gmr_parks_percent_avg  \
# 0                    -0.588235            -15.071429
#
#    gmr_transit_stations_1week_before_avg  \
# 0                              -0.583333
#
#    gmr_grocery_and_pharmacy_1week_before_avg  \
# 0                                       8.52
#
#   gmr_retail_and_recreation_1week_before_avg  \
# 0                                    2.62069
#
#   gmr_workplaces_percent_1week_before_avg  \
# 0                                   19.94
#
#    gmr_residential_percent_1week_before_avg  \
# 0                                 -0.722222
#
#    gmr_parks_percent_1week_before_avg gmr_transit_stations_2weeks_avg  \
# 0                          -18.148148                            -9.1
#
#   gmr_grocery_and_pharmacy_2weeks_avg  gmr_retail_and_recreation_2weeks_avg  \
# 0                           -3.041667                                   3.5
#
#   gmr_workplaces_percent_2weeks_avg  gmr_residential_percent_2weeks_avg  \
# 0                         -8.810345                            3.272727
#
#   gmr_parks_percent_2weeks_avg  inmet_temp_c_avg  \
# 0                       -14.44         27.860686
#
#   inmet_relative_air_humidity_avg inmet_daily_precipt_avg  \
# 0                       78.611595                2.526531
#
#   inmet_temp_c_1week_before_avg inmet_relative_air_humidity_1week_before_avg  \
# 0                     27.182616                                    81.819703
#
#   inmet_daily_precipt_1week_before_avg inmet_temp_c_2weeks_before_avg  \
# 0                             9.604082                      26.866808
#
#   inmet_relative_air_humidity_2weeks_before_avg  \
# 0                                     82.893669
#
#   inmet_daily_precipt_2weeks_before_avg AGE_GROUP
# 0                              5.281633         6
#
# [1 rows x 227 columns]

# %%
# just for check the header later
srag_2021.limit(1).toPandas()
# Out:
#    UF epi_week_year   NU_NOTIFIC  DT_NOTIFIC  SEM_NOT  DT_SIN_PRI  SEM_PRI  \
# 0  29       01-2021  68719675035  2021-01-11        2  2021-01-05        1
#
#   SG_UF_NOT                      ID_REGIONA  CO_REGIONA ID_MUNICIP  \
# 0        BA  NUCLEO REGIONAL DE SAUDE LESTE        1380   SALVADOR
#
#    CO_MUN_NOT         ID_UNIDADE  CO_UNI_NOT CS_SEXO     DT_NASC  NU_IDADE_N  \
# 0      292740  HOSPITAL DA BAHIA     3827992       F  1952-04-19          68
#
#    TP_IDADE COD_IDADE  CS_GESTANT  CS_RACA CS_ETINIA  CS_ESCOL_N ID_PAIS  \
# 0         3      3068           5        9      None           9  BRASIL
#
#    CO_PAIS SG_UF                      ID_RG_RESI  CO_RG_RESI ID_MN_RESI  \
# 0        1    BA  NUCLEO REGIONAL DE SAUDE LESTE        1380   SALVADOR
#
#    CO_MUN_RES  CS_ZONA  SURTO_SG  NOSOCOMIAL  AVE_SUINO  FEBRE  TOSSE  \
# 0      292740        1         2           2          9      2      2
#
#    GARGANTA  DISPNEIA  DESC_RESP  SATURACAO  DIARREIA  VOMITO  OUTRO_SIN  \
# 0         2         2          2          2         2       1          1
#
#          OUTRO_DES  PUERPERA FATOR_RISC  CARDIOPATI  HEMATOLOGI  SIND_DOWN  \
# 0  CONFUSAO MENTAL         2          S           1           2          2
#
#    HEPATICA  ...  DIST_PRI_NOTIFIC_q  DIST_PRI_INTERNA_q  DIST_PRI_ENTUTI_q  \
# 0         2  ...                   3                   2                  2
#
#    DIST_PRI_SAIDUTI_q  DIST_PRI_EVOLUCA_q  DIST_PRI_ENCERRA_q  \
# 0                   3                   4                   1
#
#    DIST_PRI_RAIOX_q DIST_PRI_TOMO_q  DIST_PRI_COLETA_q DIST_PRI_SOR_q  \
# 0                 6               6                  3              6
#
#    DIST_PRI_PCR_q DIST_PRI_TRA_q DIST_PRI_IF_q SYMP_GROUP1 SYMP_GROUP2  \
# 0               3              6             6           1           1
#
#   SYMP_GROUP3 SYMP_GROUP4 RF_GROUP1  RF_GROUP2 RF_GROUP3 RF_GROUP4   ANO  \
# 0           3           1         9          9         9         9  2021
#
#    gmr_transit_stations_avg gmr_grocery_and_pharmacy_avg  \
# 0                 -5.063218                    25.785714
#
#   gmr_retail_and_recreation_avg gmr_workplaces_percent_avg  \
# 0                     -16.11828                   0.560534
#
#    gmr_residential_percent_avg gmr_parks_percent_avg  \
# 0                     7.260989            -11.461095
#
#    gmr_transit_stations_1week_before_avg  \
# 0                             -13.384615
#
#    gmr_grocery_and_pharmacy_1week_before_avg  \
# 0                                  26.571429
#
#   gmr_retail_and_recreation_1week_before_avg  \
# 0                                 -19.401434
#
#   gmr_workplaces_percent_1week_before_avg  \
# 0                              -12.686145
#
#    gmr_residential_percent_1week_before_avg  \
# 0                                  7.114846
#
#    gmr_parks_percent_1week_before_avg gmr_transit_stations_2weeks_avg  \
# 0                             3.63141                      -14.966667
#
#   gmr_grocery_and_pharmacy_2weeks_avg  gmr_retail_and_recreation_2weeks_avg  \
# 0                           30.004695                            -16.609155
#
#   gmr_workplaces_percent_2weeks_avg  gmr_residential_percent_2weeks_avg  \
# 0                         -7.159544                            6.598886
#
#   gmr_parks_percent_2weeks_avg  inmet_temp_c_avg  \
# 0                   -16.958824         26.274545
#
#   inmet_relative_air_humidity_avg inmet_daily_precipt_avg  \
# 0                       62.914755                0.502703
#
#   inmet_temp_c_1week_before_avg inmet_relative_air_humidity_1week_before_avg  \
# 0                     25.558466                                    62.840933
#
#   inmet_daily_precipt_1week_before_avg inmet_temp_c_2weeks_before_avg  \
# 0                             0.676667                      25.456032
#
#   inmet_relative_air_humidity_2weeks_before_avg  \
# 0                                     68.208723
#
#   inmet_daily_precipt_2weeks_before_avg AGE_GROUP
# 0                              1.274419         8
#
# [1 rows x 226 columns]

# %% [markdown]
# # The SUPER SRAG at last

# %%
super_srag_cols = ['NU_NOTIFIC', 'CS_SEXO', 'DT_NASC', 'AGE_AT_NOTIF', 'AGE_GROUP', 'CS_GESTANT', 'CS_RACA', 'CS_ETINIA', 'CS_ESCOL_N', 'SG_UF', 'CO_MUN_RES',
                   'SEM_PRI', 'SEM_NOT', 'DIST_PRI_NOTIFIC', 'DT_SIN_PRI', 'SG_UF_NOT', 'CO_MUN_NOT', 'SURTO_SG', 'NOSOCOMIAL', 'AVE_SUINO', 'VACINA', 'HOSPITAL', 'DIST_PRI_INTERNA', 'SUPORT_VEN', 'UTI', 'DIST_PRI_ENTUTI', 'CLASSI_OUT', 'CRITERIO', 'EVOLUCAO', 'CLASSI_FIN',
                   'SYMP_GROUP1', 'SYMP_GROUP2', 'SYMP_GROUP3', 'SYMP_GROUP4', 'OUTRO_SIN', 'OUTRO_DES',
                   'RF_GROUP1', 'RF_GROUP2', 'RF_GROUP3', 'RF_GROUP4', 'OBES_IMC', 'OUT_MORBI', 'MORB_DESC',
                   'RAIOX_RES', 'DIST_PRI_RAIOX', 'TOMO_RES', 'DIST_PRI_TOMO', 'AMOSTRA', 'TP_AMOSTRA', 'DT_COLETA', 'DIST_PRI_COLETA', 'PP_IF_RESUL', 'PP_TRA_RESUL', 'DIST_PRI_TRA', 'PP_PCR_RESUL', 'DIST_PRI_PCR', 'PP_RES_SOR_IGA', 'PP_RES_SOR_IGM', 'PP_RES_SOR_IGG', 'DIST_PRI_SOR', 'DIST_PRI_IF',
                   'DIST_PRI_NOTIFIC_q', 'DIST_PRI_INTERNA_q', 'DIST_PRI_ENTUTI_q', 'DIST_PRI_SAIDUTI_q', 'DIST_PRI_EVOLUCA_q', 'DIST_PRI_ENCERRA_q', 'DIST_PRI_RAIOX_q', 'DIST_PRI_TOMO_q', 'DIST_PRI_COLETA_q', 'DIST_PRI_SOR_q', 'DIST_PRI_PCR_q', 'DIST_PRI_TRA_q', 'DIST_PRI_IF_q',
                   'epi_week_year', 'gmr_transit_stations_avg', 'gmr_grocery_and_pharmacy_avg', 'gmr_retail_and_recreation_avg', 'gmr_workplaces_percent_avg', 'gmr_residential_percent_avg', 'gmr_parks_percent_avg',
                   'gmr_transit_stations_1week_before_avg', 'gmr_grocery_and_pharmacy_1week_before_avg', 'gmr_retail_and_recreation_1week_before_avg', 'gmr_workplaces_percent_1week_before_avg', 'gmr_residential_percent_1week_before_avg',
                   'gmr_parks_percent_1week_before_avg', 'gmr_transit_stations_2weeks_avg', 'gmr_grocery_and_pharmacy_2weeks_avg', 'gmr_retail_and_recreation_2weeks_avg', 'gmr_workplaces_percent_2weeks_avg',
                   'gmr_residential_percent_2weeks_avg', 'gmr_parks_percent_2weeks_avg',
                   'inmet_temp_c_avg', 'inmet_relative_air_humidity_avg', 'inmet_daily_precipt_avg', 'inmet_temp_c_1week_before_avg', 'inmet_relative_air_humidity_1week_before_avg', 
                   'inmet_daily_precipt_1week_before_avg', 'inmet_temp_c_2weeks_before_avg', 'inmet_relative_air_humidity_2weeks_before_avg', 'inmet_daily_precipt_2weeks_before_avg']

# %%
srag_2019.printSchema()
# Out:
# root
#  |-- UF: string (nullable = true)
#  |-- epi_week_year: string (nullable = true)
#  |-- NU_NOTIFIC: long (nullable = true)
#  |-- DT_NOTIFIC: date (nullable = true)
#  |-- SEM_NOT: string (nullable = true)
#  |-- DT_SIN_PRI: date (nullable = true)
#  |-- SEM_PRI: string (nullable = true)
#  |-- SG_UF_NOT: string (nullable = true)
#  |-- ID_REGIONA: string (nullable = true)
#  |-- CO_REGIONA: string (nullable = true)
#  |-- ID_MUNICIP: string (nullable = true)
#  |-- CO_MUN_NOT: string (nullable = true)
#  |-- ID_UNIDADE: string (nullable = true)
#  |-- CO_UNI_NOT: string (nullable = true)
#  |-- CS_SEXO: string (nullable = true)
#  |-- DT_NASC: date (nullable = true)
#  |-- NU_IDADE_N: integer (nullable = true)
#  |-- TP_IDADE: integer (nullable = true)
#  |-- COD_IDADE: integer (nullable = true)
#  |-- CS_GESTANT: integer (nullable = true)
#  |-- CS_RACA: integer (nullable = true)
#  |-- CS_ETINIA: string (nullable = true)
#  |-- CS_ESCOL_N: integer (nullable = true)
#  |-- ID_PAIS: string (nullable = true)
#  |-- CO_PAIS: integer (nullable = true)
#  |-- SG_UF: string (nullable = true)
#  |-- CO_RG_RESI: integer (nullable = true)
#  |-- ID_MN_RESI: string (nullable = true)
#  |-- CO_MUN_RES: integer (nullable = true)
#  |-- CS_ZONA: integer (nullable = true)
#  |-- SURTO_SG: integer (nullable = true)
#  |-- NOSOCOMIAL: integer (nullable = true)
#  |-- AVE_SUINO: integer (nullable = true)
#  |-- FEBRE: integer (nullable = true)
#  |-- TOSSE: integer (nullable = true)
#  |-- GARGANTA: integer (nullable = true)
#  |-- DISPNEIA: integer (nullable = true)
#  |-- DESC_RESP: integer (nullable = true)
#  |-- SATURACAO: integer (nullable = true)
#  |-- DIARREIA: integer (nullable = true)
#  |-- VOMITO: integer (nullable = true)
#  |-- OUTRO_SIN: integer (nullable = true)
#  |-- OUTRO_DES: string (nullable = true)
#  |-- PUERPERA: integer (nullable = true)
#  |-- CARDIOPATI: integer (nullable = true)
#  |-- HEMATOLOGI: integer (nullable = true)
#  |-- SIND_DOWN: integer (nullable = true)
#  |-- HEPATICA: integer (nullable = true)
#  |-- ASMA: integer (nullable = true)
#  |-- DIABETES: integer (nullable = true)
#  |-- NEUROLOGIC: integer (nullable = true)
#  |-- PNEUMOPATI: integer (nullable = true)
#  |-- IMUNODEPRE: integer (nullable = true)
#  |-- RENAL: integer (nullable = true)
#  |-- OBESIDADE: integer (nullable = true)
#  |-- OBES_IMC: double (nullable = true)
#  |-- OUT_MORBI: integer (nullable = true)
#  |-- MORB_DESC: string (nullable = true)
#  |-- VACINA: integer (nullable = true)
#  |-- DT_UT_DOSE: date (nullable = true)
#  |-- MAE_VAC: integer (nullable = true)
#  |-- DT_VAC_MAE: date (nullable = true)
#  |-- M_AMAMENTA: integer (nullable = true)
#  |-- DT_DOSEUNI: date (nullable = true)
#  |-- DT_1_DOSE: date (nullable = true)
#  |-- DT_2_DOSE: date (nullable = true)
#  |-- ANTIVIRAL: integer (nullable = true)
#  |-- TP_ANTIVIR: integer (nullable = true)
#  |-- OUT_ANTIV: string (nullable = true)
#  |-- DT_ANTIVIR: date (nullable = true)
#  |-- HOSPITAL: integer (nullable = true)
#  |-- DT_INTERNA: date (nullable = true)
#  |-- SG_UF_INTE: string (nullable = true)
#  |-- ID_RG_INTE: string (nullable = true)
#  |-- CO_RG_INTE: integer (nullable = true)
#  |-- ID_MN_INTE: string (nullable = true)
#  |-- CO_MU_INTE: integer (nullable = true)
#  |-- UTI: integer (nullable = true)
#  |-- DT_ENTUTI: date (nullable = true)
#  |-- DT_SAIDUTI: date (nullable = true)
#  |-- SUPORT_VEN: integer (nullable = true)
#  |-- RAIOX_RES: integer (nullable = true)
#  |-- RAIOX_OUT: string (nullable = true)
#  |-- DT_RAIOX: date (nullable = true)
#  |-- AMOSTRA: integer (nullable = true)
#  |-- DT_COLETA: date (nullable = true)
#  |-- TP_AMOSTRA: integer (nullable = true)
#  |-- OUT_AMOST: string (nullable = true)
#  |-- REQUI_GAL: string (nullable = true)
#  |-- IF_RESUL: integer (nullable = true)
#  |-- DT_IF: date (nullable = true)
#  |-- POS_IF_FLU: integer (nullable = true)
#  |-- TP_FLU_IF: integer (nullable = true)
#  |-- POS_IF_OUT: integer (nullable = true)
#  |-- IF_VSR: integer (nullable = true)
#  |-- IF_PARA1: integer (nullable = true)
#  |-- IF_PARA2: integer (nullable = true)
#  |-- IF_PARA3: integer (nullable = true)
#  |-- IF_ADENO: integer (nullable = true)
#  |-- IF_OUTRO: integer (nullable = true)
#  |-- DS_IF_OUT: string (nullable = true)
#  |-- LAB_IF: string (nullable = true)
#  |-- CO_LAB_IF: integer (nullable = true)
#  |-- PCR_RESUL: integer (nullable = true)
#  |-- DT_PCR: date (nullable = true)
#  |-- POS_PCRFLU: integer (nullable = true)
#  |-- TP_FLU_PCR: integer (nullable = true)
#  |-- PCR_FLUASU: integer (nullable = true)
#  |-- FLUASU_OUT: string (nullable = true)
#  |-- PCR_FLUBLI: integer (nullable = true)
#  |-- FLUBLI_OUT: string (nullable = true)
#  |-- POS_PCROUT: integer (nullable = true)
#  |-- PCR_VSR: integer (nullable = true)
#  |-- PCR_PARA1: integer (nullable = true)
#  |-- PCR_PARA2: integer (nullable = true)
#  |-- PCR_PARA3: integer (nullable = true)
#  |-- PCR_PARA4: integer (nullable = true)
#  |-- PCR_ADENO: integer (nullable = true)
#  |-- PCR_METAP: integer (nullable = true)
#  |-- PCR_BOCA: integer (nullable = true)
#  |-- PCR_RINO: integer (nullable = true)
#  |-- PCR_OUTRO: integer (nullable = true)
#  |-- DS_PCR_OUT: string (nullable = true)
#  |-- LAB_PCR: string (nullable = true)
#  |-- CO_LAB_PCR: integer (nullable = true)
#  |-- CLASSI_FIN: integer (nullable = true)
#  |-- CLASSI_OUT: string (nullable = true)
#  |-- CRITERIO: integer (nullable = true)
#  |-- EVOLUCAO: integer (nullable = true)
#  |-- DT_EVOLUCA: date (nullable = true)
#  |-- DT_ENCERRA: date (nullable = true)
#  |-- OBSERVA: string (nullable = true)
#  |-- DT_DIGITA: date (nullable = true)
#  |-- HISTO_VGM: integer (nullable = true)
#  |-- PAIS_VGM: string (nullable = true)
#  |-- CO_PS_VGM: string (nullable = true)
#  |-- LO_PS_VGM: string (nullable = true)
#  |-- DT_VGM: date (nullable = true)
#  |-- DT_RT_VGM: date (nullable = true)
#  |-- PCR_SARS2: integer (nullable = true)
#  |-- PAC_COCBO: string (nullable = true)
#  |-- PAC_DSCBO: string (nullable = true)
#  |-- AGE_AT_NOTIF: long (nullable = true)
#  |-- PP_IF_RESUL: string (nullable = true)
#  |-- PP_TRA_RESUL: string (nullable = true)
#  |-- PP_PCR_RESUL: string (nullable = true)
#  |-- PP_RES_SOR_IGA: string (nullable = true)
#  |-- PP_RES_SOR_IGM: string (nullable = true)
#  |-- PP_RES_SOR_IGG: string (nullable = true)
#  |-- DT_TRA: string (nullable = true)
#  |-- DT_TOMO: string (nullable = true)
#  |-- DT_CO_SOR: string (nullable = true)
#  |-- DIST_PRI_NOTIFIC: integer (nullable = true)
#  |-- DIST_PRI_INTERNA: integer (nullable = true)
#  |-- DIST_PRI_ENTUTI: integer (nullable = true)
#  |-- DIST_PRI_SAIDUTI: integer (nullable = true)
#  |-- DIST_PRI_EVOLUCA: integer (nullable = true)
#  |-- DIST_PRI_ENCERRA: integer (nullable = true)
#  |-- DIST_PRI_RAIOX: integer (nullable = true)
#  |-- DIST_PRI_TOMO: integer (nullable = true)
#  |-- DIST_PRI_COLETA: integer (nullable = true)
#  |-- DIST_PRI_SOR: integer (nullable = true)
#  |-- DIST_PRI_PCR: integer (nullable = true)
#  |-- DIST_PRI_TRA: integer (nullable = true)
#  |-- DIST_PRI_IF: integer (nullable = true)
#  |-- DIST_PRI_NOTIFIC_q: string (nullable = true)
#  |-- DIST_PRI_INTERNA_q: string (nullable = true)
#  |-- DIST_PRI_ENTUTI_q: string (nullable = true)
#  |-- DIST_PRI_SAIDUTI_q: string (nullable = true)
#  |-- DIST_PRI_EVOLUCA_q: string (nullable = true)
#  |-- DIST_PRI_ENCERRA_q: string (nullable = true)
#  |-- DIST_PRI_RAIOX_q: string (nullable = true)
#  |-- DIST_PRI_TOMO_q: string (nullable = true)
#  |-- DIST_PRI_COLETA_q: string (nullable = true)
#  |-- DIST_PRI_SOR_q: string (nullable = true)
#  |-- DIST_PRI_PCR_q: string (nullable = true)
#  |-- DIST_PRI_TRA_q: string (nullable = true)
#  |-- DIST_PRI_IF_q: string (nullable = true)
#  |-- SYMP_GROUP1: string (nullable = true)
#  |-- SYMP_GROUP2: string (nullable = true)
#  |-- SYMP_GROUP3: string (nullable = true)
#  |-- SYMP_GROUP4: string (nullable = true)
#  |-- RF_GROUP1: string (nullable = true)
#  |-- RF_GROUP2: string (nullable = true)
#  |-- RF_GROUP3: string (nullable = true)
#  |-- RF_GROUP4: string (nullable = true)
#  |-- ANO: string (nullable = false)
#  |-- gmr_transit_stations_avg: double (nullable = true)
#  |-- gmr_grocery_and_pharmacy_avg: double (nullable = true)
#  |-- gmr_retail_and_recreation_avg: double (nullable = true)
#  |-- gmr_workplaces_percent_avg: double (nullable = true)
#  |-- gmr_residential_percent_avg: double (nullable = true)
#  |-- gmr_parks_percent_avg: double (nullable = true)
#  |-- gmr_transit_stations_1week_before_avg: double (nullable = true)
#  |-- gmr_grocery_and_pharmacy_1week_before_avg: double (nullable = true)
#  |-- gmr_retail_and_recreation_1week_before_avg: double (nullable = true)
#  |-- gmr_workplaces_percent_1week_before_avg: double (nullable = true)
#  |-- gmr_residential_percent_1week_before_avg: double (nullable = true)
#  |-- gmr_parks_percent_1week_before_avg: double (nullable = true)
#  |-- gmr_transit_stations_2weeks_avg: double (nullable = true)
#  |-- gmr_grocery_and_pharmacy_2weeks_avg: double (nullable = true)
#  |-- gmr_retail_and_recreation_2weeks_avg: double (nullable = true)
#  |-- gmr_workplaces_percent_2weeks_avg: double (nullable = true)
#  |-- gmr_residential_percent_2weeks_avg: double (nullable = true)
#  |-- gmr_parks_percent_2weeks_avg: double (nullable = true)
#  |-- inmet_temp_c_avg: double (nullable = true)
#  |-- inmet_relative_air_humidity_avg: double (nullable = true)
#  |-- inmet_daily_precipt_avg: double (nullable = true)
#  |-- inmet_temp_c_1week_before_avg: double (nullable = true)
#  |-- inmet_relative_air_humidity_1week_before_avg: double (nullable = true)
#  |-- inmet_daily_precipt_1week_before_avg: double (nullable = true)
#  |-- inmet_temp_c_2weeks_before_avg: double (nullable = true)
#  |-- inmet_relative_air_humidity_2weeks_before_avg: double (nullable = true)
#  |-- inmet_daily_precipt_2weeks_before_avg: double (nullable = true)
#  |-- AGE_GROUP: integer (nullable = false)

# %%
srag_2020.printSchema()
# Out:
# root
#  |-- UF: string (nullable = true)
#  |-- epi_week_year: string (nullable = true)
#  |-- NU_NOTIFIC: long (nullable = true)
#  |-- DT_NOTIFIC: date (nullable = true)
#  |-- SEM_NOT: integer (nullable = true)
#  |-- DT_SIN_PRI: date (nullable = true)
#  |-- SEM_PRI: integer (nullable = true)
#  |-- SG_UF_NOT: string (nullable = true)
#  |-- ID_REGIONA: string (nullable = true)
#  |-- CO_REGIONA: integer (nullable = true)
#  |-- ID_MUNICIP: string (nullable = true)
#  |-- CO_MUN_NOT: integer (nullable = true)
#  |-- ID_UNIDADE: string (nullable = true)
#  |-- CO_UNI_NOT: integer (nullable = true)
#  |-- CS_SEXO: string (nullable = true)
#  |-- DT_NASC: date (nullable = true)
#  |-- NU_IDADE_N: integer (nullable = true)
#  |-- TP_IDADE: integer (nullable = true)
#  |-- COD_IDADE: string (nullable = true)
#  |-- CS_GESTANT: integer (nullable = true)
#  |-- CS_RACA: integer (nullable = true)
#  |-- CS_ETINIA: string (nullable = true)
#  |-- CS_ESCOL_N: integer (nullable = true)
#  |-- ID_PAIS: string (nullable = true)
#  |-- CO_PAIS: integer (nullable = true)
#  |-- SG_UF: string (nullable = true)
#  |-- ID_RG_RESI: string (nullable = true)
#  |-- CO_RG_RESI: integer (nullable = true)
#  |-- ID_MN_RESI: string (nullable = true)
#  |-- CO_MUN_RES: integer (nullable = true)
#  |-- CS_ZONA: integer (nullable = true)
#  |-- SURTO_SG: integer (nullable = true)
#  |-- NOSOCOMIAL: integer (nullable = true)
#  |-- AVE_SUINO: integer (nullable = true)
#  |-- FEBRE: integer (nullable = true)
#  |-- TOSSE: integer (nullable = true)
#  |-- GARGANTA: integer (nullable = true)
#  |-- DISPNEIA: integer (nullable = true)
#  |-- DESC_RESP: integer (nullable = true)
#  |-- SATURACAO: integer (nullable = true)
#  |-- DIARREIA: integer (nullable = true)
#  |-- VOMITO: integer (nullable = true)
#  |-- OUTRO_SIN: integer (nullable = true)
#  |-- OUTRO_DES: string (nullable = true)
#  |-- PUERPERA: integer (nullable = true)
#  |-- FATOR_RISC: string (nullable = true)
#  |-- CARDIOPATI: integer (nullable = true)
#  |-- HEMATOLOGI: integer (nullable = true)
#  |-- SIND_DOWN: integer (nullable = true)
#  |-- HEPATICA: integer (nullable = true)
#  |-- ASMA: integer (nullable = true)
#  |-- DIABETES: integer (nullable = true)
#  |-- NEUROLOGIC: integer (nullable = true)
#  |-- PNEUMOPATI: integer (nullable = true)
#  |-- IMUNODEPRE: integer (nullable = true)
#  |-- RENAL: integer (nullable = true)
#  |-- OBESIDADE: integer (nullable = true)
#  |-- OBES_IMC: string (nullable = true)
#  |-- OUT_MORBI: integer (nullable = true)
#  |-- MORB_DESC: string (nullable = true)
#  |-- VACINA: integer (nullable = true)
#  |-- DT_UT_DOSE: date (nullable = true)
#  |-- MAE_VAC: integer (nullable = true)
#  |-- DT_VAC_MAE: date (nullable = true)
#  |-- M_AMAMENTA: integer (nullable = true)
#  |-- DT_DOSEUNI: date (nullable = true)
#  |-- DT_1_DOSE: date (nullable = true)
#  |-- DT_2_DOSE: date (nullable = true)
#  |-- ANTIVIRAL: integer (nullable = true)
#  |-- TP_ANTIVIR: integer (nullable = true)
#  |-- OUT_ANTIV: string (nullable = true)
#  |-- DT_ANTIVIR: date (nullable = true)
#  |-- HOSPITAL: string (nullable = true)
#  |-- DT_INTERNA: date (nullable = true)
#  |-- SG_UF_INTE: string (nullable = true)
#  |-- ID_RG_INTE: string (nullable = true)
#  |-- CO_RG_INTE: integer (nullable = true)
#  |-- ID_MN_INTE: string (nullable = true)
#  |-- CO_MU_INTE: integer (nullable = true)
#  |-- UTI: integer (nullable = true)
#  |-- DT_ENTUTI: date (nullable = true)
#  |-- DT_SAIDUTI: date (nullable = true)
#  |-- SUPORT_VEN: integer (nullable = true)
#  |-- RAIOX_RES: integer (nullable = true)
#  |-- RAIOX_OUT: string (nullable = true)
#  |-- DT_RAIOX: date (nullable = true)
#  |-- AMOSTRA: integer (nullable = true)
#  |-- DT_COLETA: date (nullable = true)
#  |-- TP_AMOSTRA: integer (nullable = true)
#  |-- OUT_AMOST: string (nullable = true)
#  |-- PCR_RESUL: integer (nullable = true)
#  |-- DT_PCR: date (nullable = true)
#  |-- POS_PCRFLU: integer (nullable = true)
#  |-- TP_FLU_PCR: integer (nullable = true)
#  |-- PCR_FLUASU: integer (nullable = true)
#  |-- FLUASU_OUT: string (nullable = true)
#  |-- PCR_FLUBLI: integer (nullable = true)
#  |-- FLUBLI_OUT: string (nullable = true)
#  |-- POS_PCROUT: integer (nullable = true)
#  |-- PCR_VSR: integer (nullable = true)
#  |-- PCR_PARA1: integer (nullable = true)
#  |-- PCR_PARA2: integer (nullable = true)
#  |-- PCR_PARA3: integer (nullable = true)
#  |-- PCR_PARA4: integer (nullable = true)
#  |-- PCR_ADENO: integer (nullable = true)
#  |-- PCR_METAP: integer (nullable = true)
#  |-- PCR_BOCA: integer (nullable = true)
#  |-- PCR_RINO: integer (nullable = true)
#  |-- PCR_OUTRO: integer (nullable = true)
#  |-- DS_PCR_OUT: string (nullable = true)
#  |-- CLASSI_FIN: integer (nullable = true)
#  |-- CLASSI_OUT: string (nullable = true)
#  |-- CRITERIO: string (nullable = true)
#  |-- EVOLUCAO: string (nullable = true)
#  |-- DT_EVOLUCA: date (nullable = true)
#  |-- DT_ENCERRA: date (nullable = true)
#  |-- DT_DIGITA: date (nullable = true)
#  |-- HISTO_VGM: integer (nullable = true)
#  |-- PAIS_VGM: string (nullable = true)
#  |-- CO_PS_VGM: integer (nullable = true)
#  |-- LO_PS_VGM: string (nullable = true)
#  |-- DT_VGM: date (nullable = true)
#  |-- DT_RT_VGM: date (nullable = true)
#  |-- PCR_SARS2: integer (nullable = true)
#  |-- PAC_COCBO: string (nullable = true)
#  |-- PAC_DSCBO: string (nullable = true)
#  |-- OUT_ANIM: string (nullable = true)
#  |-- DOR_ABD: integer (nullable = true)
#  |-- FADIGA: integer (nullable = true)
#  |-- PERD_OLFT: integer (nullable = true)
#  |-- PERD_PALA: integer (nullable = true)
#  |-- TOMO_RES: string (nullable = true)
#  |-- TOMO_OUT: string (nullable = true)
#  |-- DT_TOMO: date (nullable = true)
#  |-- TP_TES_AN: integer (nullable = true)
#  |-- DT_RES_AN: date (nullable = true)
#  |-- RES_AN: integer (nullable = true)
#  |-- POS_AN_FLU: integer (nullable = true)
#  |-- TP_FLU_AN: integer (nullable = true)
#  |-- POS_AN_OUT: integer (nullable = true)
#  |-- AN_SARS2: integer (nullable = true)
#  |-- AN_VSR: integer (nullable = true)
#  |-- AN_PARA1: integer (nullable = true)
#  |-- AN_PARA2: integer (nullable = true)
#  |-- AN_PARA3: integer (nullable = true)
#  |-- AN_ADENO: integer (nullable = true)
#  |-- AN_OUTRO: integer (nullable = true)
#  |-- DS_AN_OUT: string (nullable = true)
#  |-- TP_AM_SOR: integer (nullable = true)
#  |-- SOR_OUT: string (nullable = true)
#  |-- DT_CO_SOR: date (nullable = true)
#  |-- TP_SOR: integer (nullable = true)
#  |-- OUT_SOR: string (nullable = true)
#  |-- DT_RES: date (nullable = true)
#  |-- PP_RES_SOR_IGG: string (nullable = true)
#  |-- PP_RES_SOR_IGM: string (nullable = true)
#  |-- RES_IGA: integer (nullable = true)
#  |-- AGE_AT_NOTIF: long (nullable = true)
#  |-- PP_IF_RESUL: string (nullable = true)
#  |-- PP_TRA_RESUL: string (nullable = true)
#  |-- PP_PCR_RESUL: string (nullable = true)
#  |-- PP_RES_SOR_IGA: string (nullable = true)
#  |-- DT_IF: date (nullable = true)
#  |-- DT_TRA: date (nullable = true)
#  |-- DIST_PRI_NOTIFIC: integer (nullable = true)
#  |-- DIST_PRI_INTERNA: integer (nullable = true)
#  |-- DIST_PRI_ENTUTI: integer (nullable = true)
#  |-- DIST_PRI_SAIDUTI: integer (nullable = true)
#  |-- DIST_PRI_EVOLUCA: integer (nullable = true)
#  |-- DIST_PRI_ENCERRA: integer (nullable = true)
#  |-- DIST_PRI_RAIOX: integer (nullable = true)
#  |-- DIST_PRI_TOMO: integer (nullable = true)
#  |-- DIST_PRI_COLETA: integer (nullable = true)
#  |-- DIST_PRI_SOR: integer (nullable = true)
#  |-- DIST_PRI_PCR: integer (nullable = true)
#  |-- DIST_PRI_TRA: integer (nullable = true)
#  |-- DIST_PRI_IF: integer (nullable = true)
#  |-- DIST_PRI_NOTIFIC_q: string (nullable = true)
#  |-- DIST_PRI_INTERNA_q: string (nullable = true)
#  |-- DIST_PRI_ENTUTI_q: string (nullable = true)
#  |-- DIST_PRI_SAIDUTI_q: string (nullable = true)
#  |-- DIST_PRI_EVOLUCA_q: string (nullable = true)
#  |-- DIST_PRI_ENCERRA_q: string (nullable = true)
#  |-- DIST_PRI_RAIOX_q: string (nullable = true)
#  |-- DIST_PRI_TOMO_q: string (nullable = true)
#  |-- DIST_PRI_COLETA_q: string (nullable = true)
#  |-- DIST_PRI_SOR_q: string (nullable = true)
#  |-- DIST_PRI_PCR_q: string (nullable = true)
#  |-- DIST_PRI_TRA_q: string (nullable = true)
#  |-- DIST_PRI_IF_q: string (nullable = true)
#  |-- SYMP_GROUP1: string (nullable = true)
#  |-- SYMP_GROUP2: string (nullable = true)
#  |-- SYMP_GROUP3: string (nullable = true)
#  |-- SYMP_GROUP4: string (nullable = true)
#  |-- RF_GROUP1: string (nullable = true)
#  |-- RF_GROUP2: string (nullable = true)
#  |-- RF_GROUP3: string (nullable = true)
#  |-- RF_GROUP4: string (nullable = true)
#  |-- ANO: string (nullable = false)
#  |-- gmr_transit_stations_avg: double (nullable = true)
#  |-- gmr_grocery_and_pharmacy_avg: double (nullable = true)
#  |-- gmr_retail_and_recreation_avg: double (nullable = true)
#  |-- gmr_workplaces_percent_avg: double (nullable = true)
#  |-- gmr_residential_percent_avg: double (nullable = true)
#  |-- gmr_parks_percent_avg: double (nullable = true)
#  |-- gmr_transit_stations_1week_before_avg: double (nullable = true)
#  |-- gmr_grocery_and_pharmacy_1week_before_avg: double (nullable = true)
#  |-- gmr_retail_and_recreation_1week_before_avg: double (nullable = true)
#  |-- gmr_workplaces_percent_1week_before_avg: double (nullable = true)
#  |-- gmr_residential_percent_1week_before_avg: double (nullable = true)
#  |-- gmr_parks_percent_1week_before_avg: double (nullable = true)
#  |-- gmr_transit_stations_2weeks_avg: double (nullable = true)
#  |-- gmr_grocery_and_pharmacy_2weeks_avg: double (nullable = true)
#  |-- gmr_retail_and_recreation_2weeks_avg: double (nullable = true)
#  |-- gmr_workplaces_percent_2weeks_avg: double (nullable = true)
#  |-- gmr_residential_percent_2weeks_avg: double (nullable = true)
#  |-- gmr_parks_percent_2weeks_avg: double (nullable = true)
#  |-- inmet_temp_c_avg: double (nullable = true)
#  |-- inmet_relative_air_humidity_avg: double (nullable = true)
#  |-- inmet_daily_precipt_avg: double (nullable = true)
#  |-- inmet_temp_c_1week_before_avg: double (nullable = true)
#  |-- inmet_relative_air_humidity_1week_before_avg: double (nullable = true)
#  |-- inmet_daily_precipt_1week_before_avg: double (nullable = true)
#  |-- inmet_temp_c_2weeks_before_avg: double (nullable = true)
#  |-- inmet_relative_air_humidity_2weeks_before_avg: double (nullable = true)
#  |-- inmet_daily_precipt_2weeks_before_avg: double (nullable = true)
#  |-- AGE_GROUP: integer (nullable = false)

# %%
# adding lost columns 
srag_2019 = srag_2019.withColumn('TOMO_RES', F.lit(None).cast('string'))

# %%
srag_2019 = srag_2019.select(super_srag_cols)
srag_2020 = srag_2020.select(super_srag_cols)
srag_2021 = srag_2021.select(super_srag_cols)

# %%
super_srag = srag_2019.union(srag_2020).union(srag_2021)

# %%
# srag 2019 has 48554 records
# srag 2020 has 1193735 records
# srag 2021 has 868367 records
# super srag must contain (48554 + 1193735 + 868367 =) 2110656 records
print('super srag has', super_srag.count(), 'records')
# Out:
# super srag has 2110656 records

# %%
# now the are united, lets create the last attributes
suffix = 'avg'
gmr_inmet_cols = {'gmr_transit_stations_': [],
                  'gmr_grocery_and_pharmacy_': [], 
                  'gmr_retail_and_recreation_': [], 
                  'gmr_workplaces_percent_': [], 
                  'gmr_residential_percent_': [], 
                  'gmr_parks_percent_': [], 
                  'gmr_transit_stations_1week_before_': [], 
                  'gmr_grocery_and_pharmacy_1week_before_': [], 
                  'gmr_retail_and_recreation_1week_before_': [], 
                  'gmr_workplaces_percent_1week_before_': [], 
                  'gmr_residential_percent_1week_before_': [], 
                  'gmr_parks_percent_1week_before_': [], 
                  'gmr_transit_stations_2weeks_': [], 
                  'gmr_grocery_and_pharmacy_2weeks_': [], 
                  'gmr_retail_and_recreation_2weeks_': [], 
                  'gmr_workplaces_percent_2weeks_': [], 
                  'gmr_residential_percent_2weeks_': [], 
                  'gmr_parks_percent_2weeks_': [], 
                  'inmet_temp_c_': [], 
                  'inmet_relative_air_humidity_': [], 
                  'inmet_daily_precipt_': [], 
                  'inmet_temp_c_1week_before_': [], 
                  'inmet_relative_air_humidity_1week_before_' : [],
                  'inmet_daily_precipt_1week_before_': [], 
                  'inmet_temp_c_2weeks_before_': [], 
                  'inmet_relative_air_humidity_2weeks_before_': [], 
                  'inmet_daily_precipt_2weeks_before_': []
                 }

# %%
# generating quintiles 
for col in list(gmr_inmet_cols.keys()):
    quint_cut = super_srag.select(col+suffix).approxQuantile(col+suffix, [0.2, 0.4, 0.6, 0.8], 0)
    gmr_inmet_cols[col].append(quint_cut)

# %%
# Showing the quintiles cuttofs 
for col in pd.DataFrame(gmr_inmet_cols).columns:
    print(col, list(pd.DataFrame(gmr_inmet_cols)[col]))
# Out:
# gmr_transit_stations_ [[-43.09183673469388, -32.61737331954498, -25.20892494929006, -17.24561403508772]]
# gmr_grocery_and_pharmacy_ [[0.36936936936936937, 8.107558139534884, 13.838709677419354, 19.86090775988287]]
# gmr_retail_and_recreation_ [[-42.607894736842105, -31.163636363636364, -22.735064935064933, -15.647230320699709]]
# gmr_workplaces_percent_ [[-15.347786811201445, -7.407114624505929, -4.023725391216558, 0.5605338417540515]]
# gmr_residential_percent_ [[5.825, 7.780269058295964, 9.963333333333333, 12.902788844621513]]
# gmr_parks_percent_ [[-45.52965235173824, -36.97651663405088, -30.29383886255924, -21.115384615384617]]
# gmr_transit_stations_1week_before_ [[-44.09894736842105, -32.61737331954498, -25.263959390862944, -17.85185185185185]]
# gmr_grocery_and_pharmacy_1week_before_ [[-0.16783216783216784, 7.644859813084112, 13.094644167278062, 18.64406779661017]]
# gmr_retail_and_recreation_1week_before_ [[-42.81818181818182, -31.208955223880597, -22.889212827988338, -15.928205128205128]]
# gmr_workplaces_percent_1week_before_ [[-15.347786811201445, -7.351599852887091, -3.9318181818181817, 0.33611111111111114]]
# gmr_residential_percent_1week_before_ [[5.746001279590531, 7.714285714285714, 9.980842911877394, 13.173153296266879]]
# gmr_parks_percent_1week_before_ [[-45.42248062015504, -36.97651663405088, -30.672727272727272, -21.639327024185068]]
# gmr_transit_stations_2weeks_ [[-44.16945606694561, -32.86206896551724, -25.244274809160306, -17.40625]]
# gmr_grocery_and_pharmacy_2weeks_ [[-0.5689655172413793, 7.173590504451038, 11.925925925925926, 18.068483063328426]]
# gmr_retail_and_recreation_2weeks_ [[-43.526233359436176, -30.847341337907377, -22.798561151079138, -16.060301507537687]]
# gmr_workplaces_percent_2weeks_ [[-17.4364406779661, -7.7555555555555555, -4.397341211225997, -0.5694656488549619]]
# gmr_residential_percent_2weeks_ [[5.692477876106195, 7.639135959339263, 10.018041237113403, 13.193877551020408]]
# gmr_parks_percent_2weeks_ [[-45.38961038961039, -36.54710144927536, -29.9047131147541, -20.95306859205776]]
# inmet_temp_c_ [[19.99995412088011, 22.3166005555556, 23.721603579832205, 25.526168289473578]]
# inmet_relative_air_humidity_ [[65.59553142063525, 69.93693714285736, 73.8520828571426, 78.24404857142858]]
# inmet_daily_precipt_ [[0.3383720930232559, 1.4355555555555408, 3.35503875968993, 5.962886597938155]]
# inmet_temp_c_1week_before_ [[20.05500949193533, 22.322388241935233, 23.761091968254064, 25.53099282105264]]
# inmet_relative_air_humidity_1week_before_ [[65.65009503030261, 70.04159629710138, 73.88706227868933, 78.36411010769187]]
# inmet_daily_precipt_1week_before_ [[0.3585585585585601, 1.5249999999999975, 3.567741935483844, 6.042424242424034]]
# inmet_temp_c_2weeks_before_ [[20.174016811110565, 22.320047571428823, 23.821744027322836, 25.50684535398227]]
# inmet_relative_air_humidity_2weeks_before_ [[65.91730179032191, 70.25798429936523, 73.88706227868934, 78.47414770987979]]
# inmet_daily_precipt_2weeks_before_ [[0.3714285714285674, 1.6878787878788217, 3.640816326530609, 6.274725274725252]]

# %%
# Showing the quintiles cuttofs
pd.DataFrame(gmr_inmet_cols)
# Out:
#                                gmr_transit_stations_  \
# 0  [-43.09183673469388, -32.61737331954498, -25.2...
#
#                            gmr_grocery_and_pharmacy_  \
# 0  [0.36936936936936937, 8.107558139534884, 13.83...
#
#                           gmr_retail_and_recreation_  \
# 0  [-42.607894736842105, -31.163636363636364, -22...
#
#                              gmr_workplaces_percent_  \
# 0  [-15.347786811201445, -7.407114624505929, -4.0...
#
#                             gmr_residential_percent_  \
# 0  [5.825, 7.780269058295964, 9.963333333333333, ...
#
#                                   gmr_parks_percent_  \
# 0  [-45.52965235173824, -36.97651663405088, -30.2...
#
#                   gmr_transit_stations_1week_before_  \
# 0  [-44.09894736842105, -32.61737331954498, -25.2...
#
#               gmr_grocery_and_pharmacy_1week_before_  \
# 0  [-0.16783216783216784, 7.644859813084112, 13.0...
#
#              gmr_retail_and_recreation_1week_before_  \
# 0  [-42.81818181818182, -31.208955223880597, -22....
#
#                 gmr_workplaces_percent_1week_before_  \
# 0  [-15.347786811201445, -7.351599852887091, -3.9...
#
#                gmr_residential_percent_1week_before_  \
# 0  [5.746001279590531, 7.714285714285714, 9.98084...
#
#                      gmr_parks_percent_1week_before_  \
# 0  [-45.42248062015504, -36.97651663405088, -30.6...
#
#                         gmr_transit_stations_2weeks_  \
# 0  [-44.16945606694561, -32.86206896551724, -25.2...
#
#                     gmr_grocery_and_pharmacy_2weeks_  \
# 0  [-0.5689655172413793, 7.173590504451038, 11.92...
#
#                    gmr_retail_and_recreation_2weeks_  \
# 0  [-43.526233359436176, -30.847341337907377, -22...
#
#                       gmr_workplaces_percent_2weeks_  \
# 0  [-17.4364406779661, -7.7555555555555555, -4.39...
#
#                      gmr_residential_percent_2weeks_  \
# 0  [5.692477876106195, 7.639135959339263, 10.0180...
#
#                            gmr_parks_percent_2weeks_  \
# 0  [-45.38961038961039, -36.54710144927536, -29.9...
#
#                                        inmet_temp_c_  \
# 0  [19.99995412088011, 22.3166005555556, 23.72160...
#
#                         inmet_relative_air_humidity_  \
# 0  [65.59553142063525, 69.93693714285736, 73.8520...
#
#                                 inmet_daily_precipt_  \
# 0  [0.3383720930232559, 1.4355555555555408, 3.355...
#
#                           inmet_temp_c_1week_before_  \
# 0  [20.05500949193533, 22.322388241935233, 23.761...
#
#            inmet_relative_air_humidity_1week_before_  \
# 0  [65.65009503030261, 70.04159629710138, 73.8870...
#
#                    inmet_daily_precipt_1week_before_  \
# 0  [0.3585585585585601, 1.5249999999999975, 3.567...
#
#                          inmet_temp_c_2weeks_before_  \
# 0  [20.174016811110565, 22.320047571428823, 23.82...
#
#           inmet_relative_air_humidity_2weeks_before_  \
# 0  [65.91730179032191, 70.25798429936523, 73.8870...
#
#                   inmet_daily_precipt_2weeks_before_
# 0  [0.3714285714285674, 1.6878787878788217, 3.640...

# %%
n_suffix = 'q'
for col in list(gmr_inmet_cols.keys()):
    super_srag = super_srag.withColumn(col+n_suffix, F.when(F.col(col+suffix) <= gmr_inmet_cols[col][0][0], '1')\
                                                                  .when((F.col(col+suffix) > gmr_inmet_cols[col][0][0]) &  (F.col(col+suffix) <= gmr_inmet_cols[col][0][1]), '2')\
                                                                  .when((F.col(col+suffix) > gmr_inmet_cols[col][0][1]) &  (F.col(col+suffix) <= gmr_inmet_cols[col][0][2]), '3')\
                                                                  .when((F.col(col+suffix) > gmr_inmet_cols[col][0][2]) &  (F.col(col+suffix) <= gmr_inmet_cols[col][0][3]), '4')\
                                                                  .when(F.col(col+suffix) > gmr_inmet_cols[col][0][3], '5')\
                                                                  .otherwise('6'))

# %%
# making all column names uppercase
for col in super_srag.columns:
    super_srag = super_srag.withColumnRenamed(col, col.upper())

# %% [markdown]
# #### writing super srag

# %%
super_srag.write.parquet('gs://ai-covid19-datalake/standard/super-srag/super_srag_v1.parquet')

# %%
super_srag.coalesce(1).write.csv('gs://ai-covid19-datalake/standard/super-srag/super_srag_v1.csv', header=True)
