# %%
import pandas as pd
import pyspark.sql.functions as F
from datetime import datetime
from pyspark.sql.types import *
from pyspark import StorageLevel

import numpy as np
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", 1000)
pd.set_option("mode.chained_assignment", None)

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import GBTClassifier
from pyspark.ml.feature import IndexToString, StringIndexer, VectorIndexer
# from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import OneHotEncoderEstimator, StringIndexer, VectorAssembler

from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

from pyspark.sql import Row
from pyspark.ml.linalg import Vectors

# %%
# !pip install scikit-plot

# %%
import sklearn
import scikitplot as skplt
from sklearn.metrics import classification_report, confusion_matrix, precision_score

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
result_schema = StructType([
                    StructField('experiment_filter', StringType(), True),
                    StructField('undersampling_method', StringType(), True),
                    StructField('undersampling_column', StringType(), True),
                    StructField('filename', StringType(), True),
                    StructField('experiment_id', StringType(), True),
                    StructField('n_covid', IntegerType(), True),
                    StructField('n_not_covid', IntegerType(), True),
                    StructField('model_name', StringType(), True),
                    StructField('model_seed', StringType(), True),
                    StructField('model_maxIter', IntegerType(), True),
                    StructField('model_maxDepth', IntegerType(), True),
                    StructField('model_maxBins', IntegerType(), True),
                    StructField('model_minInstancesPerNode', IntegerType(), True),
                    StructField('model_minInfoGain', FloatType(), True),
                    StructField('model_featureSubsetStrategy', StringType(), True),
                    StructField('model_n_estimators', IntegerType(), True),
                    StructField('model_learning_rate', FloatType(), True),
                    StructField('model_impurity', StringType(), True),
                    StructField('model_AUC_ROC', StringType(), True),
                    StructField('model_AUC_PR', StringType(), True),
                    StructField('model_covid_precision', StringType(), True),
                    StructField('model_covid_recall', StringType(), True),
                    StructField('model_covid_f1', StringType(), True),
                    StructField('model_not_covid_precision', StringType(), True),
                    StructField('model_not_covid_recall', StringType(), True),
                    StructField('model_not_covid_f1', StringType(), True),
                    StructField('model_avg_precision', StringType(), True),
                    StructField('model_avg_recall', StringType(), True),
                    StructField('model_avg_f1', StringType(), True),
                    StructField('model_avg_acc', StringType(), True),
                    StructField('model_TP', StringType(), True),
                    StructField('model_TN', StringType(), True),
                    StructField('model_FN', StringType(), True),
                    StructField('model_FP', StringType(), True),
                    StructField('model_time_exec', StringType(), True),
                    StructField('model_col_set', StringType(), True)
                          ])

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# undersamp_col = ['03-STRSAMP-AG', '04-STRSAMP-EW'] 
# dfs = ['ds-1', 'ds-2', 'ds-3']
# cols_sets = ['cols_set_1', 'cols_set_2', 'cols_set_3']

undersamp_col = ['03-STRSAMP-AG']
dfs = ['ds-2']
cols_sets = ['cols_set_1']

# %%
# lists of params
model_maxIter = [20, 50, 100] 
model_maxDepth = [3, 5, 7] 
model_maxBins = [32, 64] 
# model_learningRate = [0.01, 0.1, 0.5]
# model_loss = ['logLoss', 'leastSquaresError', 'leastAbsoluteError']


list_of_param_dicts = []

for maxIter in model_maxIter:
    for maxDepth in model_maxDepth:
        for maxBins in model_maxBins: 
            params_dict = {}
            params_dict['maxIter'] = maxIter
            params_dict['maxDepth'] = maxDepth
            params_dict['maxBins'] = maxBins
            list_of_param_dicts.append(params_dict)

            

print("There is {} set of params.".format(len(list_of_param_dicts)))
# list_of_param_dicts
# Out:
# There is 18 set of params.

# %%
prefix = 'gs://ai-covid19-datalake/trusted/experiment_map/'

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# filename = 'gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment0.parquet'
# df = spark.read.parquet(filename)
# df.limit(2).toPandas()

# %%
# params_dict = {'maxIter': 100,
#                'maxDepth': 3,
#                'maxBins': 32,
#                'learningRate': 0.5,
#                'loss': 'leastAbsoluteError'}
# cols = 'cols_set_1'
# experiment_filter = 'ds-1'
# undersampling_method = '03-STRSAMP-AG', 
# experiment_id = 0

# %%
# run_gbt(df, params_dict, cols, filename, experiment_filter, undersampling_method, experiment_id)

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
def run_gbt(exp_df, params_dict, cols, filename, experiment_filter, 
            undersampling_method, experiment_id):
    import time
    start_time = time.time()
    
    n_covid = exp_df.filter(F.col('CLASSI_FIN') == 1.0).count()
    n_not_covid = exp_df.filter(F.col('CLASSI_FIN') == 0.0).count()
    
    
    id_cols = ['NU_NOTIFIC', 'CLASSI_FIN']

    labelIndexer = StringIndexer(inputCol="CLASSI_FIN", outputCol="indexedLabel").fit(exp_df)    
    
    input_cols = [x for x in exp_df.columns if x not in id_cols]
    assembler = VectorAssembler(inputCols = input_cols, outputCol= 'features')
    exp_df = assembler.transform(exp_df)
    
    # Automatically identify categorical features, and index them.
    # Set maxCategories so features with > 4 distinct values are treated as continuous.
    featureIndexer = VectorIndexer(inputCol="features", outputCol="indexedFeatures", maxCategories=30).fit(exp_df)
    
    # Split the data into training and test sets (30% held out for testing)
    (trainingData, testData) = exp_df.randomSplit([0.7, 0.3])
    trainingData = trainingData.persist(StorageLevel.MEMORY_ONLY)
    testData = testData.persist(StorageLevel.MEMORY_ONLY)
    
    # Train a RandomForest model.
    gbt = GBTClassifier(labelCol = "indexedLabel", featuresCol = "indexedFeatures",
                       maxIter = params_dict['maxIter'],
                       maxDepth = params_dict['maxDepth'],
                       maxBins = params_dict['maxBins'])
    
    # Convert indexed labels back to original labels.
    labelConverter = IndexToString(inputCol="prediction", outputCol="predictedLabel",
                               labels=labelIndexer.labels)

    # Chain indexers and forest in a Pipeline
    pipeline = Pipeline(stages=[labelIndexer, featureIndexer, gbt, labelConverter])

    # Train model.  This also runs the indexers.
    model = pipeline.fit(trainingData)
    
    # Make predictions.
    predictions = model.transform(testData)    
    
    
    pred = predictions.select(['CLASSI_FIN', 'predictedLabel'])\
                  .withColumn('predictedLabel', F.col('predictedLabel').cast('double'))\
                  .withColumn('predictedLabel', F.when(F.col('predictedLabel') == 1.0, 'covid').otherwise('n-covid'))\
                  .withColumn('CLASSI_FIN', F.when(F.col('CLASSI_FIN') == 1.0, 'covid').otherwise('n-covid'))\
                  .toPandas()

    y_true = pred['CLASSI_FIN'].tolist()
    y_pred = pred['predictedLabel'].tolist()
    
    report = classification_report(y_true, y_pred, output_dict=True)
    
    
    evaluator_ROC = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderROC")
    accuracy_ROC = evaluator_ROC.evaluate(predictions)


    
    evaluator_PR = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderPR")
    accuracy_PR = evaluator_PR.evaluate(predictions)
    
    conf_matrix = confusion_matrix(y_true, y_pred)

    result_dict = {}
    
    result_dict['experiment_filter'] = experiment_filter
    result_dict['undersampling_method'] = undersampling_method
    result_dict['filename'] = filename
    result_dict['experiment_id'] = experiment_id
    result_dict['n_covid'] = n_covid
    result_dict['n_not_covid'] = n_not_covid
    result_dict['model_name'] = 'GBT'
    result_dict['params'] = params_dict
    result_dict['model_AUC_ROC'] = accuracy_ROC
    result_dict['model_AUC_PR'] = accuracy_PR
    result_dict['model_covid_precision'] = report['covid']['precision']
    result_dict['model_covid_recall'] = report['covid']['recall']
    result_dict['model_covid_f1'] = report['covid']['f1-score']
    result_dict['model_not_covid_precision'] = report['n-covid']['precision']
    result_dict['model_not_covid_recall'] = report['n-covid']['recall']
    result_dict['model_not_covid_f1'] = report['n-covid']['f1-score']
    result_dict['model_avg_precision'] = report['macro avg']['precision']
    result_dict['model_avg_recall'] = report['macro avg']['recall']
    result_dict['model_avg_f1'] = report['macro avg']['f1-score']
    result_dict['model_avg_acc'] = report['accuracy']
    result_dict['model_TP'] = conf_matrix[0][0]
    result_dict['model_TN'] = conf_matrix[1][1]
    result_dict['model_FN'] = conf_matrix[0][1]
    result_dict['model_FP'] = conf_matrix[1][0]
    result_dict['model_time_exec'] = time.time() - start_time
    result_dict['model_col_set'] = cols
    
    return result_dict

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %% [markdown]
# # Running GBT on 10 samples for each experiment
# ### 3x col sets -> ['cols_set_1', 'cols_set_2', 'cols_set_3']
# ### 3x model_maxIter -> [100, 200, 300]
# ### 3x model_maxDepth -> [5, 10, 15]
# ### 3x model_maxBins -> [16, 32, 64]
# Total: 10 * 3 * 3 * 3 * 3 = 810

# %%
experiments = []

# %% [markdown]
# ### Datasets: strat_samp_lab_agegrp

# %%
for uc in undersamp_col: 
    for ds in dfs:
        for col_set in cols_sets:
            for params_dict in list_of_param_dicts: 
                for id_exp in range(50):
                    filename = prefix + uc + '/' + ds + '/' + col_set + '/' + 'experiment' + str(id_exp) + '.parquet'
                    exp_dataframe = spark.read.parquet(filename)
#                     if 'SG_UF_NOT' in exp_dataframe.columns:
#                         exp_dataframe = exp_dataframe.withColumn('SG_UF_NOT', F.col('SG_UF_NOT').cast('float'))
                    print('read {}'.format(filename))
                    
                    undersampling_method = uc
                    experiment_filter = ds
                    experiment_id = id_exp

                    try:                     
                        model = run_gbt(exp_dataframe, params_dict, col_set, filename, experiment_filter, undersampling_method, experiment_id)
                        experiments.append(model)

                        print("Parameters ==> {}\n Results: \n AUC_PR: {} \n Precision: {} \n Time: {}".format(str(params_dict), str(model['model_AUC_PR']), str(model['model_avg_precision']), str(model['model_time_exec'])))
                        print('=========================== \n')
                    except:
                        print('=========== W A R N I N G =========== \n')
                        print('Something wrong with the exp: {}, {}, {}'.format(filename, params_dict, col_set))
# Out:
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.93746419423911
#  Precision: 0.9378847415366959
#  Time: 25.329426765441895
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9390924727576834
#  Precision: 0.9391304937725391
#  Time: 14.94358229637146
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9346535476235804
#  Precision: 0.9356771469900028
#  Time: 14.746891260147095
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9399085682560679
#  Precision: 0.9388894992207278
#  Time: 14.39287257194519
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.939192895222293
#  Precision: 0.9377543503675078
#  Time: 14.132079839706421
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9390928058990542
#  Precision: 0.9369766924888652
#  Time: 13.945234537124634
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.937254777459691
#  Precision: 0.9370675973001987
#  Time: 13.710296630859375
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9353450716027176
#  Precision: 0.9379427303337289
#  Time: 13.495286226272583
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9377868759745177
#  Precision: 0.9391136894155716
#  Time: 13.984312057495117
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9344295459777177
#  Precision: 0.937386395582448
#  Time: 13.43479871749878
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9371197362727093
#  Precision: 0.9383229313661379
#  Time: 13.889158725738525
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9369731462021026
#  Precision: 0.9367233636291264
#  Time: 13.569412469863892
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9411241370871022
#  Precision: 0.9390599086196472
#  Time: 13.570613145828247
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9345236052949454
#  Precision: 0.9361907190169441
#  Time: 13.417893409729004
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9344233142168317
#  Precision: 0.9363501832882664
#  Time: 13.591392040252686
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9379388385350883
#  Precision: 0.9371091153066429
#  Time: 13.594298839569092
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9352405093815105
#  Precision: 0.9354604258955526
#  Time: 13.733888387680054
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9345100303063565
#  Precision: 0.9350140550800194
#  Time: 13.80407428741455
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.937773103671223
#  Precision: 0.9379897011150743
#  Time: 16.578757524490356
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9375429235068934
#  Precision: 0.9373797246851514
#  Time: 13.225107669830322
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9388762127658841
#  Precision: 0.9399508845847151
#  Time: 13.54867172241211
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9365092864679101
#  Precision: 0.9377999409571575
#  Time: 15.687735795974731
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9385257375644651
#  Precision: 0.9364139976717876
#  Time: 13.542200088500977
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9382112647069903
#  Precision: 0.9365621793910477
#  Time: 13.527307748794556
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9407530030962917
#  Precision: 0.9393277671391467
#  Time: 13.550784349441528
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9357030686748092
#  Precision: 0.9377540210545244
#  Time: 13.30318808555603
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9385160109475424
#  Precision: 0.9382122275994782
#  Time: 13.74254846572876
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9397172969849469
#  Precision: 0.9382947972203435
#  Time: 14.223917245864868
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9375083022084117
#  Precision: 0.9370532879253618
#  Time: 13.570342540740967
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9373276097677492
#  Precision: 0.9383955635721937
#  Time: 13.224558353424072
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.940307884775313
#  Precision: 0.9396892066570821
#  Time: 13.400193691253662
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.938037900491039
#  Precision: 0.9394131876046
#  Time: 13.65985918045044
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9391696512240428
#  Precision: 0.9381605497622669
#  Time: 14.106205701828003
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9363789756051465
#  Precision: 0.9376788833443954
#  Time: 13.325031757354736
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9354141252652757
#  Precision: 0.9366107780723558
#  Time: 13.735082626342773
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9373255154390308
#  Precision: 0.9381039659599344
#  Time: 13.20784068107605
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9374636421238437
#  Precision: 0.9390072167451375
#  Time: 13.581140518188477
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9401916864155647
#  Precision: 0.9398230330543943
#  Time: 13.836735010147095
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9341531449224084
#  Precision: 0.9342223549430795
#  Time: 13.39293098449707
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9404898792727385
#  Precision: 0.9410652312267771
#  Time: 13.401257038116455
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9359978800337657
#  Precision: 0.9367789407807992
#  Time: 14.542642593383789
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.940529749271912
#  Precision: 0.9396393162718075
#  Time: 14.555484771728516
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9360345332539212
#  Precision: 0.9375284384707634
#  Time: 14.365483522415161
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9382613955197189
#  Precision: 0.9383280484267764
#  Time: 13.947558641433716
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9381364990020539
#  Precision: 0.9372435683908782
#  Time: 13.556007862091064
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9388731020539026
#  Precision: 0.9370316380087884
#  Time: 13.392067432403564
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9385639533081688
#  Precision: 0.9386760975286197
#  Time: 14.217816591262817
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9398757518744181
#  Precision: 0.9378206159821172
#  Time: 13.483052015304565
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9353778912561623
#  Precision: 0.936532513052915
#  Time: 12.936401128768921
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9360765821255729
#  Precision: 0.9366107624541982
#  Time: 13.435199737548828
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.935955534539635
#  Precision: 0.9377428549923976
#  Time: 16.175060510635376
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9353839779202952
#  Precision: 0.9370504184305318
#  Time: 13.49687647819519
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9401970341240473
#  Precision: 0.9403034991256886
#  Time: 13.318293333053589
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9355793609136245
#  Precision: 0.9370054184011885
#  Time: 13.14161729812622
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9383813707896665
#  Precision: 0.9370558690398307
#  Time: 12.995577096939087
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9392931127273065
#  Precision: 0.9378772306829861
#  Time: 13.185396909713745
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9373979825470461
#  Precision: 0.937905141728563
#  Time: 13.50571584701538
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9349639435629901
#  Precision: 0.9365510618965172
#  Time: 13.531460523605347
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9369344848070507
#  Precision: 0.9358352175884386
#  Time: 13.437949419021606
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9382797532499835
#  Precision: 0.9376378156670685
#  Time: 21.171818017959595
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9381739072892386
#  Precision: 0.9378726318969581
#  Time: 13.453415393829346
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9397540453527455
#  Precision: 0.9392495921317714
#  Time: 13.34692645072937
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9368039734465397
#  Precision: 0.9361694347621426
#  Time: 13.1768639087677
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9363617041259935
#  Precision: 0.9373034261780253
#  Time: 14.549637079238892
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9371219851205235
#  Precision: 0.9392857103906873
#  Time: 13.226617574691772
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9388923010638569
#  Precision: 0.9382356948400159
#  Time: 14.551150798797607
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.93427337293634
#  Precision: 0.9352728414357961
#  Time: 13.29678463935852
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.936080000093909
#  Precision: 0.9352511652644813
#  Time: 14.11890172958374
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9379138067092437
#  Precision: 0.9364810849831059
#  Time: 13.18835735321045
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9387665315435154
#  Precision: 0.9384118228564438
#  Time: 13.638965368270874
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9383911210263218
#  Precision: 0.9385604131522027
#  Time: 13.719335317611694
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9388439123626668
#  Precision: 0.9395360436714078
#  Time: 13.082396745681763
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9386857034018725
#  Precision: 0.9394520876259006
#  Time: 12.929954290390015
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9403347167671605
#  Precision: 0.9392796971379094
#  Time: 13.619516134262085
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9374599648507336
#  Precision: 0.9379610224802104
#  Time: 13.233597993850708
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9357574712064877
#  Precision: 0.9373669840264962
#  Time: 13.181632995605469
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9370810442993263
#  Precision: 0.9372210092463165
#  Time: 13.796572923660278
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9406005439730086
#  Precision: 0.9385956155556117
#  Time: 13.195730924606323
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9378155123917692
#  Precision: 0.9369447268708562
#  Time: 13.380081176757812
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9366858733226782
#  Precision: 0.9387920563035566
#  Time: 13.385734796524048
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9369754664751125
#  Precision: 0.9366223133182874
#  Time: 12.935670137405396
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9405319186651787
#  Precision: 0.9408593313332794
#  Time: 13.009970426559448
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9385362428372666
#  Precision: 0.9389240890710356
#  Time: 13.253262519836426
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9373024235127027
#  Precision: 0.9387139517977029
#  Time: 12.914525270462036
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9367654293607998
#  Precision: 0.9362222513457275
#  Time: 13.000245094299316
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9373119654903542
#  Precision: 0.9362853322439185
#  Time: 13.124216079711914
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.937034508183898
#  Precision: 0.9381252186079049
#  Time: 13.362059116363525
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9381465083072862
#  Precision: 0.939456432641177
#  Time: 13.819116830825806
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9352681867093389
#  Precision: 0.9369142772311083
#  Time: 13.479872941970825
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9351933800065658
#  Precision: 0.9371483163364323
#  Time: 13.289019584655762
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9369251524195443
#  Precision: 0.9368825294218665
#  Time: 13.956478357315063
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9407320906415031
#  Precision: 0.9388029577448959
#  Time: 13.190964937210083
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9376475746585343
#  Precision: 0.9397359973952129
#  Time: 13.306448459625244
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9351591780482351
#  Precision: 0.9351195505759771
#  Time: 12.979371786117554
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.938103305977003
#  Precision: 0.937989309758934
#  Time: 13.068254232406616
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9377956594727028
#  Precision: 0.9377631218459466
#  Time: 13.131692886352539
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9399915981997091
#  Precision: 0.9387244525348974
#  Time: 13.447876214981079
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9402102800225353
#  Precision: 0.9368537618101401
#  Time: 13.431435823440552
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9341006303092465
#  Precision: 0.9365911792073253
#  Time: 13.272721290588379
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9384476774885979
#  Precision: 0.9384967779953238
#  Time: 14.208345890045166
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9472509395518602
#  Precision: 0.9483743794019205
#  Time: 15.89893126487732
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9442492265405968
#  Precision: 0.9454213691146391
#  Time: 15.506490707397461
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9472910008032245
#  Precision: 0.9481237480034441
#  Time: 15.681528568267822
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9494977931165842
#  Precision: 0.9488410124174335
#  Time: 15.754377365112305
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9465283387994432
#  Precision: 0.9478337802545034
#  Time: 15.70397686958313
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.947301356263832
#  Precision: 0.9472312339087263
#  Time: 15.512112855911255
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9475935965548201
#  Precision: 0.9481030512068565
#  Time: 15.970641374588013
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.946037049550811
#  Precision: 0.9467272378314698
#  Time: 16.16736388206482
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9461036449273669
#  Precision: 0.9474219942492953
#  Time: 15.712985277175903
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9433863598165138
#  Precision: 0.9461132728917225
#  Time: 15.931924819946289
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9438417770936345
#  Precision: 0.9468155611561171
#  Time: 16.062859296798706
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9472710894800573
#  Precision: 0.9481774967512966
#  Time: 16.199809074401855
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9448558317749882
#  Precision: 0.9445160515382407
#  Time: 15.626246452331543
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9424074092493537
#  Precision: 0.9445682343346157
#  Time: 16.499206066131592
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9455269064653148
#  Precision: 0.9474707427979919
#  Time: 15.846839427947998
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9492559509716899
#  Precision: 0.9485867370879486
#  Time: 15.913905382156372
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9445662871547402
#  Precision: 0.946256900101397
#  Time: 17.201032400131226
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9457365795933712
#  Precision: 0.9471647373091354
#  Time: 16.878337860107422
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9481186465851514
#  Precision: 0.9481001619892413
#  Time: 15.977296352386475
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9427645485324426
#  Precision: 0.9448235600319441
#  Time: 16.27233123779297
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9447292791837291
#  Precision: 0.9475319710050292
#  Time: 16.642054557800293
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9462641341391953
#  Precision: 0.9477676696901092
#  Time: 19.661473989486694
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9469209332359626
#  Precision: 0.9477850838291032
#  Time: 16.70295810699463
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9454953713446818
#  Precision: 0.9457868223044407
#  Time: 15.900291919708252
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9484768772619311
#  Precision: 0.9480663572037056
#  Time: 15.654728889465332
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9476065037761383
#  Precision: 0.9483781004953802
#  Time: 20.58082103729248
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9468775791398617
#  Precision: 0.9477662669112005
#  Time: 15.822880506515503
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9457165727267355
#  Precision: 0.945579406598474
#  Time: 16.106430053710938
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9472334714562254
#  Precision: 0.9462278223643963
#  Time: 16.43517827987671
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9471019857591977
#  Precision: 0.9480901112326311
#  Time: 16.4098961353302
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9455863037506398
#  Precision: 0.9456961491875224
#  Time: 16.019296646118164
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9440090739120799
#  Precision: 0.9476736523560951
#  Time: 15.902178525924683
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9481125031510397
#  Precision: 0.9484355437005849
#  Time: 15.935884475708008
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9444068836428535
#  Precision: 0.9467941386324801
#  Time: 16.014528036117554
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9451405177488323
#  Precision: 0.9476498002383109
#  Time: 16.897521257400513
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.945519654948757
#  Precision: 0.9466218245397922
#  Time: 17.025248050689697
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.943999736821201
#  Precision: 0.9467797098402057
#  Time: 17.629915714263916
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9449456300757261
#  Precision: 0.9467227364730997
#  Time: 17.657265663146973
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9483452101385709
#  Precision: 0.9489474796326784
#  Time: 16.765480518341064
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9449638802254946
#  Precision: 0.9460302593548107
#  Time: 16.315967559814453
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9473159571440863
#  Precision: 0.9485793738513338
#  Time: 16.500427722930908
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9486470084816402
#  Precision: 0.9495831749570287
#  Time: 16.989543676376343
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9436612358996335
#  Precision: 0.946708375031893
#  Time: 21.75873303413391
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9493137849615843
#  Precision: 0.948532023475846
#  Time: 15.868138313293457
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9453412303466087
#  Precision: 0.9457253007715841
#  Time: 16.164884090423584
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9471770583794501
#  Precision: 0.9461856930983936
#  Time: 17.288267612457275
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9453141544853004
#  Precision: 0.9467130332541649
#  Time: 16.171994924545288
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.944983464388624
#  Precision: 0.9455234449024463
#  Time: 16.3171808719635
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9461481959622835
#  Precision: 0.9471989648715964
#  Time: 16.24124312400818
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9431691729971946
#  Precision: 0.9451809744963449
#  Time: 16.303199291229248
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9439044387169541
#  Precision: 0.9461199520655823
#  Time: 16.55345630645752
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9448611823893317
#  Precision: 0.9470981716468823
#  Time: 16.966323137283325
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9506146553187187
#  Precision: 0.9494834393203748
#  Time: 17.595116138458252
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.945534930670937
#  Precision: 0.9472038341530129
#  Time: 16.461215019226074
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9476144335112439
#  Precision: 0.9475184886668351
#  Time: 16.148197174072266
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9460678533207814
#  Precision: 0.9467073448794407
#  Time: 16.301141500473022
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9459211839691728
#  Precision: 0.948083725131178
#  Time: 16.508402109146118
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9446958344911004
#  Precision: 0.9474356459178076
#  Time: 16.348106622695923
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9472958097663391
#  Precision: 0.9478256153647369
#  Time: 16.497455835342407
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9464097682622484
#  Precision: 0.947522132835968
#  Time: 16.074331521987915
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9424097682899771
#  Precision: 0.9443816545457395
#  Time: 16.220683336257935
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9473822252848584
#  Precision: 0.9481273752735199
#  Time: 16.591369152069092
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9426306116348905
#  Precision: 0.9434112061106147
#  Time: 17.968169450759888
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9465951373479807
#  Precision: 0.9474234734765024
#  Time: 16.339634656906128
# ===========================
#
# ...
#  Results:
#  AUC_PR: 0.9477612654027368
#  Precision: 0.9534692750225828
#  Time: 110.45895624160767
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9499214651396618
#  Precision: 0.9560308913372215
#  Time: 109.40406918525696
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9491090637183254
#  Precision: 0.9547312160390382
#  Time: 111.30386424064636
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment48.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9466452934525398
#  Precision: 0.9539596035772231
#  Time: 108.98159527778625
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.950002846230134
#  Precision: 0.9548290713075812
#  Time: 111.04459166526794
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment0.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9504739647057302
#  Precision: 0.9561978062736518
#  Time: 112.45796489715576
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment1.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9491007526957497
#  Precision: 0.9542706412164982
#  Time: 110.54825806617737
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment2.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9475897111139633
#  Precision: 0.9543649924274578
#  Time: 111.20147943496704
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment3.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9528350300934754
#  Precision: 0.9580618408282178
#  Time: 110.79379177093506
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment4.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9487547837578162
#  Precision: 0.9545302989429254
#  Time: 110.8054552078247
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment5.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9494517890206979
#  Precision: 0.9553349265053244
#  Time: 110.19715666770935
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment6.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9487166605117505
#  Precision: 0.9551758149605568
#  Time: 112.85161209106445
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment7.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9499104774203632
#  Precision: 0.9549883407728402
#  Time: 112.36145329475403
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment8.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9515083204057432
#  Precision: 0.9561580921202804
#  Time: 110.42115902900696
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment9.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9494829721074498
#  Precision: 0.9544475016141669
#  Time: 110.58676266670227
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment10.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9498598512611244
#  Precision: 0.9551337484163047
#  Time: 110.66592025756836
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment11.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9486190706605653
#  Precision: 0.9545518775987526
#  Time: 111.62097764015198
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment12.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9504190007267016
#  Precision: 0.9535239839464943
#  Time: 112.27584385871887
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment13.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9505145837073193
#  Precision: 0.9550990239206536
#  Time: 110.60255646705627
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment14.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9508827077810575
#  Precision: 0.9553896583313273
#  Time: 111.1362853050232
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment15.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9494347777617784
#  Precision: 0.954207166469486
#  Time: 109.91070461273193
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment16.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9487355308353358
#  Precision: 0.955277687788656
#  Time: 111.21346020698547
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment17.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9506438233583957
#  Precision: 0.9553004505812317
#  Time: 113.72281694412231
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment18.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9486916503703999
#  Precision: 0.9545641911069381
#  Time: 112.4449610710144
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment19.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.946184462102195
#  Precision: 0.9532108873610202
#  Time: 112.2326648235321
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment20.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9465424437668661
#  Precision: 0.9538814811247173
#  Time: 112.38248372077942
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment21.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9488923479318657
#  Precision: 0.95507973434128
#  Time: 112.02709126472473
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment22.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9488977737481423
#  Precision: 0.9534467757435753
#  Time: 109.83443331718445
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment23.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9469245904179738
#  Precision: 0.9540747376515161
#  Time: 111.15312790870667
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment24.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9500790536373088
#  Precision: 0.9552704313227467
#  Time: 120.42462086677551
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment25.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9482288977863214
#  Precision: 0.9544821896424756
#  Time: 110.40825510025024
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment26.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9492247936485365
#  Precision: 0.9543334828575297
#  Time: 111.2603611946106
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment27.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9480452655968746
#  Precision: 0.9542312351819323
#  Time: 110.02485728263855
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment28.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9495055031149863
#  Precision: 0.9547465478621828
#  Time: 110.2708740234375
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment29.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9509910040403355
#  Precision: 0.9558780742595031
#  Time: 111.1452054977417
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment30.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9489908122620309
#  Precision: 0.9540317610524197
#  Time: 109.4249165058136
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment31.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.949787999913908
#  Precision: 0.9554317452038511
#  Time: 110.95111751556396
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment32.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9485417074346338
#  Precision: 0.954686259231027
#  Time: 112.61663436889648
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment33.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9495268207640829
#  Precision: 0.9549072525494118
#  Time: 109.13107180595398
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment34.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9493663816372013
#  Precision: 0.9549665226505941
#  Time: 108.88526225090027
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment35.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9472536791310124
#  Precision: 0.9546997259820884
#  Time: 110.748220205307
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment36.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9487070541559349
#  Precision: 0.9532197423560247
#  Time: 117.5547559261322
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment37.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9483458564441203
#  Precision: 0.9552693443989221
#  Time: 117.85212135314941
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment38.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9503074602987232
#  Precision: 0.9551983956973782
#  Time: 110.47851395606995
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment39.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9503236326064407
#  Precision: 0.9556192854487497
#  Time: 111.52815699577332
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment40.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9501680731472609
#  Precision: 0.9548732196210732
#  Time: 109.36680316925049
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment41.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9530774073814173
#  Precision: 0.9575747159402602
#  Time: 109.7043559551239
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment42.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9497246995044761
#  Precision: 0.9548884681402072
#  Time: 110.91731238365173
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment43.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9519091573125775
#  Precision: 0.9570110470685411
#  Time: 112.52274775505066
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment44.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9513135719865814
#  Precision: 0.9559886965877622
#  Time: 110.32210040092468
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment45.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9494916445793753
#  Precision: 0.9547451688453337
#  Time: 108.83777117729187
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9503734412315255
#  Precision: 0.9564910105310402
#  Time: 110.77770709991455
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9512906591964985
#  Precision: 0.9564083538122666
#  Time: 110.05765223503113
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment48.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9496418943347472
#  Precision: 0.9539219859767587
#  Time: 112.46875619888306
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9475254944699903
#  Precision: 0.9530331166460853
#  Time: 111.70571899414062
# ===========================

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
for i in range(len(experiments)):
    for d in list(experiments[i].keys()):
        experiments[i][d] = str(experiments[i][d])

# %%
# experiments

# %%
cols = ['experiment_filter', 'undersampling_method', 'filename', 'experiment_id', 'n_covid', 'n_not_covid', 'model_name', 'params', 'model_AUC_ROC', 'model_AUC_PR', 'model_covid_precision', 'model_covid_recall', 'model_covid_f1', 'model_not_covid_precision', 'model_not_covid_recall', 'model_not_covid_f1', 'model_avg_precision', 'model_avg_recall', 'model_avg_f1', 'model_avg_acc', 'model_TP', 'model_TN', 'model_FN', 'model_FP', 'model_time_exec', 'model_col_set']

# %%
intermed_results = spark.createDataFrame(data=experiments).select(cols)
intermed_results.toPandas()
# Out:
# /usr/lib/spark/python/pyspark/sql/session.py:346: UserWarning: inferring schema from dict is deprecated,please use pyspark.sql.Row instead
#   warnings.warn("inferring schema from dict is deprecated,"

# %%
intermed_results.write.parquet('gs://ai-covid19-datalake/trusted/intermed_results/STRSAMP/GBT_experiments-AG-ds2-cs1.parquet', mode='overwrite')

# %%
print('finished')
# Out:
# finished

# %%
intermed_results.show()
# Out:
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# |experiment_filter|undersampling_method|            filename|experiment_id|n_covid|n_not_covid|model_name|              params|     model_AUC_ROC|      model_AUC_PR|model_covid_precision|model_covid_recall|    model_covid_f1|model_not_covid_precision|model_not_covid_recall|model_not_covid_f1|model_avg_precision|  model_avg_recall|      model_avg_f1|     model_avg_acc|model_TP|model_TN|model_FN|model_FP|   model_time_exec|model_col_set|
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|            0|  53203|      44538|       GBT|{'maxIter': 20, '...|0.9291226778058329|  0.93746419423911|    0.908580452711002|0.9747740963855421|0.9405140314231224|       0.9671890303623898|    0.8834712592261239|0.9234365867913502| 0.9378847415366959| 0.929122677805833|0.9319753091072362| 0.933047122559542|   15534|   11850|     402|    1563|25.329426765441895|   cols_set_1|
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|            1|  53038|      44538|       GBT|{'maxIter': 20, '...|0.9310440076613891|0.9390924727576834|   0.9104901728628937|0.9748985801217038|0.9415942206440553|       0.9677708146821844|    0.8871894352010744|0.9257298559750877| 0.9391304937725391|0.9310440076613891|0.9336620383095715|0.9346105075568045|   15380|   11891|     396|    1512| 14.94358229637146|   cols_set_1|
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|            2|  53459|      44538|       GBT|{'maxIter': 20, '...|0.9273795712276476|0.9346535476235804|   0.9069781194559432|0.9723578266658214|0.9385307346326835|       0.9643761745240624|    0.8824013157894737|0.9215693929338279| 0.9356771469900028|0.9273795712276476|0.9300500637832557|0.9310782531133144|   15337|   11803|     436|    1573|14.746891260147095|   cols_set_1|
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|            3|  52952|      44538|       GBT|{'maxIter': 20, '...|0.9301336080516135|0.9399085682560679|   0.9082362679595577| 0.976417493007882|0.9410935824781742|        0.969542730481898|     0.883849723095345| 0.924715186156677| 0.9388894992207278|0.9301336080516136|0.9329043843174256|0.9339038977108682|   15361|   11810|     371|    1552| 14.39287257194519|   cols_set_1|
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|            4|  52087|      44538|       GBT|{'maxIter': 20, '...|0.9293512647327298| 0.939192895222293|   0.9067024128686327|0.9755769230769231|0.9398795738767949|       0.9688062878663828|    0.8831256063885364|0.9239839144184593| 0.9377543503675078|0.9293512647327298|0.9319317441476271|0.9328597537846133|   15219|   11833|     381|    1566|14.132079839706421|   cols_set_1|
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|            5|  52315|      44538|       GBT|{'maxIter': 20, '...| 0.928657239084998|0.9390928058990542|   0.9050296034926141|0.9755044156513891|0.9389464540547248|       0.9689237814851162|    0.8818100625186067|0.9233167082294265| 0.9369766924888652|0.9286572390849979|0.9311315811420756|0.9320183771460154|   15133|   11848|     380|    1588|13.945234537124634|   cols_set_1|
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|            6|  53153|      44538|       GBT|{'maxIter': 20, '...| 0.927832408588078| 0.937254777459691|    0.906329997672795|0.9753318307037315|0.9395657418576598|       0.9678051969276026|    0.8803329864724245|0.9219990658570761| 0.9370675973001987| 0.927832408588078| 0.930782403857368|0.9318969618704547|   15578|   11844|     394|    1610|13.710296630859375|   cols_set_1|
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|            7|  53255|      44538|       GBT|{'maxIter': 20, '...|0.9295980248695853|0.9353450716027176|   0.9115618424129063|0.9727420159680639|0.9411587205793603|       0.9643236182545514|     0.886454033771107|0.9237506842887309| 0.9379427303337289|0.9295980248695854|0.9324547024340456|0.9335763191061757|   15595|   11812|     437|    1513|13.495286226272583|   cols_set_1|
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|            8|  53062|      44538|       GBT|{'maxIter': 20, '...|0.9303589786733627|0.9377868759745177|   0.9111729576158173|0.9748759305210918|0.9419486318817993|       0.9670544212153258|    0.8858420268256334|0.9246684556450043| 0.9391136894155716|0.9303589786733626|0.9333085437634019| 0.934427894380501|   15715|   11888|     405|    1532|13.984312057495117|   cols_set_1|
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|            9|  53148|      44538|       GBT|{'maxIter': 20, '...|0.9280652856773074|0.9344295459777177|   0.9101571527617287|0.9734890619206525|0.9407584353538369|       0.9646156384031672|    0.8826415094339622|0.9218097264916844|  0.937386395582448|0.9280652856773074|0.9312840809227606|0.9325903778200598|   15753|   11695|     429|    1555| 13.43479871749878|   cols_set_1|
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|           10|  53539|      44538|       GBT|{'maxIter': 20, '...|0.9287793526524283|0.9371197362727093|   0.9091541135573581|0.9755066517468606|0.9411623583038445|       0.9674917491749175|    0.8820520535579961|0.9227984575430865| 0.9383229313661379|0.9287793526524284|0.9319804079234655|0.9332198774676651|   15692|   11726|     394|    1568|13.889158725738525|   cols_set_1|
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|           11|  53003|      44538|       GBT|{'maxIter': 20, '...|0.9271760478920099|0.9369731462021026|   0.9054781049343438|0.9755687129947024| 0.939217568702748|       0.9679686223239091|    0.8787833827893176|0.9212224900847655| 0.9367233636291264|0.9271760478920099|0.9302200293937568|0.9313801862828112|   15653|   11846|     392|    1634|13.569412469863892|   cols_set_1|
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|           12|  51577|      44538|       GBT|{'maxIter': 20, '...|0.9318455796910619|0.9411241370871022|   0.9089810226036504|0.9752301906367526|0.9409409409409409|       0.9691387946356439|    0.8884609687453711| 0.927047913446677| 0.9390599086196472|0.9318455796910619| 0.933994427193809| 0.934725487484442|   15040|   11996|     382|    1506|13.570613145828247|   cols_set_1|
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|           13|  52510|      44538|       GBT|{'maxIter': 20, '...|0.9280354288084864|0.9345236052949454|   0.9085141705205739|0.9720248667850799|0.9391970579221575|       0.9638672675133142|     0.884045990831893|0.9222326748196926| 0.9361907190169441|0.9280354288084864| 0.930714866370925|0.9317532936603488|   15323|   11764|     441|    1543|13.417893409729004|   cols_set_1|
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|           14|  52884|      44538|       GBT|{'maxIter': 20, '...|0.9276039173436318|0.9344233142168317|   0.9083382266588373|0.9727707206640674|0.9394509899186202|       0.9643621399176955|    0.8824371140231962| 0.921582507472078| 0.9363501832882664|0.9276039173436319|0.9305167486953492|0.9316655243317341|   15469|   11717|     433|    1561|13.591392040252686|   cols_set_1|
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|           15|  52068|      44538|       GBT|{'maxIter': 20, '...|0.9284698542831573|0.9379388385350883|   0.9063135238550759|0.9750434167363479|0.9394230471291792|       0.9679047067582099|    0.8818962918299669|0.9229009740899949| 0.9371091153066429|0.9284698542831573| 0.931162010609587|0.9321533923303835|   15159|   11701|     388|    1567|13.594298839569092|   cols_set_1|
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|           16|  52872|      44538|       GBT|{'maxIter': 20, '...|0.9274718941776714|0.9352405093815105|   0.9061463761250592|0.9723598932520016|0.9380861889290749|       0.9647744756660458|     0.882583895103341|0.9218508201795109| 0.9354604258955526|0.9274718941776713|0.9299685045542929|0.9309094640352977|   15303|   11914|     435|    1585|13.733888387680054|   cols_set_1|
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|           17|  52377|      44538|       GBT|{'maxIter': 20, '...|0.9265935366988254|0.9345100303063565|   0.9054125998225377|0.9724887222822288|0.9377527263815709|        0.964615510337501|    0.8806983511154219|0.9207488299531982| 0.9350140550800194|0.9265935366988254|0.9292507781673846| 0.930272458993892|   15306|   11804|     433|    1599| 13.80407428741455|   cols_set_1|
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|           18|  52304|      44538|       GBT|{'maxIter': 20, '...|0.9294047444023905| 0.937773103671223|   0.9086812144212524|0.9747471534889638|0.9405554703084241|       0.9672981878088962|    0.8840623353158172|0.9238091491956103| 0.9379897011150743|0.9294047444023905|0.9321823097520172|0.9332161081230175|   15324|   11743|     397|    1540|16.578757524490356|   cols_set_1|
# |             ds-2|       03-STRSAMP-AG|gs://ai-covid19-d...|           19|  52485|      44538|       GBT|{'maxIter': 20, '...|0.9286723923270556|0.9375429235068934|   0.9073388565720665|0.9748121961997349|0.9398660986001216|       0.9674205927982363|    0.8825325884543762| 0.923028980990963| 0.9373797246851514|0.9286723923270556|0.9314475397955423|0.9324813777079205|   15442|   11848|     399|    1577|13.225107669830322|   cols_set_1|
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# only showing top 20 rows
