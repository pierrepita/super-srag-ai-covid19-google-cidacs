# %%
import pandas as pd
import pyspark.sql.functions as F
from datetime import datetime
from pyspark.sql.types import *
from pyspark import StorageLevel

import numpy as np
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", 1000)
pd.set_option("mode.chained_assignment", None)

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import GBTClassifier
from pyspark.ml.feature import IndexToString, StringIndexer, VectorIndexer
# from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import OneHotEncoderEstimator, StringIndexer, VectorAssembler

from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

from pyspark.sql import Row
from pyspark.ml.linalg import Vectors

# %%
# !pip install scikit-plot

# %%
import sklearn
import scikitplot as skplt
from sklearn.metrics import classification_report, confusion_matrix, precision_score

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
result_schema = StructType([
                    StructField('experiment_filter', StringType(), True),
                    StructField('undersampling_method', StringType(), True),
                    StructField('undersampling_column', StringType(), True),
                    StructField('filename', StringType(), True),
                    StructField('experiment_id', StringType(), True),
                    StructField('n_covid', IntegerType(), True),
                    StructField('n_not_covid', IntegerType(), True),
                    StructField('model_name', StringType(), True),
                    StructField('model_seed', StringType(), True),
                    StructField('model_maxIter', IntegerType(), True),
                    StructField('model_maxDepth', IntegerType(), True),
                    StructField('model_maxBins', IntegerType(), True),
                    StructField('model_minInstancesPerNode', IntegerType(), True),
                    StructField('model_minInfoGain', FloatType(), True),
                    StructField('model_featureSubsetStrategy', StringType(), True),
                    StructField('model_n_estimators', IntegerType(), True),
                    StructField('model_learning_rate', FloatType(), True),
                    StructField('model_impurity', StringType(), True),
                    StructField('model_AUC_ROC', StringType(), True),
                    StructField('model_AUC_PR', StringType(), True),
                    StructField('model_covid_precision', StringType(), True),
                    StructField('model_covid_recall', StringType(), True),
                    StructField('model_covid_f1', StringType(), True),
                    StructField('model_not_covid_precision', StringType(), True),
                    StructField('model_not_covid_recall', StringType(), True),
                    StructField('model_not_covid_f1', StringType(), True),
                    StructField('model_avg_precision', StringType(), True),
                    StructField('model_avg_recall', StringType(), True),
                    StructField('model_avg_f1', StringType(), True),
                    StructField('model_avg_acc', StringType(), True),
                    StructField('model_TP', StringType(), True),
                    StructField('model_TN', StringType(), True),
                    StructField('model_FN', StringType(), True),
                    StructField('model_FP', StringType(), True),
                    StructField('model_time_exec', StringType(), True),
                    StructField('model_col_set', StringType(), True)
                          ])

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# undersamp_col = ['03-STRSAMP-AG', '04-STRSAMP-EW'] 
# dfs = ['ds-1', 'ds-2', 'ds-3']
# cols_sets = ['cols_set_1', 'cols_set_2', 'cols_set_3']

undersamp_col = ['02-KMODES']
dfs = ['ds-1']
cols_sets = ['cols_set_3']

# %%
# lists of params
model_maxIter = [20, 50, 100] 
model_maxDepth = [3, 5, 7] 
model_maxBins = [32, 64] 
# model_learningRate = [0.01, 0.1, 0.5]
# model_loss = ['logLoss', 'leastSquaresError', 'leastAbsoluteError']



list_of_param_dicts = []

for maxIter in model_maxIter:
    for maxDepth in model_maxDepth:
        for maxBins in model_maxBins: 
            params_dict = {}
            params_dict['maxIter'] = maxIter
            params_dict['maxDepth'] = maxDepth
            params_dict['maxBins'] = maxBins
            list_of_param_dicts.append(params_dict)

            

print("There is {} set of params.".format(len(list_of_param_dicts)))
# list_of_param_dicts
# Out:
# There is 18 set of params.

# %%
prefix = 'gs://ai-covid19-datalake/trusted/experiment_map/'

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# filename = 'gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment0.parquet'
# df = spark.read.parquet(filename)
# df.limit(2).toPandas()

# %%
# params_dict = {'maxIter': 100,
#                'maxDepth': 3,
#                'maxBins': 32,
#                'learningRate': 0.5,
#                'loss': 'leastAbsoluteError'}
# cols = 'cols_set_1'
# experiment_filter = 'ds-1'
# undersampling_method = '03-STRSAMP-AG', 
# experiment_id = 0

# %%
# run_gbt(df, params_dict, cols, filename, experiment_filter, undersampling_method, experiment_id)

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
def run_gbt(exp_df, params_dict, cols, filename, experiment_filter, 
            undersampling_method, experiment_id):
    import time
    start_time = time.time()
    
    n_covid = exp_df.filter(F.col('CLASSI_FIN') == 1.0).count()
    n_not_covid = exp_df.filter(F.col('CLASSI_FIN') == 0.0).count()
    
    
    id_cols = ['NU_NOTIFIC', 'CLASSI_FIN']

    labelIndexer = StringIndexer(inputCol="CLASSI_FIN", outputCol="indexedLabel").fit(exp_df)    
    
    input_cols = [x for x in exp_df.columns if x not in id_cols]
    assembler = VectorAssembler(inputCols = input_cols, outputCol= 'features')
    exp_df = assembler.transform(exp_df)
    
    # Automatically identify categorical features, and index them.
    # Set maxCategories so features with > 4 distinct values are treated as continuous.
    featureIndexer = VectorIndexer(inputCol="features", outputCol="indexedFeatures", maxCategories=30).fit(exp_df)
    
    # Split the data into training and test sets (30% held out for testing)
    (trainingData, testData) = exp_df.randomSplit([0.7, 0.3])
    trainingData = trainingData.persist(StorageLevel.MEMORY_ONLY)
    testData = testData.persist(StorageLevel.MEMORY_ONLY)
    
    # Train a RandomForest model.
    gbt = GBTClassifier(labelCol = "indexedLabel", featuresCol = "indexedFeatures",
                       maxIter = params_dict['maxIter'],
                       maxDepth = params_dict['maxDepth'],
                       maxBins = params_dict['maxBins'])
    
    # Convert indexed labels back to original labels.
    labelConverter = IndexToString(inputCol="prediction", outputCol="predictedLabel",
                               labels=labelIndexer.labels)

    # Chain indexers and forest in a Pipeline
    pipeline = Pipeline(stages=[labelIndexer, featureIndexer, gbt, labelConverter])

    # Train model.  This also runs the indexers.
    model = pipeline.fit(trainingData)
    
    # Make predictions.
    predictions = model.transform(testData)    
    
    
    pred = predictions.select(['CLASSI_FIN', 'predictedLabel'])\
                  .withColumn('predictedLabel', F.col('predictedLabel').cast('double'))\
                  .withColumn('predictedLabel', F.when(F.col('predictedLabel') == 1.0, 'covid').otherwise('n-covid'))\
                  .withColumn('CLASSI_FIN', F.when(F.col('CLASSI_FIN') == 1.0, 'covid').otherwise('n-covid'))\
                  .toPandas()

    y_true = pred['CLASSI_FIN'].tolist()
    y_pred = pred['predictedLabel'].tolist()
    
    report = classification_report(y_true, y_pred, output_dict=True)
    
    
    evaluator_ROC = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderROC")
    accuracy_ROC = evaluator_ROC.evaluate(predictions)


    
    evaluator_PR = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderPR")
    accuracy_PR = evaluator_PR.evaluate(predictions)
    
    conf_matrix = confusion_matrix(y_true, y_pred)

    result_dict = {}
    
    result_dict['experiment_filter'] = experiment_filter
    result_dict['undersampling_method'] = undersampling_method
    result_dict['filename'] = filename
    result_dict['experiment_id'] = experiment_id
    result_dict['n_covid'] = n_covid
    result_dict['n_not_covid'] = n_not_covid
    result_dict['model_name'] = 'GBT'
    result_dict['params'] = params_dict
    result_dict['model_AUC_ROC'] = accuracy_ROC
    result_dict['model_AUC_PR'] = accuracy_PR
    result_dict['model_covid_precision'] = report['covid']['precision']
    result_dict['model_covid_recall'] = report['covid']['recall']
    result_dict['model_covid_f1'] = report['covid']['f1-score']
    result_dict['model_not_covid_precision'] = report['n-covid']['precision']
    result_dict['model_not_covid_recall'] = report['n-covid']['recall']
    result_dict['model_not_covid_f1'] = report['n-covid']['f1-score']
    result_dict['model_avg_precision'] = report['macro avg']['precision']
    result_dict['model_avg_recall'] = report['macro avg']['recall']
    result_dict['model_avg_f1'] = report['macro avg']['f1-score']
    result_dict['model_avg_acc'] = report['accuracy']
    result_dict['model_TP'] = conf_matrix[0][0]
    result_dict['model_TN'] = conf_matrix[1][1]
    result_dict['model_FN'] = conf_matrix[0][1]
    result_dict['model_FP'] = conf_matrix[1][0]
    result_dict['model_time_exec'] = time.time() - start_time
    result_dict['model_col_set'] = cols
    
    return result_dict

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %% [markdown]
# # Running GBT on 10 samples for each experiment
# ### 3x col sets -> ['cols_set_1', 'cols_set_2', 'cols_set_3']
# ### 3x model_maxIter -> [100, 200, 300]
# ### 3x model_maxDepth -> [5, 10, 15]
# ### 3x model_maxBins -> [16, 32, 64]
# Total: 10 * 3 * 3 * 3 * 3 = 810

# %%
experiments = []

# %% [markdown]
# ### Datasets: strat_samp_lab_agegrp

# %%
for uc in undersamp_col: 
    for ds in dfs:
        for col_set in cols_sets:
            for params_dict in list_of_param_dicts: 
                for id_exp in range(50):
                    filename = prefix + uc + '/' + ds + '/' + col_set + '/' + 'experiment' + str(id_exp) + '.parquet'
                    exp_dataframe = spark.read.parquet(filename)
#                     if 'SG_UF_NOT' in exp_dataframe.columns:
#                         exp_dataframe = exp_dataframe.withColumn('SG_UF_NOT', F.col('SG_UF_NOT').cast('float'))
                    print('read {}'.format(filename))
                    
                    undersampling_method = uc
                    experiment_filter = ds
                    experiment_id = id_exp

                    try:                     
                        model = run_gbt(exp_dataframe, params_dict, col_set, filename, experiment_filter, undersampling_method, experiment_id)
                        experiments.append(model)

                        print("Parameters ==> {}\n Results: \n AUC_PR: {} \n Precision: {} \n Time: {}".format(str(params_dict), str(model['model_AUC_PR']), str(model['model_avg_precision']), str(model['model_time_exec'])))
                        print('=========================== \n')
                    except:
                        print('=========== W A R N I N G =========== \n')
                        print('Something wrong with the exp: {}, {}, {}'.format(filename, params_dict, col_set))
# Out:
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9140109015244392
#  Precision: 0.9234257379001578
#  Time: 34.41333293914795
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9180455554404899
#  Precision: 0.9236628120847448
#  Time: 22.87675380706787
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9220409904356249
#  Precision: 0.925896171996587
#  Time: 26.08534860610962
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9198730807354483
#  Precision: 0.9236772005891423
#  Time: 21.89140248298645
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9203189030692257
#  Precision: 0.9238441706055394
#  Time: 21.902908325195312
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9181088547161143
#  Precision: 0.9184813294993575
#  Time: 22.280579328536987
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9288339603436868
#  Precision: 0.9216645777203473
#  Time: 21.965956211090088
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9136682311159114
#  Precision: 0.9240147455206652
#  Time: 24.345571279525757
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9226173924567878
#  Precision: 0.9227948040267578
#  Time: 22.351064682006836
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9224540251027746
#  Precision: 0.9282855638932923
#  Time: 22.225757122039795
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9237005821223976
#  Precision: 0.9235239848613657
#  Time: 22.290780782699585
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9177292230803724
#  Precision: 0.9237063165172299
#  Time: 22.026009559631348
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9204407387610193
#  Precision: 0.9181495551447469
#  Time: 22.047720193862915
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9184635036621258
#  Precision: 0.923863428021384
#  Time: 22.41209840774536
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9262697872266363
#  Precision: 0.9235273671149451
#  Time: 22.196207284927368
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9135985095550664
#  Precision: 0.9237461262025541
#  Time: 22.683027267456055
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.918368366882778
#  Precision: 0.9269586899634781
#  Time: 23.730854034423828
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9243613824657592
#  Precision: 0.9205126710189713
#  Time: 26.047561407089233
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9246780504361084
#  Precision: 0.9233181111315233
#  Time: 22.157198905944824
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9192274788719579
#  Precision: 0.9226545851577028
#  Time: 22.69204092025757
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9221144289361071
#  Precision: 0.9255064751810944
#  Time: 24.58328080177307
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.915720547821654
#  Precision: 0.9236199104730461
#  Time: 23.439741373062134
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9259734625393102
#  Precision: 0.9222808251899182
#  Time: 22.032835245132446
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9148278149170921
#  Precision: 0.9260833671746425
#  Time: 21.988967180252075
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9220673629837587
#  Precision: 0.920067695647454
#  Time: 21.646461486816406
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9194004606099212
#  Precision: 0.9270727996460464
#  Time: 22.564269542694092
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8795890836213331
#  Precision: 0.9218229326401111
#  Time: 23.182324409484863
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9224515432236429
#  Precision: 0.9205579602649927
#  Time: 24.290740489959717
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9137145353161454
#  Precision: 0.9248470405940143
#  Time: 23.58733081817627
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9255635914914881
#  Precision: 0.9209468464632742
#  Time: 23.565874814987183
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9257983182448587
#  Precision: 0.9233900654140089
#  Time: 23.565516233444214
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9158180984582804
#  Precision: 0.9244842499249035
#  Time: 24.397632122039795
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9256414862080057
#  Precision: 0.9200681051149944
#  Time: 22.752475023269653
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9207230215732342
#  Precision: 0.9239272090982729
#  Time: 24.430417776107788
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9185707833563576
#  Precision: 0.9233947546565063
#  Time: 23.05080270767212
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9246412058135387
#  Precision: 0.9230024405143409
#  Time: 22.50872302055359
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9188054379475318
#  Precision: 0.9251408204891175
#  Time: 23.932132720947266
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9175453575028995
#  Precision: 0.9216305283493531
#  Time: 22.211204767227173
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9210371071432973
#  Precision: 0.9182520694482572
#  Time: 22.95651364326477
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9188502299987654
#  Precision: 0.9288335506712053
#  Time: 22.31424355506897
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9253872936446838
#  Precision: 0.9225953302403571
#  Time: 24.188474416732788
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9178853111631672
#  Precision: 0.9273327326211223
#  Time: 22.644212007522583
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9172919000721014
#  Precision: 0.924943256356114
#  Time: 23.326011657714844
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9222257872264888
#  Precision: 0.9223173918852778
#  Time: 21.903569221496582
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9194771655573052
#  Precision: 0.9199092473640267
#  Time: 22.315626859664917
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9211484335986113
#  Precision: 0.9263856345491501
#  Time: 22.37312912940979
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9250043616273766
#  Precision: 0.925331665538963
#  Time: 24.93389582633972
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9258148516820175
#  Precision: 0.9232089333104331
#  Time: 21.6789128780365
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.924282705429515
#  Precision: 0.920290122839584
#  Time: 22.493815422058105
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9229008057200017
#  Precision: 0.9215052943888302
#  Time: 23.21707510948181
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9171736840239239
#  Precision: 0.9249447347799309
#  Time: 25.05505657196045
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9185745672069554
#  Precision: 0.9245269286754003
#  Time: 22.619932889938354
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9204308015383698
#  Precision: 0.9243481097680051
#  Time: 22.851480960845947
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9182673353708858
#  Precision: 0.9221397472283803
#  Time: 22.372370719909668
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9229303494726713
#  Precision: 0.9249238779436675
#  Time: 22.301929235458374
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9237725502929388
#  Precision: 0.9212745712660861
#  Time: 22.825724601745605
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9242539598913656
#  Precision: 0.9205612172657796
#  Time: 22.60583806037903
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.920103472493104
#  Precision: 0.927379942371924
#  Time: 23.181333541870117
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9236406985467988
#  Precision: 0.9237634997883509
#  Time: 23.55504059791565
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9188713632756754
#  Precision: 0.9246232195022076
#  Time: 26.353713274002075
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.924251106313679
#  Precision: 0.9238153890290173
#  Time: 24.60942268371582
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9173580892942642
#  Precision: 0.9220125924164805
#  Time: 23.375415802001953
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9297124904823154
#  Precision: 0.9244509175005642
#  Time: 23.474202632904053
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9179868343547984
#  Precision: 0.9245869819793142
#  Time: 24.332297563552856
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9210211652184105
#  Precision: 0.9204547421016644
#  Time: 24.067328691482544
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9180963213704064
#  Precision: 0.9248161333015956
#  Time: 24.795239448547363
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9176127724082521
#  Precision: 0.9240420963586387
#  Time: 23.466412782669067
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9243753719797903
#  Precision: 0.9212835090497322
#  Time: 23.18373394012451
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9195631373661265
#  Precision: 0.9209424848579235
#  Time: 23.364704608917236
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9197559803024
#  Precision: 0.9218489645849635
#  Time: 22.835861444473267
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9172879220462
#  Precision: 0.9242649564253826
#  Time: 24.661999464035034
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9186306344225564
#  Precision: 0.9249650445138679
#  Time: 23.070756673812866
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9218030511301099
#  Precision: 0.9207580889235787
#  Time: 23.88228130340576
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9147891526460159
#  Precision: 0.9264407729401909
#  Time: 23.415563821792603
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9255853497067023
#  Precision: 0.9228699926138431
#  Time: 23.309386491775513
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9150200848506445
#  Precision: 0.9231955538534486
#  Time: 22.365296363830566
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8817817774331033
#  Precision: 0.9222590446516288
#  Time: 22.68685507774353
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9232561952732034
#  Precision: 0.9221592843297645
#  Time: 22.792535305023193
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9132055229331314
#  Precision: 0.9229402211090849
#  Time: 22.630903720855713
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9218518002770967
#  Precision: 0.9196856807663112
#  Time: 22.637415170669556
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.92459784151656
#  Precision: 0.9227083969990094
#  Time: 23.67673397064209
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9161179565963061
#  Precision: 0.9247931681012582
#  Time: 22.40133047103882
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9264403617315398
#  Precision: 0.9230151369870875
#  Time: 22.933652877807617
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9208750540494066
#  Precision: 0.923457562069504
#  Time: 22.337289571762085
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9229222825563747
#  Precision: 0.9247228904966285
#  Time: 22.449858903884888
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9193461702910023
#  Precision: 0.921651361765244
#  Time: 22.309786558151245
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9195122706750098
#  Precision: 0.9235624176035334
#  Time: 23.022035837173462
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9214852984710085
#  Precision: 0.925178568903569
#  Time: 22.022929668426514
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9268243194945319
#  Precision: 0.922678016932319
#  Time: 22.712607622146606
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9157364693982226
#  Precision: 0.9259854337820266
#  Time: 23.146303415298462
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9244783313347331
#  Precision: 0.9201559605404614
#  Time: 22.153550624847412
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9176489788145552
#  Precision: 0.9278816606989256
#  Time: 22.81847095489502
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9164646103068517
#  Precision: 0.9245320297028649
#  Time: 22.503130674362183
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9221165201828335
#  Precision: 0.922785717930618
#  Time: 23.246213674545288
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9220734791974617
#  Precision: 0.9244517033352261
#  Time: 23.96630311012268
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9203190111126462
#  Precision: 0.9252319980738365
#  Time: 24.812870264053345
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9221641414559928
#  Precision: 0.9224029855237212
#  Time: 24.3229763507843
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9268106603534917
#  Precision: 0.9221033036587648
#  Time: 24.44970154762268
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9215195217133229
#  Precision: 0.9206022344810568
#  Time: 24.88035774230957
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9219604504879415
#  Precision: 0.922872502200482
#  Time: 24.407188177108765
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9160791203639498
#  Precision: 0.9276304428904429
#  Time: 27.165554761886597
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.92313731358941
#  Precision: 0.9283453486865827
#  Time: 31.478975534439087
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9243113535573044
#  Precision: 0.9272349222651658
#  Time: 26.947043657302856
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9274332502885596
#  Precision: 0.9294347614950076
#  Time: 26.52897572517395
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9215589810896504
#  Precision: 0.9242898040533631
#  Time: 25.954699993133545
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9239622238439311
#  Precision: 0.9237710940942111
#  Time: 26.728065490722656
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9294798894134317
#  Precision: 0.9240018401954352
#  Time: 26.562477350234985
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9164791356377211
#  Precision: 0.9280136378747568
#  Time: 26.81804132461548
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9225974679063992
#  Precision: 0.9243455738736188
#  Time: 27.014354944229126
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9180119835574743
#  Precision: 0.9261882755628608
#  Time: 27.64933943748474
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9219574766422187
#  Precision: 0.9258081442799534
#  Time: 26.479559421539307
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9215419677111626
#  Precision: 0.926766981879592
#  Time: 26.171521425247192
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9275033385882454
#  Precision: 0.9248947850959501
#  Time: 25.465052604675293
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9216118997662877
#  Precision: 0.9279808736400612
#  Time: 26.40894842147827
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9268913134875217
#  Precision: 0.9253152064770591
#  Time: 25.586710929870605
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9162478927421853
#  Precision: 0.9268507880094394
#  Time: 26.36812663078308
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.918990408352943
#  Precision: 0.9289985106892292
#  Time: 26.09405755996704
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9282069434648734
#  Precision: 0.9225238442472328
#  Time: 25.602651357650757
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9236335905412605
#  Precision: 0.9257596133482902
#  Time: 26.25070333480835
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_3/experiment19.parquet

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
for i in range(len(experiments)):
    for d in list(experiments[i].keys()):
        experiments[i][d] = str(experiments[i][d])

# %%
# experiments

# %%
cols = ['experiment_filter', 'undersampling_method', 'filename', 'experiment_id', 'n_covid', 'n_not_covid', 'model_name', 'params', 'model_AUC_ROC', 'model_AUC_PR', 'model_covid_precision', 'model_covid_recall', 'model_covid_f1', 'model_not_covid_precision', 'model_not_covid_recall', 'model_not_covid_f1', 'model_avg_precision', 'model_avg_recall', 'model_avg_f1', 'model_avg_acc', 'model_TP', 'model_TN', 'model_FN', 'model_FP', 'model_time_exec', 'model_col_set']

# %%
intermed_results = spark.createDataFrame(data=experiments).select(cols)
intermed_results.toPandas()

# %%
intermed_results.write.parquet('gs://ai-covid19-datalake/trusted/intermed_results/KMODES/GBT_experiments-kmodes-ds1-cs3.parquet', mode='overwrite')

# %%
print('finished')

# %%
intermed_results.show()
