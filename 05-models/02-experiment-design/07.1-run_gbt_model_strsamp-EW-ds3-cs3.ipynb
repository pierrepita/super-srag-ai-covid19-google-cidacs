# %%
import pandas as pd
import pyspark.sql.functions as F
from datetime import datetime
from pyspark.sql.types import *
from pyspark import StorageLevel

import numpy as np
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", 1000)
pd.set_option("mode.chained_assignment", None)

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import GBTClassifier
from pyspark.ml.feature import IndexToString, StringIndexer, VectorIndexer
# from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import OneHotEncoderEstimator, StringIndexer, VectorAssembler

from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

from pyspark.sql import Row
from pyspark.ml.linalg import Vectors

# %%
# !pip install scikit-plot

# %%
import sklearn
import scikitplot as skplt
from sklearn.metrics import classification_report, confusion_matrix, precision_score

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
result_schema = StructType([
                    StructField('experiment_filter', StringType(), True),
                    StructField('undersampling_method', StringType(), True),
                    StructField('undersampling_column', StringType(), True),
                    StructField('filename', StringType(), True),
                    StructField('experiment_id', StringType(), True),
                    StructField('n_covid', IntegerType(), True),
                    StructField('n_not_covid', IntegerType(), True),
                    StructField('model_name', StringType(), True),
                    StructField('model_seed', StringType(), True),
                    StructField('model_maxIter', IntegerType(), True),
                    StructField('model_maxDepth', IntegerType(), True),
                    StructField('model_maxBins', IntegerType(), True),
                    StructField('model_minInstancesPerNode', IntegerType(), True),
                    StructField('model_minInfoGain', FloatType(), True),
                    StructField('model_featureSubsetStrategy', StringType(), True),
                    StructField('model_n_estimators', IntegerType(), True),
                    StructField('model_learning_rate', FloatType(), True),
                    StructField('model_impurity', StringType(), True),
                    StructField('model_AUC_ROC', StringType(), True),
                    StructField('model_AUC_PR', StringType(), True),
                    StructField('model_covid_precision', StringType(), True),
                    StructField('model_covid_recall', StringType(), True),
                    StructField('model_covid_f1', StringType(), True),
                    StructField('model_not_covid_precision', StringType(), True),
                    StructField('model_not_covid_recall', StringType(), True),
                    StructField('model_not_covid_f1', StringType(), True),
                    StructField('model_avg_precision', StringType(), True),
                    StructField('model_avg_recall', StringType(), True),
                    StructField('model_avg_f1', StringType(), True),
                    StructField('model_avg_acc', StringType(), True),
                    StructField('model_TP', StringType(), True),
                    StructField('model_TN', StringType(), True),
                    StructField('model_FN', StringType(), True),
                    StructField('model_FP', StringType(), True),
                    StructField('model_time_exec', StringType(), True),
                    StructField('model_col_set', StringType(), True)
                          ])

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# undersamp_col = ['03-STRSAMP-AG', '04-STRSAMP-EW'] 
# dfs = ['ds-1', 'ds-2', 'ds-3']
# cols_sets = ['cols_set_1', 'cols_set_2', 'cols_set_3']

undersamp_col = ['04-STRSAMP-EW']
dfs = ['ds-3']
cols_sets = ['cols_set_3']

# %%
# lists of params
model_maxIter = [20, 50, 100] 
model_maxDepth = [3, 5, 7] 
model_maxBins = [32, 64] 
# model_learningRate = [0.01, 0.1, 0.5]
# model_loss = ['logLoss', 'leastSquaresError', 'leastAbsoluteError']



list_of_param_dicts = []

for maxIter in model_maxIter:
    for maxDepth in model_maxDepth:
        for maxBins in model_maxBins: 
            params_dict = {}
            params_dict['maxIter'] = maxIter
            params_dict['maxDepth'] = maxDepth
            params_dict['maxBins'] = maxBins
            list_of_param_dicts.append(params_dict)

print("There is {} set of params.".format(len(list_of_param_dicts)))
# list_of_param_dicts
# Out:
# There is 18 set of params.

# %%
prefix = 'gs://ai-covid19-datalake/trusted/experiment_map/'

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# filename = 'gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment0.parquet'
# df = spark.read.parquet(filename)
# df.limit(2).toPandas()

# %%
# params_dict = {'maxIter': 100,
#                'maxDepth': 3,
#                'maxBins': 32,
#                'learningRate': 0.5,
#                'loss': 'leastAbsoluteError'}
# cols = 'cols_set_1'
# experiment_filter = 'ds-1'
# undersampling_method = '03-STRSAMP-AG', 
# experiment_id = 0

# %%
# run_gbt(df, params_dict, cols, filename, experiment_filter, undersampling_method, experiment_id)

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
def run_gbt(exp_df, params_dict, cols, filename, experiment_filter, 
            undersampling_method, experiment_id):
    import time
    start_time = time.time()
    
    n_covid = exp_df.filter(F.col('CLASSI_FIN') == 1.0).count()
    n_not_covid = exp_df.filter(F.col('CLASSI_FIN') == 0.0).count()
    
    
    id_cols = ['NU_NOTIFIC', 'CLASSI_FIN']

    labelIndexer = StringIndexer(inputCol="CLASSI_FIN", outputCol="indexedLabel").fit(exp_df)    
    
    input_cols = [x for x in exp_df.columns if x not in id_cols]
    assembler = VectorAssembler(inputCols = input_cols, outputCol= 'features')
    exp_df = assembler.transform(exp_df)
    
    # Automatically identify categorical features, and index them.
    # Set maxCategories so features with > 4 distinct values are treated as continuous.
    featureIndexer = VectorIndexer(inputCol="features", outputCol="indexedFeatures", maxCategories=30).fit(exp_df)
    
    # Split the data into training and test sets (30% held out for testing)
    (trainingData, testData) = exp_df.randomSplit([0.7, 0.3])
    trainingData = trainingData.persist(StorageLevel.MEMORY_ONLY)
    testData = testData.persist(StorageLevel.MEMORY_ONLY)
    
    # Train a RandomForest model.
    gbt = GBTClassifier(labelCol = "indexedLabel", featuresCol = "indexedFeatures",
                       maxIter = params_dict['maxIter'],
                       maxDepth = params_dict['maxDepth'],
                       maxBins = params_dict['maxBins'])
    
    # Convert indexed labels back to original labels.
    labelConverter = IndexToString(inputCol="prediction", outputCol="predictedLabel",
                               labels=labelIndexer.labels)

    # Chain indexers and forest in a Pipeline
    pipeline = Pipeline(stages=[labelIndexer, featureIndexer, gbt, labelConverter])

    # Train model.  This also runs the indexers.
    model = pipeline.fit(trainingData)
    
    # Make predictions.
    predictions = model.transform(testData)    
    
    
    pred = predictions.select(['CLASSI_FIN', 'predictedLabel'])\
                  .withColumn('predictedLabel', F.col('predictedLabel').cast('double'))\
                  .withColumn('predictedLabel', F.when(F.col('predictedLabel') == 1.0, 'covid').otherwise('n-covid'))\
                  .withColumn('CLASSI_FIN', F.when(F.col('CLASSI_FIN') == 1.0, 'covid').otherwise('n-covid'))\
                  .toPandas()

    y_true = pred['CLASSI_FIN'].tolist()
    y_pred = pred['predictedLabel'].tolist()
    
    report = classification_report(y_true, y_pred, output_dict=True)
    
    
    evaluator_ROC = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderROC")
    accuracy_ROC = evaluator_ROC.evaluate(predictions)


    
    evaluator_PR = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderPR")
    accuracy_PR = evaluator_PR.evaluate(predictions)
    
    conf_matrix = confusion_matrix(y_true, y_pred)

    result_dict = {}
    
    result_dict['experiment_filter'] = experiment_filter
    result_dict['undersampling_method'] = undersampling_method
    result_dict['filename'] = filename
    result_dict['experiment_id'] = experiment_id
    result_dict['n_covid'] = n_covid
    result_dict['n_not_covid'] = n_not_covid
    result_dict['model_name'] = 'GBT'
    result_dict['params'] = params_dict
    result_dict['model_AUC_ROC'] = accuracy_ROC
    result_dict['model_AUC_PR'] = accuracy_PR
    result_dict['model_covid_precision'] = report['covid']['precision']
    result_dict['model_covid_recall'] = report['covid']['recall']
    result_dict['model_covid_f1'] = report['covid']['f1-score']
    result_dict['model_not_covid_precision'] = report['n-covid']['precision']
    result_dict['model_not_covid_recall'] = report['n-covid']['recall']
    result_dict['model_not_covid_f1'] = report['n-covid']['f1-score']
    result_dict['model_avg_precision'] = report['macro avg']['precision']
    result_dict['model_avg_recall'] = report['macro avg']['recall']
    result_dict['model_avg_f1'] = report['macro avg']['f1-score']
    result_dict['model_avg_acc'] = report['accuracy']
    result_dict['model_TP'] = conf_matrix[0][0]
    result_dict['model_TN'] = conf_matrix[1][1]
    result_dict['model_FN'] = conf_matrix[0][1]
    result_dict['model_FP'] = conf_matrix[1][0]
    result_dict['model_time_exec'] = time.time() - start_time
    result_dict['model_col_set'] = cols
    
    return result_dict

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %% [markdown]
# # Running GBT on 10 samples for each experiment
# ### 3x col sets -> ['cols_set_1', 'cols_set_2', 'cols_set_3']
# ### 3x model_maxIter -> [100, 200, 300]
# ### 3x model_maxDepth -> [5, 10, 15]
# ### 3x model_maxBins -> [16, 32, 64]
# Total: 10 * 3 * 3 * 3 * 3 = 810

# %%
experiments = []

# %% [markdown]
# ### Datasets: strat_samp_lab_agegrp

# %%
for uc in undersamp_col: 
    for ds in dfs:
        for col_set in cols_sets:
            for params_dict in list_of_param_dicts: 
                for id_exp in range(50):
                    filename = prefix + uc + '/' + ds + '/' + col_set + '/' + 'experiment' + str(id_exp) + '.parquet'
                    exp_dataframe = spark.read.parquet(filename)
#                     if 'SG_UF_NOT' in exp_dataframe.columns:
#                         exp_dataframe = exp_dataframe.withColumn('SG_UF_NOT', F.col('SG_UF_NOT').cast('float'))
                    print('read {}'.format(filename))
                    
                    undersampling_method = uc
                    experiment_filter = ds
                    experiment_id = id_exp

                    try:                     
                        model = run_gbt(exp_dataframe, params_dict, col_set, filename, experiment_filter, undersampling_method, experiment_id)
                        experiments.append(model)

                        print("Parameters ==> {}\n Results: \n AUC_PR: {} \n Precision: {} \n Time: {}".format(str(params_dict), str(model['model_AUC_PR']), str(model['model_avg_precision']), str(model['model_time_exec'])))
                        print('=========================== \n')
                    except:
                        print('=========== W A R N I N G =========== \n')
                        print('Something wrong with the exp: {}, {}, {}'.format(filename, params_dict, col_set))
# Out:
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9021239493664106
#  Precision: 0.931410639915641
#  Time: 25.97623300552368
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8980083574455276
#  Precision: 0.9293055719604272
#  Time: 14.400279521942139
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9018861785596823
#  Precision: 0.9319956660832516
#  Time: 13.929572105407715
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9001049451809635
#  Precision: 0.9309592738517694
#  Time: 17.46992778778076
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9034819055784309
#  Precision: 0.931578717648876
#  Time: 13.361764669418335
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9054621633494588
#  Precision: 0.9331085491364617
#  Time: 13.389218091964722
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8980478151613618
#  Precision: 0.9291250044755368
#  Time: 13.669918775558472
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9025569112508545
#  Precision: 0.9325619410218007
#  Time: 13.389512062072754
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9016625618117056
#  Precision: 0.9306766963603617
#  Time: 13.4413321018219
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9031863391721048
#  Precision: 0.9317397323555521
#  Time: 13.495094060897827
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9047143812650135
#  Precision: 0.9326472727072502
#  Time: 13.672492027282715
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.897438644929706
#  Precision: 0.9289844539218344
#  Time: 13.389970064163208
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8990804652012104
#  Precision: 0.9284260035123673
#  Time: 13.354323148727417
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.899031300559481
#  Precision: 0.9291890944909493
#  Time: 13.336814880371094
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8987300785789571
#  Precision: 0.9301598299714258
#  Time: 13.31729245185852
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8977794915334208
#  Precision: 0.9285038351972719
#  Time: 13.148677110671997
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8986063721444422
#  Precision: 0.9289120281432719
#  Time: 13.421673774719238
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8943810258978541
#  Precision: 0.9270202630007158
#  Time: 13.781352996826172
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9009964261566108
#  Precision: 0.9292686109016178
#  Time: 13.19821834564209
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9044014713134765
#  Precision: 0.9321037103226548
#  Time: 13.218761444091797
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9001524472553738
#  Precision: 0.9304997730407643
#  Time: 13.208572149276733
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.903371102517785
#  Precision: 0.9325948680867171
#  Time: 13.630662441253662
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.901957060049863
#  Precision: 0.9304780045216434
#  Time: 13.387411117553711
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8997151606148966
#  Precision: 0.9300921864081145
#  Time: 13.671733617782593
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9042413314950735
#  Precision: 0.9329257110706132
#  Time: 13.253830432891846
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8989930924694771
#  Precision: 0.9299856156982316
#  Time: 13.280131816864014
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.900868615375969
#  Precision: 0.930552091037149
#  Time: 12.947087526321411
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9017747867045807
#  Precision: 0.9320600406414575
#  Time: 12.878015995025635
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9000968180017312
#  Precision: 0.9291749501149491
#  Time: 15.932297945022583
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9021973941355013
#  Precision: 0.9312260735848835
#  Time: 13.968236923217773
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9035751146227173
#  Precision: 0.9318064841112197
#  Time: 13.122886657714844
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9010582660967383
#  Precision: 0.9316186635596976
#  Time: 14.437732219696045
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8985386157701458
#  Precision: 0.9297841702186341
#  Time: 13.276399612426758
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8959487767225007
#  Precision: 0.9276727635457651
#  Time: 13.314771175384521
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8996394868715992
#  Precision: 0.9305084304246831
#  Time: 13.208609580993652
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9006282581291094
#  Precision: 0.9301864476323465
#  Time: 13.319754600524902
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9016017185950228
#  Precision: 0.9311143594215419
#  Time: 13.394752264022827
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9028792040994617
#  Precision: 0.931259555027107
#  Time: 13.081668615341187
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8966024163423946
#  Precision: 0.9281582332967642
#  Time: 13.186346054077148
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9030911144121438
#  Precision: 0.932492037824082
#  Time: 13.185739755630493
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9037018665600312
#  Precision: 0.9321502130602135
#  Time: 13.456946611404419
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9022086423663025
#  Precision: 0.9308557777765678
#  Time: 13.11599588394165
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8986709931517234
#  Precision: 0.9313189698803714
#  Time: 13.048194646835327
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9000804034975879
#  Precision: 0.9302705092424242
#  Time: 13.225444078445435
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8978131150790073
#  Precision: 0.9283903436150516
#  Time: 12.863970756530762
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9014064583060675
#  Precision: 0.9298330849103476
#  Time: 12.83768892288208
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9024757638881323
#  Precision: 0.9318690157699341
#  Time: 12.906360864639282
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9039268258722567
#  Precision: 0.9313118698120351
#  Time: 12.820504665374756
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9085758090448484
#  Precision: 0.9342381777500248
#  Time: 13.528531551361084
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9023605771923088
#  Precision: 0.9312011033600595
#  Time: 13.403839826583862
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8992778621359196
#  Precision: 0.9303057131555852
#  Time: 13.081037759780884
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8950487086508074
#  Precision: 0.9278948191360308
#  Time: 13.187265157699585
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8983573352139949
#  Precision: 0.9303854831484686
#  Time: 13.354509115219116
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9053245539531493
#  Precision: 0.9332161059956796
#  Time: 13.63522481918335
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.907564761182476
#  Precision: 0.9332238595435542
#  Time: 12.958833456039429
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9035505458288636
#  Precision: 0.9316249426315465
#  Time: 12.905850410461426
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9049190438214616
#  Precision: 0.9316945899941481
#  Time: 13.540056705474854
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9044085887686085
#  Precision: 0.9324107216095292
#  Time: 13.131277084350586
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8979046450341529
#  Precision: 0.9298608158495816
#  Time: 13.408136129379272
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9043463620591488
#  Precision: 0.9324828414203226
#  Time: 13.636653423309326
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9038873246463555
#  Precision: 0.9326981875400859
#  Time: 13.476175785064697
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8909399934853452
#  Precision: 0.9250654378458018
#  Time: 15.70601749420166
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9007360696356199
#  Precision: 0.9302167679835281
#  Time: 13.41119933128357
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8975828642220792
#  Precision: 0.929115748359091
#  Time: 13.06846809387207
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9000660593511487
#  Precision: 0.9315632443160485
#  Time: 15.460673093795776
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8990814747035528
#  Precision: 0.928974057178841
#  Time: 14.824320077896118
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8960467324853268
#  Precision: 0.9282939834503752
#  Time: 13.304131746292114
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8934642044331851
#  Precision: 0.9263206475022574
#  Time: 13.7773756980896
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8993835406825659
#  Precision: 0.9289540259394735
#  Time: 14.100180387496948
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8972790876619929
#  Precision: 0.9289169371699555
#  Time: 13.40322995185852
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9003592125666688
#  Precision: 0.9302607263051401
#  Time: 13.305299043655396
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9035037777784651
#  Precision: 0.9322570769060652
#  Time: 13.342448949813843
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8963612271457968
#  Precision: 0.928280998358122
#  Time: 13.171962261199951
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8993241223091079
#  Precision: 0.9301497597253512
#  Time: 13.950396537780762
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9028304371015078
#  Precision: 0.932773919850853
#  Time: 14.420880556106567
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8978519008218112
#  Precision: 0.9288051781079343
#  Time: 13.003180027008057
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9013983615967025
#  Precision: 0.9305830627145653
#  Time: 13.284217119216919
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9011120768458635
#  Precision: 0.9309636097000464
#  Time: 13.12440037727356
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9014387403845652
#  Precision: 0.9304443531702568
#  Time: 13.129257678985596
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9045815078232782
#  Precision: 0.9320730786331057
#  Time: 14.444928884506226
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8979332041281125
#  Precision: 0.9289548148527864
#  Time: 13.094501256942749
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9009969810579436
#  Precision: 0.9318984127790109
#  Time: 13.245984315872192
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8988573213804076
#  Precision: 0.9305054387713242
#  Time: 14.828214883804321
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8997026755297868
#  Precision: 0.9302834745021616
#  Time: 13.942866086959839
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8977555852094531
#  Precision: 0.928224432646374
#  Time: 13.617198944091797
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8988887659689414
#  Precision: 0.9294272194052149
#  Time: 13.559731483459473
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8982192674328562
#  Precision: 0.9297396087467362
#  Time: 14.125619173049927
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9026371014717678
#  Precision: 0.9314046873797379
#  Time: 14.124259948730469
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.896911203030394
#  Precision: 0.9277727857989131
#  Time: 14.188302040100098
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9001952950102518
#  Precision: 0.9316972451074192
#  Time: 14.025325059890747
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8987264593546324
#  Precision: 0.9298891605049269
#  Time: 13.6196870803833
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9004871991104231
#  Precision: 0.9311818623528165
#  Time: 13.565546989440918
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9004964088403564
#  Precision: 0.9305570864267008
#  Time: 15.108092546463013
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9011629268188973
#  Precision: 0.9307036424847488
#  Time: 13.830913066864014
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9062423915744271
#  Precision: 0.9331881697680333
#  Time: 13.841328382492065
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8987294188125178
#  Precision: 0.9290594951338382
#  Time: 15.03737735748291
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8995029579290866
#  Precision: 0.9311382146694465
#  Time: 24.3333477973938
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9016415391371402
#  Precision: 0.930175287915393
#  Time: 13.33092975616455
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8999988286634699
#  Precision: 0.930059434364222
#  Time: 14.25110411643982
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9037671667180672
#  Precision: 0.9314850146825258
#  Time: 13.315640211105347
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9029624075415366
#  Precision: 0.9336619799370403
#  Time: 16.47304344177246
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8995171616628188
#  Precision: 0.9322991040514284
#  Time: 16.726210355758667
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9048348355098266
#  Precision: 0.9351681342139722
#  Time: 17.03213858604431
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9059893075713988
#  Precision: 0.9346664199402768
#  Time: 16.651012420654297
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9040409316932038
#  Precision: 0.9336800425385818
#  Time: 16.381193161010742
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9017878678895771
#  Precision: 0.9330410652650265
#  Time: 17.160449266433716
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9073748260692349
#  Precision: 0.9363346617710607
#  Time: 16.24219560623169
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9053711084319401
#  Precision: 0.9351835456104689
#  Time: 17.02520442008972
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8996960550982979
#  Precision: 0.9324032700059597
#  Time: 17.248682260513306
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9036837806410706
#  Precision: 0.9337510297402418
#  Time: 17.132127046585083
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.899080314648486
#  Precision: 0.9321971870346764
#  Time: 18.734174251556396
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9016443562501908
#  Precision: 0.9331405725356332
#  Time: 16.366777181625366
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.903721496041098
#  Precision: 0.9340336682851917
#  Time: 16.895474433898926
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9018087402869607
#  Precision: 0.9333856568127041
#  Time: 16.89091444015503
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9070578172355493
#  Precision: 0.9354746589404614
#  Time: 18.426411151885986
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9004810866436513
#  Precision: 0.9319851416116914
#  Time: 16.466745615005493
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9041497684324089
#  Precision: 0.9335936639313793
#  Time: 16.45653462409973
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9030839898889788
#  Precision: 0.933051183213482
#  Time: 16.754120111465454
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9000557359152113
#  Precision: 0.9312827926012544
#  Time: 16.204283714294434
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9008488160929019
#  Precision: 0.9317984284273486
#  Time: 17.69712996482849
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.90756245618529
#  Precision: 0.9368270739075357
#  Time: 16.521580696105957
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9026295251895966
#  Precision: 0.9329452993953249
#  Time: 16.57918071746826
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9041988544059409
#  Precision: 0.9335415189289551
#  Time: 16.276368141174316
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9082474165043917
#  Precision: 0.9367095141295891
#  Time: 16.43840265274048
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9002092415316989
#  Precision: 0.9325737368657735
#  Time: 16.667500495910645
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8997184275547092
#  Precision: 0.9330091628914619
#  Time: 16.526326417922974
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.903795975521624
#  Precision: 0.9327924981772955
#  Time: 16.424018144607544
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9016135455717582
#  Precision: 0.9330707855567859
#  Time: 16.38631272315979
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9030539528527999
#  Precision: 0.9331774756602019
#  Time: 21.736220121383667
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9036937193656646
#  Precision: 0.934038764749723
#  Time: 16.018176078796387
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9011335931518151
#  Precision: 0.9322717585981241
#  Time: 15.887686729431152
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9011881596972057
#  Precision: 0.9330018426400084
#  Time: 16.777784824371338
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9026273775792633
#  Precision: 0.9334546275992583
#  Time: 15.744079113006592
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9028460575284226
#  Precision: 0.9342446780711214
#  Time: 16.548150300979614
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9012966818212259
#  Precision: 0.9332319038708776
#  Time: 16.482863664627075
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9013428871619685
#  Precision: 0.9335953486689093
#  Time: 18.090455770492554
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.906158369682534
#  Precision: 0.9341848459884383
#  Time: 17.80301260948181
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9073954492064485
#  Precision: 0.9361928505736847
#  Time: 18.43632197380066
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9040746746615186
#  Precision: 0.9347547422093943
#  Time: 16.27738380432129
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9042422765203708
#  Precision: 0.9354487328472502
#  Time: 17.066328525543213
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9085855729957092
#  Precision: 0.9377597097579021
#  Time: 16.181623697280884
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9064704825191197
#  Precision: 0.934387699261825
#  Time: 15.926612138748169
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9047387024184962
#  Precision: 0.9348131736847896
#  Time: 16.447742223739624
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9027629825503286
#  Precision: 0.9323802338483834
#  Time: 16.8766872882843
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8975242269573949
#  Precision: 0.9315360254127991
#  Time: 16.16048312187195
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8998381598554154
#  Precision: 0.9312549675392527
#  Time: 16.083106994628906
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.902784024338698
#  Precision: 0.933224465606477
#  Time: 16.936882972717285
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8990674079359401
#  Precision: 0.9313255620930931
#  Time: 17.53142809867859
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9061283713645931
#  Precision: 0.9345058985469056
#  Time: 16.36056613922119
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9066317033365501
#  Precision: 0.9356896849305134
#  Time: 16.21663498878479
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9038229251223701
#  Precision: 0.9338370689135072
#  Time: 16.24775457382202
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9015966317933459
#  Precision: 0.9327900303981185
#  Time: 16.64212131500244
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9036028206930531
#  Precision: 0.9348260446140827
#  Time: 16.642814874649048
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9019068267686828
#  Precision: 0.9326527698896636
#  Time: 16.258954524993896
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9059366946709286
#  Precision: 0.9347276625167812
#  Time: 16.35666513442993
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9036584656763972
#  Precision: 0.9332055450938266
#  Time: 15.928329944610596
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9039299367048725
#  Precision: 0.934651497504934
#  Time: 16.371336698532104
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9041063289478772
#  Precision: 0.9336737197634976
#  Time: 16.421393394470215
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9000319839101762
#  Precision: 0.9331998039903469
#  Time: 15.948970794677734
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9015980300584983
#  Precision: 0.9326718728393859
#  Time: 16.123603105545044
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9032151504799036
#  Precision: 0.9343094243935908
#  Time: 37.41488265991211
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.900217562004505
#  Precision: 0.9324542832844163
#  Time: 16.300148487091064
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8998393320667697
#  Precision: 0.9304756924155462
#  Time: 16.567482948303223
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9052289528699784
#  Precision: 0.9347105640824571
#  Time: 16.505932569503784
# ===========================
#
# ...
#  Results:
#  AUC_PR: 0.9071888083211649
#  Precision: 0.9370879418208735
#  Time: 128.246652841568
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9065113992813488
#  Precision: 0.9362188267055165
#  Time: 124.97745895385742
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.909086100231833
#  Precision: 0.9374743250217321
#  Time: 125.93543434143066
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9077898534719826
#  Precision: 0.9365902459149791
#  Time: 126.75261235237122
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9101372673369403
#  Precision: 0.9379259430749604
#  Time: 124.23265719413757
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9084571571561568
#  Precision: 0.9372786246943354
#  Time: 128.50553822517395
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9076459743652507
#  Precision: 0.9370567021650307
#  Time: 130.56178951263428
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9081049570167093
#  Precision: 0.9379891396637003
#  Time: 128.70854544639587
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9109257343150531
#  Precision: 0.939411038078656
#  Time: 123.1736524105072
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9142127176062737
#  Precision: 0.940418416374331
#  Time: 130.82609724998474
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9062907573411205
#  Precision: 0.935437785060552
#  Time: 126.53173661231995
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9088607529927588
#  Precision: 0.9374757615735339
#  Time: 124.52129077911377
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.907435955406393
#  Precision: 0.9375361271062791
#  Time: 129.18126702308655
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.90516068249193
#  Precision: 0.9354554636237651
#  Time: 128.40577125549316
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.90372959430572
#  Precision: 0.9357781214570795
#  Time: 129.11739325523376
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9037007191422572
#  Precision: 0.9353496229959408
#  Time: 129.46260690689087
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9091957647759101
#  Precision: 0.9373409112127769
#  Time: 140.14594745635986
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9056120675546978
#  Precision: 0.9350689102085261
#  Time: 126.50238537788391
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9081363055542614
#  Precision: 0.9372199875871275
#  Time: 129.20686960220337
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9094710946893052
#  Precision: 0.9379727870529598
#  Time: 129.10646629333496
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9029979453178051
#  Precision: 0.9339914605946406
#  Time: 125.4536235332489
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment16.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9045674931465627
#  Precision: 0.9353181307357188
#  Time: 136.67851781845093
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9065907394086948
#  Precision: 0.9364925376966451
#  Time: 130.63898873329163
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment18.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9037969850657696
#  Precision: 0.9350229027279835
#  Time: 126.67634701728821
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment19.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9099720949534998
#  Precision: 0.9382437523293314
#  Time: 124.26140642166138
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment20.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9059891113393892
#  Precision: 0.9365446997511921
#  Time: 131.30061531066895
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment21.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9065767179435066
#  Precision: 0.9362859550887511
#  Time: 131.88218688964844
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment22.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9111043208720494
#  Precision: 0.9376214982444127
#  Time: 128.97891473770142
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment23.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9075421274344987
#  Precision: 0.9361843255209029
#  Time: 126.17895936965942
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment24.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9060875456586708
#  Precision: 0.9367504219410622
#  Time: 129.33038926124573
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment25.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9055426064986205
#  Precision: 0.9366330868777686
#  Time: 130.8057370185852
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment26.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9113371373924752
#  Precision: 0.9385452793799647
#  Time: 131.15060567855835
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment27.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9071786983137801
#  Precision: 0.9359246908454121
#  Time: 131.315247297287
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment28.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.902575117992339
#  Precision: 0.9336000970646152
#  Time: 130.03991842269897
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment29.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9098929723118485
#  Precision: 0.9385549338016198
#  Time: 130.73085284233093
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment30.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9054623224191605
#  Precision: 0.9357805849740128
#  Time: 126.81637120246887
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment31.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9068687858712466
#  Precision: 0.936445802633449
#  Time: 128.7956154346466
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment32.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9045433302346128
#  Precision: 0.9357235415963504
#  Time: 128.58335375785828
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment33.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9073659756610523
#  Precision: 0.9372458716588717
#  Time: 127.97324323654175
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment34.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9055886039266727
#  Precision: 0.9363286794142188
#  Time: 129.48803210258484
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment35.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9059771088584597
#  Precision: 0.9366682275650584
#  Time: 128.82133078575134
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment36.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9042828450614686
#  Precision: 0.9356779603689718
#  Time: 133.22999358177185
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment37.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9066873070013853
#  Precision: 0.9361265384302918
#  Time: 123.68007326126099
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment38.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.906483009319586
#  Precision: 0.9359480027848565
#  Time: 132.28774905204773
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment39.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9089610242966041
#  Precision: 0.9384691818170422
#  Time: 126.00826597213745
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment40.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.908252232747253
#  Precision: 0.9363924479562937
#  Time: 127.24264025688171
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment41.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9090710657562259
#  Precision: 0.937936237473338
#  Time: 124.75823330879211
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment42.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9071507326636324
#  Precision: 0.9364667429725635
#  Time: 133.2448012828827
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment43.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9091398338710893
#  Precision: 0.9372758447255429
#  Time: 130.59177494049072
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment44.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9071634350284847
#  Precision: 0.9365940505765573
#  Time: 131.55720615386963
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment45.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9122611468199827
#  Precision: 0.938939357727411
#  Time: 127.03240060806274
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9095817593629589
#  Precision: 0.9377800796482035
#  Time: 126.46750617027283
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9054392316511829
#  Precision: 0.9361996504208964
#  Time: 131.67997074127197
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9079620768995326
#  Precision: 0.9368350958934958
#  Time: 129.05715703964233
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9090420948599287
#  Precision: 0.9372144392350894
#  Time: 127.3957154750824
# ===========================

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
for i in range(len(experiments)):
    for d in list(experiments[i].keys()):
        experiments[i][d] = str(experiments[i][d])

# %%
# experiments

# %%
cols = ['experiment_filter', 'undersampling_method', 'filename', 'experiment_id', 'n_covid', 'n_not_covid', 'model_name', 'params', 'model_AUC_ROC', 'model_AUC_PR', 'model_covid_precision', 'model_covid_recall', 'model_covid_f1', 'model_not_covid_precision', 'model_not_covid_recall', 'model_not_covid_f1', 'model_avg_precision', 'model_avg_recall', 'model_avg_f1', 'model_avg_acc', 'model_TP', 'model_TN', 'model_FN', 'model_FP', 'model_time_exec', 'model_col_set']

# %%
intermed_results = spark.createDataFrame(data=experiments).select(cols)
intermed_results.toPandas()
# Out:
# /usr/lib/spark/python/pyspark/sql/session.py:346: UserWarning: inferring schema from dict is deprecated,please use pyspark.sql.Row instead
#   warnings.warn("inferring schema from dict is deprecated,"

# %%
intermed_results.write.parquet('gs://ai-covid19-datalake/trusted/intermed_results/STRSAMP/GBT_experiments-EW-ds3-cs3.parquet', mode='overwrite')

# %%
print('finished')
# Out:
# finished

# %%
intermed_results.show()
# Out:
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# |experiment_filter|undersampling_method|            filename|experiment_id|n_covid|n_not_covid|model_name|              params|     model_AUC_ROC|      model_AUC_PR|model_covid_precision|model_covid_recall|    model_covid_f1|model_not_covid_precision|model_not_covid_recall|model_not_covid_f1|model_avg_precision|  model_avg_recall|      model_avg_f1|     model_avg_acc|model_TP|model_TN|model_FN|model_FP|   model_time_exec|model_col_set|
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|            0|  76008|      44538|       GBT|{'maxIter': 20, '...|0.9109028255543815|0.9021239493664106|   0.9176135189852498|0.9712249092578825|0.9436583811344805|       0.9452077608460322|    0.8505807418508805|0.8954011201388341|  0.931410639915641|0.9109028255543815|0.9195297506366573|0.9267646084170993|   22209|   11351|     658|    1994| 25.97623300552368|   cols_set_3|
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|            1|  76098|      44538|       GBT|{'maxIter': 20, '...|0.9120562777693558|0.8980083574455276|   0.9200067221241912|0.9670125855597262|0.9429241931664046|       0.9386044217966631|    0.8570999699789853|0.8960025106900474| 0.9293055719604272|0.9120562777693557| 0.919463351928226| 0.926297645194473|   21898|   11420|     747|    1904|14.400279521942139|   cols_set_3|
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|            2|  76542|      44538|       GBT|{'maxIter': 20, '...|0.9110809438578115|0.9018861785596823|   0.9187243216857178|0.9716904014111776|0.9444653535733701|       0.9452670104807852|    0.8504714863044455|  0.89536716041601| 0.9319956660832516|0.9110809438578116|0.9199162569946902|0.9274416063379319|   22585|   11364|     658|    1998|13.929572105407715|   cols_set_3|
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|            3|  75793|      44538|       GBT|{'maxIter': 20, '...|0.9140222541513071|0.9001049451809635|   0.9219596154653457|0.9677874234345393|0.9443178397901706|        0.939958932238193|    0.8602570848680748|0.8983436690478059| 0.9309592738517694| 0.914022254151307|0.9213307544189883|0.9280475608400933|   21962|   11444|     731|    1859| 17.46992778778076|   cols_set_3|
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|            4|  74465|      44538|       GBT|{'maxIter': 20, '...|0.9111718298730014|0.9034819055784309|   0.9168065815983881|0.9714895698972557|0.9433562960243591|       0.9463508536993639|    0.8508540898487471|0.8960653009470223|  0.931578717648876|0.9111718298730014|0.9197107984856907|0.9266744940176674|   21842|   11307|     641|    1982|13.361764669418335|   cols_set_3|
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|            5|  74906|      44538|       GBT|{'maxIter': 20, '...| 0.913011960297613|0.9054621633494588|   0.9186051333084546|0.9721783394769177|0.9446327683615819|       0.9476119649644686|    0.8538455811183084|0.8982884894058669| 0.9331085491364617| 0.913011960297613|0.9214606288837244|0.9282973025207764|   22154|   11468|     634|    1963|13.389218091964722|   cols_set_3|
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|            6|  75869|      44538|       GBT|{'maxIter': 20, '...|0.9078540588069318|0.8980478151613618|   0.9156903851687426|0.9702090592334495|0.9421616934886967|       0.9425596237823312|    0.8454990583804143|0.8913949886828416| 0.9291250044755368|0.9078540588069319|0.9167783410857692|0.9245204912377536|   22276|   11224|     684|    2051|13.669918775558472|   cols_set_3|
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|            7|  75764|      44538|       GBT|{'maxIter': 20, '...|0.9131032160579754|0.9025569112508545|   0.9207306924101198|0.9709082931110136|0.9451539874418008|       0.9443931896334815|    0.8552981390049373|0.8976403061224489| 0.9325619410218007|0.9131032160579755|0.9213971467821249|0.9285773884021694|   22127|   11260|     663|    1905|13.389512062072754|   cols_set_3|
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|            8|  75929|      44538|       GBT|{'maxIter': 20, '...|0.9121542560977453|0.9016625618117056|   0.9183605186114596|0.9692769488831995|0.9431320333304699|       0.9429928741092637|    0.8550315633122911|0.8968606372205343| 0.9306766963603617|0.9121542560977454|0.9199963352755021|0.9266867853484315|   21958|   11513|     696|    1952|  13.4413321018219|   cols_set_3|
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|            9|  75880|      44538|       GBT|{'maxIter': 20, '...|0.9139921677997309|0.9031863391721048|   0.9200168563000422|0.9693202504106913|0.9440252524160595|        0.943462608411062|    0.8586640851887706|0.8990682624459085| 0.9317397323555521|0.9139921677997309| 0.921546757430984|0.9279873164218959|   21832|   11531|     691|    1898|13.495094060897827|   cols_set_3|
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|           10|  76773|      44538|       GBT|{'maxIter': 20, '...|0.9123365900997844|0.9047143812650135|    0.918088027290124|0.9720313601127555|0.9442899319669676|       0.9472065181243765|    0.8526418200868133|0.8974399369830642| 0.9326472727072502|0.9123365900997844|0.9208649344750159|0.9277990351023124|   22069|   11393|     635|    1969|13.672492027282715|   cols_set_3|
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|           11|  75938|      44538|       GBT|{'maxIter': 20, '...|0.9122594289708928| 0.897438644929706|   0.9203513786146604|0.9663283318623125|0.9427796435029708|       0.9376175292290082|    0.8581905260794732|0.8961475345784168| 0.9289844539218344|0.9122594289708928|0.9194635890406938| 0.926213807844988|   21897|   11468|     763|    1895|13.389970064163208|   cols_set_3|
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|           12|  74219|      44538|       GBT|{'maxIter': 20, '...|0.9107577032708776|0.8990804652012104|   0.9167019744089484|0.9671881984801073|0.9412685982772122|        0.940150032615786|    0.8543272080616479|0.8951863354037267| 0.9284260035123673|0.9107577032708776|0.9182274668404695|0.9247197903306753|   21636|   11530|     734|    1966|13.354323148727417|   cols_set_3|
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|           13|  75346|      44538|       GBT|{'maxIter': 20, '...|0.9115585669917977| 0.899031300559481|   0.9184404636459431|0.9674554899436132|0.9423110188548695|       0.9399377253359554|    0.8556616440399821| 0.895821944552909| 0.9291890944909493|0.9115585669917976|0.9190664817038892|0.9257424364719308|   21790|   11471|     733|    1935|13.336814880371094|   cols_set_3|
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|           14|  75248|      44538|       GBT|{'maxIter': 20, '...|0.9142755104727698|0.8987300785789571|   0.9225295777019915|0.9663065049614112|0.9439107396717357|       0.9377900822408599|    0.8622445159841282|0.8984320149777674| 0.9301598299714258|0.9142755104727698|0.9211713773247515|0.9277309058614565|   21911|   11517|     764|    1840| 13.31729245185852|   cols_set_3|
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|           15|  74762|      44538|       GBT|{'maxIter': 20, '...|0.9091259126254256|0.8977794915334208|   0.9164086687306502|0.9684322221239721|0.9417024935511608|       0.9405990016638935|    0.8498196031268791|0.8929079134417944| 0.9285038351972719|0.9091259126254256|0.9173052034964776|0.9245030900283948|   21904|   11306|     714|    1998|13.148677110671997|   cols_set_3|
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|           16|  75621|      44538|       GBT|{'maxIter': 20, '...|0.9100947510563723|0.8986063721444422|   0.9170729674542651|0.9682770151355157|0.9419796682718031|       0.9407510888322788|    0.8519124869772288| 0.894130511188347| 0.9289120281432719|0.9100947510563722| 0.918055089730075|0.9250400929049384|   22007|   11448|     721|    1990|13.421673774719238|   cols_set_3|
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|           17|  75031|      44538|       GBT|{'maxIter': 20, '...|0.9103803853885232|0.8943810258978541|   0.9190053435435688|0.9649231312952818|0.9414046505613861|       0.9350351824578629|    0.8558376394817644|0.8936852394916911| 0.9270202630007158|0.9103803853885231|0.9175449450265386|0.9244491372363778|   21842|   11428|     794|    1925|13.781352996826172|   cols_set_3|
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|           18|  75151|      44538|       GBT|{'maxIter': 20, '...|0.9112947324319454|0.9009964261566108|   0.9164482029598309|0.9681511591548667| 0.941590459847514|       0.9420890188434048|    0.8544383057090239|0.8961254683818133| 0.9292686109016178|0.9112947324319454|0.9188579641146637|0.9252266281074467|   21674|   11599|     713|    1976| 13.19821834564209|   cols_set_3|
# |             ds-3|       04-STRSAMP-EW|gs://ai-covid19-d...|           19|  75145|      44538|       GBT|{'maxIter': 20, '...|0.9134793274775449|0.9044014713134765|   0.9188213566151779|0.9704304650441105|0.9439210021344947|       0.9453860640301318|    0.8565281899109792| 0.898766200910754| 0.9321037103226548|0.9134793274775448|0.9213436015226244|0.9278241807031662|   21890|   11546|     667|    1934|13.218761444091797|   cols_set_3|
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# only showing top 20 rows
