# %%
import pandas as pd
import pyspark.sql.functions as F
from datetime import datetime
from pyspark.sql.types import *
from pyspark.storagelevel import StorageLevel
import json

import numpy as np
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", 1000)
pd.set_option("mode.chained_assignment", None)

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
filters = ['nofilter', 'pcrpositive', 'labpositive']

cols_sets = {'cols_set_1': ['NU_NOTIFIC', 'CLASSI_FIN', 'CRITERIO', 'EVOLUCAO', 
                            'AGE_GROUP', 'DIST_PRI_NOTIFIC_Q',
                            'DIST_PRI_INTERNA_Q', 'DIST_PRI_ENTUTI_Q', 'DIST_PRI_SAIDUTI_Q', 'DIST_PRI_EVOLUCA_Q', 'DIST_PRI_ENCERRA_Q',
                            'SYMP_GROUP1', 'SYMP_GROUP2', 'SYMP_GROUP3', 'SYMP_GROUP4',
                            'RF_GROUP1', 'RF_GROUP2', 'RF_GROUP3', 'RF_GROUP4',
                            'SUPORT_VEN', 'UTI', 'HOSPITAL',
                            'DIST_PRI_RAIOX_Q', 'DIST_PRI_COLETA_Q', 'DIST_PRI_TOMO_Q', 'DIST_PRI_IF_Q', 'DIST_PRI_TRA_Q', 'DIST_PRI_PCR_Q', 'DIST_PRI_SOR_Q',
                            'GMR_TRANSIT_STATIONS_1WEEK_BEFORE_Q', 'GMR_RETAIL_AND_RECREATION_1WEEK_BEFORE_Q', 'GMR_RESIDENTIAL_PERCENT_1WEEK_BEFORE_Q', 'GMR_WORKPLACES_PERCENT_1WEEK_BEFORE_Q',
                            'GMR_TRANSIT_STATIONS_2WEEKS_Q', 'GMR_RETAIL_AND_RECREATION_2WEEKS_Q', 'GMR_RESIDENTIAL_PERCENT_2WEEKS_Q', 'GMR_WORKPLACES_PERCENT_2WEEKS_Q',
                            'INMET_RELATIVE_AIR_HUMIDITY_1WEEK_BEFORE_Q', 'INMET_RELATIVE_AIR_HUMIDITY_2WEEKS_BEFORE_Q'],
             'cols_set_2': ['NU_NOTIFIC', 'SG_UF', 'CS_SEXO','CS_RACA', 'CRITERIO', 'SURTO_SG', 'SUPORT_VEN', 'EVOLUCAO',
                            'OUTRO_SIN', 'AGE_GROUP', 
                            'SYMP_GROUP1',  'SYMP_GROUP2', 'SYMP_GROUP3', 'SYMP_GROUP4',
                            'RF_GROUP1', 'RF_GROUP2', 'RF_GROUP3',  'RF_GROUP4',
                            'DIST_PRI_EVOLUCA_Q', 'DIST_PRI_ENCERRA_Q', 'DIST_PRI_INTERNA_Q',
                            'DIST_PRI_NOTIFIC_Q', 'DIST_PRI_COLETA_Q', 'DIST_PRI_PCR_Q', 'CLASSI_FIN'],
             'cols_set_3': ['NU_NOTIFIC', 'SG_UF', 'SG_UF_NOT', 'SYMP_GROUP1', 'SYMP_GROUP2', 'SYMP_GROUP3', 'SYMP_GROUP4',
                            'AGE_GROUP', 'CS_SEXO', 'CS_RACA', 'EVOLUCAO', 'CS_ESCOL_N',
                            'UTI', 'SUPORT_VEN', 'DIST_PRI_ENTUTI_Q', 'DIST_PRI_INTERNA_Q',
                            'CLASSI_FIN']}


undersamp_col = {'03-STRSAMP-AG': 'AGE_GROUP', '04-STRSAMP-EW': 'EPI_WEEK_YEAR'}

# state_codes_dict = {
#                 'RO': 11, 'AC': 12, 'AM': 13, 'RR': 14, 'PA': 15, 'AP': 16, 'TO': 17, 
#                 'MA': 21, 'PI': 22, 'CE': 23, 'RN': 24, 'PB': 25, 'PE': 26, 'AL': 27, 'SE': 28, 'BA': 29,
#                 'MG': 31, 'ES': 32, 'RJ': 33, 'SP': 35, 
#                 'PR': 41, 'SC': 42, 'RS': 43,
#                 'MS': 50, 'MT': 51, 'GO': 52, 'DF': 53
#               }

# %%
def dropDupeDfCols(df):
    newcols = []
    dupcols = []

    for i in range(len(df.columns)):
        if df.columns[i] not in newcols:
            newcols.append(df.columns[i])
        else:
            dupcols.append(i)

    df = df.toDF(*[str(i) for i in range(len(df.columns))])
    for dupcol in dupcols:
        df = df.drop(str(dupcol))

    return df.toDF(*newcols)


def format_state(state_col):
    state_codes_dict = {
                'RO': 11, 'AC': 12, 'AM': 13, 'RR': 14, 'PA': 15, 'AP': 16, 'TO': 17, 
                'MA': 21, 'PI': 22, 'CE': 23, 'RN': 24, 'PB': 25, 'PE': 26, 'AL': 27, 'SE': 28, 'BA': 29,
                'MG': 31, 'ES': 32, 'RJ': 33, 'SP': 35, 
                'PR': 41, 'SC': 42, 'RS': 43,
                'MS': 50, 'MT': 51, 'GO': 52, 'DF': 53
              }
    if state_col != None:
        return str(state_codes_dict[state_col])
udf_format_state = F.udf(format_state, StringType())

def format_sex(df, sex_col_name):
    return df.withColumn(sex_col_name, F.when(F.col(sex_col_name) == 'F', '2').otherwise('1'))

def preprocessing(df):
    for col in df.columns:
        if col == 'CS_SEXO':
            df = format_sex(df, col)
            
        if col in ['SG_UF', 'SG_UF_NOT']:
            df = df.withColumn(col, udf_format_state(F.col(col)))
            
        if (col not in ['NU_NOTIFIC']) and ((col in cols_sets['cols_set_1']) or (col in cols_sets['cols_set_2']) or (col in cols_sets['cols_set_3'])):
            df = df.withColumn(col, F.col(col).cast('float'))
    
    df = df.na.fill('9999')
    df = df.na.fill(9999)
    df = df.withColumn('CLASSI_FIN', F.when(F.col('CLASSI_FIN') == 5, 1.0).otherwise(0.0))
    
    return dropDupeDfCols(df)

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %% [markdown]
# # Reading data

# %%
not_covid = spark.read.parquet('gs://ai-covid19-datalake/trusted/super-srag_filters/super-srag_notcovid_nofilter.parquet')
not_covid.limit(2).toPandas()
# Out:
#     NU_NOTIFIC CS_SEXO     DT_NASC  AGE_AT_NOTIF  AGE_GROUP  CS_GESTANT  \
# 0  77309712285       M  2020-09-18             0          1           6
# 1  85899613066       M  2010-03-11            10          3           6
#
#    CS_RACA CS_ETINIA  CS_ESCOL_N SG_UF  CO_MUN_RES SEM_PRI SEM_NOT  \
# 0        4      None         0.0    SP      352620       4       4
# 1        9      None         NaN    SP      355030       4       5
#
#    DIST_PRI_NOTIFIC  DT_SIN_PRI SG_UF_NOT CO_MUN_NOT  SURTO_SG  NOSOCOMIAL  \
# 0                 2  2021-01-26        SP     352220         9           2
# 1                 5  2021-01-28        SP     355030         2           2
#
#    AVE_SUINO  VACINA HOSPITAL  DIST_PRI_INTERNA  SUPORT_VEN  UTI  \
# 0          2     NaN        1               1.0           2  2.0
# 1          9     9.0        2               NaN           3  NaN
#
#   DIST_PRI_ENTUTI CLASSI_OUT CRITERIO EVOLUCAO  CLASSI_FIN SYMP_GROUP1  \
# 0            None       None        1        1           2           3
# 1            None       None        1        1           2           8
#
#   SYMP_GROUP2 SYMP_GROUP3 SYMP_GROUP4  OUTRO_SIN OUTRO_DES RF_GROUP1  \
# 0           8           1           1        2.0      None         1
# 1           1           1           1        NaN      None         1
#
#   RF_GROUP2 RF_GROUP3 RF_GROUP4 OBES_IMC OUT_MORBI MORB_DESC  RAIOX_RES  \
# 0         1         1         1     None      None      None        NaN
# 1         1         1         1     None      None      None        6.0
#
#   DIST_PRI_RAIOX TOMO_RES DIST_PRI_TOMO  AMOSTRA  TP_AMOSTRA   DT_COLETA  \
# 0           None     None          None        1           1  2021-01-27
# 1           None        6          None        1           1  2021-01-31
#
#    DIST_PRI_COLETA PP_IF_RESUL PP_TRA_RESUL  DIST_PRI_TRA PP_PCR_RESUL  \
# 0                1           6            3           2.0            4
# 1                3           9            9           NaN            3
#
#    DIST_PRI_PCR PP_RES_SOR_IGA PP_RES_SOR_IGM PP_RES_SOR_IGG DIST_PRI_SOR  \
# 0             6              4              4              4         None
# 1             3              4              4              4         None
#
#   DIST_PRI_IF DIST_PRI_NOTIFIC_Q DIST_PRI_INTERNA_Q DIST_PRI_ENTUTI_Q  \
# 0        None                  1                  1                 6
# 1        None                  2                  6                 6
#
#   DIST_PRI_SAIDUTI_Q DIST_PRI_EVOLUCA_Q DIST_PRI_ENCERRA_Q DIST_PRI_RAIOX_Q  \
# 0                  6                  4                  4                6
# 1                  6                  1                  2                6
#
#   DIST_PRI_TOMO_Q DIST_PRI_COLETA_Q DIST_PRI_SOR_Q DIST_PRI_PCR_Q  \
# 0               6                 1              6              2
# 1               6                 2              6              1
#
#   DIST_PRI_TRA_Q DIST_PRI_IF_Q EPI_WEEK_YEAR  GMR_TRANSIT_STATIONS_AVG  \
# 0              1             6       04-2021                -25.895942
# 1              6             6       04-2021                -25.895942
#
#    GMR_GROCERY_AND_PHARMACY_AVG  GMR_RETAIL_AND_RECREATION_AVG  \
# 0                      6.296242                     -28.311178
# 1                      6.296242                     -28.311178
#
#    GMR_WORKPLACES_PERCENT_AVG  GMR_RESIDENTIAL_PERCENT_AVG  \
# 0                   -6.281181                     6.003215
# 1                   -6.281181                     6.003215
#
#    GMR_PARKS_PERCENT_AVG  GMR_TRANSIT_STATIONS_1WEEK_BEFORE_AVG  \
# 0             -23.171171                             -26.123958
# 1             -23.171171                             -26.123958
#
#    GMR_GROCERY_AND_PHARMACY_1WEEK_BEFORE_AVG  \
# 0                                   4.771699
# 1                                   4.771699
#
#    GMR_RETAIL_AND_RECREATION_1WEEK_BEFORE_AVG  \
# 0                                  -24.164021
# 1                                  -24.164021
#
#    GMR_WORKPLACES_PERCENT_1WEEK_BEFORE_AVG  \
# 0                                -7.336648
# 1                                -7.336648
#
#    GMR_RESIDENTIAL_PERCENT_1WEEK_BEFORE_AVG  \
# 0                                  5.483269
# 1                                  5.483269
#
#    GMR_PARKS_PERCENT_1WEEK_BEFORE_AVG  GMR_TRANSIT_STATIONS_2WEEKS_AVG  \
# 0                          -25.172172                       -23.547269
# 1                          -25.172172                       -23.547269
#
#    GMR_GROCERY_AND_PHARMACY_2WEEKS_AVG  GMR_RETAIL_AND_RECREATION_2WEEKS_AVG  \
# 0                             8.872993                            -20.801375
# 1                             8.872993                            -20.801375
#
#    GMR_WORKPLACES_PERCENT_2WEEKS_AVG  GMR_RESIDENTIAL_PERCENT_2WEEKS_AVG  \
# 0                          -4.632532                            5.748876
# 1                          -4.632532                            5.748876
#
#    GMR_PARKS_PERCENT_2WEEKS_AVG  INMET_TEMP_C_AVG  \
# 0                     -25.86341         24.476172
# 1                     -25.86341         24.476172
#
#    INMET_RELATIVE_AIR_HUMIDITY_AVG  INMET_DAILY_PRECIPT_AVG  \
# 0                        72.664078                 4.339216
# 1                        72.664078                 4.339216
#
#    INMET_TEMP_C_1WEEK_BEFORE_AVG  \
# 0                       24.36574
# 1                       24.36574
#
#    INMET_RELATIVE_AIR_HUMIDITY_1WEEK_BEFORE_AVG  \
# 0                                     75.171226
# 1                                     75.171226
#
#    INMET_DAILY_PRECIPT_1WEEK_BEFORE_AVG  INMET_TEMP_C_2WEEKS_BEFORE_AVG  \
# 0                                 6.304                       24.070494
# 1                                 6.304                       24.070494
#
#    INMET_RELATIVE_AIR_HUMIDITY_2WEEKS_BEFORE_AVG  \
# 0                                      79.940901
# 1                                      79.940901
#
#    INMET_DAILY_PRECIPT_2WEEKS_BEFORE_AVG GMR_TRANSIT_STATIONS_Q  \
# 0                               6.042424                      3
# 1                               6.042424                      3
#
#   GMR_GROCERY_AND_PHARMACY_Q GMR_RETAIL_AND_RECREATION_Q  \
# 0                          2                           3
# 1                          2                           3
#
#   GMR_WORKPLACES_PERCENT_Q GMR_RESIDENTIAL_PERCENT_Q GMR_PARKS_PERCENT_Q  \
# 0                        3                         2                   4
# 1                        3                         2                   4
#
#   GMR_TRANSIT_STATIONS_1WEEK_BEFORE_Q GMR_GROCERY_AND_PHARMACY_1WEEK_BEFORE_Q  \
# 0                                   3                                       2
# 1                                   3                                       2
#
#   GMR_RETAIL_AND_RECREATION_1WEEK_BEFORE_Q  \
# 0                                        3
# 1                                        3
#
#   GMR_WORKPLACES_PERCENT_1WEEK_BEFORE_Q  \
# 0                                     3
# 1                                     3
#
#   GMR_RESIDENTIAL_PERCENT_1WEEK_BEFORE_Q GMR_PARKS_PERCENT_1WEEK_BEFORE_Q  \
# 0                                      1                                4
# 1                                      1                                4
#
#   GMR_TRANSIT_STATIONS_2WEEKS_Q GMR_GROCERY_AND_PHARMACY_2WEEKS_Q  \
# 0                             4                                 3
# 1                             4                                 3
#
#   GMR_RETAIL_AND_RECREATION_2WEEKS_Q GMR_WORKPLACES_PERCENT_2WEEKS_Q  \
# 0                                  4                               3
# 1                                  4                               3
#
#   GMR_RESIDENTIAL_PERCENT_2WEEKS_Q GMR_PARKS_PERCENT_2WEEKS_Q INMET_TEMP_C_Q  \
# 0                                2                          4              4
# 1                                2                          4              4
#
#   INMET_RELATIVE_AIR_HUMIDITY_Q INMET_DAILY_PRECIPT_Q  \
# 0                             3                     4
# 1                             3                     4
#
#   INMET_TEMP_C_1WEEK_BEFORE_Q INMET_RELATIVE_AIR_HUMIDITY_1WEEK_BEFORE_Q  \
# 0                           4                                          4
# 1                           4                                          4
#
#   INMET_DAILY_PRECIPT_1WEEK_BEFORE_Q INMET_TEMP_C_2WEEKS_BEFORE_Q  \
# 0                                  5                            4
# 1                                  5                            4
#
#   INMET_RELATIVE_AIR_HUMIDITY_2WEEKS_BEFORE_Q  \
# 0                                           5
# 1                                           5
#
#   INMET_DAILY_PRECIPT_2WEEKS_BEFORE_Q   ANO
# 0                                   4  2021
# 1                                   4  2021

# %%
df1 = spark.read.parquet('gs://ai-covid19-datalake/trusted/super-srag_filters/super-srag_covid_nofilter.parquet')
df1.limit(2).toPandas()
# Out:
#     NU_NOTIFIC CS_SEXO     DT_NASC  AGE_AT_NOTIF  AGE_GROUP  CS_GESTANT  \
# 0  77309859740       M  1968-12-02            52          7           6
# 1  68719688318       F  1968-12-02            52          7           5
#
#    CS_RACA CS_ETINIA  CS_ESCOL_N SG_UF  CO_MUN_RES SEM_PRI SEM_NOT  \
# 0        4      None         4.0    BA      290730      19      20
# 1        4      None         NaN    BA      292370      19      19
#
#    DIST_PRI_NOTIFIC  DT_SIN_PRI SG_UF_NOT CO_MUN_NOT SURTO_SG  NOSOCOMIAL  \
# 0                 7  2021-05-13        BA     291920     None         NaN
# 1                 5  2021-05-10        BA     290520     None         2.0
#
#    AVE_SUINO  VACINA HOSPITAL  DIST_PRI_INTERNA  SUPORT_VEN  UTI  \
# 0        NaN     9.0        1                 6           2    2
# 1        9.0     NaN        1                 6           2    1
#
#    DIST_PRI_ENTUTI CLASSI_OUT CRITERIO EVOLUCAO  CLASSI_FIN SYMP_GROUP1  \
# 0              NaN       None        1     None           5           4
# 1              6.0       None        1        2           5           8
#
#   SYMP_GROUP2 SYMP_GROUP3 SYMP_GROUP4  OUTRO_SIN OUTRO_DES RF_GROUP1  \
# 0           6           1           1        2.0      None         9
# 1           6           2           5        NaN      None         1
#
#   RF_GROUP2 RF_GROUP3 RF_GROUP4 OBES_IMC OUT_MORBI MORB_DESC RAIOX_RES  \
# 0         9         9         9     None         2      None      None
# 1         1         5         1     None      None      None      None
#
#   DIST_PRI_RAIOX TOMO_RES  DIST_PRI_TOMO  AMOSTRA  TP_AMOSTRA   DT_COLETA  \
# 0           None     None            NaN        1           1  2021-05-14
# 1           None        1            5.0        1           1  2021-05-14
#
#    DIST_PRI_COLETA PP_IF_RESUL PP_TRA_RESUL  DIST_PRI_TRA PP_PCR_RESUL  \
# 0                1           2            9           NaN            6
# 1                4           6            2           4.0            6
#
#   DIST_PRI_PCR PP_RES_SOR_IGA PP_RES_SOR_IGM PP_RES_SOR_IGG DIST_PRI_SOR  \
# 0         None              4              4              4         None
# 1         None              4              4              4         None
#
#    DIST_PRI_IF DIST_PRI_NOTIFIC_Q DIST_PRI_INTERNA_Q DIST_PRI_ENTUTI_Q  \
# 0          1.0                  3                  3                 6
# 1          NaN                  2                  3                 3
#
#   DIST_PRI_SAIDUTI_Q DIST_PRI_EVOLUCA_Q DIST_PRI_ENCERRA_Q DIST_PRI_RAIOX_Q  \
# 0                  6                  6                  1                6
# 1                  6                  2                  1                6
#
#   DIST_PRI_TOMO_Q DIST_PRI_COLETA_Q DIST_PRI_SOR_Q DIST_PRI_PCR_Q  \
# 0               6                 1              6              6
# 1               2                 3              6              6
#
#   DIST_PRI_TRA_Q DIST_PRI_IF_Q EPI_WEEK_YEAR  GMR_TRANSIT_STATIONS_AVG  \
# 0              6             1       19-2021                -26.208333
# 1              3             6       19-2021                -26.208333
#
#    GMR_GROCERY_AND_PHARMACY_AVG  GMR_RETAIL_AND_RECREATION_AVG  \
# 0                     31.788462                     -24.079137
# 1                     31.788462                     -24.079137
#
#    GMR_WORKPLACES_PERCENT_AVG  GMR_RESIDENTIAL_PERCENT_AVG  \
# 0                   -0.099905                     7.358333
# 1                   -0.099905                     7.358333
#
#    GMR_PARKS_PERCENT_AVG  GMR_TRANSIT_STATIONS_1WEEK_BEFORE_AVG  \
# 0              -44.62533                             -25.097436
# 1              -44.62533                             -25.097436
#
#    GMR_GROCERY_AND_PHARMACY_1WEEK_BEFORE_AVG  \
# 0                                  34.628571
# 1                                  34.628571
#
#    GMR_RETAIL_AND_RECREATION_1WEEK_BEFORE_AVG  \
# 0                                  -20.930314
# 1                                  -20.930314
#
#    GMR_WORKPLACES_PERCENT_1WEEK_BEFORE_AVG  \
# 0                                 0.773764
# 1                                 0.773764
#
#    GMR_RESIDENTIAL_PERCENT_1WEEK_BEFORE_AVG  \
# 0                                   6.81768
# 1                                   6.81768
#
#    GMR_PARKS_PERCENT_1WEEK_BEFORE_AVG  GMR_TRANSIT_STATIONS_2WEEKS_AVG  \
# 0                          -44.472296                       -31.233161
# 1                          -44.472296                       -31.233161
#
#    GMR_GROCERY_AND_PHARMACY_2WEEKS_AVG  GMR_RETAIL_AND_RECREATION_2WEEKS_AVG  \
# 0                            17.257009                            -30.477193
# 1                            17.257009                            -30.477193
#
#    GMR_WORKPLACES_PERCENT_2WEEKS_AVG  GMR_RESIDENTIAL_PERCENT_2WEEKS_AVG  \
# 0                          -4.605239                            8.130556
# 1                          -4.605239                            8.130556
#
#    GMR_PARKS_PERCENT_2WEEKS_AVG  INMET_TEMP_C_AVG  \
# 0                    -46.526854         22.265185
# 1                    -46.526854         22.265185
#
#    INMET_RELATIVE_AIR_HUMIDITY_AVG  INMET_DAILY_PRECIPT_AVG  \
# 0                        71.299468                 1.115789
# 1                        71.299468                 1.115789
#
#    INMET_TEMP_C_1WEEK_BEFORE_AVG  \
# 0                      23.258355
# 1                      23.258355
#
#    INMET_RELATIVE_AIR_HUMIDITY_1WEEK_BEFORE_AVG  \
# 0                                     74.984254
# 1                                     74.984254
#
#    INMET_DAILY_PRECIPT_1WEEK_BEFORE_AVG  INMET_TEMP_C_2WEEKS_BEFORE_AVG  \
# 0                                  2.16                       24.092008
# 1                                  2.16                       24.092008
#
#    INMET_RELATIVE_AIR_HUMIDITY_2WEEKS_BEFORE_AVG  \
# 0                                      74.733094
# 1                                      74.733094
#
#    INMET_DAILY_PRECIPT_2WEEKS_BEFORE_AVG GMR_TRANSIT_STATIONS_Q  \
# 0                               1.653012                      3
# 1                               1.653012                      3
#
#   GMR_GROCERY_AND_PHARMACY_Q GMR_RETAIL_AND_RECREATION_Q  \
# 0                          5                           3
# 1                          5                           3
#
#   GMR_WORKPLACES_PERCENT_Q GMR_RESIDENTIAL_PERCENT_Q GMR_PARKS_PERCENT_Q  \
# 0                        4                         2                   2
# 1                        4                         2                   2
#
#   GMR_TRANSIT_STATIONS_1WEEK_BEFORE_Q GMR_GROCERY_AND_PHARMACY_1WEEK_BEFORE_Q  \
# 0                                   4                                       5
# 1                                   4                                       5
#
#   GMR_RETAIL_AND_RECREATION_1WEEK_BEFORE_Q  \
# 0                                        4
# 1                                        4
#
#   GMR_WORKPLACES_PERCENT_1WEEK_BEFORE_Q  \
# 0                                     5
# 1                                     5
#
#   GMR_RESIDENTIAL_PERCENT_1WEEK_BEFORE_Q GMR_PARKS_PERCENT_1WEEK_BEFORE_Q  \
# 0                                      2                                2
# 1                                      2                                2
#
#   GMR_TRANSIT_STATIONS_2WEEKS_Q GMR_GROCERY_AND_PHARMACY_2WEEKS_Q  \
# 0                             3                                 4
# 1                             3                                 4
#
#   GMR_RETAIL_AND_RECREATION_2WEEKS_Q GMR_WORKPLACES_PERCENT_2WEEKS_Q  \
# 0                                  3                               3
# 1                                  3                               3
#
#   GMR_RESIDENTIAL_PERCENT_2WEEKS_Q GMR_PARKS_PERCENT_2WEEKS_Q INMET_TEMP_C_Q  \
# 0                                3                          1              2
# 1                                3                          1              2
#
#   INMET_RELATIVE_AIR_HUMIDITY_Q INMET_DAILY_PRECIPT_Q  \
# 0                             3                     2
# 1                             3                     2
#
#   INMET_TEMP_C_1WEEK_BEFORE_Q INMET_RELATIVE_AIR_HUMIDITY_1WEEK_BEFORE_Q  \
# 0                           3                                          4
# 1                           3                                          4
#
#   INMET_DAILY_PRECIPT_1WEEK_BEFORE_Q INMET_TEMP_C_2WEEKS_BEFORE_Q  \
# 0                                  3                            4
# 1                                  3                            4
#
#   INMET_RELATIVE_AIR_HUMIDITY_2WEEKS_BEFORE_Q  \
# 0                                           4
# 1                                           4
#
#   INMET_DAILY_PRECIPT_2WEEKS_BEFORE_Q   ANO
# 0                                   2  2021
# 1                                   2  2021

# %%
df2 = spark.read.parquet('gs://ai-covid19-datalake/trusted/super-srag_filters/super-srag_covid_pcrpositive.parquet')
df2.limit(2).toPandas()
# Out:
#     NU_NOTIFIC CS_SEXO     DT_NASC  AGE_AT_NOTIF  AGE_GROUP  CS_GESTANT  \
# 0  68719818720       F  1988-06-04            32          5           5
# 1  77309826880       M  1964-05-31            56          7           6
#
#    CS_RACA CS_ETINIA  CS_ESCOL_N SG_UF  CO_MUN_RES SEM_PRI SEM_NOT  \
# 0        4      None         3.0    BA      292740      19      20
# 1        9      None         NaN    BA      292740      19      19
#
#    DIST_PRI_NOTIFIC  DT_SIN_PRI SG_UF_NOT CO_MUN_NOT SURTO_SG  NOSOCOMIAL  \
# 0                 7  2021-05-12        BA     292740     None           2
# 1                 2  2021-05-10        BA     292740     None           2
#
#    AVE_SUINO  VACINA HOSPITAL  DIST_PRI_INTERNA  SUPORT_VEN  UTI  \
# 0          9       9        1                 6           9    2
# 1          9       9        1                 1           3    1
#
#    DIST_PRI_ENTUTI CLASSI_OUT CRITERIO EVOLUCAO  CLASSI_FIN SYMP_GROUP1  \
# 0              NaN       None        1     None           5           3
# 1              1.0       None        1     None           5           3
#
#   SYMP_GROUP2 SYMP_GROUP3 SYMP_GROUP4  OUTRO_SIN          OUTRO_DES RF_GROUP1  \
# 0           1           1           4        1.0  PROSTACAO INTENSA         9
# 1           2           1           1        NaN               None         1
#
#   RF_GROUP2 RF_GROUP3 RF_GROUP4 OBES_IMC OUT_MORBI MORB_DESC  RAIOX_RES  \
# 0         9         9         9       34         2      None        6.0
# 1         1         1         1     None      None      None        NaN
#
#   DIST_PRI_RAIOX TOMO_RES  DIST_PRI_TOMO  AMOSTRA  TP_AMOSTRA   DT_COLETA  \
# 0           None        1            6.0        1           1  2021-05-15
# 1           None        6            NaN        1           1  2021-05-10
#
#    DIST_PRI_COLETA PP_IF_RESUL PP_TRA_RESUL DIST_PRI_TRA PP_PCR_RESUL  \
# 0                3           9            9         None            2
# 1                0           9            9         None            2
#
#    DIST_PRI_PCR PP_RES_SOR_IGA PP_RES_SOR_IGM PP_RES_SOR_IGG DIST_PRI_SOR  \
# 0             7              4              4              4         None
# 1             2              4              4              4         None
#
#   DIST_PRI_IF DIST_PRI_NOTIFIC_Q DIST_PRI_INTERNA_Q DIST_PRI_ENTUTI_Q  \
# 0        None                  3                  3                 6
# 1        None                  1                  1                 1
#
#   DIST_PRI_SAIDUTI_Q DIST_PRI_EVOLUCA_Q DIST_PRI_ENCERRA_Q DIST_PRI_RAIOX_Q  \
# 0                  6                  6                  1                6
# 1                  6                  6                  6                6
#
#   DIST_PRI_TOMO_Q DIST_PRI_COLETA_Q DIST_PRI_SOR_Q DIST_PRI_PCR_Q  \
# 0               2                 2              6              3
# 1               6                 1              6              1
#
#   DIST_PRI_TRA_Q DIST_PRI_IF_Q EPI_WEEK_YEAR  GMR_TRANSIT_STATIONS_AVG  \
# 0              6             6       19-2021                -26.208333
# 1              6             6       19-2021                -26.208333
#
#    GMR_GROCERY_AND_PHARMACY_AVG  GMR_RETAIL_AND_RECREATION_AVG  \
# 0                     31.788462                     -24.079137
# 1                     31.788462                     -24.079137
#
#    GMR_WORKPLACES_PERCENT_AVG  GMR_RESIDENTIAL_PERCENT_AVG  \
# 0                   -0.099905                     7.358333
# 1                   -0.099905                     7.358333
#
#    GMR_PARKS_PERCENT_AVG  GMR_TRANSIT_STATIONS_1WEEK_BEFORE_AVG  \
# 0              -44.62533                             -25.097436
# 1              -44.62533                             -25.097436
#
#    GMR_GROCERY_AND_PHARMACY_1WEEK_BEFORE_AVG  \
# 0                                  34.628571
# 1                                  34.628571
#
#    GMR_RETAIL_AND_RECREATION_1WEEK_BEFORE_AVG  \
# 0                                  -20.930314
# 1                                  -20.930314
#
#    GMR_WORKPLACES_PERCENT_1WEEK_BEFORE_AVG  \
# 0                                 0.773764
# 1                                 0.773764
#
#    GMR_RESIDENTIAL_PERCENT_1WEEK_BEFORE_AVG  \
# 0                                   6.81768
# 1                                   6.81768
#
#    GMR_PARKS_PERCENT_1WEEK_BEFORE_AVG  GMR_TRANSIT_STATIONS_2WEEKS_AVG  \
# 0                          -44.472296                       -31.233161
# 1                          -44.472296                       -31.233161
#
#    GMR_GROCERY_AND_PHARMACY_2WEEKS_AVG  GMR_RETAIL_AND_RECREATION_2WEEKS_AVG  \
# 0                            17.257009                            -30.477193
# 1                            17.257009                            -30.477193
#
#    GMR_WORKPLACES_PERCENT_2WEEKS_AVG  GMR_RESIDENTIAL_PERCENT_2WEEKS_AVG  \
# 0                          -4.605239                            8.130556
# 1                          -4.605239                            8.130556
#
#    GMR_PARKS_PERCENT_2WEEKS_AVG  INMET_TEMP_C_AVG  \
# 0                    -46.526854         22.265185
# 1                    -46.526854         22.265185
#
#    INMET_RELATIVE_AIR_HUMIDITY_AVG  INMET_DAILY_PRECIPT_AVG  \
# 0                        71.299468                 1.115789
# 1                        71.299468                 1.115789
#
#    INMET_TEMP_C_1WEEK_BEFORE_AVG  \
# 0                      23.258355
# 1                      23.258355
#
#    INMET_RELATIVE_AIR_HUMIDITY_1WEEK_BEFORE_AVG  \
# 0                                     74.984254
# 1                                     74.984254
#
#    INMET_DAILY_PRECIPT_1WEEK_BEFORE_AVG  INMET_TEMP_C_2WEEKS_BEFORE_AVG  \
# 0                                  2.16                       24.092008
# 1                                  2.16                       24.092008
#
#    INMET_RELATIVE_AIR_HUMIDITY_2WEEKS_BEFORE_AVG  \
# 0                                      74.733094
# 1                                      74.733094
#
#    INMET_DAILY_PRECIPT_2WEEKS_BEFORE_AVG GMR_TRANSIT_STATIONS_Q  \
# 0                               1.653012                      3
# 1                               1.653012                      3
#
#   GMR_GROCERY_AND_PHARMACY_Q GMR_RETAIL_AND_RECREATION_Q  \
# 0                          5                           3
# 1                          5                           3
#
#   GMR_WORKPLACES_PERCENT_Q GMR_RESIDENTIAL_PERCENT_Q GMR_PARKS_PERCENT_Q  \
# 0                        4                         2                   2
# 1                        4                         2                   2
#
#   GMR_TRANSIT_STATIONS_1WEEK_BEFORE_Q GMR_GROCERY_AND_PHARMACY_1WEEK_BEFORE_Q  \
# 0                                   4                                       5
# 1                                   4                                       5
#
#   GMR_RETAIL_AND_RECREATION_1WEEK_BEFORE_Q  \
# 0                                        4
# 1                                        4
#
#   GMR_WORKPLACES_PERCENT_1WEEK_BEFORE_Q  \
# 0                                     5
# 1                                     5
#
#   GMR_RESIDENTIAL_PERCENT_1WEEK_BEFORE_Q GMR_PARKS_PERCENT_1WEEK_BEFORE_Q  \
# 0                                      2                                2
# 1                                      2                                2
#
#   GMR_TRANSIT_STATIONS_2WEEKS_Q GMR_GROCERY_AND_PHARMACY_2WEEKS_Q  \
# 0                             3                                 4
# 1                             3                                 4
#
#   GMR_RETAIL_AND_RECREATION_2WEEKS_Q GMR_WORKPLACES_PERCENT_2WEEKS_Q  \
# 0                                  3                               3
# 1                                  3                               3
#
#   GMR_RESIDENTIAL_PERCENT_2WEEKS_Q GMR_PARKS_PERCENT_2WEEKS_Q INMET_TEMP_C_Q  \
# 0                                3                          1              2
# 1                                3                          1              2
#
#   INMET_RELATIVE_AIR_HUMIDITY_Q INMET_DAILY_PRECIPT_Q  \
# 0                             3                     2
# 1                             3                     2
#
#   INMET_TEMP_C_1WEEK_BEFORE_Q INMET_RELATIVE_AIR_HUMIDITY_1WEEK_BEFORE_Q  \
# 0                           3                                          4
# 1                           3                                          4
#
#   INMET_DAILY_PRECIPT_1WEEK_BEFORE_Q INMET_TEMP_C_2WEEKS_BEFORE_Q  \
# 0                                  3                            4
# 1                                  3                            4
#
#   INMET_RELATIVE_AIR_HUMIDITY_2WEEKS_BEFORE_Q  \
# 0                                           4
# 1                                           4
#
#   INMET_DAILY_PRECIPT_2WEEKS_BEFORE_Q   ANO
# 0                                   2  2021
# 1                                   2  2021

# %%
df3 = spark.read.parquet('gs://ai-covid19-datalake/trusted/super-srag_filters/super-srag_covid_labpositive.parquet')
df3.limit(2).toPandas()
# Out:
#     NU_NOTIFIC CS_SEXO     DT_NASC  AGE_AT_NOTIF  AGE_GROUP  CS_GESTANT  \
# 0  77309859740       M  1968-12-02            52          7           6
# 1  68719688318       F  1968-12-02            52          7           5
#
#    CS_RACA CS_ETINIA  CS_ESCOL_N SG_UF  CO_MUN_RES SEM_PRI SEM_NOT  \
# 0        4      None         4.0    BA      290730      19      20
# 1        4      None         NaN    BA      292370      19      19
#
#    DIST_PRI_NOTIFIC  DT_SIN_PRI SG_UF_NOT CO_MUN_NOT SURTO_SG  NOSOCOMIAL  \
# 0                 7  2021-05-13        BA     291920     None         NaN
# 1                 5  2021-05-10        BA     290520     None         2.0
#
#    AVE_SUINO  VACINA HOSPITAL  DIST_PRI_INTERNA  SUPORT_VEN  UTI  \
# 0        NaN     9.0        1                 6           2    2
# 1        9.0     NaN        1                 6           2    1
#
#    DIST_PRI_ENTUTI CLASSI_OUT CRITERIO EVOLUCAO  CLASSI_FIN SYMP_GROUP1  \
# 0              NaN       None        1     None           5           4
# 1              6.0       None        1        2           5           8
#
#   SYMP_GROUP2 SYMP_GROUP3 SYMP_GROUP4  OUTRO_SIN OUTRO_DES RF_GROUP1  \
# 0           6           1           1        2.0      None         9
# 1           6           2           5        NaN      None         1
#
#   RF_GROUP2 RF_GROUP3 RF_GROUP4 OBES_IMC OUT_MORBI MORB_DESC RAIOX_RES  \
# 0         9         9         9     None         2      None      None
# 1         1         5         1     None      None      None      None
#
#   DIST_PRI_RAIOX TOMO_RES  DIST_PRI_TOMO  AMOSTRA  TP_AMOSTRA   DT_COLETA  \
# 0           None     None            NaN        1           1  2021-05-14
# 1           None        1            5.0        1           1  2021-05-14
#
#    DIST_PRI_COLETA PP_IF_RESUL PP_TRA_RESUL  DIST_PRI_TRA PP_PCR_RESUL  \
# 0                1           2            9           NaN            6
# 1                4           6            2           4.0            6
#
#   DIST_PRI_PCR PP_RES_SOR_IGA PP_RES_SOR_IGM PP_RES_SOR_IGG DIST_PRI_SOR  \
# 0         None              4              4              4         None
# 1         None              4              4              4         None
#
#    DIST_PRI_IF DIST_PRI_NOTIFIC_Q DIST_PRI_INTERNA_Q DIST_PRI_ENTUTI_Q  \
# 0          1.0                  3                  3                 6
# 1          NaN                  2                  3                 3
#
#   DIST_PRI_SAIDUTI_Q DIST_PRI_EVOLUCA_Q DIST_PRI_ENCERRA_Q DIST_PRI_RAIOX_Q  \
# 0                  6                  6                  1                6
# 1                  6                  2                  1                6
#
#   DIST_PRI_TOMO_Q DIST_PRI_COLETA_Q DIST_PRI_SOR_Q DIST_PRI_PCR_Q  \
# 0               6                 1              6              6
# 1               2                 3              6              6
#
#   DIST_PRI_TRA_Q DIST_PRI_IF_Q EPI_WEEK_YEAR  GMR_TRANSIT_STATIONS_AVG  \
# 0              6             1       19-2021                -26.208333
# 1              3             6       19-2021                -26.208333
#
#    GMR_GROCERY_AND_PHARMACY_AVG  GMR_RETAIL_AND_RECREATION_AVG  \
# 0                     31.788462                     -24.079137
# 1                     31.788462                     -24.079137
#
#    GMR_WORKPLACES_PERCENT_AVG  GMR_RESIDENTIAL_PERCENT_AVG  \
# 0                   -0.099905                     7.358333
# 1                   -0.099905                     7.358333
#
#    GMR_PARKS_PERCENT_AVG  GMR_TRANSIT_STATIONS_1WEEK_BEFORE_AVG  \
# 0              -44.62533                             -25.097436
# 1              -44.62533                             -25.097436
#
#    GMR_GROCERY_AND_PHARMACY_1WEEK_BEFORE_AVG  \
# 0                                  34.628571
# 1                                  34.628571
#
#    GMR_RETAIL_AND_RECREATION_1WEEK_BEFORE_AVG  \
# 0                                  -20.930314
# 1                                  -20.930314
#
#    GMR_WORKPLACES_PERCENT_1WEEK_BEFORE_AVG  \
# 0                                 0.773764
# 1                                 0.773764
#
#    GMR_RESIDENTIAL_PERCENT_1WEEK_BEFORE_AVG  \
# 0                                   6.81768
# 1                                   6.81768
#
#    GMR_PARKS_PERCENT_1WEEK_BEFORE_AVG  GMR_TRANSIT_STATIONS_2WEEKS_AVG  \
# 0                          -44.472296                       -31.233161
# 1                          -44.472296                       -31.233161
#
#    GMR_GROCERY_AND_PHARMACY_2WEEKS_AVG  GMR_RETAIL_AND_RECREATION_2WEEKS_AVG  \
# 0                            17.257009                            -30.477193
# 1                            17.257009                            -30.477193
#
#    GMR_WORKPLACES_PERCENT_2WEEKS_AVG  GMR_RESIDENTIAL_PERCENT_2WEEKS_AVG  \
# 0                          -4.605239                            8.130556
# 1                          -4.605239                            8.130556
#
#    GMR_PARKS_PERCENT_2WEEKS_AVG  INMET_TEMP_C_AVG  \
# 0                    -46.526854         22.265185
# 1                    -46.526854         22.265185
#
#    INMET_RELATIVE_AIR_HUMIDITY_AVG  INMET_DAILY_PRECIPT_AVG  \
# 0                        71.299468                 1.115789
# 1                        71.299468                 1.115789
#
#    INMET_TEMP_C_1WEEK_BEFORE_AVG  \
# 0                      23.258355
# 1                      23.258355
#
#    INMET_RELATIVE_AIR_HUMIDITY_1WEEK_BEFORE_AVG  \
# 0                                     74.984254
# 1                                     74.984254
#
#    INMET_DAILY_PRECIPT_1WEEK_BEFORE_AVG  INMET_TEMP_C_2WEEKS_BEFORE_AVG  \
# 0                                  2.16                       24.092008
# 1                                  2.16                       24.092008
#
#    INMET_RELATIVE_AIR_HUMIDITY_2WEEKS_BEFORE_AVG  \
# 0                                      74.733094
# 1                                      74.733094
#
#    INMET_DAILY_PRECIPT_2WEEKS_BEFORE_AVG GMR_TRANSIT_STATIONS_Q  \
# 0                               1.653012                      3
# 1                               1.653012                      3
#
#   GMR_GROCERY_AND_PHARMACY_Q GMR_RETAIL_AND_RECREATION_Q  \
# 0                          5                           3
# 1                          5                           3
#
#   GMR_WORKPLACES_PERCENT_Q GMR_RESIDENTIAL_PERCENT_Q GMR_PARKS_PERCENT_Q  \
# 0                        4                         2                   2
# 1                        4                         2                   2
#
#   GMR_TRANSIT_STATIONS_1WEEK_BEFORE_Q GMR_GROCERY_AND_PHARMACY_1WEEK_BEFORE_Q  \
# 0                                   4                                       5
# 1                                   4                                       5
#
#   GMR_RETAIL_AND_RECREATION_1WEEK_BEFORE_Q  \
# 0                                        4
# 1                                        4
#
#   GMR_WORKPLACES_PERCENT_1WEEK_BEFORE_Q  \
# 0                                     5
# 1                                     5
#
#   GMR_RESIDENTIAL_PERCENT_1WEEK_BEFORE_Q GMR_PARKS_PERCENT_1WEEK_BEFORE_Q  \
# 0                                      2                                2
# 1                                      2                                2
#
#   GMR_TRANSIT_STATIONS_2WEEKS_Q GMR_GROCERY_AND_PHARMACY_2WEEKS_Q  \
# 0                             3                                 4
# 1                             3                                 4
#
#   GMR_RETAIL_AND_RECREATION_2WEEKS_Q GMR_WORKPLACES_PERCENT_2WEEKS_Q  \
# 0                                  3                               3
# 1                                  3                               3
#
#   GMR_RESIDENTIAL_PERCENT_2WEEKS_Q GMR_PARKS_PERCENT_2WEEKS_Q INMET_TEMP_C_Q  \
# 0                                3                          1              2
# 1                                3                          1              2
#
#   INMET_RELATIVE_AIR_HUMIDITY_Q INMET_DAILY_PRECIPT_Q  \
# 0                             3                     2
# 1                             3                     2
#
#   INMET_TEMP_C_1WEEK_BEFORE_Q INMET_RELATIVE_AIR_HUMIDITY_1WEEK_BEFORE_Q  \
# 0                           3                                          4
# 1                           3                                          4
#
#   INMET_DAILY_PRECIPT_1WEEK_BEFORE_Q INMET_TEMP_C_2WEEKS_BEFORE_Q  \
# 0                                  3                            4
# 1                                  3                            4
#
#   INMET_RELATIVE_AIR_HUMIDITY_2WEEKS_BEFORE_Q  \
# 0                                           4
# 1                                           4
#
#   INMET_DAILY_PRECIPT_2WEEKS_BEFORE_Q   ANO
# 0                                   2  2021
# 1                                   2  2021

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %% [markdown]
# # Preprocessing data

# %%
not_covid = preprocessing(not_covid)
not_covid.limit(2).toPandas()
# Out:
#     NU_NOTIFIC  CS_SEXO     DT_NASC  AGE_AT_NOTIF  AGE_GROUP  CS_GESTANT  \
# 0  77309712285      1.0  2020-09-18             0        1.0           6
# 1  85899613066      1.0  2010-03-11            10        3.0           6
#
#    CS_RACA CS_ETINIA  CS_ESCOL_N  SG_UF  CO_MUN_RES SEM_PRI SEM_NOT  \
# 0      4.0      9999         0.0   35.0      352620       4       4
# 1      9.0      9999      9999.0   35.0      355030       4       5
#
#    DIST_PRI_NOTIFIC  DT_SIN_PRI  SG_UF_NOT CO_MUN_NOT  SURTO_SG  NOSOCOMIAL  \
# 0                 2  2021-01-26       35.0     352220       9.0           2
# 1                 5  2021-01-28       35.0     355030       2.0           2
#
#    AVE_SUINO  VACINA  HOSPITAL  DIST_PRI_INTERNA  SUPORT_VEN     UTI  \
# 0          2    9999       1.0                 1         2.0     2.0
# 1          9       9       2.0              9999         3.0  9999.0
#
#    DIST_PRI_ENTUTI CLASSI_OUT  CRITERIO  EVOLUCAO  CLASSI_FIN  SYMP_GROUP1  \
# 0             9999       9999       1.0       1.0         0.0          3.0
# 1             9999       9999       1.0       1.0         0.0          8.0
#
#    SYMP_GROUP2  SYMP_GROUP3  SYMP_GROUP4  OUTRO_SIN OUTRO_DES  RF_GROUP1  \
# 0          8.0          1.0          1.0        2.0      9999        1.0
# 1          1.0          1.0          1.0     9999.0      9999        1.0
#
#    RF_GROUP2  RF_GROUP3  RF_GROUP4 OBES_IMC OUT_MORBI MORB_DESC  RAIOX_RES  \
# 0        1.0        1.0        1.0     9999      9999      9999       9999
# 1        1.0        1.0        1.0     9999      9999      9999          6
#
#    DIST_PRI_RAIOX TOMO_RES  DIST_PRI_TOMO  AMOSTRA  TP_AMOSTRA   DT_COLETA  \
# 0            9999     9999           9999        1           1  2021-01-27
# 1            9999        6           9999        1           1  2021-01-31
#
#    DIST_PRI_COLETA PP_IF_RESUL PP_TRA_RESUL  DIST_PRI_TRA PP_PCR_RESUL  \
# 0                1           6            3             2            4
# 1                3           9            9          9999            3
#
#    DIST_PRI_PCR PP_RES_SOR_IGA PP_RES_SOR_IGM PP_RES_SOR_IGG  DIST_PRI_SOR  \
# 0             6              4              4              4          9999
# 1             3              4              4              4          9999
#
#    DIST_PRI_IF  DIST_PRI_NOTIFIC_Q  DIST_PRI_INTERNA_Q  DIST_PRI_ENTUTI_Q  \
# 0         9999                 1.0                 1.0                6.0
# 1         9999                 2.0                 6.0                6.0
#
#    DIST_PRI_SAIDUTI_Q  DIST_PRI_EVOLUCA_Q  DIST_PRI_ENCERRA_Q  \
# 0                 6.0                 4.0                 4.0
# 1                 6.0                 1.0                 2.0
#
#    DIST_PRI_RAIOX_Q  DIST_PRI_TOMO_Q  DIST_PRI_COLETA_Q  DIST_PRI_SOR_Q  \
# 0               6.0              6.0                1.0             6.0
# 1               6.0              6.0                2.0             6.0
#
#    DIST_PRI_PCR_Q  DIST_PRI_TRA_Q  DIST_PRI_IF_Q EPI_WEEK_YEAR  \
# 0             2.0             1.0            6.0       04-2021
# 1             1.0             6.0            6.0       04-2021
#
#    GMR_TRANSIT_STATIONS_AVG  GMR_GROCERY_AND_PHARMACY_AVG  \
# 0                -25.895942                      6.296242
# 1                -25.895942                      6.296242
#
#    GMR_RETAIL_AND_RECREATION_AVG  GMR_WORKPLACES_PERCENT_AVG  \
# 0                     -28.311178                   -6.281181
# 1                     -28.311178                   -6.281181
#
#    GMR_RESIDENTIAL_PERCENT_AVG  GMR_PARKS_PERCENT_AVG  \
# 0                     6.003215             -23.171171
# 1                     6.003215             -23.171171
#
#    GMR_TRANSIT_STATIONS_1WEEK_BEFORE_AVG  \
# 0                             -26.123958
# 1                             -26.123958
#
#    GMR_GROCERY_AND_PHARMACY_1WEEK_BEFORE_AVG  \
# 0                                   4.771699
# 1                                   4.771699
#
#    GMR_RETAIL_AND_RECREATION_1WEEK_BEFORE_AVG  \
# 0                                  -24.164021
# 1                                  -24.164021
#
#    GMR_WORKPLACES_PERCENT_1WEEK_BEFORE_AVG  \
# 0                                -7.336648
# 1                                -7.336648
#
#    GMR_RESIDENTIAL_PERCENT_1WEEK_BEFORE_AVG  \
# 0                                  5.483269
# 1                                  5.483269
#
#    GMR_PARKS_PERCENT_1WEEK_BEFORE_AVG  GMR_TRANSIT_STATIONS_2WEEKS_AVG  \
# 0                          -25.172172                       -23.547269
# 1                          -25.172172                       -23.547269
#
#    GMR_GROCERY_AND_PHARMACY_2WEEKS_AVG  GMR_RETAIL_AND_RECREATION_2WEEKS_AVG  \
# 0                             8.872993                            -20.801375
# 1                             8.872993                            -20.801375
#
#    GMR_WORKPLACES_PERCENT_2WEEKS_AVG  GMR_RESIDENTIAL_PERCENT_2WEEKS_AVG  \
# 0                          -4.632532                            5.748876
# 1                          -4.632532                            5.748876
#
#    GMR_PARKS_PERCENT_2WEEKS_AVG  INMET_TEMP_C_AVG  \
# 0                     -25.86341         24.476172
# 1                     -25.86341         24.476172
#
#    INMET_RELATIVE_AIR_HUMIDITY_AVG  INMET_DAILY_PRECIPT_AVG  \
# 0                        72.664078                 4.339216
# 1                        72.664078                 4.339216
#
#    INMET_TEMP_C_1WEEK_BEFORE_AVG  \
# 0                       24.36574
# 1                       24.36574
#
#    INMET_RELATIVE_AIR_HUMIDITY_1WEEK_BEFORE_AVG  \
# 0                                     75.171226
# 1                                     75.171226
#
#    INMET_DAILY_PRECIPT_1WEEK_BEFORE_AVG  INMET_TEMP_C_2WEEKS_BEFORE_AVG  \
# 0                                 6.304                       24.070494
# 1                                 6.304                       24.070494
#
#    INMET_RELATIVE_AIR_HUMIDITY_2WEEKS_BEFORE_AVG  \
# 0                                      79.940901
# 1                                      79.940901
#
#    INMET_DAILY_PRECIPT_2WEEKS_BEFORE_AVG GMR_TRANSIT_STATIONS_Q  \
# 0                               6.042424                      3
# 1                               6.042424                      3
#
#   GMR_GROCERY_AND_PHARMACY_Q GMR_RETAIL_AND_RECREATION_Q  \
# 0                          2                           3
# 1                          2                           3
#
#   GMR_WORKPLACES_PERCENT_Q GMR_RESIDENTIAL_PERCENT_Q GMR_PARKS_PERCENT_Q  \
# 0                        3                         2                   4
# 1                        3                         2                   4
#
#    GMR_TRANSIT_STATIONS_1WEEK_BEFORE_Q  \
# 0                                  3.0
# 1                                  3.0
#
#   GMR_GROCERY_AND_PHARMACY_1WEEK_BEFORE_Q  \
# 0                                       2
# 1                                       2
#
#    GMR_RETAIL_AND_RECREATION_1WEEK_BEFORE_Q  \
# 0                                       3.0
# 1                                       3.0
#
#    GMR_WORKPLACES_PERCENT_1WEEK_BEFORE_Q  \
# 0                                    3.0
# 1                                    3.0
#
#    GMR_RESIDENTIAL_PERCENT_1WEEK_BEFORE_Q GMR_PARKS_PERCENT_1WEEK_BEFORE_Q  \
# 0                                     1.0                                4
# 1                                     1.0                                4
#
#    GMR_TRANSIT_STATIONS_2WEEKS_Q GMR_GROCERY_AND_PHARMACY_2WEEKS_Q  \
# 0                            4.0                                 3
# 1                            4.0                                 3
#
#    GMR_RETAIL_AND_RECREATION_2WEEKS_Q  GMR_WORKPLACES_PERCENT_2WEEKS_Q  \
# 0                                 4.0                              3.0
# 1                                 4.0                              3.0
#
#    GMR_RESIDENTIAL_PERCENT_2WEEKS_Q GMR_PARKS_PERCENT_2WEEKS_Q INMET_TEMP_C_Q  \
# 0                               2.0                          4              4
# 1                               2.0                          4              4
#
#   INMET_RELATIVE_AIR_HUMIDITY_Q INMET_DAILY_PRECIPT_Q  \
# 0                             3                     4
# 1                             3                     4
#
#   INMET_TEMP_C_1WEEK_BEFORE_Q  INMET_RELATIVE_AIR_HUMIDITY_1WEEK_BEFORE_Q  \
# 0                           4                                         4.0
# 1                           4                                         4.0
#
#   INMET_DAILY_PRECIPT_1WEEK_BEFORE_Q INMET_TEMP_C_2WEEKS_BEFORE_Q  \
# 0                                  5                            4
# 1                                  5                            4
#
#    INMET_RELATIVE_AIR_HUMIDITY_2WEEKS_BEFORE_Q  \
# 0                                          5.0
# 1                                          5.0
#
#   INMET_DAILY_PRECIPT_2WEEKS_BEFORE_Q   ANO
# 0                                   4  2021
# 1                                   4  2021

# %%
df1 = preprocessing(df1)
df1.limit(2).toPandas()
# Out:
#     NU_NOTIFIC  CS_SEXO     DT_NASC  AGE_AT_NOTIF  AGE_GROUP  CS_GESTANT  \
# 0  77309859740      1.0  1968-12-02            52        7.0           6
# 1  68719688318      2.0  1968-12-02            52        7.0           5
#
#    CS_RACA CS_ETINIA  CS_ESCOL_N  SG_UF  CO_MUN_RES SEM_PRI SEM_NOT  \
# 0      4.0      9999         4.0   29.0      290730      19      20
# 1      4.0      9999      9999.0   29.0      292370      19      19
#
#    DIST_PRI_NOTIFIC  DT_SIN_PRI  SG_UF_NOT CO_MUN_NOT  SURTO_SG  NOSOCOMIAL  \
# 0                 7  2021-05-13       29.0     291920    9999.0        9999
# 1                 5  2021-05-10       29.0     290520    9999.0           2
#
#    AVE_SUINO  VACINA  HOSPITAL  DIST_PRI_INTERNA  SUPORT_VEN  UTI  \
# 0       9999       9       1.0                 6         2.0  2.0
# 1          9    9999       1.0                 6         2.0  1.0
#
#    DIST_PRI_ENTUTI CLASSI_OUT  CRITERIO  EVOLUCAO  CLASSI_FIN  SYMP_GROUP1  \
# 0             9999       9999       1.0    9999.0         1.0          4.0
# 1                6       9999       1.0       2.0         1.0          8.0
#
#    SYMP_GROUP2  SYMP_GROUP3  SYMP_GROUP4  OUTRO_SIN OUTRO_DES  RF_GROUP1  \
# 0          6.0          1.0          1.0        2.0      9999        9.0
# 1          6.0          2.0          5.0     9999.0      9999        1.0
#
#    RF_GROUP2  RF_GROUP3  RF_GROUP4 OBES_IMC OUT_MORBI MORB_DESC  RAIOX_RES  \
# 0        9.0        9.0        9.0     9999         2      9999       9999
# 1        1.0        5.0        1.0     9999      9999      9999       9999
#
#    DIST_PRI_RAIOX TOMO_RES  DIST_PRI_TOMO  AMOSTRA  TP_AMOSTRA   DT_COLETA  \
# 0            9999     9999           9999        1           1  2021-05-14
# 1            9999        1              5        1           1  2021-05-14
#
#    DIST_PRI_COLETA PP_IF_RESUL PP_TRA_RESUL  DIST_PRI_TRA PP_PCR_RESUL  \
# 0                1           2            9          9999            6
# 1                4           6            2             4            6
#
#    DIST_PRI_PCR PP_RES_SOR_IGA PP_RES_SOR_IGM PP_RES_SOR_IGG  DIST_PRI_SOR  \
# 0          9999              4              4              4          9999
# 1          9999              4              4              4          9999
#
#    DIST_PRI_IF  DIST_PRI_NOTIFIC_Q  DIST_PRI_INTERNA_Q  DIST_PRI_ENTUTI_Q  \
# 0            1                 3.0                 3.0                6.0
# 1         9999                 2.0                 3.0                3.0
#
#    DIST_PRI_SAIDUTI_Q  DIST_PRI_EVOLUCA_Q  DIST_PRI_ENCERRA_Q  \
# 0                 6.0                 6.0                 1.0
# 1                 6.0                 2.0                 1.0
#
#    DIST_PRI_RAIOX_Q  DIST_PRI_TOMO_Q  DIST_PRI_COLETA_Q  DIST_PRI_SOR_Q  \
# 0               6.0              6.0                1.0             6.0
# 1               6.0              2.0                3.0             6.0
#
#    DIST_PRI_PCR_Q  DIST_PRI_TRA_Q  DIST_PRI_IF_Q EPI_WEEK_YEAR  \
# 0             6.0             6.0            1.0       19-2021
# 1             6.0             3.0            6.0       19-2021
#
#    GMR_TRANSIT_STATIONS_AVG  GMR_GROCERY_AND_PHARMACY_AVG  \
# 0                -26.208333                     31.788462
# 1                -26.208333                     31.788462
#
#    GMR_RETAIL_AND_RECREATION_AVG  GMR_WORKPLACES_PERCENT_AVG  \
# 0                     -24.079137                   -0.099905
# 1                     -24.079137                   -0.099905
#
#    GMR_RESIDENTIAL_PERCENT_AVG  GMR_PARKS_PERCENT_AVG  \
# 0                     7.358333              -44.62533
# 1                     7.358333              -44.62533
#
#    GMR_TRANSIT_STATIONS_1WEEK_BEFORE_AVG  \
# 0                             -25.097436
# 1                             -25.097436
#
#    GMR_GROCERY_AND_PHARMACY_1WEEK_BEFORE_AVG  \
# 0                                  34.628571
# 1                                  34.628571
#
#    GMR_RETAIL_AND_RECREATION_1WEEK_BEFORE_AVG  \
# 0                                  -20.930314
# 1                                  -20.930314
#
#    GMR_WORKPLACES_PERCENT_1WEEK_BEFORE_AVG  \
# 0                                 0.773764
# 1                                 0.773764
#
#    GMR_RESIDENTIAL_PERCENT_1WEEK_BEFORE_AVG  \
# 0                                   6.81768
# 1                                   6.81768
#
#    GMR_PARKS_PERCENT_1WEEK_BEFORE_AVG  GMR_TRANSIT_STATIONS_2WEEKS_AVG  \
# 0                          -44.472296                       -31.233161
# 1                          -44.472296                       -31.233161
#
#    GMR_GROCERY_AND_PHARMACY_2WEEKS_AVG  GMR_RETAIL_AND_RECREATION_2WEEKS_AVG  \
# 0                            17.257009                            -30.477193
# 1                            17.257009                            -30.477193
#
#    GMR_WORKPLACES_PERCENT_2WEEKS_AVG  GMR_RESIDENTIAL_PERCENT_2WEEKS_AVG  \
# 0                          -4.605239                            8.130556
# 1                          -4.605239                            8.130556
#
#    GMR_PARKS_PERCENT_2WEEKS_AVG  INMET_TEMP_C_AVG  \
# 0                    -46.526854         22.265185
# 1                    -46.526854         22.265185
#
#    INMET_RELATIVE_AIR_HUMIDITY_AVG  INMET_DAILY_PRECIPT_AVG  \
# 0                        71.299468                 1.115789
# 1                        71.299468                 1.115789
#
#    INMET_TEMP_C_1WEEK_BEFORE_AVG  \
# 0                      23.258355
# 1                      23.258355
#
#    INMET_RELATIVE_AIR_HUMIDITY_1WEEK_BEFORE_AVG  \
# 0                                     74.984254
# 1                                     74.984254
#
#    INMET_DAILY_PRECIPT_1WEEK_BEFORE_AVG  INMET_TEMP_C_2WEEKS_BEFORE_AVG  \
# 0                                  2.16                       24.092008
# 1                                  2.16                       24.092008
#
#    INMET_RELATIVE_AIR_HUMIDITY_2WEEKS_BEFORE_AVG  \
# 0                                      74.733094
# 1                                      74.733094
#
#    INMET_DAILY_PRECIPT_2WEEKS_BEFORE_AVG GMR_TRANSIT_STATIONS_Q  \
# 0                               1.653012                      3
# 1                               1.653012                      3
#
#   GMR_GROCERY_AND_PHARMACY_Q GMR_RETAIL_AND_RECREATION_Q  \
# 0                          5                           3
# 1                          5                           3
#
#   GMR_WORKPLACES_PERCENT_Q GMR_RESIDENTIAL_PERCENT_Q GMR_PARKS_PERCENT_Q  \
# 0                        4                         2                   2
# 1                        4                         2                   2
#
#    GMR_TRANSIT_STATIONS_1WEEK_BEFORE_Q  \
# 0                                  4.0
# 1                                  4.0
#
#   GMR_GROCERY_AND_PHARMACY_1WEEK_BEFORE_Q  \
# 0                                       5
# 1                                       5
#
#    GMR_RETAIL_AND_RECREATION_1WEEK_BEFORE_Q  \
# 0                                       4.0
# 1                                       4.0
#
#    GMR_WORKPLACES_PERCENT_1WEEK_BEFORE_Q  \
# 0                                    5.0
# 1                                    5.0
#
#    GMR_RESIDENTIAL_PERCENT_1WEEK_BEFORE_Q GMR_PARKS_PERCENT_1WEEK_BEFORE_Q  \
# 0                                     2.0                                2
# 1                                     2.0                                2
#
#    GMR_TRANSIT_STATIONS_2WEEKS_Q GMR_GROCERY_AND_PHARMACY_2WEEKS_Q  \
# 0                            3.0                                 4
# 1                            3.0                                 4
#
#    GMR_RETAIL_AND_RECREATION_2WEEKS_Q  GMR_WORKPLACES_PERCENT_2WEEKS_Q  \
# 0                                 3.0                              3.0
# 1                                 3.0                              3.0
#
#    GMR_RESIDENTIAL_PERCENT_2WEEKS_Q GMR_PARKS_PERCENT_2WEEKS_Q INMET_TEMP_C_Q  \
# 0                               3.0                          1              2
# 1                               3.0                          1              2
#
#   INMET_RELATIVE_AIR_HUMIDITY_Q INMET_DAILY_PRECIPT_Q  \
# 0                             3                     2
# 1                             3                     2
#
#   INMET_TEMP_C_1WEEK_BEFORE_Q  INMET_RELATIVE_AIR_HUMIDITY_1WEEK_BEFORE_Q  \
# 0                           3                                         4.0
# 1                           3                                         4.0
#
#   INMET_DAILY_PRECIPT_1WEEK_BEFORE_Q INMET_TEMP_C_2WEEKS_BEFORE_Q  \
# 0                                  3                            4
# 1                                  3                            4
#
#    INMET_RELATIVE_AIR_HUMIDITY_2WEEKS_BEFORE_Q  \
# 0                                          4.0
# 1                                          4.0
#
#   INMET_DAILY_PRECIPT_2WEEKS_BEFORE_Q   ANO
# 0                                   2  2021
# 1                                   2  2021

# %%
df2 = preprocessing(df2)
df2.limit(2).toPandas()
# Out:
#     NU_NOTIFIC  CS_SEXO     DT_NASC  AGE_AT_NOTIF  AGE_GROUP  CS_GESTANT  \
# 0  68719818720      2.0  1988-06-04            32        5.0           5
# 1  77309826880      1.0  1964-05-31            56        7.0           6
#
#    CS_RACA CS_ETINIA  CS_ESCOL_N  SG_UF  CO_MUN_RES SEM_PRI SEM_NOT  \
# 0      4.0      9999         3.0   29.0      292740      19      20
# 1      9.0      9999      9999.0   29.0      292740      19      19
#
#    DIST_PRI_NOTIFIC  DT_SIN_PRI  SG_UF_NOT CO_MUN_NOT  SURTO_SG  NOSOCOMIAL  \
# 0                 7  2021-05-12       29.0     292740    9999.0           2
# 1                 2  2021-05-10       29.0     292740    9999.0           2
#
#    AVE_SUINO  VACINA  HOSPITAL  DIST_PRI_INTERNA  SUPORT_VEN  UTI  \
# 0          9       9       1.0                 6         9.0  2.0
# 1          9       9       1.0                 1         3.0  1.0
#
#    DIST_PRI_ENTUTI CLASSI_OUT  CRITERIO  EVOLUCAO  CLASSI_FIN  SYMP_GROUP1  \
# 0             9999       9999       1.0    9999.0         1.0          3.0
# 1                1       9999       1.0    9999.0         1.0          3.0
#
#    SYMP_GROUP2  SYMP_GROUP3  SYMP_GROUP4  OUTRO_SIN          OUTRO_DES  \
# 0          1.0          1.0          4.0        1.0  PROSTACAO INTENSA
# 1          2.0          1.0          1.0     9999.0               9999
#
#    RF_GROUP1  RF_GROUP2  RF_GROUP3  RF_GROUP4 OBES_IMC OUT_MORBI MORB_DESC  \
# 0        9.0        9.0        9.0        9.0       34         2      9999
# 1        1.0        1.0        1.0        1.0     9999      9999      9999
#
#    RAIOX_RES  DIST_PRI_RAIOX TOMO_RES  DIST_PRI_TOMO  AMOSTRA  TP_AMOSTRA  \
# 0          6            9999        1              6        1           1
# 1       9999            9999        6           9999        1           1
#
#     DT_COLETA  DIST_PRI_COLETA PP_IF_RESUL PP_TRA_RESUL  DIST_PRI_TRA  \
# 0  2021-05-15                3           9            9          9999
# 1  2021-05-10                0           9            9          9999
#
#   PP_PCR_RESUL  DIST_PRI_PCR PP_RES_SOR_IGA PP_RES_SOR_IGM PP_RES_SOR_IGG  \
# 0            2             7              4              4              4
# 1            2             2              4              4              4
#
#    DIST_PRI_SOR  DIST_PRI_IF  DIST_PRI_NOTIFIC_Q  DIST_PRI_INTERNA_Q  \
# 0          9999         9999                 3.0                 3.0
# 1          9999         9999                 1.0                 1.0
#
#    DIST_PRI_ENTUTI_Q  DIST_PRI_SAIDUTI_Q  DIST_PRI_EVOLUCA_Q  \
# 0                6.0                 6.0                 6.0
# 1                1.0                 6.0                 6.0
#
#    DIST_PRI_ENCERRA_Q  DIST_PRI_RAIOX_Q  DIST_PRI_TOMO_Q  DIST_PRI_COLETA_Q  \
# 0                 1.0               6.0              2.0                2.0
# 1                 6.0               6.0              6.0                1.0
#
#    DIST_PRI_SOR_Q  DIST_PRI_PCR_Q  DIST_PRI_TRA_Q  DIST_PRI_IF_Q  \
# 0             6.0             3.0             6.0            6.0
# 1             6.0             1.0             6.0            6.0
#
#   EPI_WEEK_YEAR  GMR_TRANSIT_STATIONS_AVG  GMR_GROCERY_AND_PHARMACY_AVG  \
# 0       19-2021                -26.208333                     31.788462
# 1       19-2021                -26.208333                     31.788462
#
#    GMR_RETAIL_AND_RECREATION_AVG  GMR_WORKPLACES_PERCENT_AVG  \
# 0                     -24.079137                   -0.099905
# 1                     -24.079137                   -0.099905
#
#    GMR_RESIDENTIAL_PERCENT_AVG  GMR_PARKS_PERCENT_AVG  \
# 0                     7.358333              -44.62533
# 1                     7.358333              -44.62533
#
#    GMR_TRANSIT_STATIONS_1WEEK_BEFORE_AVG  \
# 0                             -25.097436
# 1                             -25.097436
#
#    GMR_GROCERY_AND_PHARMACY_1WEEK_BEFORE_AVG  \
# 0                                  34.628571
# 1                                  34.628571
#
#    GMR_RETAIL_AND_RECREATION_1WEEK_BEFORE_AVG  \
# 0                                  -20.930314
# 1                                  -20.930314
#
#    GMR_WORKPLACES_PERCENT_1WEEK_BEFORE_AVG  \
# 0                                 0.773764
# 1                                 0.773764
#
#    GMR_RESIDENTIAL_PERCENT_1WEEK_BEFORE_AVG  \
# 0                                   6.81768
# 1                                   6.81768
#
#    GMR_PARKS_PERCENT_1WEEK_BEFORE_AVG  GMR_TRANSIT_STATIONS_2WEEKS_AVG  \
# 0                          -44.472296                       -31.233161
# 1                          -44.472296                       -31.233161
#
#    GMR_GROCERY_AND_PHARMACY_2WEEKS_AVG  GMR_RETAIL_AND_RECREATION_2WEEKS_AVG  \
# 0                            17.257009                            -30.477193
# 1                            17.257009                            -30.477193
#
#    GMR_WORKPLACES_PERCENT_2WEEKS_AVG  GMR_RESIDENTIAL_PERCENT_2WEEKS_AVG  \
# 0                          -4.605239                            8.130556
# 1                          -4.605239                            8.130556
#
#    GMR_PARKS_PERCENT_2WEEKS_AVG  INMET_TEMP_C_AVG  \
# 0                    -46.526854         22.265185
# 1                    -46.526854         22.265185
#
#    INMET_RELATIVE_AIR_HUMIDITY_AVG  INMET_DAILY_PRECIPT_AVG  \
# 0                        71.299468                 1.115789
# 1                        71.299468                 1.115789
#
#    INMET_TEMP_C_1WEEK_BEFORE_AVG  \
# 0                      23.258355
# 1                      23.258355
#
#    INMET_RELATIVE_AIR_HUMIDITY_1WEEK_BEFORE_AVG  \
# 0                                     74.984254
# 1                                     74.984254
#
#    INMET_DAILY_PRECIPT_1WEEK_BEFORE_AVG  INMET_TEMP_C_2WEEKS_BEFORE_AVG  \
# 0                                  2.16                       24.092008
# 1                                  2.16                       24.092008
#
#    INMET_RELATIVE_AIR_HUMIDITY_2WEEKS_BEFORE_AVG  \
# 0                                      74.733094
# 1                                      74.733094
#
#    INMET_DAILY_PRECIPT_2WEEKS_BEFORE_AVG GMR_TRANSIT_STATIONS_Q  \
# 0                               1.653012                      3
# 1                               1.653012                      3
#
#   GMR_GROCERY_AND_PHARMACY_Q GMR_RETAIL_AND_RECREATION_Q  \
# 0                          5                           3
# 1                          5                           3
#
#   GMR_WORKPLACES_PERCENT_Q GMR_RESIDENTIAL_PERCENT_Q GMR_PARKS_PERCENT_Q  \
# 0                        4                         2                   2
# 1                        4                         2                   2
#
#    GMR_TRANSIT_STATIONS_1WEEK_BEFORE_Q  \
# 0                                  4.0
# 1                                  4.0
#
#   GMR_GROCERY_AND_PHARMACY_1WEEK_BEFORE_Q  \
# 0                                       5
# 1                                       5
#
#    GMR_RETAIL_AND_RECREATION_1WEEK_BEFORE_Q  \
# 0                                       4.0
# 1                                       4.0
#
#    GMR_WORKPLACES_PERCENT_1WEEK_BEFORE_Q  \
# 0                                    5.0
# 1                                    5.0
#
#    GMR_RESIDENTIAL_PERCENT_1WEEK_BEFORE_Q GMR_PARKS_PERCENT_1WEEK_BEFORE_Q  \
# 0                                     2.0                                2
# 1                                     2.0                                2
#
#    GMR_TRANSIT_STATIONS_2WEEKS_Q GMR_GROCERY_AND_PHARMACY_2WEEKS_Q  \
# 0                            3.0                                 4
# 1                            3.0                                 4
#
#    GMR_RETAIL_AND_RECREATION_2WEEKS_Q  GMR_WORKPLACES_PERCENT_2WEEKS_Q  \
# 0                                 3.0                              3.0
# 1                                 3.0                              3.0
#
#    GMR_RESIDENTIAL_PERCENT_2WEEKS_Q GMR_PARKS_PERCENT_2WEEKS_Q INMET_TEMP_C_Q  \
# 0                               3.0                          1              2
# 1                               3.0                          1              2
#
#   INMET_RELATIVE_AIR_HUMIDITY_Q INMET_DAILY_PRECIPT_Q  \
# 0                             3                     2
# 1                             3                     2
#
#   INMET_TEMP_C_1WEEK_BEFORE_Q  INMET_RELATIVE_AIR_HUMIDITY_1WEEK_BEFORE_Q  \
# 0                           3                                         4.0
# 1                           3                                         4.0
#
#   INMET_DAILY_PRECIPT_1WEEK_BEFORE_Q INMET_TEMP_C_2WEEKS_BEFORE_Q  \
# 0                                  3                            4
# 1                                  3                            4
#
#    INMET_RELATIVE_AIR_HUMIDITY_2WEEKS_BEFORE_Q  \
# 0                                          4.0
# 1                                          4.0
#
#   INMET_DAILY_PRECIPT_2WEEKS_BEFORE_Q   ANO
# 0                                   2  2021
# 1                                   2  2021

# %%
df3 = preprocessing(df3)
df3.limit(2).toPandas()
# Out:
#     NU_NOTIFIC  CS_SEXO     DT_NASC  AGE_AT_NOTIF  AGE_GROUP  CS_GESTANT  \
# 0  77309859740      1.0  1968-12-02            52        7.0           6
# 1  68719688318      2.0  1968-12-02            52        7.0           5
#
#    CS_RACA CS_ETINIA  CS_ESCOL_N  SG_UF  CO_MUN_RES SEM_PRI SEM_NOT  \
# 0      4.0      9999         4.0   29.0      290730      19      20
# 1      4.0      9999      9999.0   29.0      292370      19      19
#
#    DIST_PRI_NOTIFIC  DT_SIN_PRI  SG_UF_NOT CO_MUN_NOT  SURTO_SG  NOSOCOMIAL  \
# 0                 7  2021-05-13       29.0     291920    9999.0        9999
# 1                 5  2021-05-10       29.0     290520    9999.0           2
#
#    AVE_SUINO  VACINA  HOSPITAL  DIST_PRI_INTERNA  SUPORT_VEN  UTI  \
# 0       9999       9       1.0                 6         2.0  2.0
# 1          9    9999       1.0                 6         2.0  1.0
#
#    DIST_PRI_ENTUTI CLASSI_OUT  CRITERIO  EVOLUCAO  CLASSI_FIN  SYMP_GROUP1  \
# 0             9999       9999       1.0    9999.0         1.0          4.0
# 1                6       9999       1.0       2.0         1.0          8.0
#
#    SYMP_GROUP2  SYMP_GROUP3  SYMP_GROUP4  OUTRO_SIN OUTRO_DES  RF_GROUP1  \
# 0          6.0          1.0          1.0        2.0      9999        9.0
# 1          6.0          2.0          5.0     9999.0      9999        1.0
#
#    RF_GROUP2  RF_GROUP3  RF_GROUP4 OBES_IMC OUT_MORBI MORB_DESC  RAIOX_RES  \
# 0        9.0        9.0        9.0     9999         2      9999       9999
# 1        1.0        5.0        1.0     9999      9999      9999       9999
#
#    DIST_PRI_RAIOX TOMO_RES  DIST_PRI_TOMO  AMOSTRA  TP_AMOSTRA   DT_COLETA  \
# 0            9999     9999           9999        1           1  2021-05-14
# 1            9999        1              5        1           1  2021-05-14
#
#    DIST_PRI_COLETA PP_IF_RESUL PP_TRA_RESUL  DIST_PRI_TRA PP_PCR_RESUL  \
# 0                1           2            9          9999            6
# 1                4           6            2             4            6
#
#    DIST_PRI_PCR PP_RES_SOR_IGA PP_RES_SOR_IGM PP_RES_SOR_IGG  DIST_PRI_SOR  \
# 0          9999              4              4              4          9999
# 1          9999              4              4              4          9999
#
#    DIST_PRI_IF  DIST_PRI_NOTIFIC_Q  DIST_PRI_INTERNA_Q  DIST_PRI_ENTUTI_Q  \
# 0            1                 3.0                 3.0                6.0
# 1         9999                 2.0                 3.0                3.0
#
#    DIST_PRI_SAIDUTI_Q  DIST_PRI_EVOLUCA_Q  DIST_PRI_ENCERRA_Q  \
# 0                 6.0                 6.0                 1.0
# 1                 6.0                 2.0                 1.0
#
#    DIST_PRI_RAIOX_Q  DIST_PRI_TOMO_Q  DIST_PRI_COLETA_Q  DIST_PRI_SOR_Q  \
# 0               6.0              6.0                1.0             6.0
# 1               6.0              2.0                3.0             6.0
#
#    DIST_PRI_PCR_Q  DIST_PRI_TRA_Q  DIST_PRI_IF_Q EPI_WEEK_YEAR  \
# 0             6.0             6.0            1.0       19-2021
# 1             6.0             3.0            6.0       19-2021
#
#    GMR_TRANSIT_STATIONS_AVG  GMR_GROCERY_AND_PHARMACY_AVG  \
# 0                -26.208333                     31.788462
# 1                -26.208333                     31.788462
#
#    GMR_RETAIL_AND_RECREATION_AVG  GMR_WORKPLACES_PERCENT_AVG  \
# 0                     -24.079137                   -0.099905
# 1                     -24.079137                   -0.099905
#
#    GMR_RESIDENTIAL_PERCENT_AVG  GMR_PARKS_PERCENT_AVG  \
# 0                     7.358333              -44.62533
# 1                     7.358333              -44.62533
#
#    GMR_TRANSIT_STATIONS_1WEEK_BEFORE_AVG  \
# 0                             -25.097436
# 1                             -25.097436
#
#    GMR_GROCERY_AND_PHARMACY_1WEEK_BEFORE_AVG  \
# 0                                  34.628571
# 1                                  34.628571
#
#    GMR_RETAIL_AND_RECREATION_1WEEK_BEFORE_AVG  \
# 0                                  -20.930314
# 1                                  -20.930314
#
#    GMR_WORKPLACES_PERCENT_1WEEK_BEFORE_AVG  \
# 0                                 0.773764
# 1                                 0.773764
#
#    GMR_RESIDENTIAL_PERCENT_1WEEK_BEFORE_AVG  \
# 0                                   6.81768
# 1                                   6.81768
#
#    GMR_PARKS_PERCENT_1WEEK_BEFORE_AVG  GMR_TRANSIT_STATIONS_2WEEKS_AVG  \
# 0                          -44.472296                       -31.233161
# 1                          -44.472296                       -31.233161
#
#    GMR_GROCERY_AND_PHARMACY_2WEEKS_AVG  GMR_RETAIL_AND_RECREATION_2WEEKS_AVG  \
# 0                            17.257009                            -30.477193
# 1                            17.257009                            -30.477193
#
#    GMR_WORKPLACES_PERCENT_2WEEKS_AVG  GMR_RESIDENTIAL_PERCENT_2WEEKS_AVG  \
# 0                          -4.605239                            8.130556
# 1                          -4.605239                            8.130556
#
#    GMR_PARKS_PERCENT_2WEEKS_AVG  INMET_TEMP_C_AVG  \
# 0                    -46.526854         22.265185
# 1                    -46.526854         22.265185
#
#    INMET_RELATIVE_AIR_HUMIDITY_AVG  INMET_DAILY_PRECIPT_AVG  \
# 0                        71.299468                 1.115789
# 1                        71.299468                 1.115789
#
#    INMET_TEMP_C_1WEEK_BEFORE_AVG  \
# 0                      23.258355
# 1                      23.258355
#
#    INMET_RELATIVE_AIR_HUMIDITY_1WEEK_BEFORE_AVG  \
# 0                                     74.984254
# 1                                     74.984254
#
#    INMET_DAILY_PRECIPT_1WEEK_BEFORE_AVG  INMET_TEMP_C_2WEEKS_BEFORE_AVG  \
# 0                                  2.16                       24.092008
# 1                                  2.16                       24.092008
#
#    INMET_RELATIVE_AIR_HUMIDITY_2WEEKS_BEFORE_AVG  \
# 0                                      74.733094
# 1                                      74.733094
#
#    INMET_DAILY_PRECIPT_2WEEKS_BEFORE_AVG GMR_TRANSIT_STATIONS_Q  \
# 0                               1.653012                      3
# 1                               1.653012                      3
#
#   GMR_GROCERY_AND_PHARMACY_Q GMR_RETAIL_AND_RECREATION_Q  \
# 0                          5                           3
# 1                          5                           3
#
#   GMR_WORKPLACES_PERCENT_Q GMR_RESIDENTIAL_PERCENT_Q GMR_PARKS_PERCENT_Q  \
# 0                        4                         2                   2
# 1                        4                         2                   2
#
#    GMR_TRANSIT_STATIONS_1WEEK_BEFORE_Q  \
# 0                                  4.0
# 1                                  4.0
#
#   GMR_GROCERY_AND_PHARMACY_1WEEK_BEFORE_Q  \
# 0                                       5
# 1                                       5
#
#    GMR_RETAIL_AND_RECREATION_1WEEK_BEFORE_Q  \
# 0                                       4.0
# 1                                       4.0
#
#    GMR_WORKPLACES_PERCENT_1WEEK_BEFORE_Q  \
# 0                                    5.0
# 1                                    5.0
#
#    GMR_RESIDENTIAL_PERCENT_1WEEK_BEFORE_Q GMR_PARKS_PERCENT_1WEEK_BEFORE_Q  \
# 0                                     2.0                                2
# 1                                     2.0                                2
#
#    GMR_TRANSIT_STATIONS_2WEEKS_Q GMR_GROCERY_AND_PHARMACY_2WEEKS_Q  \
# 0                            3.0                                 4
# 1                            3.0                                 4
#
#    GMR_RETAIL_AND_RECREATION_2WEEKS_Q  GMR_WORKPLACES_PERCENT_2WEEKS_Q  \
# 0                                 3.0                              3.0
# 1                                 3.0                              3.0
#
#    GMR_RESIDENTIAL_PERCENT_2WEEKS_Q GMR_PARKS_PERCENT_2WEEKS_Q INMET_TEMP_C_Q  \
# 0                               3.0                          1              2
# 1                               3.0                          1              2
#
#   INMET_RELATIVE_AIR_HUMIDITY_Q INMET_DAILY_PRECIPT_Q  \
# 0                             3                     2
# 1                             3                     2
#
#   INMET_TEMP_C_1WEEK_BEFORE_Q  INMET_RELATIVE_AIR_HUMIDITY_1WEEK_BEFORE_Q  \
# 0                           3                                         4.0
# 1                           3                                         4.0
#
#   INMET_DAILY_PRECIPT_1WEEK_BEFORE_Q INMET_TEMP_C_2WEEKS_BEFORE_Q  \
# 0                                  3                            4
# 1                                  3                            4
#
#    INMET_RELATIVE_AIR_HUMIDITY_2WEEKS_BEFORE_Q  \
# 0                                          4.0
# 1                                          4.0
#
#   INMET_DAILY_PRECIPT_2WEEKS_BEFORE_Q   ANO
# 0                                   2  2021
# 1                                   2  2021

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %% [markdown]
# # Creating all experiment datasets for stratified sampling strategy

# %%
dfs = {
    'ds-1': {'df': df1.persist(StorageLevel.MEMORY_ONLY), 'fractions': {'EPI_WEEK_YEAR': {}, 'AGE_GROUP': {}}},
    'ds-2': {'df': df2.persist(StorageLevel.MEMORY_ONLY), 'fractions': {'EPI_WEEK_YEAR': {}, 'AGE_GROUP': {}}},
    'ds-3': {'df': df3.persist(StorageLevel.MEMORY_ONLY), 'fractions': {'EPI_WEEK_YEAR': {}, 'AGE_GROUP': {}}}
}

# %%
for df in list(dfs.keys()): 
    ag_list = dfs[df]['df'].select('AGE_GROUP').filter(F.col('AGE_GROUP').isNotNull()).distinct().rdd.flatMap(lambda x: x).collect()
    for ag in ag_list:
        dfs[df]['fractions']['AGE_GROUP'][ag] = 0.035
    
    ew_list = dfs[df]['df'].select('EPI_WEEK_YEAR').filter(F.col('EPI_WEEK_YEAR').isNotNull()).distinct().rdd.flatMap(lambda x: x).collect()
    for ew in ew_list:
        dfs[df]['fractions']['EPI_WEEK_YEAR'][ew] = 0.035
#     print(dfs[df]['fractions'])

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
for undersamp_met in list(undersamp_col.keys()): 
    for ds in list(dfs.keys()):
        for col_set in list(cols_sets.keys()):
            for exp_id in range(50): 
                df = dfs[ds]['df'].select(cols_sets[col_set])

                fractions = dfs[ds]['fractions'][undersamp_col[undersamp_met]]
                df = df.sampleBy(undersamp_col[undersamp_met], fractions=fractions, seed=exp_id)
                df = df.union(not_covid.select(cols_sets[col_set]))
                
                prefix = 'gs://ai-covid19-datalake/trusted/experiment_map/'
                filename = 'experiment' + str(exp_id) + '.parquet'
                uri = prefix + undersamp_met + '/' + ds + '/' + col_set + '/' + filename
                
                df.write.parquet(uri, mode='overwrite')

                print('Dataframe written: {}'.format(uri))
                df.select('CLASSI_FIN').groupBy('CLASSI_FIN').count().show()
                print('')
# Out:
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment0.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86324|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment1.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86460|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment2.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|87179|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment3.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86086|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment4.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|84842|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment5.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85210|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment6.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86207|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment7.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86112|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment8.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86427|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment9.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86261|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment10.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|87217|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment11.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86536|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment12.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|84591|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment13.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85783|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment14.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85729|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment15.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85062|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment16.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85904|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment17.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85341|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment18.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85671|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment19.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85416|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment20.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86640|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment21.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85942|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment22.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85462|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment23.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85947|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment24.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86425|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment25.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|87097|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment26.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|84790|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment27.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85330|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment28.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85522|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment29.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86425|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment30.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85830|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment31.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86823|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment32.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86047|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment33.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86715|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment34.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86410|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment35.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85995|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment36.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86597|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment37.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85406|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment38.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85922|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment39.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86638|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment40.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85731|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment41.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85539|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment42.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86827|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment43.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85708|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment44.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86382|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment45.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85323|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment46.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85681|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment47.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|84689|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment48.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85958|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment49.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85599|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment0.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86324|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment1.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86460|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment2.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|87179|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment3.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86086|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment4.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|84842|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment5.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85210|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment6.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86207|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment7.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86112|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment8.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86427|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment9.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86261|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment10.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|87217|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment11.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86536|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment12.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|84591|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment13.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85783|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment14.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85729|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment15.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85062|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment16.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85904|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment17.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85341|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment18.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85671|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment19.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85416|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment20.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86640|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment21.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85942|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment22.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85462|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment23.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85947|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment24.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86425|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment25.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|87097|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment26.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|84790|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment27.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85330|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment28.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85522|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment29.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86425|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment30.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85830|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment31.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86823|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment32.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86047|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment33.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86715|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment34.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86410|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment35.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85995|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment36.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86597|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment37.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85406|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment38.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85922|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment39.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86638|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment40.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85731|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment41.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85539|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment42.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86827|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment43.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85708|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment44.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86382|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment45.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85323|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment46.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85681|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment47.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|84689|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment48.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85958|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_2/experiment49.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85599|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment0.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86324|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment1.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86460|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment2.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|87179|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment3.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86086|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment4.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|84842|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment5.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85210|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment6.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86207|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment7.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86112|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment8.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86427|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment9.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86261|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment10.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|87217|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment11.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86536|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment12.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|84591|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment13.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85783|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment14.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85729|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment15.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85062|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment16.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85904|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment17.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85341|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment18.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85671|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment19.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85416|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment20.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86640|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment21.parquet
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment22.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85462|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment23.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85947|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment24.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86425|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment25.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|87097|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment26.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|84790|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment27.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85330|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment28.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85522|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment29.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86425|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment30.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85830|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment31.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86823|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment32.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86047|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment33.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86715|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment34.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86410|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment35.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85995|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment36.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86597|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment37.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85406|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment38.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85922|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment39.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86638|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment40.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85731|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment41.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85539|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment42.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86827|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment43.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85708|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment44.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|86382|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment45.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85323|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment46.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85681|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment47.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|84689|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment48.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85958|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment49.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|85599|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment0.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53203|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment1.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53038|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment2.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53459|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment3.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52952|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment4.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52087|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment5.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52315|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment6.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53153|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment7.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53255|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment8.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53062|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment9.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53148|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment10.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53539|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment11.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53003|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment12.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|51577|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment13.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52510|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment14.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52884|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment15.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52068|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment16.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52872|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment17.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52377|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment18.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52304|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment19.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52485|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment20.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53305|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment21.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52854|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment22.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52510|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment23.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52757|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment24.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52863|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment25.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53750|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment26.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|51857|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment27.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52281|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment28.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52536|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment29.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53105|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment30.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52586|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment31.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53361|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment32.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52723|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment33.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53241|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment34.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53070|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment35.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52769|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment36.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53148|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment37.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52625|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment38.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52603|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment39.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53261|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment40.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52690|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment41.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52442|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment42.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53883|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment43.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52717|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment44.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53137|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment45.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52202|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment46.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52640|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment47.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|51712|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment48.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52868|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_1/experiment49.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52385|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_2/experiment0.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53203|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_2/experiment1.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53038|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_2/experiment2.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|53459|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_2/experiment3.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52952|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_2/experiment4.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|52087|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-2/cols_set_2/experiment5.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# ...
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|76345|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_2/experiment32.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75589|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_2/experiment33.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|76251|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_2/experiment34.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75841|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_2/experiment35.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75507|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_2/experiment36.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|76172|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_2/experiment37.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75200|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_2/experiment38.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75482|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_2/experiment39.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|76226|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_2/experiment40.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75491|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_2/experiment41.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75124|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_2/experiment42.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|76645|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_2/experiment43.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75383|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_2/experiment44.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|76023|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_2/experiment45.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|74887|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_2/experiment46.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75443|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_2/experiment47.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|74333|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_2/experiment48.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75545|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_2/experiment49.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75281|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment0.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|76008|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment1.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|76098|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment2.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|76542|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment3.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75793|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment4.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|74465|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment5.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|74906|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment6.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75869|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment7.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75764|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment8.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75929|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment9.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75880|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment10.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|76773|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment11.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75938|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment12.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|74219|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment13.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75346|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment14.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75248|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment15.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|74762|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment16.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75621|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment17.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75031|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment18.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75151|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment19.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75145|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment20.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|76229|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment21.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75500|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment22.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75147|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment23.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75618|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment24.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75859|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment25.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|76707|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment26.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|74583|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment27.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75020|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment28.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75223|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment29.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75961|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment30.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75323|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment31.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|76345|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment32.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75589|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment33.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|76251|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment34.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75841|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment35.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75507|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment36.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|76172|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment37.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75200|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment38.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75482|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment39.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|76226|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment40.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75491|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment41.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75124|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment42.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|76645|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment43.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75383|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment44.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|76023|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment45.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|74887|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment46.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75443|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment47.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|74333|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment48.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75545|
# +----------+-----+
#
#
# Dataframe written: gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-3/cols_set_3/experiment49.parquet
# +----------+-----+
# |CLASSI_FIN|count|
# +----------+-----+
# |       0.0|44538|
# |       1.0|75281|
# +----------+-----+

# %%
print('finished')
# Out:
# finished
