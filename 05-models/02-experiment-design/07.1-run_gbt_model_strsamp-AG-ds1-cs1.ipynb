# %%
import pandas as pd
import pyspark.sql.functions as F
from datetime import datetime
from pyspark.sql.types import *
from pyspark import StorageLevel

import numpy as np
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", 1000)
pd.set_option("mode.chained_assignment", None)

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import GBTClassifier
from pyspark.ml.feature import IndexToString, StringIndexer, VectorIndexer
# from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import OneHotEncoderEstimator, StringIndexer, VectorAssembler

from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

from pyspark.sql import Row
from pyspark.ml.linalg import Vectors

# %%
# !pip install scikit-plot

# %%
import sklearn
import scikitplot as skplt
from sklearn.metrics import classification_report, confusion_matrix, precision_score

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
result_schema = StructType([
                    StructField('experiment_filter', StringType(), True),
                    StructField('undersampling_method', StringType(), True),
                    StructField('undersampling_column', StringType(), True),
                    StructField('filename', StringType(), True),
                    StructField('experiment_id', StringType(), True),
                    StructField('n_covid', IntegerType(), True),
                    StructField('n_not_covid', IntegerType(), True),
                    StructField('model_name', StringType(), True),
                    StructField('model_seed', StringType(), True),
                    StructField('model_maxIter', IntegerType(), True),
                    StructField('model_maxDepth', IntegerType(), True),
                    StructField('model_maxBins', IntegerType(), True),
                    StructField('model_minInstancesPerNode', IntegerType(), True),
                    StructField('model_minInfoGain', FloatType(), True),
                    StructField('model_featureSubsetStrategy', StringType(), True),
                    StructField('model_n_estimators', IntegerType(), True),
                    StructField('model_learning_rate', FloatType(), True),
                    StructField('model_impurity', StringType(), True),
                    StructField('model_AUC_ROC', StringType(), True),
                    StructField('model_AUC_PR', StringType(), True),
                    StructField('model_covid_precision', StringType(), True),
                    StructField('model_covid_recall', StringType(), True),
                    StructField('model_covid_f1', StringType(), True),
                    StructField('model_not_covid_precision', StringType(), True),
                    StructField('model_not_covid_recall', StringType(), True),
                    StructField('model_not_covid_f1', StringType(), True),
                    StructField('model_avg_precision', StringType(), True),
                    StructField('model_avg_recall', StringType(), True),
                    StructField('model_avg_f1', StringType(), True),
                    StructField('model_avg_acc', StringType(), True),
                    StructField('model_TP', StringType(), True),
                    StructField('model_TN', StringType(), True),
                    StructField('model_FN', StringType(), True),
                    StructField('model_FP', StringType(), True),
                    StructField('model_time_exec', StringType(), True),
                    StructField('model_col_set', StringType(), True)
                          ])

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# undersamp_col = ['03-STRSAMP-AG', '04-STRSAMP-EW'] 
# dfs = ['ds-1', 'ds-2', 'ds-3']
# cols_sets = ['cols_set_1', 'cols_set_2', 'cols_set_3']

undersamp_col = ['03-STRSAMP-AG']
dfs = ['ds-1']
cols_sets = ['cols_set_1']

# %%
# lists of params
model_maxIter = [20, 50, 100] 
model_maxDepth = [3, 5, 7] 
model_maxBins = [32, 64] 
# model_learningRate = [0.01, 0.1, 0.5]
# model_loss = ['logLoss', 'leastSquaresError', 'leastAbsoluteError']


list_of_param_dicts = []

for maxIter in model_maxIter:
    for maxDepth in model_maxDepth:
        for maxBins in model_maxBins: 
            params_dict = {}
            params_dict['maxIter'] = maxIter
            params_dict['maxDepth'] = maxDepth
            params_dict['maxBins'] = maxBins
            list_of_param_dicts.append(params_dict)

            

print("There is {} set of params.".format(len(list_of_param_dicts)))
# list_of_param_dicts
# Out:
# There is 18 set of params.

# %%
prefix = 'gs://ai-covid19-datalake/trusted/experiment_map/'

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# filename = 'gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment0.parquet'
# df = spark.read.parquet(filename)
# df.limit(2).toPandas()

# %%
# params_dict = {'maxIter': 100,
#                'maxDepth': 3,
#                'maxBins': 32,
#                'learningRate': 0.5,
#                'loss': 'leastAbsoluteError'}
# cols = 'cols_set_1'
# experiment_filter = 'ds-1'
# undersampling_method = '03-STRSAMP-AG', 
# experiment_id = 0

# %%
# run_gbt(df, params_dict, cols, filename, experiment_filter, undersampling_method, experiment_id)

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
def run_gbt(exp_df, params_dict, cols, filename, experiment_filter, 
            undersampling_method, experiment_id):
    import time
    start_time = time.time()
    
    n_covid = exp_df.filter(F.col('CLASSI_FIN') == 1.0).count()
    n_not_covid = exp_df.filter(F.col('CLASSI_FIN') == 0.0).count()
    
    
    id_cols = ['NU_NOTIFIC', 'CLASSI_FIN']

    labelIndexer = StringIndexer(inputCol="CLASSI_FIN", outputCol="indexedLabel").fit(exp_df)    
    
    input_cols = [x for x in exp_df.columns if x not in id_cols]
    assembler = VectorAssembler(inputCols = input_cols, outputCol= 'features')
    exp_df = assembler.transform(exp_df)
    
    # Automatically identify categorical features, and index them.
    # Set maxCategories so features with > 4 distinct values are treated as continuous.
    featureIndexer = VectorIndexer(inputCol="features", outputCol="indexedFeatures", maxCategories=30).fit(exp_df)
    
    # Split the data into training and test sets (30% held out for testing)
    (trainingData, testData) = exp_df.randomSplit([0.7, 0.3])
    trainingData = trainingData.persist(StorageLevel.MEMORY_ONLY)
    testData = testData.persist(StorageLevel.MEMORY_ONLY)
    
    # Train a RandomForest model.
    gbt = GBTClassifier(labelCol = "indexedLabel", featuresCol = "indexedFeatures",
                       maxIter = params_dict['maxIter'],
                       maxDepth = params_dict['maxDepth'],
                       maxBins = params_dict['maxBins'])
    
    # Convert indexed labels back to original labels.
    labelConverter = IndexToString(inputCol="prediction", outputCol="predictedLabel",
                               labels=labelIndexer.labels)

    # Chain indexers and forest in a Pipeline
    pipeline = Pipeline(stages=[labelIndexer, featureIndexer, gbt, labelConverter])

    # Train model.  This also runs the indexers.
    model = pipeline.fit(trainingData)
    
    # Make predictions.
    predictions = model.transform(testData)    
    
    
    pred = predictions.select(['CLASSI_FIN', 'predictedLabel'])\
                  .withColumn('predictedLabel', F.col('predictedLabel').cast('double'))\
                  .withColumn('predictedLabel', F.when(F.col('predictedLabel') == 1.0, 'covid').otherwise('n-covid'))\
                  .withColumn('CLASSI_FIN', F.when(F.col('CLASSI_FIN') == 1.0, 'covid').otherwise('n-covid'))\
                  .toPandas()

    y_true = pred['CLASSI_FIN'].tolist()
    y_pred = pred['predictedLabel'].tolist()
    
    report = classification_report(y_true, y_pred, output_dict=True)
    
    
    evaluator_ROC = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderROC")
    accuracy_ROC = evaluator_ROC.evaluate(predictions)


    
    evaluator_PR = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderPR")
    accuracy_PR = evaluator_PR.evaluate(predictions)
    
    conf_matrix = confusion_matrix(y_true, y_pred)

    result_dict = {}
    
    result_dict['experiment_filter'] = experiment_filter
    result_dict['undersampling_method'] = undersampling_method
    result_dict['filename'] = filename
    result_dict['experiment_id'] = experiment_id
    result_dict['n_covid'] = n_covid
    result_dict['n_not_covid'] = n_not_covid
    result_dict['model_name'] = 'GBT'
    result_dict['params'] = params_dict
    result_dict['model_AUC_ROC'] = accuracy_ROC
    result_dict['model_AUC_PR'] = accuracy_PR
    result_dict['model_covid_precision'] = report['covid']['precision']
    result_dict['model_covid_recall'] = report['covid']['recall']
    result_dict['model_covid_f1'] = report['covid']['f1-score']
    result_dict['model_not_covid_precision'] = report['n-covid']['precision']
    result_dict['model_not_covid_recall'] = report['n-covid']['recall']
    result_dict['model_not_covid_f1'] = report['n-covid']['f1-score']
    result_dict['model_avg_precision'] = report['macro avg']['precision']
    result_dict['model_avg_recall'] = report['macro avg']['recall']
    result_dict['model_avg_f1'] = report['macro avg']['f1-score']
    result_dict['model_avg_acc'] = report['accuracy']
    result_dict['model_TP'] = conf_matrix[0][0]
    result_dict['model_TN'] = conf_matrix[1][1]
    result_dict['model_FN'] = conf_matrix[0][1]
    result_dict['model_FP'] = conf_matrix[1][0]
    result_dict['model_time_exec'] = time.time() - start_time
    result_dict['model_col_set'] = cols
    
    return result_dict

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %% [markdown]
# # Running GBT on 10 samples for each experiment
# ### 3x col sets -> ['cols_set_1', 'cols_set_2', 'cols_set_3']
# ### 3x model_maxIter -> [100, 200, 300]
# ### 3x model_maxDepth -> [5, 10, 15]
# ### 3x model_maxBins -> [16, 32, 64]
# Total: 10 * 3 * 3 * 3 * 3 = 810

# %%
experiments = []

# %% [markdown]
# ### Datasets: strat_samp_lab_agegrp

# %%
for uc in undersamp_col: 
    for ds in dfs:
        for col_set in cols_sets:
            for params_dict in list_of_param_dicts: 
                for id_exp in range(50):
                    filename = prefix + uc + '/' + ds + '/' + col_set + '/' + 'experiment' + str(id_exp) + '.parquet'
                    exp_dataframe = spark.read.parquet(filename)
                    print('read {}'.format(filename))
                    
                    undersampling_method = uc
                    experiment_filter = ds
                    experiment_id = id_exp

                    try:                     
                        model = run_gbt(exp_dataframe, params_dict, col_set, filename, experiment_filter, undersampling_method, experiment_id)
                        experiments.append(model)

                        print("Parameters ==> {}\n Results: \n AUC_PR: {} \n Precision: {} \n Time: {}".format(str(params_dict), str(model['model_AUC_PR']), str(model['model_avg_precision']), str(model['model_time_exec'])))
                        print('=========================== \n')
                    except:
                        print('=========== W A R N I N G =========== \n')
                        print('Something wrong with the exp: {}, {}, {}'.format(filename, params_dict, col_set))
# Out:
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9094649933545622
#  Precision: 0.9406195587510764
#  Time: 30.657063484191895
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.912901718413028
#  Precision: 0.9424524406142084
#  Time: 21.075178623199463
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9075175165979023
#  Precision: 0.9397554771770111
#  Time: 20.98622989654541
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9147499723834716
#  Precision: 0.9441348508097849
#  Time: 20.430898189544678
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9047826404983332
#  Precision: 0.9383271154030557
#  Time: 20.568678617477417
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9115188006936144
#  Precision: 0.941219918930995
#  Time: 20.44645071029663
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9127535244260301
#  Precision: 0.9426821977155617
#  Time: 19.93346333503723
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9005928701788943
#  Precision: 0.9351232390721412
#  Time: 21.80299425125122
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9141973045717118
#  Precision: 0.9439216339761264
#  Time: 19.930517196655273
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9098922604372479
#  Precision: 0.9413805618850002
#  Time: 19.80210828781128
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9102526538849401
#  Precision: 0.9415497595563522
#  Time: 20.301900386810303
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9088884909674331
#  Precision: 0.9406772229234179
#  Time: 20.286974668502808
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9109300275837467
#  Precision: 0.9410082333599123
#  Time: 20.330854654312134
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9073442598860648
#  Precision: 0.9397383815134784
#  Time: 20.785757064819336
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9062617081709647
#  Precision: 0.9390340391646241
#  Time: 19.903852701187134
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9093322755258607
#  Precision: 0.9404115714099812
#  Time: 19.778645515441895
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9084494709900967
#  Precision: 0.9393583752590735
#  Time: 19.383732080459595
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9078151046845653
#  Precision: 0.9394808682022607
#  Time: 19.861103057861328
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9129653877326133
#  Precision: 0.9424441745986261
#  Time: 19.24604344367981
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9098975166813399
#  Precision: 0.941324608354549
#  Time: 19.340341806411743
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9080796465545216
#  Precision: 0.9401719574538085
#  Time: 19.192095518112183
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.910314971649215
#  Precision: 0.9410567850205369
#  Time: 19.96625304222107
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9125033014299254
#  Precision: 0.9415234362486786
#  Time: 20.020272731781006
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9128337358827558
#  Precision: 0.9421249701344996
#  Time: 19.949296712875366
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9132680827704686
#  Precision: 0.9433249637420905
#  Time: 21.182832717895508
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9018592921655812
#  Precision: 0.936625488030018
#  Time: 20.37343955039978
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.910263249610886
#  Precision: 0.9400577707953531
#  Time: 19.69020986557007
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9121923792665524
#  Precision: 0.9414382005478208
#  Time: 20.325167417526245
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9159137144166125
#  Precision: 0.9434653084485041
#  Time: 20.38011384010315
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9092689408295196
#  Precision: 0.9412816655633002
#  Time: 20.33214831352234
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9005217616076957
#  Precision: 0.9357838156162674
#  Time: 19.64062190055847
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9152242414451817
#  Precision: 0.9444626538738862
#  Time: 19.768722772598267
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9080745843555647
#  Precision: 0.9404458626911968
#  Time: 19.459206581115723
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9147783368178114
#  Precision: 0.9436071591942566
#  Time: 19.488733530044556
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9135000576223071
#  Precision: 0.9434197642378591
#  Time: 19.51546859741211
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9086029181043502
#  Precision: 0.939097311285932
#  Time: 20.370946884155273
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9113369257797035
#  Precision: 0.9430971675897464
#  Time: 19.932788848876953
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.914079401049101
#  Precision: 0.943250649018308
#  Time: 23.858519792556763
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9107774516129347
#  Precision: 0.9418494711955161
#  Time: 19.490870475769043
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9114767384763062
#  Precision: 0.9416527178371061
#  Time: 19.339462518692017
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9120225506306716
#  Precision: 0.9419613107605138
#  Time: 19.192652463912964
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9093522712713777
#  Precision: 0.9416991487270678
#  Time: 21.20354175567627
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9133926133129999
#  Precision: 0.9431819640143857
#  Time: 20.233729600906372
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9115813689934079
#  Precision: 0.9418162463657956
#  Time: 19.886636972427368
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9099119798448081
#  Precision: 0.9406950162249862
#  Time: 20.771657943725586
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9099697735350792
#  Precision: 0.9413969828195222
#  Time: 19.966378927230835
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9103415027969265
#  Precision: 0.94095542034928
#  Time: 19.265788793563843
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9121142536063673
#  Precision: 0.9407528069439319
#  Time: 19.764694929122925
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9130893297144614
#  Precision: 0.9427353485748275
#  Time: 19.84545135498047
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9092214594143008
#  Precision: 0.9406256116216765
#  Time: 19.894338846206665
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9098547609675782
#  Precision: 0.9415390219831712
#  Time: 19.842331171035767
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9117463941403352
#  Precision: 0.9424364659168898
#  Time: 19.975197076797485
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9112530305424306
#  Precision: 0.9422264551659526
#  Time: 19.676755666732788
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9136900098470664
#  Precision: 0.9425677409451141
#  Time: 19.600016832351685
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9097611594188646
#  Precision: 0.9407024038810889
#  Time: 19.616299390792847
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9085936504077228
#  Precision: 0.9398770737101816
#  Time: 19.435232877731323
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.913160389180012
#  Precision: 0.9435597061879006
#  Time: 20.095812559127808
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9131426466636821
#  Precision: 0.9434000922880587
#  Time: 19.79788064956665
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9066972691589447
#  Precision: 0.9392976364702597
#  Time: 20.409220457077026
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9089284508563864
#  Precision: 0.9402751986603656
#  Time: 20.23620057106018
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9106934402303595
#  Precision: 0.9427379036010891
#  Time: 19.825385332107544
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9072707936607033
#  Precision: 0.9392369714585423
#  Time: 19.91561794281006
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9089932628592968
#  Precision: 0.939543547997291
#  Time: 19.870932579040527
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9085068640722798
#  Precision: 0.9401180665526259
#  Time: 19.325520038604736
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9155100691366961
#  Precision: 0.9443935322561245
#  Time: 19.268856048583984
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9130528270662057
#  Precision: 0.9426941483350202
#  Time: 18.922564268112183
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.908791530321153
#  Precision: 0.9402477083717564
#  Time: 19.27206301689148
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9092805926145259
#  Precision: 0.9407813834131492
#  Time: 19.23913335800171
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9049997144845768
#  Precision: 0.9370667614710821
#  Time: 19.48439598083496
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9124936289820983
#  Precision: 0.9418595789601032
#  Time: 19.49813961982727
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9112818858574991
#  Precision: 0.9426065925814349
#  Time: 19.468481063842773
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9100204619325003
#  Precision: 0.9407503886035191
#  Time: 19.800023317337036
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9047376922813309
#  Precision: 0.9377894563565458
#  Time: 19.503547191619873
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9099050159767889
#  Precision: 0.9408143026678932
#  Time: 19.981488466262817
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9144988660363569
#  Precision: 0.9434043163363472
#  Time: 19.680426359176636
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9106372368029015
#  Precision: 0.9419786732797608
#  Time: 19.489177227020264
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9130598182875856
#  Precision: 0.941861207490575
#  Time: 19.499431610107422
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9131167064407001
#  Precision: 0.9422030570858524
#  Time: 19.57598114013672
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9101675688414662
#  Precision: 0.9410120348050643
#  Time: 20.47311234474182
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9075569882686109
#  Precision: 0.9396655413165951
#  Time: 21.966277360916138
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9105849756593144
#  Precision: 0.9409500651018614
#  Time: 20.10746741294861
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9067250780372196
#  Precision: 0.9397170354468437
#  Time: 20.189040660858154
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9116031447651554
#  Precision: 0.9413843099840191
#  Time: 22.09150767326355
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9102067986447305
#  Precision: 0.9413890038971366
#  Time: 20.501099824905396
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9094172544562291
#  Precision: 0.9407913419322781
#  Time: 20.091418743133545
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9057589834903014
#  Precision: 0.939320190936157
#  Time: 19.946306705474854
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9110291356882819
#  Precision: 0.9418707402064528
#  Time: 19.95190453529358
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9113771199030398
#  Precision: 0.94166020685607
#  Time: 20.150867700576782
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9107904824566853
#  Precision: 0.941849543298954
#  Time: 20.033105850219727
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9116847275651836
#  Precision: 0.9426177033667298
#  Time: 20.14168429374695
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9061375340635652
#  Precision: 0.9386350593500334
#  Time: 19.780495643615723
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9071930991590493
#  Precision: 0.9392062007354485
#  Time: 20.475300312042236
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.912891766987328
#  Precision: 0.9430216442366108
#  Time: 21.332886695861816
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9106553059598653
#  Precision: 0.9413915228099587
#  Time: 20.994269132614136
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9089461419045172
#  Precision: 0.9410833942023349
#  Time: 21.215237379074097
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9030045512632823
#  Precision: 0.9363048347211743
#  Time: 21.741291046142578
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9113002442651371
#  Precision: 0.9410835640624572
#  Time: 21.173572540283203
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9166483557392782
#  Precision: 0.9442692279089613
#  Time: 20.63017201423645
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9146850351694259
#  Precision: 0.9425451707860438
#  Time: 20.8233003616333
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9136473396511097
#  Precision: 0.9427624761399827
#  Time: 20.28429412841797
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9161552335631775
#  Precision: 0.9463462315406832
#  Time: 23.677408456802368
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9223762409954294
#  Precision: 0.9494795573560213
#  Time: 23.27449369430542
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9249717503565976
#  Precision: 0.9514290176608917
#  Time: 23.1786892414093
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9224689552367068
#  Precision: 0.9491412203769263
#  Time: 23.687183618545532
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9211827809754752
#  Precision: 0.94874864538446
#  Time: 23.721814393997192
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.919876039776518
#  Precision: 0.9475482779833502
#  Time: 24.041555404663086
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.922116083956753
#  Precision: 0.9484222808576698
#  Time: 24.185426950454712
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9238549139572091
#  Precision: 0.9495950837883778
#  Time: 24.904260396957397
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9224257476623069
#  Precision: 0.9486954154165914
#  Time: 23.903395414352417
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9245873374910637
#  Precision: 0.9508935482881149
#  Time: 24.11250352859497
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.92235599139824
#  Precision: 0.9497460870692758
#  Time: 24.116687774658203
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9218927438776554
#  Precision: 0.9491657492794525
#  Time: 24.102171182632446
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9246788255039481
#  Precision: 0.9490133484602427
#  Time: 23.480950117111206
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9226191408657295
#  Precision: 0.9496525207771037
#  Time: 24.667712211608887
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.919202658215533
#  Precision: 0.9468907352456507
#  Time: 24.51995587348938
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9181028741863021
#  Precision: 0.9459971314317904
#  Time: 23.23465609550476
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9233174791963029
#  Precision: 0.9498784994425373
#  Time: 23.792450666427612
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9220913456146344
#  Precision: 0.9489656886174205
#  Time: 23.125035285949707
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9210118647108873
#  Precision: 0.9479456820847008
#  Time: 23.449148893356323
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9273022607126089
#  Precision: 0.9516725664545149
#  Time: 22.788177967071533
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9210841378240188
#  Precision: 0.9481595959912941
#  Time: 22.88666558265686
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9238206704781979
#  Precision: 0.949023180627445
#  Time: 23.314310550689697
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9203385597188041
#  Precision: 0.9478069667823007
#  Time: 23.31912136077881
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9211656573517762
#  Precision: 0.948297013614509
#  Time: 23.35516619682312
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9192035417501445
#  Precision: 0.9477807481326097
#  Time: 23.14435863494873
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9214333167132025
#  Precision: 0.9486399250410957
#  Time: 23.668086528778076
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9239526160102417
#  Precision: 0.9492076754796188
#  Time: 22.900297164916992
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9217565904212647
#  Precision: 0.9479183010629222
#  Time: 22.716301679611206
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9229972963286214
#  Precision: 0.9488000532448585
#  Time: 23.726000547409058
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9221853892509381
#  Precision: 0.9491143096830222
#  Time: 23.33881378173828
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9175864544621821
#  Precision: 0.9463239427130583
#  Time: 23.865465879440308
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9229758486498726
#  Precision: 0.9497460609279629
#  Time: 23.051828861236572
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9227323551317494
#  Precision: 0.949219531955979
#  Time: 23.39292073249817
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.92001203887328
#  Precision: 0.947897516529592
#  Time: 22.716623067855835
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9217900187230398
#  Precision: 0.9485934863834531
#  Time: 27.75087857246399
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9229158814567595
#  Precision: 0.9489075230073869
#  Time: 22.717154502868652
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9207798725165197
#  Precision: 0.9485254671550001
#  Time: 23.55009150505066
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9221694495174391
#  Precision: 0.9477953915031825
#  Time: 22.589390754699707
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.922598379322664
#  Precision: 0.9497351524290469
#  Time: 23.125964403152466
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9221044233789326
#  Precision: 0.9486465044111096
#  Time: 23.94987201690674
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9248314396052925
#  Precision: 0.950450922812702
#  Time: 23.543579578399658
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.926014502948647
#  Precision: 0.9513506855447708
#  Time: 22.867537021636963
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9217646024494004
#  Precision: 0.9483831192478114
#  Time: 25.191394090652466
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9228549483547338
#  Precision: 0.9485357408633909
#  Time: 23.160366773605347
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9187499756437938
#  Precision: 0.947908786217244
#  Time: 22.71921992301941
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9229487458774164
#  Precision: 0.9489860382219635
#  Time: 23.16135287284851
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9206072575551368
#  Precision: 0.9475405654313176
#  Time: 22.413838624954224
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9224766215807066
#  Precision: 0.9480077065454706
#  Time: 22.963327169418335
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9250604967865853
#  Precision: 0.9504679291278806
#  Time: 23.040022611618042
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9264104831557836
#  Precision: 0.9509232968294659
#  Time: 23.290091037750244
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9253595288260936
#  Precision: 0.9505483278590066
#  Time: 22.73975110054016
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9225758470649476
#  Precision: 0.9494005365910523
#  Time: 23.009709358215332
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9229560163698441
#  Precision: 0.9497070414248892
#  Time: 24.159475326538086
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.925859780403734
#  Precision: 0.951043185467463
#  Time: 23.928104877471924
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.919199473319958
#  Precision: 0.9467691479991978
#  Time: 25.040513515472412
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9255868646426941
#  Precision: 0.9507271435762911
#  Time: 25.127946376800537
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9221077187003607
#  Precision: 0.9489390159781711
#  Time: 26.20894742012024
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9266728429442317
#  Precision: 0.951892576913824
#  Time: 23.219682455062866
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9232528961658875
#  Precision: 0.9498180834715209
#  Time: 22.942078590393066
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9219768746650031
#  Precision: 0.949457891708684
#  Time: 26.44574522972107
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9177793853089605
#  Precision: 0.9476802992111458
#  Time: 23.648857593536377
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.923748136814845
#  Precision: 0.9496471197421773
#  Time: 24.382358074188232
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9243114450771878
#  Precision: 0.949890405024691
#  Time: 24.007179021835327
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.92337927100574
#  Precision: 0.9494514844243107
#  Time: 26.4254150390625
# ===========================
#
# ...
#  Results:
#  AUC_PR: 0.928294757239803
#  Precision: 0.9538162977649534
#  Time: 134.98953557014465
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9279360716989922
#  Precision: 0.9539885747026674
#  Time: 131.89572763442993
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9300312569749359
#  Precision: 0.953995150846638
#  Time: 130.71516609191895
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment48.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9282530948832192
#  Precision: 0.9542563754659478
#  Time: 135.08014798164368
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9272672658209532
#  Precision: 0.9539943575936787
#  Time: 134.72308373451233
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment0.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9295826653563747
#  Precision: 0.9551848045481273
#  Time: 136.10300970077515
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment1.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9277371040358975
#  Precision: 0.9535474229986789
#  Time: 134.74961519241333
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment2.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9307589974894795
#  Precision: 0.9556037943549203
#  Time: 133.4030065536499
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment3.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9266549421086157
#  Precision: 0.9533875868393611
#  Time: 135.171635389328
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment4.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9283893224347397
#  Precision: 0.9543002991885764
#  Time: 133.72110676765442
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment5.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9329372071885759
#  Precision: 0.9556613898385566
#  Time: 132.82249474525452
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment6.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9296026660280561
#  Precision: 0.9557478425007317
#  Time: 134.1944944858551
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment7.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9264750702349216
#  Precision: 0.9538364543539459
#  Time: 134.50470638275146
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment8.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9260566950854351
#  Precision: 0.9537659740127593
#  Time: 132.39458227157593
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment9.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9286081027574279
#  Precision: 0.9551593677005116
#  Time: 130.6938602924347
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment10.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9275510763656325
#  Precision: 0.9539722216345379
#  Time: 126.34634065628052
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment11.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9303506390708695
#  Precision: 0.9552900820349594
#  Time: 128.66014957427979
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment12.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9299791559442256
#  Precision: 0.9542666278337701
#  Time: 126.43481802940369
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment13.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9259224003777143
#  Precision: 0.9526666238341537
#  Time: 124.2022852897644
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment14.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9226490858656807
#  Precision: 0.9515794120903912
#  Time: 124.98770332336426
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment15.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9285164959523108
#  Precision: 0.9539311527157075
#  Time: 125.33717131614685
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment16.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9276005910385566
#  Precision: 0.9536702047489634
#  Time: 128.33903002738953
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment17.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9273810916210504
#  Precision: 0.953202964119634
#  Time: 123.89934372901917
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment18.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9285296384176541
#  Precision: 0.9541937536500544
#  Time: 125.03481698036194
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment19.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9305159063086237
#  Precision: 0.9555356439137422
#  Time: 124.24372410774231
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment20.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9309632513390709
#  Precision: 0.9559740007200948
#  Time: 126.16128158569336
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment21.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9296964122912112
#  Precision: 0.9548989292449541
#  Time: 124.90051531791687
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment22.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9291533832435754
#  Precision: 0.9547913134900488
#  Time: 124.7318503856659
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment23.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9279281841804089
#  Precision: 0.9546140822218212
#  Time: 125.61331605911255
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment24.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9272754008333213
#  Precision: 0.953833098626972
#  Time: 126.14990401268005
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment25.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9266394606750384
#  Precision: 0.9535841173759504
#  Time: 127.11953639984131
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment26.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.931159804786082
#  Precision: 0.9561232161478281
#  Time: 124.17699694633484
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment27.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.930753096760929
#  Precision: 0.9551932585834668
#  Time: 125.38890552520752
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment28.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9313474752780168
#  Precision: 0.9558085021244512
#  Time: 123.73291420936584
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment29.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9278229799673233
#  Precision: 0.9542593823079603
#  Time: 123.90594387054443
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment30.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9279269029315291
#  Precision: 0.9537365053782219
#  Time: 125.70618748664856
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment31.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9303363395480136
#  Precision: 0.9560957092799608
#  Time: 124.42619609832764
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment32.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.925681189128327
#  Precision: 0.9529107696913606
#  Time: 124.98441982269287
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment33.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9270098177994466
#  Precision: 0.9540488031543256
#  Time: 125.17168855667114
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment34.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9240014840856376
#  Precision: 0.9522804639547067
#  Time: 124.37737560272217
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment35.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9264071334630838
#  Precision: 0.952979275378975
#  Time: 125.68724846839905
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment36.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9282232230761396
#  Precision: 0.9547802021647985
#  Time: 126.03259658813477
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment37.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9247326590286173
#  Precision: 0.9518071765207641
#  Time: 125.6950261592865
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment38.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9279904472940707
#  Precision: 0.9538787883318154
#  Time: 124.83628106117249
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment39.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9248913353625632
#  Precision: 0.9525428748313783
#  Time: 125.73645567893982
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment40.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9272615102357179
#  Precision: 0.9533993421579073
#  Time: 125.36613368988037
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment41.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9302221817977705
#  Precision: 0.9551658794057077
#  Time: 126.3550341129303
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment42.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9305402976462565
#  Precision: 0.9554975024377064
#  Time: 126.58659267425537
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment43.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9289924655872813
#  Precision: 0.9540994473265431
#  Time: 123.33485269546509
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment44.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9269184716801304
#  Precision: 0.9535309785472341
#  Time: 126.65680813789368
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment45.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9280030367875715
#  Precision: 0.9539607235092767
#  Time: 125.97439432144165
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9288929086966946
#  Precision: 0.9544461336721044
#  Time: 126.139652967453
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9315178396734012
#  Precision: 0.9555597383543077
#  Time: 124.90312242507935
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment48.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9285639624604092
#  Precision: 0.9540626125861422
#  Time: 127.34347462654114
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9242920525122036
#  Precision: 0.9519771021329004
#  Time: 128.23366141319275
# ===========================

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
for i in range(len(experiments)):
    for d in list(experiments[i].keys()):
        experiments[i][d] = str(experiments[i][d])

# %%
# experiments

# %%
cols = ['experiment_filter', 'undersampling_method', 'filename', 'experiment_id', 'n_covid', 'n_not_covid', 'model_name', 'params', 'model_AUC_ROC', 'model_AUC_PR', 'model_covid_precision', 'model_covid_recall', 'model_covid_f1', 'model_not_covid_precision', 'model_not_covid_recall', 'model_not_covid_f1', 'model_avg_precision', 'model_avg_recall', 'model_avg_f1', 'model_avg_acc', 'model_TP', 'model_TN', 'model_FN', 'model_FP', 'model_time_exec', 'model_col_set']

# %%
intermed_results = spark.createDataFrame(data=experiments).select(cols)
intermed_results.toPandas()
# Out:
# /usr/lib/spark/python/pyspark/sql/session.py:346: UserWarning: inferring schema from dict is deprecated,please use pyspark.sql.Row instead
#   warnings.warn("inferring schema from dict is deprecated,"

# %%
intermed_results.write.parquet('gs://ai-covid19-datalake/trusted/intermed_results/STRSAMP/GBT_experiments-AG-ds1-cs1.parquet', mode='overwrite')

# %%
print('finished')
# Out:
# finished

# %%
intermed_results.show()
# Out:
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# |experiment_filter|undersampling_method|            filename|experiment_id|n_covid|n_not_covid|model_name|              params|     model_AUC_ROC|      model_AUC_PR|model_covid_precision|model_covid_recall|    model_covid_f1|model_not_covid_precision|model_not_covid_recall|model_not_covid_f1|model_avg_precision|  model_avg_recall|      model_avg_f1|     model_avg_acc|model_TP|model_TN|model_FN|model_FP|   model_time_exec|model_col_set|
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            0|  86324|      44538|       GBT|{'maxIter': 20, '...| 0.913177929127161|0.9094649933545622|   0.9245518660005877| 0.980063857954988|0.9514988848145768|        0.956687251501565|    0.8462920002993339|0.8981099110546379| 0.9406195587510764|0.9131779291271609|0.9248043979346073|0.9342809578691254|   25170|   11309|     512|    2054|30.657063484191895|   cols_set_1|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            1|  86460|      44538|       GBT|{'maxIter': 20, '...|0.9145339534362839| 0.912901718413028|   0.9249789677749735|0.9815246079801273|0.9524132346571756|       0.9599259134534434|    0.8475432988924404| 0.900240811653705| 0.9424524406142084|0.9145339534362839|0.9263270231554404|0.9355636586174363|   25288|   11402|     476|    2051|21.075178623199463|   cols_set_1|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            2|  87179|      44538|       GBT|{'maxIter': 20, '...|0.9109364499838598|0.9075175165979023|   0.9232010904656001| 0.980195757321857|0.9508451094486008|       0.9563098638884221|    0.8416771426458626|0.8953392330383481| 0.9397554771770111|0.9109364499838598|0.9230921712434744| 0.933107088989442|   25737|   11382|     520|    2141| 20.98622989654541|   cols_set_1|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            3|  86086|      44538|       GBT|{'maxIter': 20, '...|0.9170222007418666|0.9147499723834716|   0.9277200935946183|0.9818906473706613|0.9540370335557853|       0.9605496080249515|     0.852153754113072|0.9031107588666534| 0.9441348508097849|0.9170222007418667|0.9285738962112193|0.9376514088996557|   25375|   11395|     468|    1977|20.430898189544678|   cols_set_1|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            4|  84842|      44538|       GBT|{'maxIter': 20, '...| 0.912454946822225|0.9047826404983332|   0.9252564909811475|0.9776151528196297|0.9507154818084944|       0.9513977398249639|    0.8472947408248203|0.8963336535382644| 0.9383271154030557|0.9124549468222249|0.9235245676733794|0.9331923235658275|   24981|   11197|     572|    2018|20.568678617477417|   cols_set_1|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            5|  85210|      44538|       GBT|{'maxIter': 20, '...|0.9103403227303704|0.9115188006936144|   0.9208516886930984|0.9825303564433999|0.9506916808792876|       0.9615881491688916|     0.838150289017341|0.8956361302743462|  0.941219918930995|0.9103403227303705|0.9231639055768168|0.9330261769323827|   25084|   11165|     446|    2156| 20.44645071029663|   cols_set_1|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            6|  86207|      44538|       GBT|{'maxIter': 20, '...|0.9156295161858451|0.9127535244260301|   0.9264119904953391|0.9810692578684527|0.9529575452186666|       0.9589524049357845|    0.8501897745032373| 0.901301775147929| 0.9426821977155617| 0.915629516185845|0.9271296601832978|0.9362839971478049|   25342|   11424|     489|    2013| 19.93346333503723|   cols_set_1|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            7|  86112|      44538|       GBT|{'maxIter': 20, '...|0.9092150380189308|0.9005928701788943|   0.9220721554116559|0.9758762482866654|0.9482115677321157|       0.9481743227326266|    0.8425538277511961|0.8922492280896207| 0.9351232390721412|0.9092150380189308|0.9202303979108681|0.9300454884222971|   24919|   11270|     616|    2106| 21.80299425125122|   cols_set_1|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            8|  86427|      44538|       GBT|{'maxIter': 20, '...|0.9167739999075265|0.9141973045717118|   0.9277288283696207|0.9817376228087074|0.9539694127777465|       0.9601144395826321|    0.8518103770063457|0.9027255824993078| 0.9439216339761264|0.9167739999075265|0.9283474976385271|0.9375095298602287|   25481|   11410|     474|    1985|19.930517196655273|   cols_set_1|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            9|  86261|      44538|       GBT|{'maxIter': 20, '...|0.9130461733016743|0.9098922604372479|   0.9250254028160836|0.9808373095274742|0.9521141491110113|       0.9577357209539167|    0.8452550370758745| 0.897986790801305| 0.9413805618850002|0.9130461733016744|0.9250504699561581| 0.934822949236127|   25490|   11285|     498|    2066| 19.80210828781128|   cols_set_1|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           10|  87217|      44538|       GBT|{'maxIter': 20, '...|0.9093946759967622|0.9102526538849401|   0.9216240386335182|0.9829460913356988|0.9512978621275339|       0.9614754804791864|    0.8358432606578258|0.8942685370741483| 0.9415497595563522|0.9093946759967623|0.9227831996008411|0.9333131098639972|   25764|   11156|     447|    2191|20.301900386810303|   cols_set_1|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           11|  86536|      44538|       GBT|{'maxIter': 20, '...|0.9143332136971247|0.9088884909674331|   0.9262080023321916| 0.979347281624475|0.9520367075568874|       0.9551464435146444|    0.8493191457697745|0.8991295442908346| 0.9406772229234179|0.9143332136971247|0.9255831259238609|0.9349867993501219|   25417|   11414|     536|    2025|20.286974668502808|   cols_set_1|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           12|  84591|      44538|       GBT|{'maxIter': 20, '...|0.9148210498379307|0.9109300275837467|   0.9251946503743993|0.9797617169007417|0.9516966526795808|       0.9568218163454255|    0.8498803827751196|0.9001860870253791| 0.9410082333599123|0.9148210498379306|0.9259413698524799| 0.934898254312571|   24835|   11368|     513|    2008|20.330854654312134|   cols_set_1|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           13|  85783|      44538|       GBT|{'maxIter': 20, '...|0.9122140283700725|0.9073442598860648|     0.92449559219505|0.9794450957405236|0.9511773970133394|       0.9549811708319069|    0.8449829609996213| 0.896620997227691| 0.9397383815134784|0.9122140283700725|0.9238991971205152|0.9336770202345663|   25064|   11158|     526|    2047|20.785757064819336|   cols_set_1|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           14|  85729|      44538|       GBT|{'maxIter': 20, '...| 0.913525923877255|0.9062617081709647|   0.9257799427360279|0.9778868813825609|0.9511202796401352|       0.9522881355932203|    0.8491649663719489|0.8977749370830503| 0.9390340391646241|0.9135259238772548|0.9244476083615928| 0.933864006409428|   24897|   11237|     563|    1996|19.903852701187134|   cols_set_1|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           15|  85062|      44538|       GBT|{'maxIter': 20, '...|0.9111726506752911|0.9093322755258607|   0.9225860867651913|0.9809716914918506|0.9508834923934613|        0.958237056054771|    0.8413736098587316|0.8960108830472533| 0.9404115714099812|0.9111726506752911|0.9234471877203573|0.9332802793037942|   25158|   11197|     488|    2111|19.778645515441895|   cols_set_1|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           16|  85904|      44538|       GBT|{'maxIter': 20, '...| 0.911574644033656|0.9084494709900967|   0.9224007386888273|0.9797183319602997|0.9501959441464064|       0.9563160118293198|    0.8434309561070125|0.8963332541379583| 0.9393583752590735|0.9115746440336561|0.9232645991421824|0.9327165253148291|   24974|   11318|     517|    2101|19.383732080459595|   cols_set_1|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           17|  85341|      44538|       GBT|{'maxIter': 20, '...|0.9088552052062627|0.9078151046845653|   0.9206863539288608|0.9811646523308742| 0.949963907146385|       0.9582753824756607|    0.8365457580816512|0.8932825540879994| 0.9394808682022607|0.9088552052062627|0.9216232306171922|0.9318710878899178|   25004|   11024|     480|    2154|19.861103057861328|   cols_set_1|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           18|  85671|      44538|       GBT|{'maxIter': 20, '...|0.9131726748846798|0.9129653877326133|   0.9236744714374703| 0.982270194443362|0.9520716093212979|       0.9612138777597817|    0.8440751553259974|0.8988441610203267| 0.9424441745986261|0.9131726748846798|0.9254578851708123| 0.934959766285685|   25208|   11276|     455|    2083| 19.24604344367981|   cols_set_1|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           19|  85416|      44538|       GBT|{'maxIter': 20, '...|0.9139502078986284|0.9098975166813399|    0.925766404864454|0.9803004752414534|0.9522533087619368|       0.9568828118446439|    0.8475999405558032|0.8989321880294732|  0.941324608354549|0.9139502078986284|0.9255927483957049|0.9351453855878634|   25578|   11407|     514|    2051|19.340341806411743|   cols_set_1|
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# only showing top 20 rows
