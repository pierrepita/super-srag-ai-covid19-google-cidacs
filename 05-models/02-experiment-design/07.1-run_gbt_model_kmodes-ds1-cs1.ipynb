# %%
import pandas as pd
import pyspark.sql.functions as F
from datetime import datetime
from pyspark.sql.types import *
from pyspark import StorageLevel

import numpy as np
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", 1000)
pd.set_option("mode.chained_assignment", None)

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import GBTClassifier
from pyspark.ml.feature import IndexToString, StringIndexer, VectorIndexer
# from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import OneHotEncoderEstimator, StringIndexer, VectorAssembler

from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

from pyspark.sql import Row
from pyspark.ml.linalg import Vectors

# %%
# !pip install scikit-plot

# %%
import sklearn
import scikitplot as skplt
from sklearn.metrics import classification_report, confusion_matrix, precision_score

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
result_schema = StructType([
                    StructField('experiment_filter', StringType(), True),
                    StructField('undersampling_method', StringType(), True),
                    StructField('undersampling_column', StringType(), True),
                    StructField('filename', StringType(), True),
                    StructField('experiment_id', StringType(), True),
                    StructField('n_covid', IntegerType(), True),
                    StructField('n_not_covid', IntegerType(), True),
                    StructField('model_name', StringType(), True),
                    StructField('model_seed', StringType(), True),
                    StructField('model_maxIter', IntegerType(), True),
                    StructField('model_maxDepth', IntegerType(), True),
                    StructField('model_maxBins', IntegerType(), True),
                    StructField('model_minInstancesPerNode', IntegerType(), True),
                    StructField('model_minInfoGain', FloatType(), True),
                    StructField('model_featureSubsetStrategy', StringType(), True),
                    StructField('model_n_estimators', IntegerType(), True),
                    StructField('model_learning_rate', FloatType(), True),
                    StructField('model_impurity', StringType(), True),
                    StructField('model_AUC_ROC', StringType(), True),
                    StructField('model_AUC_PR', StringType(), True),
                    StructField('model_covid_precision', StringType(), True),
                    StructField('model_covid_recall', StringType(), True),
                    StructField('model_covid_f1', StringType(), True),
                    StructField('model_not_covid_precision', StringType(), True),
                    StructField('model_not_covid_recall', StringType(), True),
                    StructField('model_not_covid_f1', StringType(), True),
                    StructField('model_avg_precision', StringType(), True),
                    StructField('model_avg_recall', StringType(), True),
                    StructField('model_avg_f1', StringType(), True),
                    StructField('model_avg_acc', StringType(), True),
                    StructField('model_TP', StringType(), True),
                    StructField('model_TN', StringType(), True),
                    StructField('model_FN', StringType(), True),
                    StructField('model_FP', StringType(), True),
                    StructField('model_time_exec', StringType(), True),
                    StructField('model_col_set', StringType(), True)
                          ])

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# undersamp_col = ['03-STRSAMP-AG', '04-STRSAMP-EW'] 
# dfs = ['ds-1', 'ds-2', 'ds-3']
# cols_sets = ['cols_set_1', 'cols_set_2', 'cols_set_3']

undersamp_col = ['02-KMODES']
dfs = ['ds-1']
cols_sets = ['cols_set_1']

# %%
# lists of params
model_maxIter = [20, 50, 100] 
model_maxDepth = [3, 5, 7] 
model_maxBins = [32, 64] 
# model_learningRate = [0.01, 0.1, 0.5]
# model_loss = ['logLoss', 'leastSquaresError', 'leastAbsoluteError']


list_of_param_dicts = []

for maxIter in model_maxIter:
    for maxDepth in model_maxDepth:
        for maxBins in model_maxBins: 
            params_dict = {}
            params_dict['maxIter'] = maxIter
            params_dict['maxDepth'] = maxDepth
            params_dict['maxBins'] = maxBins
            list_of_param_dicts.append(params_dict)

            

print("There is {} set of params.".format(len(list_of_param_dicts)))
# list_of_param_dicts
# Out:
# There is 18 set of params.

# %%
prefix = 'gs://ai-covid19-datalake/trusted/experiment_map/'

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# filename = 'gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment0.parquet'
# df = spark.read.parquet(filename)
# df.limit(2).toPandas()

# %%
# params_dict = {'maxIter': 100,
#                'maxDepth': 3,
#                'maxBins': 32,
#                'learningRate': 0.5,
#                'loss': 'leastAbsoluteError'}
# cols = 'cols_set_1'
# experiment_filter = 'ds-1'
# undersampling_method = '03-STRSAMP-AG', 
# experiment_id = 0

# %%
# run_gbt(df, params_dict, cols, filename, experiment_filter, undersampling_method, experiment_id)

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
def run_gbt(exp_df, params_dict, cols, filename, experiment_filter, 
            undersampling_method, experiment_id):
    import time
    start_time = time.time()
    
    n_covid = exp_df.filter(F.col('CLASSI_FIN') == 1.0).count()
    n_not_covid = exp_df.filter(F.col('CLASSI_FIN') == 0.0).count()
    
    
    id_cols = ['NU_NOTIFIC', 'CLASSI_FIN']

    labelIndexer = StringIndexer(inputCol="CLASSI_FIN", outputCol="indexedLabel").fit(exp_df)    
    
    input_cols = [x for x in exp_df.columns if x not in id_cols]
    assembler = VectorAssembler(inputCols = input_cols, outputCol= 'features')
    exp_df = assembler.transform(exp_df)
    
    # Automatically identify categorical features, and index them.
    # Set maxCategories so features with > 4 distinct values are treated as continuous.
    featureIndexer = VectorIndexer(inputCol="features", outputCol="indexedFeatures", maxCategories=30).fit(exp_df)
    
    # Split the data into training and test sets (30% held out for testing)
    (trainingData, testData) = exp_df.randomSplit([0.7, 0.3])
    trainingData = trainingData.persist(StorageLevel.MEMORY_ONLY)
    testData = testData.persist(StorageLevel.MEMORY_ONLY)
    
    # Train a RandomForest model.
    gbt = GBTClassifier(labelCol = "indexedLabel", featuresCol = "indexedFeatures",
                       maxIter = params_dict['maxIter'],
                       maxDepth = params_dict['maxDepth'],
                       maxBins = params_dict['maxBins'])
    
    # Convert indexed labels back to original labels.
    labelConverter = IndexToString(inputCol="prediction", outputCol="predictedLabel",
                               labels=labelIndexer.labels)

    # Chain indexers and forest in a Pipeline
    pipeline = Pipeline(stages=[labelIndexer, featureIndexer, gbt, labelConverter])

    # Train model.  This also runs the indexers.
    model = pipeline.fit(trainingData)
    
    # Make predictions.
    predictions = model.transform(testData)    
    
    
    pred = predictions.select(['CLASSI_FIN', 'predictedLabel'])\
                  .withColumn('predictedLabel', F.col('predictedLabel').cast('double'))\
                  .withColumn('predictedLabel', F.when(F.col('predictedLabel') == 1.0, 'covid').otherwise('n-covid'))\
                  .withColumn('CLASSI_FIN', F.when(F.col('CLASSI_FIN') == 1.0, 'covid').otherwise('n-covid'))\
                  .toPandas()

    y_true = pred['CLASSI_FIN'].tolist()
    y_pred = pred['predictedLabel'].tolist()
    
    report = classification_report(y_true, y_pred, output_dict=True)
    
    
    evaluator_ROC = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderROC")
    accuracy_ROC = evaluator_ROC.evaluate(predictions)


    
    evaluator_PR = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderPR")
    accuracy_PR = evaluator_PR.evaluate(predictions)
    
    conf_matrix = confusion_matrix(y_true, y_pred)

    result_dict = {}
    
    result_dict['experiment_filter'] = experiment_filter
    result_dict['undersampling_method'] = undersampling_method
    result_dict['filename'] = filename
    result_dict['experiment_id'] = experiment_id
    result_dict['n_covid'] = n_covid
    result_dict['n_not_covid'] = n_not_covid
    result_dict['model_name'] = 'GBT'
    result_dict['params'] = params_dict
    result_dict['model_AUC_ROC'] = accuracy_ROC
    result_dict['model_AUC_PR'] = accuracy_PR
    result_dict['model_covid_precision'] = report['covid']['precision']
    result_dict['model_covid_recall'] = report['covid']['recall']
    result_dict['model_covid_f1'] = report['covid']['f1-score']
    result_dict['model_not_covid_precision'] = report['n-covid']['precision']
    result_dict['model_not_covid_recall'] = report['n-covid']['recall']
    result_dict['model_not_covid_f1'] = report['n-covid']['f1-score']
    result_dict['model_avg_precision'] = report['macro avg']['precision']
    result_dict['model_avg_recall'] = report['macro avg']['recall']
    result_dict['model_avg_f1'] = report['macro avg']['f1-score']
    result_dict['model_avg_acc'] = report['accuracy']
    result_dict['model_TP'] = conf_matrix[0][0]
    result_dict['model_TN'] = conf_matrix[1][1]
    result_dict['model_FN'] = conf_matrix[0][1]
    result_dict['model_FP'] = conf_matrix[1][0]
    result_dict['model_time_exec'] = time.time() - start_time
    result_dict['model_col_set'] = cols
    
    return result_dict

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %% [markdown]
# # Running GBT on 10 samples for each experiment
# ### 3x col sets -> ['cols_set_1', 'cols_set_2', 'cols_set_3']
# ### 3x model_maxIter -> [100, 200, 300]
# ### 3x model_maxDepth -> [5, 10, 15]
# ### 3x model_maxBins -> [16, 32, 64]
# Total: 10 * 3 * 3 * 3 * 3 = 810

# %%
experiments = []

# %% [markdown]
# ### Datasets: strat_samp_lab_agegrp

# %%
for uc in undersamp_col: 
    for ds in dfs:
        for col_set in cols_sets:
            for params_dict in list_of_param_dicts: 
                for id_exp in range(50):
                    filename = prefix + uc + '/' + ds + '/' + col_set + '/' + 'experiment' + str(id_exp) + '.parquet'
                    exp_dataframe = spark.read.parquet(filename)
                    print('read {}'.format(filename))
                    
                    undersampling_method = uc
                    experiment_filter = ds
                    experiment_id = id_exp

                    try:                     
                        model = run_gbt(exp_dataframe, params_dict, col_set, filename, experiment_filter, undersampling_method, experiment_id)
                        experiments.append(model)

                        print("Parameters ==> {}\n Results: \n AUC_PR: {} \n Precision: {} \n Time: {}".format(str(params_dict), str(model['model_AUC_PR']), str(model['model_avg_precision']), str(model['model_time_exec'])))
                        print('=========================== \n')
                    except:
                        print('=========== W A R N I N G =========== \n')
                        print('Something wrong with the exp: {}, {}, {}'.format(filename, params_dict, col_set))
# Out:
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9315733551356469
#  Precision: 0.9307913765706439
#  Time: 41.62877631187439
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9354008869981262
#  Precision: 0.9309995404107654
#  Time: 28.01013708114624
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9384693324640283
#  Precision: 0.930860939614748
#  Time: 27.427576780319214
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9364006755379176
#  Precision: 0.9292346133897367
#  Time: 27.903626918792725
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9260879114150724
#  Precision: 0.9228245339797236
#  Time: 27.58692717552185
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9381443596432532
#  Precision: 0.9269279992207835
#  Time: 27.42198896408081
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9341767112077928
#  Precision: 0.9232436453656965
#  Time: 29.022913694381714
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.927792013965246
#  Precision: 0.9288000607683786
#  Time: 27.900113344192505
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9342493944865194
#  Precision: 0.9276477352325438
#  Time: 27.436068058013916
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9276503444452856
#  Precision: 0.9266473939218958
#  Time: 26.787810802459717
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.931211998041493
#  Precision: 0.9258305310254383
#  Time: 27.814568996429443
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9339934529530299
#  Precision: 0.9282542471309541
#  Time: 27.619473695755005
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9402988221387953
#  Precision: 0.9277381967747566
#  Time: 26.352428674697876
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9346361680159795
#  Precision: 0.9309687939384472
#  Time: 26.54385256767273
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9361211915840358
#  Precision: 0.9262322074465953
#  Time: 26.28137707710266
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.931004100593585
#  Precision: 0.930858580659808
#  Time: 27.02816104888916
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9270805456324126
#  Precision: 0.9271430376303472
#  Time: 26.42976975440979
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9368142223384608
#  Precision: 0.9225225147527655
#  Time: 27.477734565734863
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9372202903992625
#  Precision: 0.9264641242641763
#  Time: 26.135874032974243
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9287030566130452
#  Precision: 0.9244105234709838
#  Time: 26.27331018447876
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9334281374585192
#  Precision: 0.9308727538147843
#  Time: 25.609343767166138
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9268690270511597
#  Precision: 0.9267756554067519
#  Time: 27.116715908050537
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9301429721209147
#  Precision: 0.9231580666998271
#  Time: 26.23896312713623
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9295700547426379
#  Precision: 0.9325596460083054
#  Time: 26.859752655029297
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9379763897406815
#  Precision: 0.9248395203287139
#  Time: 26.659346103668213
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9280214412888202
#  Precision: 0.9283076375828567
#  Time: 27.36453938484192
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8714922249457155
#  Precision: 0.9232768911644905
#  Time: 27.11098027229309
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9367192218984278
#  Precision: 0.9272098607827273
#  Time: 27.124125242233276
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.929954772008208
#  Precision: 0.9309846994661665
#  Time: 26.471084594726562
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9393241255946694
#  Precision: 0.9294957510716969
#  Time: 27.232008934020996
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9333710299924334
#  Precision: 0.9228369579938009
#  Time: 26.541452646255493
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9306942930929143
#  Precision: 0.9314731933974649
#  Time: 26.52873706817627
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9339287689084921
#  Precision: 0.9226178780074679
#  Time: 26.326390981674194
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9276307467208795
#  Precision: 0.9232275877953582
#  Time: 26.006055116653442
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9244450428749347
#  Precision: 0.9230207982966951
#  Time: 26.318885326385498
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9291542550996348
#  Precision: 0.9237820007237445
#  Time: 26.995535612106323
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9280721365478948
#  Precision: 0.9271353665516341
#  Time: 26.506975889205933
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9344836441960905
#  Precision: 0.9296348007416191
#  Time: 27.107228755950928
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9332328472396949
#  Precision: 0.9233864594928296
#  Time: 26.825334310531616
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9314623766776803
#  Precision: 0.9337172297833191
#  Time: 28.545623064041138
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9356462306647517
#  Precision: 0.9237523787440411
#  Time: 26.950769662857056
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9326732189017137
#  Precision: 0.9333162346565963
#  Time: 26.43789553642273
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9376996487785184
#  Precision: 0.9345031035039812
#  Time: 25.279082775115967
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9359748907201699
#  Precision: 0.9273699608066603
#  Time: 25.709168434143066
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9364951047973263
#  Precision: 0.9279301633931061
#  Time: 25.654922485351562
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9312959839049809
#  Precision: 0.9288026777524094
#  Time: 26.332356214523315
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.928962012123101
#  Precision: 0.9221822118269084
#  Time: 28.606616973876953
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9353104396818203
#  Precision: 0.9231012398323973
#  Time: 28.921316385269165
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9395830068009939
#  Precision: 0.929042022489396
#  Time: 27.825759649276733
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9288824903984934
#  Precision: 0.9230235738093664
#  Time: 26.324198961257935
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9328400435102423
#  Precision: 0.9321388897897821
#  Time: 25.576685190200806
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9360626612693795
#  Precision: 0.933107877905029
#  Time: 26.13049817085266
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9392404565309578
#  Precision: 0.9312116013302268
#  Time: 25.540989637374878
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.938181723892037
#  Precision: 0.9303808317234683
#  Time: 26.405035257339478
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9302636062310055
#  Precision: 0.924617050935463
#  Time: 25.926782846450806
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9388936700333994
#  Precision: 0.9285408191053623
#  Time: 27.554885864257812
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9384109091478076
#  Precision: 0.9254507473754996
#  Time: 25.894380569458008
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9298703799499748
#  Precision: 0.9304633774914401
#  Time: 28.427411556243896
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9344518479182912
#  Precision: 0.9273937770060747
#  Time: 27.790321350097656
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9237574093952121
#  Precision: 0.9245885110159208
#  Time: 27.900771617889404
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9366062488735329
#  Precision: 0.9289074573308281
#  Time: 27.38353157043457
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9331541807724691
#  Precision: 0.928163020454372
#  Time: 25.987371921539307
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.941701642977561
#  Precision: 0.9303530281632824
#  Time: 26.17393946647644
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9353888274153928
#  Precision: 0.9303322157720495
#  Time: 25.919705152511597
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9390092446245765
#  Precision: 0.9276007204953564
#  Time: 28.25419282913208
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9284622085833459
#  Precision: 0.9285392554385992
#  Time: 26.817335605621338
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9203815223145624
#  Precision: 0.9246393472348176
#  Time: 28.320749282836914
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9381070111788599
#  Precision: 0.9231023060060821
#  Time: 28.161686182022095
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9321644167482974
#  Precision: 0.9259062685448725
#  Time: 25.749639987945557
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9308338603657331
#  Precision: 0.9284062122727514
#  Time: 25.59669303894043
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9328273284676951
#  Precision: 0.9312282253991057
#  Time: 25.969003200531006
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9223069376408026
#  Precision: 0.9241202376720643
#  Time: 25.296940803527832
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9305698246113766
#  Precision: 0.9215968331649544
#  Time: 25.308579206466675
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9355760510574161
#  Precision: 0.9350125426574607
#  Time: 25.8396155834198
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9347953567681802
#  Precision: 0.925044337480941
#  Time: 25.314594745635986
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9294575982005725
#  Precision: 0.9298148543298472
#  Time: 25.73242497444153
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8747068379496368
#  Precision: 0.9261039002856359
#  Time: 25.128864288330078
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9379808802404473
#  Precision: 0.9260822991916864
#  Time: 25.500067949295044
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9249804894108133
#  Precision: 0.9286812301851602
#  Time: 25.395185708999634
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.933645635009927
#  Precision: 0.9247907606133465
#  Time: 24.670857906341553
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9327647288648289
#  Precision: 0.92429676010982
#  Time: 25.570191621780396
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9349242457234418
#  Precision: 0.9327902769503188
#  Time: 24.663010358810425
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9356230300317844
#  Precision: 0.9244577893362258
#  Time: 26.1631019115448
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9304080657336109
#  Precision: 0.924872295253278
#  Time: 25.506256818771362
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9326329292340649
#  Precision: 0.9258614819961088
#  Time: 27.919859886169434
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9311355995903345
#  Precision: 0.9247971502487426
#  Time: 24.843251943588257
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9302207203975488
#  Precision: 0.9280920969336443
#  Time: 25.325464010238647
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9341469680641111
#  Precision: 0.9281471482114307
#  Time: 26.125304460525513
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9352791424957633
#  Precision: 0.9246165538942843
#  Time: 25.08273696899414
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.932562450675462
#  Precision: 0.9340975045978018
#  Time: 25.428073406219482
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9312234970811288
#  Precision: 0.9206925395474971
#  Time: 25.224673986434937
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9242180347275324
#  Precision: 0.9255513493470604
#  Time: 24.764141082763672
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9362394520523849
#  Precision: 0.932809989929137
#  Time: 26.722431659698486
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9331583609805042
#  Precision: 0.9262933942937336
#  Time: 26.02673840522766
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9352651675592004
#  Precision: 0.9263429136292254
#  Time: 27.140039920806885
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9296611274934217
#  Precision: 0.9272627162598706
#  Time: 26.096724033355713
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9338018200494371
#  Precision: 0.9256588814753757
#  Time: 25.253122329711914
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9366967664031147
#  Precision: 0.9239880032845411
#  Time: 24.62041473388672
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9419279344420759
#  Precision: 0.9286025341635884
#  Time: 24.59400987625122
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9298606785862467
#  Precision: 0.9230451446035877
#  Time: 25.090026140213013
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9378585212026923
#  Precision: 0.9385470662251674
#  Time: 29.338337182998657
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9370772577093605
#  Precision: 0.9377802210928947
#  Time: 28.33150625228882
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9398484759106643
#  Precision: 0.936792423346755
#  Time: 28.55446720123291
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9404082463550735
#  Precision: 0.9361353457755919
#  Time: 28.597123622894287
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9381666659974801
#  Precision: 0.9350181532435717
#  Time: 28.60639190673828
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9415396256409915
#  Precision: 0.9358775923345422
#  Time: 29.11122488975525
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9411428658729347
#  Precision: 0.9310286578962285
#  Time: 28.590480089187622
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.934864329283103
#  Precision: 0.9371380397783129
#  Time: 29.06938600540161
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9376101786133947
#  Precision: 0.9346483775485734
#  Time: 28.859719276428223
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9317866346988987
#  Precision: 0.9350450244812145
#  Time: 29.56121826171875
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9402420672796334
#  Precision: 0.9361397465930155
#  Time: 29.16270351409912
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9378441061462528
#  Precision: 0.9351690511294372
#  Time: 29.60276961326599
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9406935511736821
#  Precision: 0.9331029977854859
#  Time: 28.584876775741577
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.938704052716952
#  Precision: 0.9386342280014737
#  Time: 28.85605812072754
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9393073754652884
#  Precision: 0.9352565104686277
#  Time: 29.015967845916748
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9348034171763653
#  Precision: 0.9357381870295087
#  Time: 29.3065402507782
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9341521515784479
#  Precision: 0.9371559872526988
#  Time: 29.24867296218872
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9426688751701717
#  Precision: 0.9332556477728735
#  Time: 29.34188747406006
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9417528109226353
#  Precision: 0.9363274315773602
#  Time: 29.26758646965027
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9388736135549076
#  Precision: 0.9359497228707561
#  Time: 31.24099588394165
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9377608190354298
#  Precision: 0.9377111910434939
#  Time: 28.420185565948486
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9352925760257436
#  Precision: 0.9353671823644996
#  Time: 32.60247230529785
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.940469134081393
#  Precision: 0.9350092829106152
#  Time: 28.731499195098877
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.939287174846123
#  Precision: 0.9422275144290275
#  Time: 29.650335550308228
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9399107284316096
#  Precision: 0.931974673335881
#  Time: 30.102906942367554
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment25.parquet
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8901133646602674
#  Precision: 0.9311447575431248
#  Time: 53.132070541381836
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9431782336994232
#  Precision: 0.9350903996059475
#  Time: 45.29877996444702
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9362329502180096
#  Precision: 0.9385512638967393
#  Time: 45.27361488342285
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9435125112470749
#  Precision: 0.9353448050106353
#  Time: 42.92425727844238
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9400481215939599
#  Precision: 0.9336713845790592
#  Time: 43.40289878845215
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9378262508338371
#  Precision: 0.9390550095779215
#  Time: 45.175092458724976
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.940678294551378
#  Precision: 0.9333466137975373
#  Time: 42.81474304199219
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9367649956599164
#  Precision: 0.9333864582340308
#  Time: 43.99237608909607
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9393379250501995
#  Precision: 0.9371106404662902
#  Time: 44.11496162414551
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9382651070354684
#  Precision: 0.9354747945267957
#  Time: 45.56007742881775
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9395878411045213
#  Precision: 0.9374074885769645
#  Time: 42.46041822433472
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9369491444631252
#  Precision: 0.9361051794699743
#  Time: 43.440146684646606
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9410049242250899
#  Precision: 0.9341592378734681
#  Time: 42.73014307022095
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9380036234027012
#  Precision: 0.940648926789323
#  Time: 43.34473013877869
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9401244983005567
#  Precision: 0.9322817688315709
#  Time: 42.308223724365234
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9352409626981074
#  Precision: 0.9386754836029965
#  Time: 43.30575442314148
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9371292178535411
#  Precision: 0.9381203282728765
#  Time: 43.97051477432251
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9415327065354372
#  Precision: 0.9368622452599606
#  Time: 43.486175537109375
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9414055223537189
#  Precision: 0.9343150804064684
#  Time: 44.56781578063965
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9377994330765657
#  Precision: 0.9377797770237183
#  Time: 44.89262318611145
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9375242937273556
#  Precision: 0.933507168079686
#  Time: 43.69776964187622
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9409618908175125
#  Precision: 0.9318853614524928
#  Time: 45.25480842590332
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9366459515448607
#  Precision: 0.9309480277284072
#  Time: 48.50293850898743
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9388347272247561
#  Precision: 0.9347622621645364
#  Time: 45.11831259727478
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9387799361641385
#  Precision: 0.9386608080096652
#  Time: 46.34094429016113
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.938627808533177
#  Precision: 0.9370410404522642
#  Time: 44.08912420272827
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9364868770853059
#  Precision: 0.9360508154714344
#  Time: 45.93356370925903
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9400550550059714
#  Precision: 0.9358767011455551
#  Time: 43.945711851119995
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9379325308092008
#  Precision: 0.9334526304556683
#  Time: 44.14605760574341
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9391415110326111
#  Precision: 0.9336907600422673
#  Time: 45.076904296875
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9366921453983336
#  Precision: 0.9283137562542247
#  Time: 42.91670560836792
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9378533034536127
#  Precision: 0.9390380105335424
#  Time: 43.50861716270447
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9385839715511057
#  Precision: 0.9349644667201146
#  Time: 42.49969148635864
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9382804663820856
#  Precision: 0.9378905924312524
#  Time: 44.78474020957947
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9380984426679408
#  Precision: 0.9336368967918012
#  Time: 42.56660723686218
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9362422124189134
#  Precision: 0.9336126948445511
#  Time: 42.32346487045288
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9451686821190627
#  Precision: 0.9361761487092588
#  Time: 41.529441595077515
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9402209884201995
#  Precision: 0.9392296331177961
#  Time: 41.747024059295654
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.940371912851694
#  Precision: 0.9341574916587976
#  Time: 43.50554084777832
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9330060703919457
#  Precision: 0.9373593739534172
#  Time: 47.84731888771057
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9357651681938376
#  Precision: 0.9377731651100343
#  Time: 44.08954691886902
# ===========================
#
# ...
#  Time: 150.05921173095703
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment45.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9422126492133194
#  Precision: 0.9463008342284596
#  Time: 151.06359124183655
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9440064131271292
#  Precision: 0.944492651761913
#  Time: 151.786288022995
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9455475078433371
#  Precision: 0.9431152338243066
#  Time: 150.73435258865356
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment48.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9377979815874223
#  Precision: 0.9396309240109993
#  Time: 149.86431407928467
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9421572286363614
#  Precision: 0.9419749357764311
#  Time: 149.14314007759094
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment0.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9396133926223806
#  Precision: 0.9452512753779496
#  Time: 156.35857105255127
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment1.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9397413243610317
#  Precision: 0.9434492610758101
#  Time: 155.49297761917114
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment2.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9400490317617829
#  Precision: 0.9437330481654662
#  Time: 152.03895330429077
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment3.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9417634761746648
#  Precision: 0.9435634007025874
#  Time: 155.13338661193848
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment4.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9432554134004869
#  Precision: 0.9446966065343733
#  Time: 154.22024822235107
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment5.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9426250789336365
#  Precision: 0.9414046115503061
#  Time: 149.26831316947937
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment6.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9455638598228636
#  Precision: 0.9412475229447743
#  Time: 145.8153269290924
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment7.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9375494248162595
#  Precision: 0.9447275947268876
#  Time: 148.0108551979065
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment8.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9424338501854471
#  Precision: 0.9438888437065126
#  Time: 147.11024641990662
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment9.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9398105171981198
#  Precision: 0.9444376572026187
#  Time: 147.55826711654663
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment10.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9436670306465761
#  Precision: 0.9442114979200313
#  Time: 149.61333680152893
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment11.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9412194065858931
#  Precision: 0.9443226417463653
#  Time: 149.9025502204895
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment12.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9431081543847583
#  Precision: 0.9416839274541008
#  Time: 147.96196675300598
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment13.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9417281139715602
#  Precision: 0.944393413971041
#  Time: 147.8612744808197
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment14.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9437314442395812
#  Precision: 0.9427213401890729
#  Time: 149.77286219596863
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment15.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9378332921309891
#  Precision: 0.9441701090913527
#  Time: 150.76059317588806
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment16.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9431354050472329
#  Precision: 0.9481564638373821
#  Time: 147.79350805282593
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment17.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9469186853813887
#  Precision: 0.9433949183058372
#  Time: 148.40571570396423
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment18.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9415262907200836
#  Precision: 0.9424666219223297
#  Time: 145.91531944274902
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment19.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9405489747747064
#  Precision: 0.943015452190912
#  Time: 148.82528376579285
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment20.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9384523387627539
#  Precision: 0.9444050568013724
#  Time: 150.25803232192993
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment21.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.942173454425913
#  Precision: 0.9446881694205638
#  Time: 147.57357954978943
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment22.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9458122824410524
#  Precision: 0.9439454842407756
#  Time: 147.89453148841858
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment23.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9395477750327346
#  Precision: 0.9477108009708235
#  Time: 148.7371528148651
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment24.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9443669251836213
#  Precision: 0.9415202610434263
#  Time: 145.18537950515747
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment25.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9424622704401862
#  Precision: 0.9463741817848265
#  Time: 147.78258609771729
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment26.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9132364085590315
#  Precision: 0.9430811597305366
#  Time: 146.8778235912323
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment27.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9451505334321367
#  Precision: 0.9439288581334788
#  Time: 150.24962663650513
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment28.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9358359643253007
#  Precision: 0.9445887281080669
#  Time: 151.12975668907166
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment29.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9446851146661828
#  Precision: 0.9427826551569289
#  Time: 153.79090404510498
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment30.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.94283712779573
#  Precision: 0.9429855626157752
#  Time: 150.21679067611694
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment31.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9443886726638034
#  Precision: 0.9485327961406588
#  Time: 150.88745188713074
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment32.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9486157387240658
#  Precision: 0.945758363714253
#  Time: 149.01637625694275
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment33.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9456937414281535
#  Precision: 0.9469118296831842
#  Time: 149.0238790512085
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment34.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9443840046818293
#  Precision: 0.9452586149936031
#  Time: 149.63964867591858
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment35.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9468860921527891
#  Precision: 0.946816946087667
#  Time: 157.55027222633362
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment36.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9411225753945676
#  Precision: 0.9457738507049154
#  Time: 156.30063724517822
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment37.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9389316211272813
#  Precision: 0.9424984061501286
#  Time: 153.55657172203064
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment38.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9445158390643266
#  Precision: 0.942306296707658
#  Time: 148.37195229530334
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment39.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9415443456525995
#  Precision: 0.9473716231816363
#  Time: 153.20650601387024
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment40.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9416795163495443
#  Precision: 0.9407052826309321
#  Time: 157.93846225738525
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment41.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9405778560514497
#  Precision: 0.9471593060410556
#  Time: 157.62456893920898
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment42.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9420309562193714
#  Precision: 0.9468243048340952
#  Time: 153.40172839164734
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment43.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9445761252923894
#  Precision: 0.9438232379765363
#  Time: 150.31206917762756
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment44.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9405365684492304
#  Precision: 0.9403960832171246
#  Time: 149.57546734809875
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment45.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9411088729056908
#  Precision: 0.9432928703776093
#  Time: 148.36219763755798
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9406072029768617
#  Precision: 0.942416010773281
#  Time: 149.61655616760254
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.943966439843517
#  Precision: 0.9415542361966875
#  Time: 149.20932579040527
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment48.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9417265720780101
#  Precision: 0.9411423254585792
#  Time: 148.5778124332428
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-1/cols_set_1/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9417931367050547
#  Precision: 0.942607477123531
#  Time: 149.20253014564514
# ===========================

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
for i in range(len(experiments)):
    for d in list(experiments[i].keys()):
        experiments[i][d] = str(experiments[i][d])

# %%
# experiments

# %%
cols = ['experiment_filter', 'undersampling_method', 'filename', 'experiment_id', 'n_covid', 'n_not_covid', 'model_name', 'params', 'model_AUC_ROC', 'model_AUC_PR', 'model_covid_precision', 'model_covid_recall', 'model_covid_f1', 'model_not_covid_precision', 'model_not_covid_recall', 'model_not_covid_f1', 'model_avg_precision', 'model_avg_recall', 'model_avg_f1', 'model_avg_acc', 'model_TP', 'model_TN', 'model_FN', 'model_FP', 'model_time_exec', 'model_col_set']

# %%
intermed_results = spark.createDataFrame(data=experiments).select(cols)
intermed_results.toPandas()
# Out:
# /usr/lib/spark/python/pyspark/sql/session.py:346: UserWarning: inferring schema from dict is deprecated,please use pyspark.sql.Row instead
#   warnings.warn("inferring schema from dict is deprecated,"

# %%
intermed_results.write.parquet('gs://ai-covid19-datalake/trusted/intermed_results/KMODES/GBT_experiments-kmodes-ds1-cs1.parquet', mode='overwrite')

# %%
df = spark.read.parquet('gs://ai-covid19-datalake/trusted/intermed_results/KMODES/GBT_experiments-kmodes-ds1-cs1.parquet')
df.limit(2).toPandas()
# Out:
#   experiment_filter undersampling_method  \
# 0              ds-1            02-KMODES
# 1              ds-1            02-KMODES
#
#                                             filename experiment_id n_covid  \
# 0  gs://ai-covid19-datalake/trusted/experiment_ma...            34   49782
# 1  gs://ai-covid19-datalake/trusted/experiment_ma...            35   48537
#
#   n_not_covid model_name                                          params  \
# 0       44538        GBT  {'maxIter': 100, 'maxDepth': 5, 'maxBins': 64}
# 1       44538        GBT  {'maxIter': 100, 'maxDepth': 5, 'maxBins': 64}
#
#         model_AUC_ROC        model_AUC_PR model_covid_precision  \
# 0  0.9392814956577603  0.9446371366585906    0.9198597386037616
# 1  0.9410308543222365  0.9453411263100637    0.9224508399531189
#
#    model_covid_recall      model_covid_f1 model_not_covid_precision  \
# 0  0.9733522228968495  0.9458502687819589        0.9681425921445278
# 1  0.9724739154310819  0.9468021118759608        0.9676168941290478
#
#   model_not_covid_recall  model_not_covid_f1 model_avg_precision  \
# 0     0.9052107684186713  0.9356196414653157  0.9440011653741447
# 1      0.909587793213391  0.9377054312098919  0.9450338670410834
#
#      model_avg_recall        model_avg_f1       model_avg_acc model_TP  \
# 0  0.9392814956577604  0.9407349551236373  0.9411764705882353    14428
# 1  0.9410308543222364  0.9422537715429263  0.9426120183122454    14167
#
#   model_TN model_FN model_FP    model_time_exec model_col_set
# 0    12004      395     1257  96.95071029663086    cols_set_1
# 1    11982      401     1191   96.1738178730011    cols_set_1

# %%
print('finished')
# Out:
# finished

# %%
intermed_results.show()
# Out:
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# |experiment_filter|undersampling_method|            filename|experiment_id|n_covid|n_not_covid|model_name|              params|     model_AUC_ROC|      model_AUC_PR|model_covid_precision|model_covid_recall|    model_covid_f1|model_not_covid_precision|model_not_covid_recall|model_not_covid_f1|model_avg_precision|  model_avg_recall|      model_avg_f1|     model_avg_acc|model_TP|model_TN|model_FN|model_FP|   model_time_exec|model_col_set|
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|            0|  53827|      44538|       GBT|{'maxIter': 20, '...|0.9180001748476496|0.9315733551356469|   0.8938597977743885|0.9763079960513327|0.9332664916988588|       0.9677229553668992|    0.8596923536439666|0.9105144529241963| 0.9307913765706439|0.9180001748476496|0.9218904723115275|0.9235472972972973|   15824|   11513|     384|    1879| 41.62877631187439|   cols_set_1|
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|            1|  52360|      44538|       GBT|{'maxIter': 20, '...| 0.918336825434314|0.9354008869981262|   0.8901488718306583|0.9788962077124768|0.9324155575183505|       0.9718502089908726|    0.8577774431561512|0.9112577484503099| 0.9309995404107654| 0.918336825434314|0.9218366529843303|0.9232684394342819|   15307|   11393|     330|    1889| 28.01013708114624|   cols_set_1|
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|            2|  50618|      44538|       GBT|{'maxIter': 20, '...|0.9204917374002849|0.9384693324640283|   0.8886632421455023|0.9787513979343464|0.9315342954637948|       0.9730586370839936|    0.8622320768662232|0.9142991496531996|  0.930860939614748|0.9204917374002848|0.9229167225584972|0.9238801294768717|   14878|   11666|     323|    1864|27.427576780319214|   cols_set_1|
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|            3|  50145|      44538|       GBT|{'maxIter': 20, '...|0.9175145617065815|0.9364006755379176|   0.8857005642934326|0.9789662265277685|0.9300009455072645|       0.9727686624860408|    0.8560628968853946| 0.910692026217379| 0.9292346133897367|0.9175145617065816|0.9203464858623218| 0.921516661366126|   14754|   11324|     317|    1904|27.903626918792725|   cols_set_1|
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|            4|  49537|      44538|       GBT|{'maxIter': 20, '...|0.9136793576201324|0.9260879114150724|   0.8849687614847482|0.9686892390211197|0.9249383822540891|        0.960680306474699|    0.8586694762191451|0.9068150208623088| 0.9228245339797236|0.9136793576201324| 0.915876701558199|0.9168528170761976|   14448|   11410|     467|    1878| 27.58692717552185|   cols_set_1|
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|            5|  47137|      44538|       GBT|{'maxIter': 20, '...|0.9188527105939799|0.9381443596432532|   0.8818862371232964|0.9766173031956352|0.9268374688991997|       0.9719697613182706|    0.8610881179923244|  0.91317532519352| 0.9269279992207835|0.9188527105939799|0.9200063970463599|0.9205897379753303|   13783|   11443|     330|    1846| 27.42198896408081|   cols_set_1|
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|            6|  44841|      44538|       GBT|{'maxIter': 20, '...|0.9189000694332969|0.9341767112077928|   0.8819010062550993|0.9682741116751269|0.9230714489040707|       0.9645862844762937|     0.869526027191467|0.9145927154934029| 0.9232436453656965|0.9189000694332969|0.9188320821987368|0.9190535025646785|   12971|   11576|     425|    1737|29.022913694381714|   cols_set_1|
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|            7|  54107|      44538|       GBT|{'maxIter': 20, '...|0.9167339896388002| 0.927792013965246|   0.8941129764065335|0.9730880809826554|0.9319303638459491|       0.9634871451302236|    0.8603798982949447|0.9090190811045707| 0.9288000607683786|   0.9167339896388|0.9204747224752599| 0.922124911236601|   15765|   11505|     436|    1867|27.900113344192505|   cols_set_1|
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|            8|  49248|      44538|       GBT|{'maxIter': 20, '...|0.9180547176977902|0.9342493944865194|   0.8866268438376204|0.9749983242844694|0.9287150837988827|       0.9686686266274674|    0.8611111111111112|0.9117286634778828| 0.9276477352325438|0.9180547176977902|0.9202218736383827|0.9211260640740349|   14546|   11532|     373|    1860|27.436068058013916|   cols_set_1|
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|            9|  52692|      44538|       GBT|{'maxIter': 20, '...|0.9164249762196433|0.9276503444452856|   0.8911420678304826|0.9708632172131147|0.9292960250084281|        0.962152720013309|    0.8619867352261719| 0.909319602216894| 0.9266473939218958|0.9164249762196433|0.9193078136126611|0.9205441708283106|   15161|   11567|     455|    1852|26.787810802459717|   cols_set_1|
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|           10|  48470|      44538|       GBT|{'maxIter': 20, '...|0.9178076531075399| 0.931211998041493|   0.8875196479094625|0.9707055425663595|0.9272506322461983|       0.9641414141414142|    0.8649097636487201|0.9118337778131592| 0.9258305310254383|0.9178076531075399|0.9195422050296788|0.9202807270109772|   14116|   11454|     426|    1789|27.814568996429443|   cols_set_1|
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|           11|  51065|      44538|       GBT|{'maxIter': 20, '...|0.9164793424825839|0.9339934529530299|   0.8860618168997532|0.9773154449413443|0.9294541868277498|       0.9704466773621548|    0.8556432400238237|0.9094362017804154| 0.9282542471309541| 0.916479342482584|0.9194451943040827|0.9206888188212466|   15079|   11493|     350|    1939|27.619473695755005|   cols_set_1|
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|           12|  45699|      44538|       GBT|{'maxIter': 20, '...| 0.921371698310912|0.9402988221387953|   0.8831423895253683|0.9761215629522432|0.9273070974394226|       0.9723340040241448|    0.8666218336695808|0.9164394927106791| 0.9277381967747566|0.9213716983109119|0.9218732950750509| 0.922251222291659|   13490|   11598|     330|    1785|26.352428674697876|   cols_set_1|
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|           13|  52031|      44538|       GBT|{'maxIter': 20, '...|0.9186688511991025|0.9346361680159795|   0.8913294797687862|0.9779299847792998|0.9326236845288497|       0.9706081081081082|    0.8594077176189052|0.9116293828335713| 0.9309687939384472|0.9186688511991026|0.9221265336812106| 0.923541523678792|   15420|   11492|     348|    1880| 26.54385256767273|   cols_set_1|
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|           14|  46660|      44538|       GBT|{'maxIter': 20, '...|0.9188706593517766|0.9361211915840358|   0.8834026223217141|0.9739792680346943|0.9264824255433324|       0.9690617925714765|    0.8637620506688588|0.9133870712818082| 0.9262322074465953|0.9188706593517766|0.9199347484125703|0.9204702126115667|   13812|   11558|     369|    1823| 26.28137707710266|   cols_set_1|
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|           15|  53477|      44538|       GBT|{'maxIter': 20, '...|0.9182926076157777| 0.931004100593585|   0.8948969634349349|0.9756555479066275|0.9335329341317364|        0.966820197884681|    0.8609296673249278|0.9108075532342307|  0.930858580659808|0.9182926076157776|0.9221702436829835|0.9238291302110139|   15590|   11335|     389|    1831| 27.02816104888916|   cols_set_1|
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|           16|  54736|      44538|       GBT|{'maxIter': 20, '...|0.9133412622633187|0.9270805456324126|   0.8891254412011877|0.9747558503777409|0.9299736302373279|       0.9651606340595067|    0.8519266741488963|0.9050154995628328| 0.9271430376303472|0.9133412622633186|0.9174945649000803|0.9193820414221143|   15870|   11386|     411|    1979| 26.42976975440979|   cols_set_1|
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|           17|  44992|      44538|       GBT|{'maxIter': 20, '...|0.9178564870635869|0.9368142223384608|   0.8764590783347952|0.9717962145582404|0.9216687952320136|       0.9685859511707358|    0.8639167595689334|0.9132620993086109| 0.9225225147527655|0.9178564870635869|0.9174654472703123|0.9176795168145552|   12990|   11624|     377|    1831|27.477734565734863|   cols_set_1|
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|           18|  48447|      44538|       GBT|{'maxIter': 20, '...|0.9161397583057275|0.9372202903992625|   0.8794466403162056|0.9786941580756013|0.9264198815952117|       0.9734816082121471|    0.8535853585358536|0.9095995523938935| 0.9264641242641763|0.9161397583057275|0.9180097169945526|0.9188723907897568|   14240|   11380|     310|    1952|26.135874032974243|   cols_set_1|
# |             ds-1|           02-KMODES|gs://ai-covid19-d...|           19|  49952|      44538|       GBT|{'maxIter': 20, '...|0.9151260714453653|0.9287030566130452|   0.8856016974840861|0.9706957272908499|0.9261983261476034|       0.9632193494578816|    0.8595564155998809|0.9084401793439787| 0.9244105234709838|0.9151260714453654|0.9173192527457911|0.9182727751448131|   14608|   11549|     441|    1887| 26.27331018447876|   cols_set_1|
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# only showing top 20 rows
