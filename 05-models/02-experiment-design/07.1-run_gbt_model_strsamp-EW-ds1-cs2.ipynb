# %%
import pandas as pd
import pyspark.sql.functions as F
from datetime import datetime
from pyspark.sql.types import *
from pyspark import StorageLevel

import numpy as np
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", 1000)
pd.set_option("mode.chained_assignment", None)

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import GBTClassifier
from pyspark.ml.feature import IndexToString, StringIndexer, VectorIndexer
# from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import OneHotEncoderEstimator, StringIndexer, VectorAssembler

from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

from pyspark.sql import Row
from pyspark.ml.linalg import Vectors

# %%
# !pip install scikit-plot

# %%
import sklearn
import scikitplot as skplt
from sklearn.metrics import classification_report, confusion_matrix, precision_score

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
result_schema = StructType([
                    StructField('experiment_filter', StringType(), True),
                    StructField('undersampling_method', StringType(), True),
                    StructField('undersampling_column', StringType(), True),
                    StructField('filename', StringType(), True),
                    StructField('experiment_id', StringType(), True),
                    StructField('n_covid', IntegerType(), True),
                    StructField('n_not_covid', IntegerType(), True),
                    StructField('model_name', StringType(), True),
                    StructField('model_seed', StringType(), True),
                    StructField('model_maxIter', IntegerType(), True),
                    StructField('model_maxDepth', IntegerType(), True),
                    StructField('model_maxBins', IntegerType(), True),
                    StructField('model_minInstancesPerNode', IntegerType(), True),
                    StructField('model_minInfoGain', FloatType(), True),
                    StructField('model_featureSubsetStrategy', StringType(), True),
                    StructField('model_n_estimators', IntegerType(), True),
                    StructField('model_learning_rate', FloatType(), True),
                    StructField('model_impurity', StringType(), True),
                    StructField('model_AUC_ROC', StringType(), True),
                    StructField('model_AUC_PR', StringType(), True),
                    StructField('model_covid_precision', StringType(), True),
                    StructField('model_covid_recall', StringType(), True),
                    StructField('model_covid_f1', StringType(), True),
                    StructField('model_not_covid_precision', StringType(), True),
                    StructField('model_not_covid_recall', StringType(), True),
                    StructField('model_not_covid_f1', StringType(), True),
                    StructField('model_avg_precision', StringType(), True),
                    StructField('model_avg_recall', StringType(), True),
                    StructField('model_avg_f1', StringType(), True),
                    StructField('model_avg_acc', StringType(), True),
                    StructField('model_TP', StringType(), True),
                    StructField('model_TN', StringType(), True),
                    StructField('model_FN', StringType(), True),
                    StructField('model_FP', StringType(), True),
                    StructField('model_time_exec', StringType(), True),
                    StructField('model_col_set', StringType(), True)
                          ])

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# undersamp_col = ['03-STRSAMP-AG', '04-STRSAMP-EW'] 
# dfs = ['ds-1', 'ds-2', 'ds-3']
# cols_sets = ['cols_set_1', 'cols_set_2', 'cols_set_3']

undersamp_col = ['04-STRSAMP-EW']
dfs = ['ds-1']
cols_sets = ['cols_set_2']

# %%
# lists of params
model_maxIter = [20, 50, 100] 
model_maxDepth = [3, 5, 7] 
model_maxBins = [32, 64] 
# model_learningRate = [0.01, 0.1, 0.5]
# model_loss = ['logLoss', 'leastSquaresError', 'leastAbsoluteError']


list_of_param_dicts = []

for maxIter in model_maxIter:
    for maxDepth in model_maxDepth:
        for maxBins in model_maxBins: 
            params_dict = {}
            params_dict['maxIter'] = maxIter
            params_dict['maxDepth'] = maxDepth
            params_dict['maxBins'] = maxBins
            list_of_param_dicts.append(params_dict)

            

print("There is {} set of params.".format(len(list_of_param_dicts)))
# list_of_param_dicts
# Out:
# There is 18 set of params.

# %%
prefix = 'gs://ai-covid19-datalake/trusted/experiment_map/'

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# filename = 'gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment0.parquet'
# df = spark.read.parquet(filename)
# df.limit(2).toPandas()

# %%
# params_dict = {'maxIter': 100,
#                'maxDepth': 3,
#                'maxBins': 32,
#                'learningRate': 0.5,
#                'loss': 'leastAbsoluteError'}
# cols = 'cols_set_1'
# experiment_filter = 'ds-1'
# undersampling_method = '03-STRSAMP-AG', 
# experiment_id = 0

# %%
# run_gbt(df, params_dict, cols, filename, experiment_filter, undersampling_method, experiment_id)

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
def run_gbt(exp_df, params_dict, cols, filename, experiment_filter, 
            undersampling_method, experiment_id):
    import time
    start_time = time.time()
    
    n_covid = exp_df.filter(F.col('CLASSI_FIN') == 1.0).count()
    n_not_covid = exp_df.filter(F.col('CLASSI_FIN') == 0.0).count()
    
    
    id_cols = ['NU_NOTIFIC', 'CLASSI_FIN']

    labelIndexer = StringIndexer(inputCol="CLASSI_FIN", outputCol="indexedLabel").fit(exp_df)    
    
    input_cols = [x for x in exp_df.columns if x not in id_cols]
    assembler = VectorAssembler(inputCols = input_cols, outputCol= 'features')
    exp_df = assembler.transform(exp_df)
    
    # Automatically identify categorical features, and index them.
    # Set maxCategories so features with > 4 distinct values are treated as continuous.
    featureIndexer = VectorIndexer(inputCol="features", outputCol="indexedFeatures", maxCategories=30).fit(exp_df)
    
    # Split the data into training and test sets (30% held out for testing)
    (trainingData, testData) = exp_df.randomSplit([0.7, 0.3])
    trainingData = trainingData.persist(StorageLevel.MEMORY_ONLY)
    testData = testData.persist(StorageLevel.MEMORY_ONLY)
    
    # Train a RandomForest model.
    gbt = GBTClassifier(labelCol = "indexedLabel", featuresCol = "indexedFeatures",
                       maxIter = params_dict['maxIter'],
                       maxDepth = params_dict['maxDepth'],
                       maxBins = params_dict['maxBins'])
    
    # Convert indexed labels back to original labels.
    labelConverter = IndexToString(inputCol="prediction", outputCol="predictedLabel",
                               labels=labelIndexer.labels)

    # Chain indexers and forest in a Pipeline
    pipeline = Pipeline(stages=[labelIndexer, featureIndexer, gbt, labelConverter])

    # Train model.  This also runs the indexers.
    model = pipeline.fit(trainingData)
    
    # Make predictions.
    predictions = model.transform(testData)    
    
    
    pred = predictions.select(['CLASSI_FIN', 'predictedLabel'])\
                  .withColumn('predictedLabel', F.col('predictedLabel').cast('double'))\
                  .withColumn('predictedLabel', F.when(F.col('predictedLabel') == 1.0, 'covid').otherwise('n-covid'))\
                  .withColumn('CLASSI_FIN', F.when(F.col('CLASSI_FIN') == 1.0, 'covid').otherwise('n-covid'))\
                  .toPandas()

    y_true = pred['CLASSI_FIN'].tolist()
    y_pred = pred['predictedLabel'].tolist()
    
    report = classification_report(y_true, y_pred, output_dict=True)
    
    
    evaluator_ROC = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderROC")
    accuracy_ROC = evaluator_ROC.evaluate(predictions)


    
    evaluator_PR = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderPR")
    accuracy_PR = evaluator_PR.evaluate(predictions)
    
    conf_matrix = confusion_matrix(y_true, y_pred)

    result_dict = {}
    
    result_dict['experiment_filter'] = experiment_filter
    result_dict['undersampling_method'] = undersampling_method
    result_dict['filename'] = filename
    result_dict['experiment_id'] = experiment_id
    result_dict['n_covid'] = n_covid
    result_dict['n_not_covid'] = n_not_covid
    result_dict['model_name'] = 'GBT'
    result_dict['params'] = params_dict
    result_dict['model_AUC_ROC'] = accuracy_ROC
    result_dict['model_AUC_PR'] = accuracy_PR
    result_dict['model_covid_precision'] = report['covid']['precision']
    result_dict['model_covid_recall'] = report['covid']['recall']
    result_dict['model_covid_f1'] = report['covid']['f1-score']
    result_dict['model_not_covid_precision'] = report['n-covid']['precision']
    result_dict['model_not_covid_recall'] = report['n-covid']['recall']
    result_dict['model_not_covid_f1'] = report['n-covid']['f1-score']
    result_dict['model_avg_precision'] = report['macro avg']['precision']
    result_dict['model_avg_recall'] = report['macro avg']['recall']
    result_dict['model_avg_f1'] = report['macro avg']['f1-score']
    result_dict['model_avg_acc'] = report['accuracy']
    result_dict['model_TP'] = conf_matrix[0][0]
    result_dict['model_TN'] = conf_matrix[1][1]
    result_dict['model_FN'] = conf_matrix[0][1]
    result_dict['model_FP'] = conf_matrix[1][0]
    result_dict['model_time_exec'] = time.time() - start_time
    result_dict['model_col_set'] = cols
    
    return result_dict

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %% [markdown]
# # Running GBT on 10 samples for each experiment
# ### 3x col sets -> ['cols_set_1', 'cols_set_2', 'cols_set_3']
# ### 3x model_maxIter -> [100, 200, 300]
# ### 3x model_maxDepth -> [5, 10, 15]
# ### 3x model_maxBins -> [16, 32, 64]
# Total: 10 * 3 * 3 * 3 * 3 = 810

# %%
experiments = []

# %% [markdown]
# ### Datasets: strat_samp_lab_agegrp

# %%
for uc in undersamp_col: 
    for ds in dfs:
        for col_set in cols_sets:
            for params_dict in list_of_param_dicts: 
                for id_exp in range(50):
                    filename = prefix + uc + '/' + ds + '/' + col_set + '/' + 'experiment' + str(id_exp) + '.parquet'
                    exp_dataframe = spark.read.parquet(filename)
                    print('read {}'.format(filename))
                    
                    undersampling_method = uc
                    experiment_filter = ds
                    experiment_id = id_exp

                    try:                     
                        model = run_gbt(exp_dataframe, params_dict, col_set, filename, experiment_filter, undersampling_method, experiment_id)
                        experiments.append(model)

                        print("Parameters ==> {}\n Results: \n AUC_PR: {} \n Precision: {} \n Time: {}".format(str(params_dict), str(model['model_AUC_PR']), str(model['model_avg_precision']), str(model['model_time_exec'])))
                        print('=========================== \n')
                    except:
                        print('=========== W A R N I N G =========== \n')
                        print('Something wrong with the exp: {}, {}, {}'.format(filename, params_dict, col_set))
# Out:
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8967713822271911
#  Precision: 0.934441443594209
#  Time: 30.091091871261597
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9002115481281546
#  Precision: 0.9359600195718856
#  Time: 16.86832284927368
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.896433398197548
#  Precision: 0.9344967382571261
#  Time: 20.346197366714478
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8990486089690051
#  Precision: 0.9355344553470735
#  Time: 15.437515020370483
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.897630226238639
#  Precision: 0.934126890074735
#  Time: 16.23236870765686
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8973111532561582
#  Precision: 0.9349556163595842
#  Time: 16.987577438354492
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8963782368303116
#  Precision: 0.9340083115337467
#  Time: 16.54643750190735
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8949321178194529
#  Precision: 0.9332257358276758
#  Time: 15.09548807144165
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8929857499456664
#  Precision: 0.9325901762510911
#  Time: 15.158035278320312
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.892346053427597
#  Precision: 0.9326576552750405
#  Time: 15.255713939666748
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8968287692653489
#  Precision: 0.9348834158390311
#  Time: 16.026110649108887
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8922625769374897
#  Precision: 0.9323337083439496
#  Time: 15.441704273223877
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9015524342897351
#  Precision: 0.9368381503473069
#  Time: 15.219181776046753
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8953760640039239
#  Precision: 0.9340707555497314
#  Time: 15.39906930923462
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8926559549258926
#  Precision: 0.9330121558174884
#  Time: 15.146762132644653
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.894629436452453
#  Precision: 0.9329430519845392
#  Time: 14.815861701965332
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8946918253775358
#  Precision: 0.9340834429581413
#  Time: 15.221842050552368
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8970845742370342
#  Precision: 0.9336923211074124
#  Time: 14.684319496154785
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8959710638980716
#  Precision: 0.9340272894805104
#  Time: 14.720254182815552
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9011131526735711
#  Precision: 0.9370606497622138
#  Time: 15.41072154045105
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8959288387407531
#  Precision: 0.9345998564722955
#  Time: 14.446007251739502
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8997330644297095
#  Precision: 0.9354437149200436
#  Time: 14.384281396865845
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8906824629999625
#  Precision: 0.9310783233150066
#  Time: 14.712386846542358
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.897515126863976
#  Precision: 0.9349881400163826
#  Time: 14.746307611465454
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8981713313205133
#  Precision: 0.9362171417613205
#  Time: 15.534908533096313
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8971588822040094
#  Precision: 0.9350852379495382
#  Time: 15.273478984832764
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8939479083512711
#  Precision: 0.9314580373751089
#  Time: 15.752201318740845
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8967583771674752
#  Precision: 0.9336283736549796
#  Time: 15.129030466079712
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8964901643769042
#  Precision: 0.9337653278589972
#  Time: 14.898586750030518
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.901381044762322
#  Precision: 0.9370519252326801
#  Time: 14.73361325263977
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8970658415819319
#  Precision: 0.9347860532683722
#  Time: 15.716169118881226
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8957893767044853
#  Precision: 0.9338955107018929
#  Time: 14.918778657913208
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8960702038335938
#  Precision: 0.9340486560591819
#  Time: 14.432063341140747
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8935906335160647
#  Precision: 0.9335337498170095
#  Time: 14.882334232330322
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8955417953526105
#  Precision: 0.9342187352119327
#  Time: 14.694591760635376
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8972235202902705
#  Precision: 0.9345561630153991
#  Time: 16.65231466293335
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8962511798097837
#  Precision: 0.934310036235835
#  Time: 15.946803569793701
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8973150382819868
#  Precision: 0.9340466370784752
#  Time: 15.472744703292847
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8939975081509797
#  Precision: 0.9334873473524113
#  Time: 15.332967519760132
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8937323104227562
#  Precision: 0.9334187742706541
#  Time: 15.934582948684692
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9012178999349019
#  Precision: 0.936861344226439
#  Time: 15.010764598846436
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8950999734312369
#  Precision: 0.9333705614635317
#  Time: 14.934745788574219
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8985409382828833
#  Precision: 0.9361395525694317
#  Time: 14.467792749404907
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8965223261640798
#  Precision: 0.9338356815217801
#  Time: 15.25671935081482
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8954400262661284
#  Precision: 0.9336080747046074
#  Time: 15.1343355178833
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8999146937668018
#  Precision: 0.9359307226159757
#  Time: 15.186115026473999
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.89724177528364
#  Precision: 0.9339571887873908
#  Time: 15.350853204727173
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8950573864087618
#  Precision: 0.9328604039513846
#  Time: 15.503705024719238
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8947412909001026
#  Precision: 0.9333235109732696
#  Time: 14.465356349945068
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.898580396687471
#  Precision: 0.9343782843320552
#  Time: 15.010462999343872
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8938831152462522
#  Precision: 0.9334884931015952
#  Time: 15.399393320083618
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8960303088483824
#  Precision: 0.9348915310761922
#  Time: 14.739046335220337
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8966076824183316
#  Precision: 0.9349438975133146
#  Time: 15.224925518035889
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8993463952905855
#  Precision: 0.9361949103168405
#  Time: 14.905939817428589
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8931521447524304
#  Precision: 0.9321483599838619
#  Time: 14.916417837142944
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8992829802651651
#  Precision: 0.9360169537685851
#  Time: 14.982351064682007
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8946290138204799
#  Precision: 0.9332580468333473
#  Time: 15.46229076385498
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8968925047813467
#  Precision: 0.9342290727380173
#  Time: 14.711655616760254
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8953463112509424
#  Precision: 0.934124618642368
#  Time: 15.05526328086853
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.898877274193174
#  Precision: 0.9362213288585497
#  Time: 15.20211148262024
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8976978962971137
#  Precision: 0.934566211585757
#  Time: 16.080406665802002
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8936257880117164
#  Precision: 0.9328244161773229
#  Time: 15.153918027877808
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9012388244435255
#  Precision: 0.9362246496958049
#  Time: 16.017557382583618
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8964254237059702
#  Precision: 0.9344161958427797
#  Time: 14.904330492019653
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8940954247334886
#  Precision: 0.932886760145749
#  Time: 15.067061424255371
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8966380250417737
#  Precision: 0.9334192112101296
#  Time: 15.654381036758423
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8966296284261595
#  Precision: 0.9349748283859882
#  Time: 16.470712184906006
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8946563178591018
#  Precision: 0.9329144438737853
#  Time: 14.539292335510254
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8951733125325935
#  Precision: 0.9336310784255353
#  Time: 15.111891269683838
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.895888550211848
#  Precision: 0.9343258037306936
#  Time: 15.043880224227905
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8992147368885495
#  Precision: 0.9364223697286413
#  Time: 14.432320594787598
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8909660942122718
#  Precision: 0.9314314909717933
#  Time: 15.459330797195435
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8944947418176676
#  Precision: 0.933088204766229
#  Time: 15.137271165847778
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8923837860435567
#  Precision: 0.9332030403246974
#  Time: 14.289254903793335
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8953181398572181
#  Precision: 0.9337123066332678
#  Time: 15.57060432434082
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8897240471837724
#  Precision: 0.9316029799143033
#  Time: 15.085438966751099
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8929327170662402
#  Precision: 0.9311102323092058
#  Time: 15.244295358657837
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8999943708023703
#  Precision: 0.9357883318838003
#  Time: 15.282532691955566
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8949510267621796
#  Precision: 0.9336720098722209
#  Time: 15.04500937461853
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8959568421429901
#  Precision: 0.9345768341284293
#  Time: 15.171999454498291
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8944523349896532
#  Precision: 0.933172028709617
#  Time: 14.88912320137024
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8954037019688793
#  Precision: 0.9338558967249708
#  Time: 15.437941789627075
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8968657140939217
#  Precision: 0.9339939800637194
#  Time: 15.6485013961792
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8941242171121251
#  Precision: 0.9335837783057375
#  Time: 15.322943449020386
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8956335503592763
#  Precision: 0.9344073663151363
#  Time: 15.404672622680664
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.892307018120537
#  Precision: 0.931767042578675
#  Time: 15.230303764343262
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.894992821797854
#  Precision: 0.9326572601911907
#  Time: 15.01231336593628
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8898848550538172
#  Precision: 0.9298697117847945
#  Time: 14.992652416229248
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8927164788230086
#  Precision: 0.9328790337932915
#  Time: 15.069217205047607
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8952715819199131
#  Precision: 0.9339025081403795
#  Time: 15.606250047683716
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8968386580308207
#  Precision: 0.9344327681737502
#  Time: 15.638757944107056
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8970355672685697
#  Precision: 0.9346037480974305
#  Time: 16.023456811904907
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8952477995335077
#  Precision: 0.9334470024373922
#  Time: 15.26517939567566
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8968610664119635
#  Precision: 0.9349841248515798
#  Time: 16.147829294204712
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8958234888155289
#  Precision: 0.934667932878634
#  Time: 15.131503582000732
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8962825433163945
#  Precision: 0.9335930699151598
#  Time: 14.889090299606323
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8983810333108323
#  Precision: 0.9357483454480081
#  Time: 14.977683782577515
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8980513868595732
#  Precision: 0.9351955768660711
#  Time: 15.061459302902222
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9001409034312671
#  Precision: 0.9360042565626796
#  Time: 14.241884708404541
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8976600916679106
#  Precision: 0.9341915308731163
#  Time: 15.013710260391235
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9145908904843791
#  Precision: 0.9448188679414347
#  Time: 19.48146104812622
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.911851780986829
#  Precision: 0.944530891119985
#  Time: 19.12506079673767
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9113900178637755
#  Precision: 0.944303198776665
#  Time: 19.107656002044678
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9093101857140082
#  Precision: 0.9429075598569922
#  Time: 18.189504146575928
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9112600534772449
#  Precision: 0.9428208779496499
#  Time: 18.040390014648438
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9122014240842925
#  Precision: 0.9439165129743063
#  Time: 18.30066728591919
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9119941824576503
#  Precision: 0.9434918077246783
#  Time: 17.857665538787842
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9118999461038739
#  Precision: 0.944164059661178
#  Time: 18.659534215927124
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9099862360275686
#  Precision: 0.9429701936077446
#  Time: 17.844711780548096
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9146768195849256
#  Precision: 0.9459794544132141
#  Time: 18.158116579055786
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9084422896713829
#  Precision: 0.9424006187567526
#  Time: 18.510438442230225
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9143329685112133
#  Precision: 0.9461120210093323
#  Time: 17.903664350509644
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9095849500045254
#  Precision: 0.9424503145068105
#  Time: 17.801507234573364
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9099635516209665
#  Precision: 0.9426587283549706
#  Time: 18.872342109680176
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9089703199399332
#  Precision: 0.942437941050573
#  Time: 18.03835916519165
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9068975217573125
#  Precision: 0.9412504792153988
#  Time: 19.086084604263306
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9111680704295113
#  Precision: 0.9437323267507909
#  Time: 18.588117837905884
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9115033045835712
#  Precision: 0.9434621092688733
#  Time: 18.151309490203857
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9111105771861404
#  Precision: 0.9435387554037976
#  Time: 22.153785705566406
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9102886371088286
#  Precision: 0.9432693971557744
#  Time: 18.090643644332886
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9083934301071421
#  Precision: 0.9422100846096508
#  Time: 18.396713256835938
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9134369231879839
#  Precision: 0.9445014585468335
#  Time: 19.104151487350464
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9109080115340026
#  Precision: 0.9433515701053943
#  Time: 17.44351840019226
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9084805726699833
#  Precision: 0.9417027169781313
#  Time: 17.80159020423889
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9095780726328418
#  Precision: 0.9429183238375491
#  Time: 17.91838502883911
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9072286791294717
#  Precision: 0.941762235483266
#  Time: 18.010864973068237
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9077998372456626
#  Precision: 0.9413830097657967
#  Time: 18.498557329177856
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.915477207158334
#  Precision: 0.9454528009541305
#  Time: 18.113243341445923
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9105786391009125
#  Precision: 0.9431658225355204
#  Time: 17.61459469795227
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9080777578754685
#  Precision: 0.9420247401337696
#  Time: 18.37087059020996
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9087125750762902
#  Precision: 0.942416126406564
#  Time: 17.74360156059265
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9105931484678467
#  Precision: 0.9426554010564431
#  Time: 18.323798656463623
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9091343094934949
#  Precision: 0.9427686420979995
#  Time: 18.381377458572388
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9105427483579261
#  Precision: 0.9433712978666208
#  Time: 18.181798458099365
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9117410114832326
#  Precision: 0.9436399562415212
#  Time: 18.48644733428955
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.913390259512989
#  Precision: 0.9456308695113329
#  Time: 18.411561965942383
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9103015706267341
#  Precision: 0.9436941785364282
#  Time: 18.477664947509766
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9095078322130303
#  Precision: 0.9427456104056121
#  Time: 18.245176553726196
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.909398793249516
#  Precision: 0.9417578268620123
#  Time: 17.671573877334595
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9081490158344117
#  Precision: 0.9420003585472273
#  Time: 18.401159286499023
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9129010652298235
#  Precision: 0.944337925994265
#  Time: 18.274721384048462
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9109527336754648
#  Precision: 0.9437426999946338
#  Time: 18.87391471862793
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9086200701066529
#  Precision: 0.9426925560624668
#  Time: 18.71426796913147
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9103052463654975
#  Precision: 0.9428467302296941
#  Time: 18.54106569290161
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.913645563184698
#  Precision: 0.9446020112860862
#  Time: 18.250792264938354
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9103240610267238
#  Precision: 0.9428578858585122
#  Time: 18.40811514854431
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9096687174495367
#  Precision: 0.9426434139495419
#  Time: 17.895267963409424
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9128960146463355
#  Precision: 0.943880524065668
#  Time: 18.617228269577026
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9062584393940919
#  Precision: 0.9416286459235529
#  Time: 18.424487352371216
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9084628537272134
#  Precision: 0.9421322131987167
#  Time: 18.509490251541138
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9095341524730123
#  Precision: 0.9421709808896567
#  Time: 18.212135076522827
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9107400743420476
#  Precision: 0.9428552724161503
#  Time: 18.661041736602783
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9134792290949777
#  Precision: 0.9452657962052673
#  Time: 18.08767580986023
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9109478579993352
#  Precision: 0.9437124528904407
#  Time: 19.09005618095398
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.909302901399394
#  Precision: 0.9421518315250419
#  Time: 18.634164333343506
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9108975562414514
#  Precision: 0.9434281356195482
#  Time: 17.836166858673096
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.905496375675689
#  Precision: 0.9402225386682753
#  Time: 18.41486358642578
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.909320916995243
#  Precision: 0.9427064483243826
#  Time: 18.775033950805664
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9104790548377022
#  Precision: 0.9428841616744971
#  Time: 18.84899091720581
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9143452681607591
#  Precision: 0.9454131554903213
#  Time: 18.558326244354248
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9098571368172107
#  Precision: 0.9421531928975555
#  Time: 18.594635725021362
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9076279861071399
#  Precision: 0.9423060786555162
#  Time: 18.862809896469116
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.913554660420576
#  Precision: 0.9443844912403507
#  Time: 18.21168041229248
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.912601067732963
#  Precision: 0.9442187351948934
#  Time: 18.334614753723145
# ===========================
#
# ...
#  Results:
#  AUC_PR: 0.9219529526491174
#  Precision: 0.950372104075049
#  Time: 120.821457862854
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9216495111295563
#  Precision: 0.9514129718614077
#  Time: 121.81371808052063
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.919089234263906
#  Precision: 0.947850127462883
#  Time: 125.09897589683533
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment48.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9240090331519187
#  Precision: 0.9518288807101993
#  Time: 123.43482804298401
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9207725331059319
#  Precision: 0.9498201214432966
#  Time: 124.55315399169922
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment0.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9160943988385997
#  Precision: 0.9475999903093792
#  Time: 125.55159163475037
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment1.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9216987300412955
#  Precision: 0.950550521367957
#  Time: 123.24508953094482
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment2.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9232217921228985
#  Precision: 0.9518608756611977
#  Time: 126.88453125953674
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment3.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9231193253880494
#  Precision: 0.9509775604111346
#  Time: 124.60986590385437
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment4.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9206690342809326
#  Precision: 0.9496442479971927
#  Time: 127.57242512702942
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment5.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9230859153511469
#  Precision: 0.9507954090041929
#  Time: 126.518146276474
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment6.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9189933248646709
#  Precision: 0.9499130350545788
#  Time: 123.8008873462677
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment7.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9204187884916377
#  Precision: 0.9501841310970907
#  Time: 129.6917281150818
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment8.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9215100745981212
#  Precision: 0.9509753736014606
#  Time: 126.09948825836182
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment9.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.920003466379999
#  Precision: 0.949323569340757
#  Time: 123.87223196029663
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment10.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9188534623640786
#  Precision: 0.9498044999985756
#  Time: 124.41937637329102
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment11.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9237009224269659
#  Precision: 0.9521616512700323
#  Time: 122.90159368515015
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment12.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9178291848859185
#  Precision: 0.9482738051279108
#  Time: 124.4084722995758
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment13.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9204361004342635
#  Precision: 0.9506307234720424
#  Time: 124.00097823143005
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment14.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9177999371296908
#  Precision: 0.9488231164485834
#  Time: 125.12806248664856
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment15.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9183750171555086
#  Precision: 0.9489220245502654
#  Time: 128.0113434791565
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment16.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9178384625695726
#  Precision: 0.9487566581382472
#  Time: 126.50755214691162
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment17.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9214241085919274
#  Precision: 0.9507688334463857
#  Time: 127.09673261642456
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment18.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9162874635233104
#  Precision: 0.9487386561450739
#  Time: 122.4863715171814
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment19.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9204841268122379
#  Precision: 0.9499144044507961
#  Time: 124.42124032974243
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment20.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9159843343712372
#  Precision: 0.9480409136375566
#  Time: 128.04339408874512
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment21.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9198667387288716
#  Precision: 0.9497218649900566
#  Time: 127.8339855670929
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment22.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9194877322348859
#  Precision: 0.9492475689822439
#  Time: 122.81682324409485
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment23.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9222987350788209
#  Precision: 0.9510687492802423
#  Time: 126.38553786277771
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment24.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9216670521260419
#  Precision: 0.9509768813008203
#  Time: 123.00469326972961
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment25.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9187260299787667
#  Precision: 0.9497405827916443
#  Time: 124.79797291755676
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment26.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9209542438422015
#  Precision: 0.950214299710765
#  Time: 122.92312002182007
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment27.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9236454369009536
#  Precision: 0.9518531923755292
#  Time: 125.4385724067688
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment28.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9201882939144863
#  Precision: 0.9493195293875631
#  Time: 127.65627551078796
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment29.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.920390843608543
#  Precision: 0.9502784928559471
#  Time: 123.4584949016571
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment30.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.919437005258138
#  Precision: 0.9495815773313673
#  Time: 125.04553484916687
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment31.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9189162434608378
#  Precision: 0.9493166886404064
#  Time: 124.07561755180359
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment32.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.919888023173231
#  Precision: 0.9495647977815354
#  Time: 127.11610651016235
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment33.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9206761620526822
#  Precision: 0.949701726333404
#  Time: 124.74303197860718
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment34.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9177703849371288
#  Precision: 0.9487943365718323
#  Time: 125.57147026062012
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment35.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9203932255453996
#  Precision: 0.9501557398424619
#  Time: 127.24387264251709
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment36.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9187657970294555
#  Precision: 0.9497931346805585
#  Time: 127.21566605567932
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment37.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9225442426908551
#  Precision: 0.9506777910052433
#  Time: 128.15456080436707
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment38.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.919656531473295
#  Precision: 0.9492918130165631
#  Time: 127.43687033653259
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment39.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.91985647839135
#  Precision: 0.9497954803633557
#  Time: 126.99824976921082
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment40.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9220538717397316
#  Precision: 0.9511576337210379
#  Time: 126.54510259628296
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment41.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9232536019053257
#  Precision: 0.9512810047623727
#  Time: 127.4710865020752
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment42.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9198921734904988
#  Precision: 0.9505537389853745
#  Time: 123.43612289428711
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment43.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9222986730158893
#  Precision: 0.9512155907850222
#  Time: 122.66997575759888
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment44.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9199890711210018
#  Precision: 0.948991721790315
#  Time: 124.64651441574097
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment45.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9203165257598765
#  Precision: 0.9502205705587476
#  Time: 127.18135166168213
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9202163496395297
#  Precision: 0.949568805962444
#  Time: 125.43332004547119
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9231478426000987
#  Precision: 0.9502806666862824
#  Time: 120.82127571105957
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment48.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9236032552903829
#  Precision: 0.9527120944969064
#  Time: 124.54152202606201
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-1/cols_set_2/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9173767199065725
#  Precision: 0.9482274623896035
#  Time: 129.0743260383606
# ===========================

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
for i in range(len(experiments)):
    for d in list(experiments[i].keys()):
        experiments[i][d] = str(experiments[i][d])

# %%
# experiments

# %%
cols = ['experiment_filter', 'undersampling_method', 'filename', 'experiment_id', 'n_covid', 'n_not_covid', 'model_name', 'params', 'model_AUC_ROC', 'model_AUC_PR', 'model_covid_precision', 'model_covid_recall', 'model_covid_f1', 'model_not_covid_precision', 'model_not_covid_recall', 'model_not_covid_f1', 'model_avg_precision', 'model_avg_recall', 'model_avg_f1', 'model_avg_acc', 'model_TP', 'model_TN', 'model_FN', 'model_FP', 'model_time_exec', 'model_col_set']

# %%
intermed_results = spark.createDataFrame(data=experiments).select(cols)
intermed_results.toPandas()
# Out:
# /usr/lib/spark/python/pyspark/sql/session.py:346: UserWarning: inferring schema from dict is deprecated,please use pyspark.sql.Row instead
#   warnings.warn("inferring schema from dict is deprecated,"

# %%
intermed_results.write.parquet('gs://ai-covid19-datalake/trusted/intermed_results/STRSAMP/GBT_experiments-EW-ds1-cs2.parquet', mode='overwrite')

# %%
print('finished')

# %%
intermed_results.show()
