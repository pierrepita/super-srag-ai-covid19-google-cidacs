# %%
import pandas as pd
import pyspark.sql.functions as F
from datetime import datetime
from pyspark.sql.types import *
from pyspark import StorageLevel

import numpy as np
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", 1000)
pd.set_option("mode.chained_assignment", None)

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import GBTClassifier
from pyspark.ml.feature import IndexToString, StringIndexer, VectorIndexer
# from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import OneHotEncoderEstimator, StringIndexer, VectorAssembler

from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

from pyspark.sql import Row
from pyspark.ml.linalg import Vectors

# %%
# !pip install scikit-plot

# %%
import sklearn
import scikitplot as skplt
from sklearn.metrics import classification_report, confusion_matrix, precision_score

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
result_schema = StructType([
                    StructField('experiment_filter', StringType(), True),
                    StructField('undersampling_method', StringType(), True),
                    StructField('undersampling_column', StringType(), True),
                    StructField('filename', StringType(), True),
                    StructField('experiment_id', StringType(), True),
                    StructField('n_covid', IntegerType(), True),
                    StructField('n_not_covid', IntegerType(), True),
                    StructField('model_name', StringType(), True),
                    StructField('model_seed', StringType(), True),
                    StructField('model_maxIter', IntegerType(), True),
                    StructField('model_maxDepth', IntegerType(), True),
                    StructField('model_maxBins', IntegerType(), True),
                    StructField('model_minInstancesPerNode', IntegerType(), True),
                    StructField('model_minInfoGain', FloatType(), True),
                    StructField('model_featureSubsetStrategy', StringType(), True),
                    StructField('model_n_estimators', IntegerType(), True),
                    StructField('model_learning_rate', FloatType(), True),
                    StructField('model_impurity', StringType(), True),
                    StructField('model_AUC_ROC', StringType(), True),
                    StructField('model_AUC_PR', StringType(), True),
                    StructField('model_covid_precision', StringType(), True),
                    StructField('model_covid_recall', StringType(), True),
                    StructField('model_covid_f1', StringType(), True),
                    StructField('model_not_covid_precision', StringType(), True),
                    StructField('model_not_covid_recall', StringType(), True),
                    StructField('model_not_covid_f1', StringType(), True),
                    StructField('model_avg_precision', StringType(), True),
                    StructField('model_avg_recall', StringType(), True),
                    StructField('model_avg_f1', StringType(), True),
                    StructField('model_avg_acc', StringType(), True),
                    StructField('model_TP', StringType(), True),
                    StructField('model_TN', StringType(), True),
                    StructField('model_FN', StringType(), True),
                    StructField('model_FP', StringType(), True),
                    StructField('model_time_exec', StringType(), True),
                    StructField('model_col_set', StringType(), True)
                          ])

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# undersamp_col = ['03-STRSAMP-AG', '04-STRSAMP-EW'] 
# dfs = ['ds-1', 'ds-2', 'ds-3']
# cols_sets = ['cols_set_1', 'cols_set_2', 'cols_set_3']

undersamp_col = ['02-KMODES']
dfs = ['ds-3']
cols_sets = ['cols_set_1']

# %%
# lists of params
model_maxIter = [20, 50, 100] 
model_maxDepth = [3, 5, 7] 
model_maxBins = [32, 64] 
# model_learningRate = [0.01, 0.1, 0.5]
# model_loss = ['logLoss', 'leastSquaresError', 'leastAbsoluteError']



list_of_param_dicts = []

for maxIter in model_maxIter:
    for maxDepth in model_maxDepth:
        for maxBins in model_maxBins: 
            params_dict = {}
            params_dict['maxIter'] = maxIter
            params_dict['maxDepth'] = maxDepth
            params_dict['maxBins'] = maxBins
            list_of_param_dicts.append(params_dict)

print("There is {} set of params.".format(len(list_of_param_dicts)))
# list_of_param_dicts
# Out:
# There is 18 set of params.

# %%
prefix = 'gs://ai-covid19-datalake/trusted/experiment_map/'

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# filename = 'gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment0.parquet'
# df = spark.read.parquet(filename)
# df.limit(2).toPandas()

# %%
# params_dict = {'maxIter': 100,
#                'maxDepth': 3,
#                'maxBins': 32,
#                'learningRate': 0.5,
#                'loss': 'leastAbsoluteError'}
# cols = 'cols_set_1'
# experiment_filter = 'ds-1'
# undersampling_method = '03-STRSAMP-AG', 
# experiment_id = 0

# %%
# run_gbt(df, params_dict, cols, filename, experiment_filter, undersampling_method, experiment_id)

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
def run_gbt(exp_df, params_dict, cols, filename, experiment_filter, 
            undersampling_method, experiment_id):
    import time
    start_time = time.time()
    
    n_covid = exp_df.filter(F.col('CLASSI_FIN') == 1.0).count()
    n_not_covid = exp_df.filter(F.col('CLASSI_FIN') == 0.0).count()
    
    
    id_cols = ['NU_NOTIFIC', 'CLASSI_FIN']

    labelIndexer = StringIndexer(inputCol="CLASSI_FIN", outputCol="indexedLabel").fit(exp_df)    
    
    input_cols = [x for x in exp_df.columns if x not in id_cols]
    assembler = VectorAssembler(inputCols = input_cols, outputCol= 'features')
    exp_df = assembler.transform(exp_df)
    
    # Automatically identify categorical features, and index them.
    # Set maxCategories so features with > 4 distinct values are treated as continuous.
    featureIndexer = VectorIndexer(inputCol="features", outputCol="indexedFeatures", maxCategories=30).fit(exp_df)
    
    # Split the data into training and test sets (30% held out for testing)
    (trainingData, testData) = exp_df.randomSplit([0.7, 0.3])
    trainingData = trainingData.persist(StorageLevel.MEMORY_ONLY)
    testData = testData.persist(StorageLevel.MEMORY_ONLY)
    
    # Train a RandomForest model.
    gbt = GBTClassifier(labelCol = "indexedLabel", featuresCol = "indexedFeatures",
                       maxIter = params_dict['maxIter'],
                       maxDepth = params_dict['maxDepth'],
                       maxBins = params_dict['maxBins'])
    
    # Convert indexed labels back to original labels.
    labelConverter = IndexToString(inputCol="prediction", outputCol="predictedLabel",
                               labels=labelIndexer.labels)

    # Chain indexers and forest in a Pipeline
    pipeline = Pipeline(stages=[labelIndexer, featureIndexer, gbt, labelConverter])

    # Train model.  This also runs the indexers.
    model = pipeline.fit(trainingData)
    
    # Make predictions.
    predictions = model.transform(testData)    
    
    
    pred = predictions.select(['CLASSI_FIN', 'predictedLabel'])\
                  .withColumn('predictedLabel', F.col('predictedLabel').cast('double'))\
                  .withColumn('predictedLabel', F.when(F.col('predictedLabel') == 1.0, 'covid').otherwise('n-covid'))\
                  .withColumn('CLASSI_FIN', F.when(F.col('CLASSI_FIN') == 1.0, 'covid').otherwise('n-covid'))\
                  .toPandas()

    y_true = pred['CLASSI_FIN'].tolist()
    y_pred = pred['predictedLabel'].tolist()
    
    report = classification_report(y_true, y_pred, output_dict=True)
    
    
    evaluator_ROC = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderROC")
    accuracy_ROC = evaluator_ROC.evaluate(predictions)


    
    evaluator_PR = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderPR")
    accuracy_PR = evaluator_PR.evaluate(predictions)
    
    conf_matrix = confusion_matrix(y_true, y_pred)

    result_dict = {}
    
    result_dict['experiment_filter'] = experiment_filter
    result_dict['undersampling_method'] = undersampling_method
    result_dict['filename'] = filename
    result_dict['experiment_id'] = experiment_id
    result_dict['n_covid'] = n_covid
    result_dict['n_not_covid'] = n_not_covid
    result_dict['model_name'] = 'GBT'
    result_dict['params'] = params_dict
    result_dict['model_AUC_ROC'] = accuracy_ROC
    result_dict['model_AUC_PR'] = accuracy_PR
    result_dict['model_covid_precision'] = report['covid']['precision']
    result_dict['model_covid_recall'] = report['covid']['recall']
    result_dict['model_covid_f1'] = report['covid']['f1-score']
    result_dict['model_not_covid_precision'] = report['n-covid']['precision']
    result_dict['model_not_covid_recall'] = report['n-covid']['recall']
    result_dict['model_not_covid_f1'] = report['n-covid']['f1-score']
    result_dict['model_avg_precision'] = report['macro avg']['precision']
    result_dict['model_avg_recall'] = report['macro avg']['recall']
    result_dict['model_avg_f1'] = report['macro avg']['f1-score']
    result_dict['model_avg_acc'] = report['accuracy']
    result_dict['model_TP'] = conf_matrix[0][0]
    result_dict['model_TN'] = conf_matrix[1][1]
    result_dict['model_FN'] = conf_matrix[0][1]
    result_dict['model_FP'] = conf_matrix[1][0]
    result_dict['model_time_exec'] = time.time() - start_time
    result_dict['model_col_set'] = cols
    
    return result_dict

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %% [markdown]
# # Running GBT on 10 samples for each experiment
# ### 3x col sets -> ['cols_set_1', 'cols_set_2', 'cols_set_3']
# ### 3x model_maxIter -> [100, 200, 300]
# ### 3x model_maxDepth -> [5, 10, 15]
# ### 3x model_maxBins -> [16, 32, 64]
# Total: 10 * 3 * 3 * 3 * 3 = 810

# %%
experiments = []

# %% [markdown]
# ### Datasets: strat_samp_lab_agegrp

# %%
for uc in undersamp_col: 
    for ds in dfs:
        for col_set in cols_sets:
            for params_dict in list_of_param_dicts: 
                for id_exp in range(50):
                    filename = prefix + uc + '/' + ds + '/' + col_set + '/' + 'experiment' + str(id_exp) + '.parquet'
                    exp_dataframe = spark.read.parquet(filename)
#                     if 'SG_UF_NOT' in exp_dataframe.columns:
#                         exp_dataframe = exp_dataframe.withColumn('SG_UF_NOT', F.col('SG_UF_NOT').cast('float'))
                    print('read {}'.format(filename))
                    
                    undersampling_method = uc
                    experiment_filter = ds
                    experiment_id = id_exp

                    try:                     
                        model = run_gbt(exp_dataframe, params_dict, col_set, filename, experiment_filter, undersampling_method, experiment_id)
                        experiments.append(model)

                        print("Parameters ==> {}\n Results: \n AUC_PR: {} \n Precision: {} \n Time: {}".format(str(params_dict), str(model['model_AUC_PR']), str(model['model_avg_precision']), str(model['model_time_exec'])))
                        print('=========================== \n')
                    except:
                        print('=========== W A R N I N G =========== \n')
                        print('Something wrong with the exp: {}, {}, {}'.format(filename, params_dict, col_set))
# Out:
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9399829478144379
#  Precision: 0.9298385617423601
#  Time: 35.13380146026611
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9361530152101806
#  Precision: 0.9282719556204506
#  Time: 23.81306791305542
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8808626643997794
#  Precision: 0.9280326999833693
#  Time: 24.04801344871521
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9361011562092537
#  Precision: 0.9266897202913531
#  Time: 23.11074662208557
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9416228273242332
#  Precision: 0.9301968204468863
#  Time: 22.584332942962646
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8697100369588571
#  Precision: 0.9234873915054764
#  Time: 22.743406772613525
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8733200311236565
#  Precision: 0.9245384238008212
#  Time: 22.48654270172119
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9340816351826626
#  Precision: 0.9281603973430863
#  Time: 23.881407260894775
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.876039241451637
#  Precision: 0.9248352263308675
#  Time: 23.398046731948853
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9391702656411957
#  Precision: 0.9301746882184195
#  Time: 23.078799962997437
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8766479656417032
#  Precision: 0.92576650727817
#  Time: 22.86751890182495
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8797133880488162
#  Precision: 0.9266555149209454
#  Time: 23.413167238235474
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8667622395121511
#  Precision: 0.9218051823110117
#  Time: 23.310824155807495
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9401743645194733
#  Precision: 0.9281141654346481
#  Time: 23.399816274642944
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8749503494167423
#  Precision: 0.9260735490424536
#  Time: 23.860937118530273
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.935746287508367
#  Precision: 0.9286449758442394
#  Time: 24.387017488479614
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.93174026943742
#  Precision: 0.9276704882529334
#  Time: 24.350393772125244
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.873244845664981
#  Precision: 0.9234201710520747
#  Time: 23.47797465324402
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8678446824576677
#  Precision: 0.9217775680658424
#  Time: 24.60763120651245
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.876990739201042
#  Precision: 0.9257556072943798
#  Time: 23.449175119400024
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9380184236230009
#  Precision: 0.9296893789222997
#  Time: 22.720576286315918
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9349557534171415
#  Precision: 0.9266416809824545
#  Time: 23.731833457946777
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8816652038184297
#  Precision: 0.9300522636491289
#  Time: 22.986659049987793
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9327338543460058
#  Precision: 0.9335338276499687
#  Time: 23.346991062164307
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8754987440224316
#  Precision: 0.9255299638341883
#  Time: 24.243053674697876
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9409684800658107
#  Precision: 0.9298669357142135
#  Time: 24.99179720878601
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8620490436891195
#  Precision: 0.9201888676225898
#  Time: 25.863993406295776
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8713578340763483
#  Precision: 0.923270084547843
#  Time: 25.058688640594482
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9343981492921446
#  Precision: 0.9277685313601778
#  Time: 26.04337239265442
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8683173679329421
#  Precision: 0.9217264788651292
#  Time: 25.144217014312744
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8752318958457118
#  Precision: 0.9258089633531362
#  Time: 25.89196801185608
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9334376071067416
#  Precision: 0.9255308019094743
#  Time: 26.35201072692871
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8761380166711763
#  Precision: 0.925330337258331
#  Time: 23.13537096977234
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8816207463990301
#  Precision: 0.9285118164284367
#  Time: 23.503186464309692
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8748676584465954
#  Precision: 0.9235834528168536
#  Time: 23.74649739265442
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.878413708558119
#  Precision: 0.9259306869119839
#  Time: 22.878057718276978
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9396603893852431
#  Precision: 0.9280642794559226
#  Time: 23.72805380821228
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8811692284794864
#  Precision: 0.9261171180942707
#  Time: 23.587749242782593
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8675963043616054
#  Precision: 0.922251760112031
#  Time: 23.445481538772583
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9294411220779812
#  Precision: 0.9277745702094508
#  Time: 23.18756413459778
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.868634726165894
#  Precision: 0.9230787015328932
#  Time: 23.07479453086853
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9341625225691251
#  Precision: 0.9308633218842028
#  Time: 22.375792026519775
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.878066067845241
#  Precision: 0.9262830039851198
#  Time: 22.853768825531006
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9386654700383125
#  Precision: 0.9281589520123321
#  Time: 24.28451657295227
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8815789893654176
#  Precision: 0.9284107172850622
#  Time: 23.113067150115967
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9349782042376721
#  Precision: 0.9267673692299248
#  Time: 22.716249465942383
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8724805546848736
#  Precision: 0.9227302417419784
#  Time: 23.86772894859314
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8665306974218986
#  Precision: 0.9196155825857455
#  Time: 24.39038920402527
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8725302401193873
#  Precision: 0.9249246124932621
#  Time: 23.412007093429565
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8743177280493082
#  Precision: 0.9255704011388033
#  Time: 22.917404413223267
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9336890627166997
#  Precision: 0.927749345514982
#  Time: 22.983082056045532
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9347443750181706
#  Precision: 0.9255384319979869
#  Time: 23.60043430328369
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8779387733281097
#  Precision: 0.925390817595341
#  Time: 23.866810083389282
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9399484998996512
#  Precision: 0.9268593114971102
#  Time: 23.31875991821289
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9397428615866659
#  Precision: 0.9277782773195029
#  Time: 28.21813988685608
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8735526582654303
#  Precision: 0.9247041612821092
#  Time: 23.511138677597046
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8731259374761104
#  Precision: 0.924225791889072
#  Time: 23.39755654335022
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9379006259402634
#  Precision: 0.9311493142914284
#  Time: 23.71373462677002
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8767642446344708
#  Precision: 0.9253592241858848
#  Time: 23.762696743011475
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9388538166264516
#  Precision: 0.9304994583882871
#  Time: 24.477391004562378
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8774301937785105
#  Precision: 0.9273423448186728
#  Time: 25.148433685302734
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8774729925104306
#  Precision: 0.9245744605823385
#  Time: 24.227314233779907
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8701752570570689
#  Precision: 0.9231620577550228
#  Time: 23.80877995491028
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9414392883474821
#  Precision: 0.9279907253240949
#  Time: 24.485912084579468
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8765645364785029
#  Precision: 0.9267745385304975
#  Time: 24.00488519668579
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9356720336783411
#  Precision: 0.9284319976740518
#  Time: 25.069079399108887
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9371394441482618
#  Precision: 0.9298330416526999
#  Time: 24.229211568832397
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8718013162701231
#  Precision: 0.9233679550829509
#  Time: 24.392519235610962
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8749369386594196
#  Precision: 0.9254583201932094
#  Time: 25.067814588546753
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8792510561289275
#  Precision: 0.926368107327532
#  Time: 24.36257243156433
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9361984619987516
#  Precision: 0.9288905134364782
#  Time: 23.69341540336609
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9371787298761356
#  Precision: 0.9270365470525215
#  Time: 24.234840869903564
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8729837252562872
#  Precision: 0.925206038322381
#  Time: 23.92612099647522
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.934926659030249
#  Precision: 0.9342530134488086
#  Time: 28.255234003067017
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8699617903974073
#  Precision: 0.9240486264436829
#  Time: 24.431018590927124
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9403270803779795
#  Precision: 0.9299597454928745
#  Time: 23.299912929534912
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8701534742175803
#  Precision: 0.9234807710802054
#  Time: 23.837774753570557
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.873813862668381
#  Precision: 0.9248273585644577
#  Time: 23.751873254776
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9342126014006629
#  Precision: 0.928601196183463
#  Time: 25.981089115142822
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8720064638829271
#  Precision: 0.9245529985612351
#  Time: 23.343910694122314
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8743477413482639
#  Precision: 0.9246853521881133
#  Time: 22.79228186607361
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9368555207765716
#  Precision: 0.9296206091946608
#  Time: 23.2981960773468
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8688081123975143
#  Precision: 0.9222016933954953
#  Time: 23.51122212409973
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8790851157400396
#  Precision: 0.9273800775266827
#  Time: 24.822026252746582
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8764742578508348
#  Precision: 0.9250094414126395
#  Time: 23.584978818893433
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8772721808353542
#  Precision: 0.9247349158332362
#  Time: 22.891095876693726
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9392462032109432
#  Precision: 0.9289758339307559
#  Time: 22.918670415878296
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8788710670311682
#  Precision: 0.926749739936436
#  Time: 23.33427882194519
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8682221694407155
#  Precision: 0.921933112715374
#  Time: 24.21300959587097
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9348446704899429
#  Precision: 0.9312851789704765
#  Time: 24.306490898132324
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8722953882473959
#  Precision: 0.9246797374881937
#  Time: 26.147517919540405
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9292315929761921
#  Precision: 0.9268069887408683
#  Time: 26.18938422203064
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8806728208584577
#  Precision: 0.9268730378119713
#  Time: 25.513057947158813
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9418899228684674
#  Precision: 0.9297563372953404
#  Time: 23.955485105514526
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8822026737477704
#  Precision: 0.9284862391652058
#  Time: 26.250707864761353
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9368291511610116
#  Precision: 0.9278551673455818
#  Time: 24.489115476608276
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8748995859079082
#  Precision: 0.9256533442935209
#  Time: 26.314094066619873
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8679853606166491
#  Precision: 0.9233117173772465
#  Time: 25.78332495689392
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8747607239961104
#  Precision: 0.9264195968462436
#  Time: 24.65545964241028
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8753662607508507
#  Precision: 0.9257246908438505
#  Time: 24.46306538581848
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.943716106248433
#  Precision: 0.9381519652959498
#  Time: 27.463005781173706
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9432325832366819
#  Precision: 0.9367342790538371
#  Time: 28.44469165802002
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8984949843143939
#  Precision: 0.9399613208411093
#  Time: 28.34386968612671
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9471728321861217
#  Precision: 0.937608874235909
#  Time: 27.68706965446472
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.949676839224892
#  Precision: 0.9399127580443765
#  Time: 29.80588960647583
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8956904412623458
#  Precision: 0.9365415052608004
#  Time: 27.234981775283813
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.892272761144103
#  Precision: 0.9344778566701846
#  Time: 27.309873342514038
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9458615313425798
#  Precision: 0.9417423146106796
#  Time: 27.686620712280273
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8955655077403626
#  Precision: 0.9364590425260162
#  Time: 27.37762975692749
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9498406276048871
#  Precision: 0.9426659294601993
#  Time: 27.18779754638672
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8936046373616129
#  Precision: 0.9359047750243623
#  Time: 27.568574905395508
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8981975393302315
#  Precision: 0.938195975041898
#  Time: 27.5466525554657
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8850933584577434
#  Precision: 0.9318089277133168
#  Time: 28.032299757003784
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9474130285052359
#  Precision: 0.9383101420151017
#  Time: 28.04422616958618
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8925469133444588
#  Precision: 0.936237977190028
#  Time: 26.032573223114014
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9474275271700334
#  Precision: 0.9392036359197095
#  Time: 27.454007863998413
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.949712813538975
#  Precision: 0.94311931184907
#  Time: 28.615236043930054
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_1/experiment17.parquet

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
for i in range(len(experiments)):
    for d in list(experiments[i].keys()):
        experiments[i][d] = str(experiments[i][d])

# %%
# experiments

# %%
cols = ['experiment_filter', 'undersampling_method', 'filename', 'experiment_id', 'n_covid', 'n_not_covid', 'model_name', 'params', 'model_AUC_ROC', 'model_AUC_PR', 'model_covid_precision', 'model_covid_recall', 'model_covid_f1', 'model_not_covid_precision', 'model_not_covid_recall', 'model_not_covid_f1', 'model_avg_precision', 'model_avg_recall', 'model_avg_f1', 'model_avg_acc', 'model_TP', 'model_TN', 'model_FN', 'model_FP', 'model_time_exec', 'model_col_set']

# %%
intermed_results = spark.createDataFrame(data=experiments).select(cols)
intermed_results.toPandas()

# %%
intermed_results.write.parquet('gs://ai-covid19-datalake/trusted/intermed_results/KMODES/GBT_experiments-kmodes-ds3-cs1.parquet', mode='overwrite')

# %%
print('finished')

# %%
intermed_results.show()
