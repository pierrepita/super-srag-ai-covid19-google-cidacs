# %%
import pandas as pd
import pyspark.sql.functions as F
from datetime import datetime
from pyspark.sql.types import *
from pyspark import StorageLevel

import numpy as np
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", 1000)
pd.set_option("mode.chained_assignment", None)

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import GBTClassifier
from pyspark.ml.feature import IndexToString, StringIndexer, VectorIndexer
# from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import OneHotEncoderEstimator, StringIndexer, VectorAssembler

from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

from pyspark.sql import Row
from pyspark.ml.linalg import Vectors

# %%
# !pip install scikit-plot

# %%
import sklearn
import scikitplot as skplt
from sklearn.metrics import classification_report, confusion_matrix, precision_score

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
result_schema = StructType([
                    StructField('experiment_filter', StringType(), True),
                    StructField('undersampling_method', StringType(), True),
                    StructField('undersampling_column', StringType(), True),
                    StructField('filename', StringType(), True),
                    StructField('experiment_id', StringType(), True),
                    StructField('n_covid', IntegerType(), True),
                    StructField('n_not_covid', IntegerType(), True),
                    StructField('model_name', StringType(), True),
                    StructField('model_seed', StringType(), True),
                    StructField('model_maxIter', IntegerType(), True),
                    StructField('model_maxDepth', IntegerType(), True),
                    StructField('model_maxBins', IntegerType(), True),
                    StructField('model_minInstancesPerNode', IntegerType(), True),
                    StructField('model_minInfoGain', FloatType(), True),
                    StructField('model_featureSubsetStrategy', StringType(), True),
                    StructField('model_n_estimators', IntegerType(), True),
                    StructField('model_learning_rate', FloatType(), True),
                    StructField('model_impurity', StringType(), True),
                    StructField('model_AUC_ROC', StringType(), True),
                    StructField('model_AUC_PR', StringType(), True),
                    StructField('model_covid_precision', StringType(), True),
                    StructField('model_covid_recall', StringType(), True),
                    StructField('model_covid_f1', StringType(), True),
                    StructField('model_not_covid_precision', StringType(), True),
                    StructField('model_not_covid_recall', StringType(), True),
                    StructField('model_not_covid_f1', StringType(), True),
                    StructField('model_avg_precision', StringType(), True),
                    StructField('model_avg_recall', StringType(), True),
                    StructField('model_avg_f1', StringType(), True),
                    StructField('model_avg_acc', StringType(), True),
                    StructField('model_TP', StringType(), True),
                    StructField('model_TN', StringType(), True),
                    StructField('model_FN', StringType(), True),
                    StructField('model_FP', StringType(), True),
                    StructField('model_time_exec', StringType(), True),
                    StructField('model_col_set', StringType(), True)
                          ])

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# undersamp_col = ['03-STRSAMP-AG', '04-STRSAMP-EW'] 
# dfs = ['ds-1', 'ds-2', 'ds-3']
# cols_sets = ['cols_set_1', 'cols_set_2', 'cols_set_3']

undersamp_col = ['03-STRSAMP-AG']
dfs = ['ds-1']
cols_sets = ['cols_set_3']

# %%
# lists of params
model_maxIter = [20, 50, 100] 
model_maxDepth = [3, 5, 7] 
model_maxBins = [32, 64] 
# model_learningRate = [0.01, 0.1, 0.5]
# model_loss = ['logLoss', 'leastSquaresError', 'leastAbsoluteError']



list_of_param_dicts = []

for maxIter in model_maxIter:
    for maxDepth in model_maxDepth:
        for maxBins in model_maxBins: 
            params_dict = {}
            params_dict['maxIter'] = maxIter
            params_dict['maxDepth'] = maxDepth
            params_dict['maxBins'] = maxBins
            list_of_param_dicts.append(params_dict)

            

print("There is {} set of params.".format(len(list_of_param_dicts)))
# list_of_param_dicts
# Out:
# There is 18 set of params.

# %%
prefix = 'gs://ai-covid19-datalake/trusted/experiment_map/'

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# filename = 'gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment0.parquet'
# df = spark.read.parquet(filename)
# df.limit(2).toPandas()

# %%
# params_dict = {'maxIter': 100,
#                'maxDepth': 3,
#                'maxBins': 32,
#                'learningRate': 0.5,
#                'loss': 'leastAbsoluteError'}
# cols = 'cols_set_1'
# experiment_filter = 'ds-1'
# undersampling_method = '03-STRSAMP-AG', 
# experiment_id = 0

# %%
# run_gbt(df, params_dict, cols, filename, experiment_filter, undersampling_method, experiment_id)

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
def run_gbt(exp_df, params_dict, cols, filename, experiment_filter, 
            undersampling_method, experiment_id):
    import time
    start_time = time.time()
    
    n_covid = exp_df.filter(F.col('CLASSI_FIN') == 1.0).count()
    n_not_covid = exp_df.filter(F.col('CLASSI_FIN') == 0.0).count()
    
    
    id_cols = ['NU_NOTIFIC', 'CLASSI_FIN']

    labelIndexer = StringIndexer(inputCol="CLASSI_FIN", outputCol="indexedLabel").fit(exp_df)    
    
    input_cols = [x for x in exp_df.columns if x not in id_cols]
    assembler = VectorAssembler(inputCols = input_cols, outputCol= 'features')
    exp_df = assembler.transform(exp_df)
    
    # Automatically identify categorical features, and index them.
    # Set maxCategories so features with > 4 distinct values are treated as continuous.
    featureIndexer = VectorIndexer(inputCol="features", outputCol="indexedFeatures", maxCategories=30).fit(exp_df)
    
    # Split the data into training and test sets (30% held out for testing)
    (trainingData, testData) = exp_df.randomSplit([0.7, 0.3])
    trainingData = trainingData.persist(StorageLevel.MEMORY_ONLY)
    testData = testData.persist(StorageLevel.MEMORY_ONLY)
    
    # Train a RandomForest model.
    gbt = GBTClassifier(labelCol = "indexedLabel", featuresCol = "indexedFeatures",
                       maxIter = params_dict['maxIter'],
                       maxDepth = params_dict['maxDepth'],
                       maxBins = params_dict['maxBins'])
    
    # Convert indexed labels back to original labels.
    labelConverter = IndexToString(inputCol="prediction", outputCol="predictedLabel",
                               labels=labelIndexer.labels)

    # Chain indexers and forest in a Pipeline
    pipeline = Pipeline(stages=[labelIndexer, featureIndexer, gbt, labelConverter])

    # Train model.  This also runs the indexers.
    model = pipeline.fit(trainingData)
    
    # Make predictions.
    predictions = model.transform(testData)    
    
    
    pred = predictions.select(['CLASSI_FIN', 'predictedLabel'])\
                  .withColumn('predictedLabel', F.col('predictedLabel').cast('double'))\
                  .withColumn('predictedLabel', F.when(F.col('predictedLabel') == 1.0, 'covid').otherwise('n-covid'))\
                  .withColumn('CLASSI_FIN', F.when(F.col('CLASSI_FIN') == 1.0, 'covid').otherwise('n-covid'))\
                  .toPandas()

    y_true = pred['CLASSI_FIN'].tolist()
    y_pred = pred['predictedLabel'].tolist()
    
    report = classification_report(y_true, y_pred, output_dict=True)
    
    
    evaluator_ROC = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderROC")
    accuracy_ROC = evaluator_ROC.evaluate(predictions)


    
    evaluator_PR = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderPR")
    accuracy_PR = evaluator_PR.evaluate(predictions)
    
    conf_matrix = confusion_matrix(y_true, y_pred)

    result_dict = {}
    
    result_dict['experiment_filter'] = experiment_filter
    result_dict['undersampling_method'] = undersampling_method
    result_dict['filename'] = filename
    result_dict['experiment_id'] = experiment_id
    result_dict['n_covid'] = n_covid
    result_dict['n_not_covid'] = n_not_covid
    result_dict['model_name'] = 'GBT'
    result_dict['params'] = params_dict
    result_dict['model_AUC_ROC'] = accuracy_ROC
    result_dict['model_AUC_PR'] = accuracy_PR
    result_dict['model_covid_precision'] = report['covid']['precision']
    result_dict['model_covid_recall'] = report['covid']['recall']
    result_dict['model_covid_f1'] = report['covid']['f1-score']
    result_dict['model_not_covid_precision'] = report['n-covid']['precision']
    result_dict['model_not_covid_recall'] = report['n-covid']['recall']
    result_dict['model_not_covid_f1'] = report['n-covid']['f1-score']
    result_dict['model_avg_precision'] = report['macro avg']['precision']
    result_dict['model_avg_recall'] = report['macro avg']['recall']
    result_dict['model_avg_f1'] = report['macro avg']['f1-score']
    result_dict['model_avg_acc'] = report['accuracy']
    result_dict['model_TP'] = conf_matrix[0][0]
    result_dict['model_TN'] = conf_matrix[1][1]
    result_dict['model_FN'] = conf_matrix[0][1]
    result_dict['model_FP'] = conf_matrix[1][0]
    result_dict['model_time_exec'] = time.time() - start_time
    result_dict['model_col_set'] = cols
    
    return result_dict

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %% [markdown]
# # Running GBT on 10 samples for each experiment
# ### 3x col sets -> ['cols_set_1', 'cols_set_2', 'cols_set_3']
# ### 3x model_maxIter -> [100, 200, 300]
# ### 3x model_maxDepth -> [5, 10, 15]
# ### 3x model_maxBins -> [16, 32, 64]
# Total: 10 * 3 * 3 * 3 * 3 = 810

# %%
experiments = []

# %% [markdown]
# ### Datasets: strat_samp_lab_agegrp

# %%
for uc in undersamp_col: 
    for ds in dfs:
        for col_set in cols_sets:
            for params_dict in list_of_param_dicts: 
                for id_exp in range(50):
                    filename = prefix + uc + '/' + ds + '/' + col_set + '/' + 'experiment' + str(id_exp) + '.parquet'
                    exp_dataframe = spark.read.parquet(filename)
#                     if 'SG_UF_NOT' in exp_dataframe.columns:
#                         exp_dataframe = exp_dataframe.withColumn('SG_UF_NOT', F.col('SG_UF_NOT').cast('float'))
                    print('read {}'.format(filename))
                    
                    undersampling_method = uc
                    experiment_filter = ds
                    experiment_id = id_exp

                    try:                     
                        model = run_gbt(exp_dataframe, params_dict, col_set, filename, experiment_filter, undersampling_method, experiment_id)
                        experiments.append(model)

                        print("Parameters ==> {}\n Results: \n AUC_PR: {} \n Precision: {} \n Time: {}".format(str(params_dict), str(model['model_AUC_PR']), str(model['model_avg_precision']), str(model['model_time_exec'])))
                        print('=========================== \n')
                    except:
                        print('=========== W A R N I N G =========== \n')
                        print('Something wrong with the exp: {}, {}, {}'.format(filename, params_dict, col_set))
# Out:
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8938978954606897
#  Precision: 0.9326806902182357
#  Time: 26.385344743728638
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8864042915568376
#  Precision: 0.9288170305886878
#  Time: 15.393377304077148
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8965531487677527
#  Precision: 0.9340266114554382
#  Time: 14.91209101676941
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8935944348218037
#  Precision: 0.9321198159779529
#  Time: 14.928250551223755
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8905665331255888
#  Precision: 0.9291021786195953
#  Time: 15.201677083969116
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8913576739408517
#  Precision: 0.9309896530475581
#  Time: 14.65681791305542
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8917438146507678
#  Precision: 0.9306636847195358
#  Time: 13.953324556350708
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8955750237521243
#  Precision: 0.9333707415821856
#  Time: 14.061280488967896
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8930677595302572
#  Precision: 0.9312787110584613
#  Time: 14.18070936203003
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8948840109718231
#  Precision: 0.9325950620472669
#  Time: 14.209043979644775
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8938294086435038
#  Precision: 0.9327030969672108
#  Time: 14.270636081695557
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.891455311965537
#  Precision: 0.9306751193262457
#  Time: 14.372894525527954
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8921780934778275
#  Precision: 0.9303351745294226
#  Time: 13.844156503677368
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8989043581580226
#  Precision: 0.9342617149236911
#  Time: 14.141108274459839
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8919814182587711
#  Precision: 0.9316252681411348
#  Time: 14.052799940109253
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8906296389846948
#  Precision: 0.9297231618077741
#  Time: 14.292774200439453
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.892514338536532
#  Precision: 0.9306563947933517
#  Time: 14.568819999694824
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8918131912717344
#  Precision: 0.9297639264220946
#  Time: 14.14940333366394
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8955412732734952
#  Precision: 0.9337914434159391
#  Time: 14.145413875579834
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8942186486379582
#  Precision: 0.9329702390858783
#  Time: 14.331554174423218
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.885482626183119
#  Precision: 0.9280853892730185
#  Time: 14.457395315170288
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8963764152177359
#  Precision: 0.9334012897290634
#  Time: 15.525186777114868
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8924434990164047
#  Precision: 0.9306625876959473
#  Time: 15.255213975906372
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8941571499787899
#  Precision: 0.9331874888692351
#  Time: 14.224601984024048
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8924256323974945
#  Precision: 0.9322987240666858
#  Time: 14.279195308685303
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8938554161900576
#  Precision: 0.9331055631854914
#  Time: 13.894365310668945
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8904786835048384
#  Precision: 0.9303905957611922
#  Time: 13.755723714828491
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8967682443667611
#  Precision: 0.9334302896149633
#  Time: 13.50171446800232
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8903512077234512
#  Precision: 0.9303129370649956
#  Time: 13.834292650222778
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8888605196479439
#  Precision: 0.9294304943483462
#  Time: 13.78102970123291
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.894821708671031
#  Precision: 0.9324896933269122
#  Time: 16.17012858390808
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8953770236163713
#  Precision: 0.9334745459832368
#  Time: 13.73165774345398
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8907766520041434
#  Precision: 0.9309911510860283
#  Time: 13.515840768814087
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8881387470200776
#  Precision: 0.9294216503193898
#  Time: 24.42580008506775
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8939408942731194
#  Precision: 0.9330336661433025
#  Time: 13.541917562484741
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8951772077869792
#  Precision: 0.9319747867296684
#  Time: 14.128603458404541
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8927297521421831
#  Precision: 0.9321927604120333
#  Time: 14.118674516677856
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8927777205265113
#  Precision: 0.9316312342456305
#  Time: 17.824729204177856
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8931285856528149
#  Precision: 0.9315971930183387
#  Time: 13.525083541870117
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8942618432629337
#  Precision: 0.9325434525858307
#  Time: 16.034531593322754
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.891269229666821
#  Precision: 0.9303228968144334
#  Time: 13.767399072647095
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8914509427033883
#  Precision: 0.9312884489008544
#  Time: 14.051922798156738
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.893519647201049
#  Precision: 0.9320290166369605
#  Time: 14.344106912612915
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8936490299482244
#  Precision: 0.9326442995456057
#  Time: 15.650429248809814
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.890667170944913
#  Precision: 0.9303670966980054
#  Time: 14.006484508514404
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8948316697343995
#  Precision: 0.9329682931541741
#  Time: 14.000924110412598
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8957501515027319
#  Precision: 0.9322707478890302
#  Time: 17.86946749687195
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8984717093174587
#  Precision: 0.9334628218769961
#  Time: 13.59897756576538
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8930344581392695
#  Precision: 0.9316288423920317
#  Time: 13.657470464706421
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8919659737255542
#  Precision: 0.9315629994194073
#  Time: 13.739045143127441
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8904172398556893
#  Precision: 0.9313341652169576
#  Time: 13.535375356674194
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8898047592254172
#  Precision: 0.9304949607210963
#  Time: 13.50655460357666
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8948188923570253
#  Precision: 0.9330942629055372
#  Time: 13.595231294631958
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8930149497214273
#  Precision: 0.9323602821591653
#  Time: 13.85201907157898
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.898792931307576
#  Precision: 0.9344146220820044
#  Time: 13.807401418685913
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8951326000019528
#  Precision: 0.9331210294548331
#  Time: 13.789385318756104
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8941979304581265
#  Precision: 0.9327397242272021
#  Time: 14.091405868530273
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8914343028644767
#  Precision: 0.9311778385170186
#  Time: 13.919631481170654
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8880392494289788
#  Precision: 0.9290176995509639
#  Time: 13.902128458023071
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8883758782129438
#  Precision: 0.9294516850044182
#  Time: 14.772433042526245
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8941554874705965
#  Precision: 0.9324187565473395
#  Time: 14.248505115509033
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8896418638092871
#  Precision: 0.9302151504601917
#  Time: 13.517013549804688
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8939235960484565
#  Precision: 0.9323318139802672
#  Time: 15.930453062057495
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8952421160753663
#  Precision: 0.932972925951423
#  Time: 13.522506713867188
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8917747357867055
#  Precision: 0.9309224886528107
#  Time: 13.419602870941162
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8907446950499796
#  Precision: 0.9300518896294493
#  Time: 14.228526830673218
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8917843127160625
#  Precision: 0.9313798770596496
#  Time: 13.668551445007324
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9000993925661019
#  Precision: 0.9353263063950815
#  Time: 13.733194351196289
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8955619962921244
#  Precision: 0.9326909331181457
#  Time: 13.418002843856812
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8891081343585806
#  Precision: 0.9301124916422202
#  Time: 13.830638408660889
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8896675087787765
#  Precision: 0.9301659105576938
#  Time: 13.96855902671814
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8949014736145705
#  Precision: 0.9321926083092753
#  Time: 13.585433959960938
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8950820073905547
#  Precision: 0.9325879560594754
#  Time: 13.821543455123901
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8959642574578435
#  Precision: 0.9333760057102249
#  Time: 13.572856664657593
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8929056284775416
#  Precision: 0.9320609929122858
#  Time: 13.749223709106445
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8888027828181635
#  Precision: 0.9296586032835019
#  Time: 13.509881734848022
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8926077081470465
#  Precision: 0.9308367284839469
#  Time: 13.443793773651123
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8924450808235942
#  Precision: 0.9316416536217558
#  Time: 14.171106815338135
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8885168081198798
#  Precision: 0.9292208799845356
#  Time: 13.362158060073853
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.890460035925944
#  Precision: 0.931188509757884
#  Time: 13.683202028274536
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8923459021024442
#  Precision: 0.9311749596454668
#  Time: 13.398454666137695
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8956028374831844
#  Precision: 0.9338917336966517
#  Time: 13.839782476425171
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8903028969604465
#  Precision: 0.9304587619663036
#  Time: 14.55477523803711
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8882617531135294
#  Precision: 0.9294609281674744
#  Time: 16.310131788253784
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.896122822526279
#  Precision: 0.9333790429945984
#  Time: 13.485119342803955
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8925877842690368
#  Precision: 0.9314816525154221
#  Time: 13.800830125808716
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8926696252671573
#  Precision: 0.9318607583726424
#  Time: 13.840193748474121
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8946650361076628
#  Precision: 0.9321226781200505
#  Time: 13.960195779800415
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8932310514891254
#  Precision: 0.9315438104842004
#  Time: 13.639419078826904
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8947411132838422
#  Precision: 0.9327869582276354
#  Time: 13.487831830978394
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8935725644805064
#  Precision: 0.9318427528316099
#  Time: 13.470812320709229
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8946472735287032
#  Precision: 0.9324134577898198
#  Time: 13.471049308776855
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8963889306404977
#  Precision: 0.933248636633611
#  Time: 13.940179347991943
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8934785037653399
#  Precision: 0.9310600996902609
#  Time: 13.27881145477295
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8907573602676185
#  Precision: 0.9308053219063805
#  Time: 13.522087574005127
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8925894660412038
#  Precision: 0.9319830571322972
#  Time: 13.36000108718872
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8916872784266452
#  Precision: 0.9309793503658736
#  Time: 13.587323427200317
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8955560645511916
#  Precision: 0.9320349522971196
#  Time: 13.410763025283813
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8906250957194812
#  Precision: 0.9304518394007164
#  Time: 13.097087621688843
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8886549948122471
#  Precision: 0.9292213803191165
#  Time: 13.638291597366333
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9035508118124411
#  Precision: 0.9389668602322668
#  Time: 16.37741780281067
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8955445140300757
#  Precision: 0.9355913160528073
#  Time: 16.28642249107361
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8982015109393667
#  Precision: 0.9363854104840453
#  Time: 16.46492314338684
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8984420126333095
#  Precision: 0.9360280318059827
#  Time: 16.623563289642334
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8998505966019248
#  Precision: 0.9356741548545522
#  Time: 16.66871166229248
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8974139306911035
#  Precision: 0.9350703866776771
#  Time: 16.411849975585938
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8978253260043223
#  Precision: 0.93622453546427
#  Time: 17.11773705482483
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8985640579838184
#  Precision: 0.9366787544535019
#  Time: 16.779415607452393
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8989787377906474
#  Precision: 0.9360900553103497
#  Time: 16.418605089187622
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8971063516639692
#  Precision: 0.9353083003914358
#  Time: 16.396004915237427
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8986840130004456
#  Precision: 0.9368301639047361
#  Time: 17.005992889404297
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8931210075768079
#  Precision: 0.9333020014607836
#  Time: 17.90830159187317
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8983419216919876
#  Precision: 0.9358394184387469
#  Time: 16.374958038330078
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8956714074940885
#  Precision: 0.9342352282206632
#  Time: 16.788124799728394
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8972653815924845
#  Precision: 0.9353668125226677
#  Time: 18.161887168884277
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8928017961852993
#  Precision: 0.9329068087004466
#  Time: 17.63080668449402
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9002072353610493
#  Precision: 0.9365246919227148
#  Time: 16.642014980316162
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8933660342409883
#  Precision: 0.9334719450044271
#  Time: 17.220732927322388
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8958453555921922
#  Precision: 0.9345408433740827
#  Time: 17.99540638923645
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8992543266301057
#  Precision: 0.9370200644799458
#  Time: 17.545589923858643
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8982447368691404
#  Precision: 0.9358135426455569
#  Time: 17.22893786430359
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.895581690227424
#  Precision: 0.9336946900150778
#  Time: 17.38329815864563
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9000330188165165
#  Precision: 0.9373728288415222
#  Time: 19.16518545150757
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8948455597344714
#  Precision: 0.9346753039467466
#  Time: 17.971723556518555
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.897758381762334
#  Precision: 0.9365291496205143
#  Time: 17.132787704467773
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9012674317757386
#  Precision: 0.9369480132732717
#  Time: 16.823487997055054
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8982151398961914
#  Precision: 0.9359952229763862
#  Time: 16.977452516555786
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8952264062282889
#  Precision: 0.9338113330614164
#  Time: 17.062350511550903
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.898050406467325
#  Precision: 0.9349472362072093
#  Time: 17.383665561676025
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8947812440318273
#  Precision: 0.9333075236477588
#  Time: 17.161900997161865
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.895330733567265
#  Precision: 0.9349588501062535
#  Time: 17.564061164855957
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8999672966208097
#  Precision: 0.936462200763623
#  Time: 17.672831296920776
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8973656328866191
#  Precision: 0.936306408020368
#  Time: 17.771397590637207
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8988730104391967
#  Precision: 0.9368152399164094
#  Time: 17.95265293121338
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8955279998371083
#  Precision: 0.9342141438840703
#  Time: 16.432159662246704
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8977831532686114
#  Precision: 0.9358246574314792
#  Time: 17.28814125061035
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8975796468526077
#  Precision: 0.9350807810133521
#  Time: 17.655683755874634
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9014712326784167
#  Precision: 0.9381593176757121
#  Time: 17.287952423095703
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8930426883799153
#  Precision: 0.9333191456441203
#  Time: 26.768008708953857
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8978434669659323
#  Precision: 0.9353204595489466
#  Time: 17.980260848999023
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9022821236170915
#  Precision: 0.9379173464853199
#  Time: 16.884945154190063
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8994851006586857
#  Precision: 0.9368309887333237
#  Time: 16.73208260536194
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8983764713649446
#  Precision: 0.9354800503061708
#  Time: 17.64259171485901
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8964665464619214
#  Precision: 0.9352426051716289
#  Time: 17.23009204864502
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8989384868400068
#  Precision: 0.9363781523120515
#  Time: 16.88937497138977
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8966429011792632
#  Precision: 0.9345450333476014
#  Time: 17.197026252746582
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9048347652385146
#  Precision: 0.938637289189664
#  Time: 17.52943444252014
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.894955382290418
#  Precision: 0.9350166204308272
#  Time: 17.220067739486694
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8969568566496335
#  Precision: 0.9354107099194249
#  Time: 17.13140630722046
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.896144351165663
#  Precision: 0.9347014723885836
#  Time: 17.701552867889404
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9002864051061416
#  Precision: 0.9363815485475142
#  Time: 17.78785991668701
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8988263706093127
#  Precision: 0.9368647833194432
#  Time: 17.38681435585022
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8955000456505435
#  Precision: 0.9341070824230413
#  Time: 16.951671838760376
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8997184290886128
#  Precision: 0.9359695641692771
#  Time: 17.396745443344116
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8995792032101074
#  Precision: 0.9365835183096863
#  Time: 17.304434299468994
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.897222725712319
#  Precision: 0.9350487520685811
#  Time: 17.868261575698853
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8969273159520922
#  Precision: 0.9356708673922158
#  Time: 17.12601351737976
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.896875923093807
#  Precision: 0.9344381421753012
#  Time: 17.35437822341919
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8949905172707155
#  Precision: 0.9341188796903663
#  Time: 17.930007934570312
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8972022976857916
#  Precision: 0.9354196925860527
#  Time: 16.75086212158203
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8973684229676109
#  Precision: 0.9352371502788366
#  Time: 17.59066677093506
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9004469692522331
#  Precision: 0.9362340123333885
#  Time: 17.207096099853516
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8988479062022918
#  Precision: 0.936469796290411
#  Time: 17.231121063232422
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.899689241506953
#  Precision: 0.9362530091592136
#  Time: 16.660616636276245
# ===========================
#
# ...
#  Results:
#  AUC_PR: 0.9066310130568642
#  Precision: 0.9410006245121594
#  Time: 135.3524227142334
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9031965095655581
#  Precision: 0.938476106445847
#  Time: 136.1080687046051
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9057596122128713
#  Precision: 0.9397941330903068
#  Time: 135.8272364139557
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9019726655946793
#  Precision: 0.9382700575006531
#  Time: 136.87903714179993
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9085699889325742
#  Precision: 0.9419137523340135
#  Time: 134.9009301662445
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9021050249840853
#  Precision: 0.9385915462479222
#  Time: 134.7409327030182
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8993816001129128
#  Precision: 0.9370387359881804
#  Time: 135.56703209877014
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9008260443025877
#  Precision: 0.9378700974811454
#  Time: 138.3956470489502
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.903492191857401
#  Precision: 0.9399141976019096
#  Time: 134.8615562915802
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9048854812959019
#  Precision: 0.9397846487399086
#  Time: 134.6158149242401
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9061038799997853
#  Precision: 0.9408400823556529
#  Time: 135.66706800460815
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9033878941614926
#  Precision: 0.9389959536687085
#  Time: 140.39322471618652
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9029330496300497
#  Precision: 0.9384714526059575
#  Time: 148.42171454429626
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9008262814470437
#  Precision: 0.9388241548443126
#  Time: 135.24944639205933
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9025584369837576
#  Precision: 0.9390612925992023
#  Time: 136.6135449409485
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9040320333698079
#  Precision: 0.9403833023898307
#  Time: 137.2854871749878
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9021918413696022
#  Precision: 0.9390613505412295
#  Time: 134.39417695999146
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.899342885563102
#  Precision: 0.936931100849804
#  Time: 135.6638560295105
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9058507564514063
#  Precision: 0.9404592084276339
#  Time: 136.0910370349884
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9058822085828664
#  Precision: 0.9399691126887604
#  Time: 146.0186071395874
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8996679831069055
#  Precision: 0.9371113004564564
#  Time: 137.8680443763733
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment16.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8988663394990526
#  Precision: 0.9365336268398654
#  Time: 136.90694785118103
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9034828537185327
#  Precision: 0.9392583361055877
#  Time: 135.4330756664276
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment18.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9011191811312699
#  Precision: 0.9377818211785947
#  Time: 135.56900668144226
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment19.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.904947518438704
#  Precision: 0.93982938054064
#  Time: 134.58204746246338
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment20.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8999172211456241
#  Precision: 0.938211102939586
#  Time: 135.80192923545837
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment21.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.899752044832771
#  Precision: 0.937301919571359
#  Time: 136.11229991912842
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment22.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9012258184956299
#  Precision: 0.937906140741932
#  Time: 135.89758777618408
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment23.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9021260811961626
#  Precision: 0.9385958753472218
#  Time: 134.0054166316986
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment24.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9056571335777747
#  Precision: 0.9406961125706024
#  Time: 136.02628231048584
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment25.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9035272210102886
#  Precision: 0.9397627244342572
#  Time: 135.06981706619263
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment26.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9057796352939262
#  Precision: 0.9399349855699665
#  Time: 135.03704118728638
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment27.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9022605150526338
#  Precision: 0.9385167598050637
#  Time: 132.0756013393402
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment28.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9016304506374702
#  Precision: 0.9382089738096615
#  Time: 136.62250423431396
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment29.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9033911772130719
#  Precision: 0.9390444564584071
#  Time: 134.80693435668945
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment30.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9004731770615346
#  Precision: 0.9381193130771941
#  Time: 135.52758359909058
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment31.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9025196133373814
#  Precision: 0.9391230957610723
#  Time: 136.2359163761139
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment32.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9024801799818853
#  Precision: 0.9390532688219972
#  Time: 133.9500925540924
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment33.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9041876979471014
#  Precision: 0.9403709790848255
#  Time: 137.24414443969727
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment34.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9006535498877691
#  Precision: 0.9377468106082139
#  Time: 137.22675323486328
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment35.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9041669337314102
#  Precision: 0.9399710636795089
#  Time: 134.4728193283081
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment36.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9052511022852476
#  Precision: 0.9399996870503893
#  Time: 138.08201694488525
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment37.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9022161460212788
#  Precision: 0.9381888294789344
#  Time: 135.3128092288971
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment38.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.904063759859083
#  Precision: 0.940020885001958
#  Time: 133.70829033851624
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment39.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9019670728570212
#  Precision: 0.9387474863277262
#  Time: 134.6692636013031
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment40.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8979866133583111
#  Precision: 0.9369954214863889
#  Time: 135.5704689025879
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment41.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9045052706912778
#  Precision: 0.9395721698348551
#  Time: 135.33367133140564
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment42.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9003281098453373
#  Precision: 0.9384163570121565
#  Time: 134.6714551448822
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment43.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.90613524208569
#  Precision: 0.9410134863699329
#  Time: 135.7230761051178
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment44.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9068597597999565
#  Precision: 0.9411339033868128
#  Time: 135.47121381759644
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment45.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9028788729743522
#  Precision: 0.9387203438941266
#  Time: 132.5588128566742
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9035686105687665
#  Precision: 0.9393214747245615
#  Time: 133.31653428077698
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.904729492473864
#  Precision: 0.9392910894504056
#  Time: 135.2771453857422
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9033049232753972
#  Precision: 0.939330273673592
#  Time: 135.13767075538635
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.898321818567313
#  Precision: 0.9364501060782856
#  Time: 134.39332461357117
# ===========================

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
for i in range(len(experiments)):
    for d in list(experiments[i].keys()):
        experiments[i][d] = str(experiments[i][d])

# %%
# experiments

# %%
cols = ['experiment_filter', 'undersampling_method', 'filename', 'experiment_id', 'n_covid', 'n_not_covid', 'model_name', 'params', 'model_AUC_ROC', 'model_AUC_PR', 'model_covid_precision', 'model_covid_recall', 'model_covid_f1', 'model_not_covid_precision', 'model_not_covid_recall', 'model_not_covid_f1', 'model_avg_precision', 'model_avg_recall', 'model_avg_f1', 'model_avg_acc', 'model_TP', 'model_TN', 'model_FN', 'model_FP', 'model_time_exec', 'model_col_set']

# %%
intermed_results = spark.createDataFrame(data=experiments).select(cols)
intermed_results.toPandas()
# Out:
# /usr/lib/spark/python/pyspark/sql/session.py:346: UserWarning: inferring schema from dict is deprecated,please use pyspark.sql.Row instead
#   warnings.warn("inferring schema from dict is deprecated,"

# %%
intermed_results.write.parquet('gs://ai-covid19-datalake/trusted/intermed_results/STRSAMP/GBT_experiments-AG-ds1-cs3.parquet', mode='overwrite')

# %%
print('finished')
# Out:
# finished

# %%
intermed_results.show()
# Out:
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# |experiment_filter|undersampling_method|            filename|experiment_id|n_covid|n_not_covid|model_name|              params|     model_AUC_ROC|      model_AUC_PR|model_covid_precision|model_covid_recall|    model_covid_f1|model_not_covid_precision|model_not_covid_recall|model_not_covid_f1|model_avg_precision|  model_avg_recall|      model_avg_f1|     model_avg_acc|model_TP|model_TN|model_FN|model_FP|   model_time_exec|model_col_set|
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            0|  86324|      44538|       GBT|{'maxIter': 20, '...|0.9125042294515648|0.8938978954606897|   0.9280959211445805|0.9704264892512402|0.9487892916228003|        0.937265459291891|    0.8545819696518894|0.8940160298809432| 0.9326806902182357|0.9125042294515648|0.9214026607518717|0.9309453190356681|   25234|   11489|     769|    1955|26.385344743728638|   cols_set_3|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            1|  86460|      44538|       GBT|{'maxIter': 20, '...|0.9090345679442914|0.8864042915568376|   0.9268616530815476|0.9677295132470733|0.9468548068046948|       0.9307724080958282|    0.8503396226415094|0.8887398935121278| 0.9288170305886878|0.9090345679442914|0.9177973501584114|0.9280687439441073|   25130|   11267|     838|    1983|15.393377304077148|   cols_set_3|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            2|  87179|      44538|       GBT|{'maxIter': 20, '...|0.9113411474403016|0.8965531487677527|   0.9263000510538983|0.9729201777233032|0.9490379226601905|        0.941753171856978|       0.8497621171573|0.8933958577569363| 0.9340266114554382|0.9113411474403016|0.9212168902085633|0.9310414560161779|   25401|   11431|     707|    2021| 14.91209101676941|   cols_set_3|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            3|  86086|      44538|       GBT|{'maxIter': 20, '...|0.9116094181222539|0.8935944348218037|   0.9268670477595427|0.9703474903474903|  0.94810902574743|        0.937372584196363|    0.8528713458970174|0.8931276951167398| 0.9321198159779529|0.9116094181222538|0.9206183604320849|0.9301386561023922|   25132|   11495|     768|    1983|14.928250551223755|   cols_set_3|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            4|  84842|      44538|       GBT|{'maxIter': 20, '...|0.9092664496759482|0.8905665331255888|   0.9237794565339948|0.9681345517567355|0.9454370612558901|       0.9344249007051958|    0.8503983475951609|0.8904337079519562| 0.9291021786195953|0.9092664496759482|0.9179353846039231|0.9271518077239113|   24579|   11528|     809|    2028|15.201677083969116|   cols_set_3|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            5|  85210|      44538|       GBT|{'maxIter': 20, '...|0.9092905089772652|0.8913576739408517|   0.9253443219363701|0.9704118975317293|0.9473424168139407|        0.936634984158746|     0.848169120422801|0.8902095962597567| 0.9309896530475581|0.9092905089772652|0.9187760065368487|0.9288227890370142|   24926|   11234|     760|    2011| 14.65681791305542|   cols_set_3|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            6|  86207|      44538|       GBT|{'maxIter': 20, '...|0.9102798129601654|0.8917438146507678|    0.925531914893617|0.9693968352226564|0.9469566696271661|       0.9357954545454545|    0.8511627906976744|0.8914749661705007| 0.9306636847195358|0.9102798129601655|0.9192158178988334|0.9287418765231519|   25056|   11529|     791|    2016|13.953324556350708|   cols_set_3|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            7|  86112|      44538|       GBT|{'maxIter': 20, '...|0.9108965110130245|0.8955750237521243|   0.9259630000370741| 0.972396340276426|0.9486117968779672|       0.9407784831272971|    0.8493966817496229|0.8927552314521242| 0.9333707415821856|0.9108965110130245|0.9206835141650457|0.9305173963281551|   24976|   11263|     709|    1997|14.061280488967896|   cols_set_3|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            8|  86427|      44538|       GBT|{'maxIter': 20, '...|0.9090845745964288|0.8930677595302572|   0.9239891783715672|0.9710235239133821|0.9469226532976319|       0.9385682437453554|    0.8471456252794753| 0.890516667319519| 0.9312787110584613|0.9090845745964287|0.9187196603085754|0.9285056530413874|   24932|   11367|     744|    2051| 14.18070936203003|   cols_set_3|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|            9|  86261|      44538|       GBT|{'maxIter': 20, '...|0.9100153083412623|0.8948840109718231|   0.9248250460405156|0.9720490883047501|0.9478492289688756|       0.9403650780540184|    0.8479815283777745|0.8917870990482905| 0.9325950620472669|0.9100153083412623| 0.919818164008583|0.9296176478080342|   25109|   11385|     722|    2041|14.209043979644775|   cols_set_3|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           10|  87217|      44538|       GBT|{'maxIter': 20, '...|0.9090567859923715|0.8938294086435038|   0.9250154776211806|0.9726583441831967|0.9482388516603514|       0.9403907163132409|    0.8454552278015462|0.8903995889490534| 0.9327030969672108|0.9090567859923715|0.9193192203047024|0.9296853208915485|   25400|   11264|     714|    2059|14.270636081695557|   cols_set_3|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           11|  86536|      44538|       GBT|{'maxIter': 20, '...|0.9104002943405707| 0.891455311965537|    0.925910901312878|0.9693073893907806|0.9471123014825154|       0.9354393373396135|    0.8514931992903607|0.8914944663725718| 0.9306751193262457|0.9104002943405707|0.9193033839275435|0.9288866345422268|   25107|   11519|     795|    2009|14.372894525527954|   cols_set_3|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           12|  84591|      44538|       GBT|{'maxIter': 20, '...|0.9101409660844877|0.8921780934778275|   0.9246304862913235|0.9691343424787133|0.9463594895779203|       0.9360398627675216|    0.8511475896902622|0.8915775141023148| 0.9303351745294226|0.9101409660844877|0.9189685018401175|0.9282274471427467|   24585|   11459|     783|    2004|13.844156503677368|   cols_set_3|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           13|  85783|      44538|       GBT|{'maxIter': 20, '...|0.9104438120083569|0.8989043581580226|   0.9236565096952909|0.9740214216163583| 0.948170616113744|       0.9448669201520913|    0.8468662024003556|0.8931864353805282| 0.9342617149236911|0.9104438120083569|0.9206785257471362|0.9302070303525387|   25008|   11431|     667|    2067|14.141108274459839|   cols_set_3|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           14|  85729|      44538|       GBT|{'maxIter': 20, '...|0.9111300706122819|0.8919814182587711|   0.9272505362822694|0.9699771733663481|0.9481327408527938|                    0.936|    0.8522829678582157|0.8921819110884006| 0.9316252681411348|0.9111300706122819|0.9201573259705972|0.9299594004545106|   25071|   11349|     776|    1967|14.052799940109253|   cols_set_3|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           15|  85062|      44538|       GBT|{'maxIter': 20, '...| 0.909839159234785|0.8906296389846948|   0.9249906191369606|0.9684909440930343|0.9462410993608814|       0.9344557044785877|    0.8511873743765354|0.8908800498655965| 0.9297231618077741|0.9098391592347848| 0.918560574613239|0.9279689348351592|   24651|   11434|     802|    1999|14.292774200439453|   cols_set_3|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           16|  85904|      44538|       GBT|{'maxIter': 20, '...|   0.9088592448612| 0.892514338536532|   0.9235232462379277|0.9704204853872478|0.9463912384678828|       0.9377895433487756|    0.8472980043351521|0.8902501276161306| 0.9306563947933517|   0.9088592448612|0.9183206830420068|0.9279676305345085|   24671|   11336|     752|    2043|14.568819999694824|   cols_set_3|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           17|  85341|      44538|       GBT|{'maxIter': 20, '...|0.9077916316675456|0.8918131912717344|    0.922084219163776|0.9700608200902492|0.9454642802508796|       0.9374436336804132|    0.8455224432448422|0.8891135303265941| 0.9297639264220946|0.9077916316675456|0.9172889052887369|0.9268867924528302|   24722|   11434|     763|    2089| 14.14940333366394|   cols_set_3|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           18|  85671|      44538|       GBT|{'maxIter': 20, '...|0.9126551977859798|0.8955412732734952|   0.9281183932346723|0.9717292532328842|0.9494232812262862|       0.9394644935972061|    0.8535811423390752|0.8944659963581664| 0.9337914434159391|0.9126551977859797|0.9219446387922263|0.9316182317182651|   25023|   11298|     728|    1938|14.145413875579834|   cols_set_3|
# |             ds-1|       03-STRSAMP-AG|gs://ai-covid19-d...|           19|  85416|      44538|       GBT|{'maxIter': 20, '...|0.9084415271698458|0.8942186486379582|   0.9244358289747997|0.9733507913890708|0.9482629248893224|       0.9415046491969569|     0.843532262950621|0.8898298314292563| 0.9329702390858783|0.9084415271698458|0.9190463781592894| 0.929590768680912|   25275|   11138|     692|    2066|14.331554174423218|   cols_set_3|
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# only showing top 20 rows
