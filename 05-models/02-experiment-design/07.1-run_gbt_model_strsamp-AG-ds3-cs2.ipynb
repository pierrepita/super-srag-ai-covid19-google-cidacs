# %%
import pandas as pd
import pyspark.sql.functions as F
from datetime import datetime
from pyspark.sql.types import *
from pyspark import StorageLevel

import numpy as np
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", 1000)
pd.set_option("mode.chained_assignment", None)

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import GBTClassifier
from pyspark.ml.feature import IndexToString, StringIndexer, VectorIndexer
# from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import OneHotEncoderEstimator, StringIndexer, VectorAssembler

from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

from pyspark.sql import Row
from pyspark.ml.linalg import Vectors

# %%
# !pip install scikit-plot

# %%
import sklearn
import scikitplot as skplt
from sklearn.metrics import classification_report, confusion_matrix, precision_score

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
result_schema = StructType([
                    StructField('experiment_filter', StringType(), True),
                    StructField('undersampling_method', StringType(), True),
                    StructField('undersampling_column', StringType(), True),
                    StructField('filename', StringType(), True),
                    StructField('experiment_id', StringType(), True),
                    StructField('n_covid', IntegerType(), True),
                    StructField('n_not_covid', IntegerType(), True),
                    StructField('model_name', StringType(), True),
                    StructField('model_seed', StringType(), True),
                    StructField('model_maxIter', IntegerType(), True),
                    StructField('model_maxDepth', IntegerType(), True),
                    StructField('model_maxBins', IntegerType(), True),
                    StructField('model_minInstancesPerNode', IntegerType(), True),
                    StructField('model_minInfoGain', FloatType(), True),
                    StructField('model_featureSubsetStrategy', StringType(), True),
                    StructField('model_n_estimators', IntegerType(), True),
                    StructField('model_learning_rate', FloatType(), True),
                    StructField('model_impurity', StringType(), True),
                    StructField('model_AUC_ROC', StringType(), True),
                    StructField('model_AUC_PR', StringType(), True),
                    StructField('model_covid_precision', StringType(), True),
                    StructField('model_covid_recall', StringType(), True),
                    StructField('model_covid_f1', StringType(), True),
                    StructField('model_not_covid_precision', StringType(), True),
                    StructField('model_not_covid_recall', StringType(), True),
                    StructField('model_not_covid_f1', StringType(), True),
                    StructField('model_avg_precision', StringType(), True),
                    StructField('model_avg_recall', StringType(), True),
                    StructField('model_avg_f1', StringType(), True),
                    StructField('model_avg_acc', StringType(), True),
                    StructField('model_TP', StringType(), True),
                    StructField('model_TN', StringType(), True),
                    StructField('model_FN', StringType(), True),
                    StructField('model_FP', StringType(), True),
                    StructField('model_time_exec', StringType(), True),
                    StructField('model_col_set', StringType(), True)
                          ])

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# undersamp_col = ['03-STRSAMP-AG', '04-STRSAMP-EW'] 
# dfs = ['ds-1', 'ds-2', 'ds-3']
# cols_sets = ['cols_set_1', 'cols_set_2', 'cols_set_3']

undersamp_col = ['03-STRSAMP-AG']
dfs = ['ds-3']
cols_sets = ['cols_set_2']

# %%
# lists of params
model_maxIter = [20, 50, 100] 
model_maxDepth = [3, 5, 7] 
model_maxBins = [32, 64] 
# model_learningRate = [0.01, 0.1, 0.5]
# model_loss = ['logLoss', 'leastSquaresError', 'leastAbsoluteError']



list_of_param_dicts = []

for maxIter in model_maxIter:
    for maxDepth in model_maxDepth:
        for maxBins in model_maxBins: 
            params_dict = {}
            params_dict['maxIter'] = maxIter
            params_dict['maxDepth'] = maxDepth
            params_dict['maxBins'] = maxBins
            list_of_param_dicts.append(params_dict)

print("There is {} set of params.".format(len(list_of_param_dicts)))
# list_of_param_dicts
# Out:
# There is 18 set of params.

# %%
prefix = 'gs://ai-covid19-datalake/trusted/experiment_map/'

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# filename = 'gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment0.parquet'
# df = spark.read.parquet(filename)
# df.limit(2).toPandas()

# %%
# params_dict = {'maxIter': 100,
#                'maxDepth': 3,
#                'maxBins': 32,
#                'learningRate': 0.5,
#                'loss': 'leastAbsoluteError'}
# cols = 'cols_set_1'
# experiment_filter = 'ds-1'
# undersampling_method = '03-STRSAMP-AG', 
# experiment_id = 0

# %%
# run_gbt(df, params_dict, cols, filename, experiment_filter, undersampling_method, experiment_id)

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
def run_gbt(exp_df, params_dict, cols, filename, experiment_filter, 
            undersampling_method, experiment_id):
    import time
    start_time = time.time()
    
    n_covid = exp_df.filter(F.col('CLASSI_FIN') == 1.0).count()
    n_not_covid = exp_df.filter(F.col('CLASSI_FIN') == 0.0).count()
    
    
    id_cols = ['NU_NOTIFIC', 'CLASSI_FIN']

    labelIndexer = StringIndexer(inputCol="CLASSI_FIN", outputCol="indexedLabel").fit(exp_df)    
    
    input_cols = [x for x in exp_df.columns if x not in id_cols]
    assembler = VectorAssembler(inputCols = input_cols, outputCol= 'features')
    exp_df = assembler.transform(exp_df)
    
    # Automatically identify categorical features, and index them.
    # Set maxCategories so features with > 4 distinct values are treated as continuous.
    featureIndexer = VectorIndexer(inputCol="features", outputCol="indexedFeatures", maxCategories=30).fit(exp_df)
    
    # Split the data into training and test sets (30% held out for testing)
    (trainingData, testData) = exp_df.randomSplit([0.7, 0.3])
    trainingData = trainingData.persist(StorageLevel.MEMORY_ONLY)
    testData = testData.persist(StorageLevel.MEMORY_ONLY)
    
    # Train a RandomForest model.
    gbt = GBTClassifier(labelCol = "indexedLabel", featuresCol = "indexedFeatures",
                       maxIter = params_dict['maxIter'],
                       maxDepth = params_dict['maxDepth'],
                       maxBins = params_dict['maxBins'])
    
    # Convert indexed labels back to original labels.
    labelConverter = IndexToString(inputCol="prediction", outputCol="predictedLabel",
                               labels=labelIndexer.labels)

    # Chain indexers and forest in a Pipeline
    pipeline = Pipeline(stages=[labelIndexer, featureIndexer, gbt, labelConverter])

    # Train model.  This also runs the indexers.
    model = pipeline.fit(trainingData)
    
    # Make predictions.
    predictions = model.transform(testData)    
    
    
    pred = predictions.select(['CLASSI_FIN', 'predictedLabel'])\
                  .withColumn('predictedLabel', F.col('predictedLabel').cast('double'))\
                  .withColumn('predictedLabel', F.when(F.col('predictedLabel') == 1.0, 'covid').otherwise('n-covid'))\
                  .withColumn('CLASSI_FIN', F.when(F.col('CLASSI_FIN') == 1.0, 'covid').otherwise('n-covid'))\
                  .toPandas()

    y_true = pred['CLASSI_FIN'].tolist()
    y_pred = pred['predictedLabel'].tolist()
    
    report = classification_report(y_true, y_pred, output_dict=True)
    
    
    evaluator_ROC = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderROC")
    accuracy_ROC = evaluator_ROC.evaluate(predictions)


    
    evaluator_PR = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderPR")
    accuracy_PR = evaluator_PR.evaluate(predictions)
    
    conf_matrix = confusion_matrix(y_true, y_pred)

    result_dict = {}
    
    result_dict['experiment_filter'] = experiment_filter
    result_dict['undersampling_method'] = undersampling_method
    result_dict['filename'] = filename
    result_dict['experiment_id'] = experiment_id
    result_dict['n_covid'] = n_covid
    result_dict['n_not_covid'] = n_not_covid
    result_dict['model_name'] = 'GBT'
    result_dict['params'] = params_dict
    result_dict['model_AUC_ROC'] = accuracy_ROC
    result_dict['model_AUC_PR'] = accuracy_PR
    result_dict['model_covid_precision'] = report['covid']['precision']
    result_dict['model_covid_recall'] = report['covid']['recall']
    result_dict['model_covid_f1'] = report['covid']['f1-score']
    result_dict['model_not_covid_precision'] = report['n-covid']['precision']
    result_dict['model_not_covid_recall'] = report['n-covid']['recall']
    result_dict['model_not_covid_f1'] = report['n-covid']['f1-score']
    result_dict['model_avg_precision'] = report['macro avg']['precision']
    result_dict['model_avg_recall'] = report['macro avg']['recall']
    result_dict['model_avg_f1'] = report['macro avg']['f1-score']
    result_dict['model_avg_acc'] = report['accuracy']
    result_dict['model_TP'] = conf_matrix[0][0]
    result_dict['model_TN'] = conf_matrix[1][1]
    result_dict['model_FN'] = conf_matrix[0][1]
    result_dict['model_FP'] = conf_matrix[1][0]
    result_dict['model_time_exec'] = time.time() - start_time
    result_dict['model_col_set'] = cols
    
    return result_dict

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %% [markdown]
# # Running GBT on 10 samples for each experiment
# ### 3x col sets -> ['cols_set_1', 'cols_set_2', 'cols_set_3']
# ### 3x model_maxIter -> [100, 200, 300]
# ### 3x model_maxDepth -> [5, 10, 15]
# ### 3x model_maxBins -> [16, 32, 64]
# Total: 10 * 3 * 3 * 3 * 3 = 810

# %%
experiments = []

# %% [markdown]
# ### Datasets: strat_samp_lab_agegrp

# %%
for uc in undersamp_col: 
    for ds in dfs:
        for col_set in cols_sets:
            for params_dict in list_of_param_dicts: 
                for id_exp in range(50):
                    filename = prefix + uc + '/' + ds + '/' + col_set + '/' + 'experiment' + str(id_exp) + '.parquet'
                    exp_dataframe = spark.read.parquet(filename)
#                     if 'SG_UF_NOT' in exp_dataframe.columns:
#                         exp_dataframe = exp_dataframe.withColumn('SG_UF_NOT', F.col('SG_UF_NOT').cast('float'))
                    print('read {}'.format(filename))
                    
                    undersampling_method = uc
                    experiment_filter = ds
                    experiment_id = id_exp

                    try:                     
                        model = run_gbt(exp_dataframe, params_dict, col_set, filename, experiment_filter, undersampling_method, experiment_id)
                        experiments.append(model)

                        print("Parameters ==> {}\n Results: \n AUC_PR: {} \n Precision: {} \n Time: {}".format(str(params_dict), str(model['model_AUC_PR']), str(model['model_avg_precision']), str(model['model_time_exec'])))
                        print('=========================== \n')
                    except:
                        print('=========== W A R N I N G =========== \n')
                        print('Something wrong with the exp: {}, {}, {}'.format(filename, params_dict, col_set))
# Out:
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9079510001445159
#  Precision: 0.9365464781184855
#  Time: 27.704296588897705
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9045204802118015
#  Precision: 0.9346793986319338
#  Time: 19.893548727035522
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9086499315745207
#  Precision: 0.9373705696632122
#  Time: 19.63073468208313
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9089844588185542
#  Precision: 0.9361718265422289
#  Time: 20.760419607162476
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9111622879972517
#  Precision: 0.9368852081000498
#  Time: 18.910874366760254
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9109964089728464
#  Precision: 0.9384130518030864
#  Time: 20.753438234329224
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.907892142645365
#  Precision: 0.9367938597474826
#  Time: 18.979822635650635
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9087619485118874
#  Precision: 0.9366926184488856
#  Time: 18.656402349472046
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.906899063392371
#  Precision: 0.9359075730592978
#  Time: 18.51894187927246
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9071052088747619
#  Precision: 0.9357683238864636
#  Time: 19.39965009689331
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9062865310938698
#  Precision: 0.9371991992033085
#  Time: 18.427087545394897
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9060444751625383
#  Precision: 0.9355296078027928
#  Time: 18.760917901992798
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.909918501643018
#  Precision: 0.9371480126621579
#  Time: 18.4181489944458
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9039140256990719
#  Precision: 0.9340780343858431
#  Time: 19.11789631843567
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9052421834975578
#  Precision: 0.9344759415505782
#  Time: 18.903894424438477
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9041613354212248
#  Precision: 0.9336055129664012
#  Time: 20.233166456222534
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.906715145154714
#  Precision: 0.9359210507797806
#  Time: 18.760483026504517
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.906929402448953
#  Precision: 0.9353527480406576
#  Time: 19.266437292099
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9063017108509221
#  Precision: 0.9355261277366012
#  Time: 18.64596438407898
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9083672721904958
#  Precision: 0.9362502103686925
#  Time: 18.815521478652954
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9081633715752818
#  Precision: 0.9372715352673995
#  Time: 18.868056774139404
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9101146698549987
#  Precision: 0.937051063163258
#  Time: 20.61836266517639
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9077296753906464
#  Precision: 0.9360810354689901
#  Time: 18.2719886302948
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9057933803876634
#  Precision: 0.9354828487962762
#  Time: 18.656149864196777
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9048245969849444
#  Precision: 0.9345254706633634
#  Time: 18.667091608047485
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9095767924759066
#  Precision: 0.938105750758313
#  Time: 19.593721628189087
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9073589699550173
#  Precision: 0.935503011164002
#  Time: 18.42894196510315
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9108961260716565
#  Precision: 0.9366959603401328
#  Time: 18.372663974761963
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.906604019686103
#  Precision: 0.9358374456477021
#  Time: 17.861160278320312
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9105638124773062
#  Precision: 0.9381159916816031
#  Time: 25.96900510787964
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9062860613216688
#  Precision: 0.935307993310976
#  Time: 17.7272846698761
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9109956393577948
#  Precision: 0.9376625982172542
#  Time: 18.43922781944275
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9032652774722123
#  Precision: 0.9328667304843645
#  Time: 18.490015506744385
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9053345497025466
#  Precision: 0.935539005303001
#  Time: 19.52782368659973
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.905650096543441
#  Precision: 0.9354492953660025
#  Time: 18.643455982208252
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9121293334088248
#  Precision: 0.9382378750414448
#  Time: 18.624831438064575
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9098692834029037
#  Precision: 0.9382090805950434
#  Time: 18.325926065444946
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.905825533663315
#  Precision: 0.9353741328156315
#  Time: 18.463636875152588
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9113832439681266
#  Precision: 0.9378942689405835
#  Time: 18.80928683280945
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.908260060336528
#  Precision: 0.937326697411409
#  Time: 18.35637664794922
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9086795791533697
#  Precision: 0.9363239450369889
#  Time: 18.95947003364563
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9093712503562934
#  Precision: 0.9373036769386895
#  Time: 18.369667530059814
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9070686762941381
#  Precision: 0.9367361294131215
#  Time: 18.757048845291138
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9084036724136431
#  Precision: 0.9359701237292344
#  Time: 19.019357919692993
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9082010372815943
#  Precision: 0.9368170860735427
#  Time: 18.3378586769104
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.909551956052781
#  Precision: 0.9367073787460154
#  Time: 18.20130705833435
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9087847970040797
#  Precision: 0.9367248457236934
#  Time: 18.441869974136353
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9081264132628912
#  Precision: 0.9352909885866876
#  Time: 18.59605646133423
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9108127993204185
#  Precision: 0.9374991310287284
#  Time: 19.715709447860718
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9112677772606169
#  Precision: 0.9386579080887701
#  Time: 19.3536274433136
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9075671310476472
#  Precision: 0.9358506639216579
#  Time: 18.521262645721436
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9045777380410819
#  Precision: 0.9342667740785626
#  Time: 18.526253938674927
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9093019629635453
#  Precision: 0.9375035746075413
#  Time: 18.466466903686523
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9057292188839392
#  Precision: 0.9354237159655114
#  Time: 18.360395669937134
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9076815307092627
#  Precision: 0.9353524773389035
#  Time: 18.455765962600708
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.910260700637236
#  Precision: 0.9374245196084277
#  Time: 18.226224184036255
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.911642605883846
#  Precision: 0.938703456032491
#  Time: 17.829126596450806
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9031655991963566
#  Precision: 0.9343645132190157
#  Time: 18.156508445739746
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9085618687994782
#  Precision: 0.936622321948833
#  Time: 17.95041513442993
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9050142398144401
#  Precision: 0.9345545869212907
#  Time: 17.53122615814209
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9044615667487594
#  Precision: 0.9343159365789542
#  Time: 17.928475618362427
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9040592615021783
#  Precision: 0.9342582551884877
#  Time: 17.948482036590576
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9133650065066743
#  Precision: 0.9380474705199751
#  Time: 17.883671522140503
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9030790462415792
#  Precision: 0.9333436052738522
#  Time: 17.917816638946533
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9114276996188555
#  Precision: 0.9373014547615033
#  Time: 18.626959323883057
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9068274274429816
#  Precision: 0.9356852976542839
#  Time: 18.971802473068237
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9072484301911993
#  Precision: 0.9363221346260047
#  Time: 18.106590509414673
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9084431453528394
#  Precision: 0.9372342163104725
#  Time: 18.659887313842773
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9093722518278458
#  Precision: 0.9360059132896257
#  Time: 18.331862211227417
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9061253532631579
#  Precision: 0.9348517042661684
#  Time: 17.94972848892212
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9065457662439274
#  Precision: 0.9358121440877996
#  Time: 18.461413860321045
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.906598124651148
#  Precision: 0.9350496427663226
#  Time: 19.942209720611572
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9087470255734497
#  Precision: 0.9360818369377663
#  Time: 18.70553231239319
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9059307111602226
#  Precision: 0.9345087567262234
#  Time: 18.908310413360596
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9090282370292595
#  Precision: 0.93769097959826
#  Time: 19.128516912460327
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9065874340294674
#  Precision: 0.9363607002505998
#  Time: 18.54038953781128
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9073503734497086
#  Precision: 0.9349399656078181
#  Time: 19.990389347076416
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9069440985159747
#  Precision: 0.9352658318262935
#  Time: 19.511073350906372
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9063145503238159
#  Precision: 0.9358567238239728
#  Time: 18.59681987762451
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9055991480397831
#  Precision: 0.9345746653294454
#  Time: 19.20200777053833
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9051659887698054
#  Precision: 0.9354646119333039
#  Time: 20.911166191101074
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9097703295823806
#  Precision: 0.9380751211237461
#  Time: 18.827509880065918
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9078285073674568
#  Precision: 0.9364458006745311
#  Time: 18.67741632461548
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9048857062272119
#  Precision: 0.9350537388455142
#  Time: 19.00378108024597
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9071419209970693
#  Precision: 0.9361587767470478
#  Time: 19.74252223968506
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9075074068089817
#  Precision: 0.9363309834326825
#  Time: 18.436259984970093
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9107201545457593
#  Precision: 0.9377223705924175
#  Time: 19.04401421546936
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9077463568339729
#  Precision: 0.9358741234639076
#  Time: 19.405285120010376
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9078645539331781
#  Precision: 0.9359699211117264
#  Time: 19.767165184020996
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9067547786722944
#  Precision: 0.935802276496677
#  Time: 19.97195816040039
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9082007041410723
#  Precision: 0.9360506820003303
#  Time: 19.94677424430847
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9103723431214896
#  Precision: 0.9368819476505186
#  Time: 18.956027507781982
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9062729182141369
#  Precision: 0.9365873860062168
#  Time: 19.21936583518982
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9080764200984084
#  Precision: 0.9373759697437789
#  Time: 19.212751865386963
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9079363363377786
#  Precision: 0.9352732016618247
#  Time: 18.958901166915894
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9094058051932281
#  Precision: 0.9367154608502821
#  Time: 18.634624004364014
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9088232761453785
#  Precision: 0.9369980568864141
#  Time: 18.253411293029785
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9079499754819396
#  Precision: 0.9352493289185411
#  Time: 28.80539584159851
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9062246746799532
#  Precision: 0.935085711664625
#  Time: 18.61384606361389
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9108958940446
#  Precision: 0.9381198326270583
#  Time: 19.51456880569458
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9262586840181977
#  Precision: 0.9484017472617396
#  Time: 22.10103988647461
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9225416602468376
#  Precision: 0.9471672760959359
#  Time: 21.94655203819275
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9252883170043485
#  Precision: 0.9477958484350233
#  Time: 22.09971284866333
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9181625917326628
#  Precision: 0.9439245685884056
#  Time: 22.501906633377075
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9255957877434604
#  Precision: 0.9474835724855952
#  Time: 22.128065586090088
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9273985304074746
#  Precision: 0.9486365681460165
#  Time: 22.32691264152527
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9236216176636074
#  Precision: 0.9472387243032038
#  Time: 22.647075176239014
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9242414606330696
#  Precision: 0.9468810413103258
#  Time: 22.220783710479736
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9245665394168179
#  Precision: 0.9474559412247335
#  Time: 22.027268409729004
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.922847872243906
#  Precision: 0.9467459703504043
#  Time: 25.12157416343689
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9256317458603951
#  Precision: 0.9483619265369452
#  Time: 22.819794178009033
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9225990406681562
#  Precision: 0.9460230735878641
#  Time: 22.07502031326294
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9244249056548699
#  Precision: 0.9468240611030088
#  Time: 21.609203338623047
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9231157112463089
#  Precision: 0.9467651874422602
#  Time: 22.27699637413025
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9249157125187304
#  Precision: 0.9474549608341892
#  Time: 21.96782898902893
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9233799127645382
#  Precision: 0.9461076391572598
#  Time: 21.984084606170654
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9222477424696973
#  Precision: 0.9469655156990558
#  Time: 21.986681699752808
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.922049248085849
#  Precision: 0.9454956424235768
#  Time: 21.70016646385193
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9223913434625581
#  Precision: 0.945642708523564
#  Time: 21.310941696166992
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9236758500383169
#  Precision: 0.9470165764385647
#  Time: 21.74698829650879
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9199969279464237
#  Precision: 0.9455094376367531
#  Time: 21.772573232650757
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9217543686382347
#  Precision: 0.9455154228148039
#  Time: 21.44450044631958
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9247806982218437
#  Precision: 0.9473578451901208
#  Time: 21.493178129196167
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9217452621378008
#  Precision: 0.9457890682598651
#  Time: 21.424495220184326
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9253281350412537
#  Precision: 0.9469896753749342
#  Time: 21.773682117462158
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9246741743242382
#  Precision: 0.9479111428006222
#  Time: 21.609862565994263
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9258556145939506
#  Precision: 0.9471021189796109
#  Time: 22.365809202194214
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9240006674434158
#  Precision: 0.9471029834882472
#  Time: 21.204578638076782
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9200193435550903
#  Precision: 0.9448833632636319
#  Time: 21.66242814064026
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9253707118415716
#  Precision: 0.948152350946287
#  Time: 22.11530375480652
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9213380621082999
#  Precision: 0.9453933864423998
#  Time: 22.230066299438477
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9256683042994351
#  Precision: 0.9490954251784869
#  Time: 22.07947874069214
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.925999583567458
#  Precision: 0.9483935387882724
#  Time: 22.147215843200684
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9203452812649252
#  Precision: 0.9450557274318458
#  Time: 22.026818990707397
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9256392723388307
#  Precision: 0.9481105410276215
#  Time: 22.10058617591858
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9206691576888174
#  Precision: 0.9439652202418807
#  Time: 23.245092391967773
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9248594660310585
#  Precision: 0.9473505961151559
#  Time: 23.245516300201416
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9216040024512574
#  Precision: 0.9454638735939513
#  Time: 21.62135148048401
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9234275544050338
#  Precision: 0.9460632461853186
#  Time: 21.964988708496094
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9210981374477626
#  Precision: 0.9454075998198328
#  Time: 24.76223635673523
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9251143902964036
#  Precision: 0.9477581383925457
#  Time: 21.597391605377197
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9239268000192815
#  Precision: 0.947197278865008
#  Time: 21.62714433670044
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9267478193860935
#  Precision: 0.9491667588989724
#  Time: 21.3862783908844
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9226041695554864
#  Precision: 0.9459958806654563
#  Time: 21.69963312149048
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9239746594804459
#  Precision: 0.9462748999352639
#  Time: 21.540459632873535
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9211219596206116
#  Precision: 0.9448777153215722
#  Time: 21.363813638687134
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9219593575557252
#  Precision: 0.9457675640929204
#  Time: 25.920902013778687
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9260806990127775
#  Precision: 0.9469105371947761
#  Time: 21.111205339431763
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9233119050543175
#  Precision: 0.9466661668975032
#  Time: 21.409627199172974
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9236015334641746
#  Precision: 0.9460302267767339
#  Time: 21.111298322677612
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9208002955181228
#  Precision: 0.9451399703702978
#  Time: 21.753983736038208
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9223819177389478
#  Precision: 0.9458328344343281
#  Time: 21.75896167755127
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.924647141256312
#  Precision: 0.9473390309690939
#  Time: 22.0292706489563
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9220982735491104
#  Precision: 0.9467605435175578
#  Time: 21.76282286643982
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9263691568363064
#  Precision: 0.9474983487927413
#  Time: 21.385351419448853
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9257386880086401
#  Precision: 0.9474392620409092
#  Time: 21.62768006324768
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.923645612358948
#  Precision: 0.9466909304794638
#  Time: 21.94349980354309
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9230534427417109
#  Precision: 0.9462392065161915
#  Time: 21.488861560821533
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.921976784136634
#  Precision: 0.9454143590498445
#  Time: 21.211442470550537
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9244746826333928
#  Precision: 0.946767173604502
#  Time: 21.922334671020508
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9210565497795582
#  Precision: 0.9460279432051503
#  Time: 21.984848260879517
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9248144254001778
#  Precision: 0.9476100095515021
#  Time: 21.62099528312683
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9224862121805191
#  Precision: 0.9450059997638767
#  Time: 21.953933238983154
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9217522224434627
#  Precision: 0.9458892107449144
#  Time: 21.655008792877197
# ===========================
#
# ...
#  Results:
#  AUC_PR: 0.9295652219199089
#  Precision: 0.9522409466405164
#  Time: 132.8068985939026
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment45.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9309808570082125
#  Precision: 0.9524671897988365
#  Time: 131.71847915649414
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9282589663037362
#  Precision: 0.9519681249528693
#  Time: 132.2544674873352
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9307576281433714
#  Precision: 0.9521771344373828
#  Time: 132.12562346458435
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment48.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9336235275315311
#  Precision: 0.9543945217580028
#  Time: 131.61436700820923
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9279891519484879
#  Precision: 0.9513425313162089
#  Time: 133.02848935127258
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment0.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9297232209894489
#  Precision: 0.9521918672065607
#  Time: 130.8235285282135
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment1.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9253812090621294
#  Precision: 0.9505208194111953
#  Time: 131.53065133094788
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment2.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9323185222718567
#  Precision: 0.952936416663255
#  Time: 132.67927861213684
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment3.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9267957705045444
#  Precision: 0.9501293598660243
#  Time: 133.08464860916138
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment4.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9319464138488253
#  Precision: 0.9531984024307496
#  Time: 132.09673714637756
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment5.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9291241531980114
#  Precision: 0.9518421540228895
#  Time: 131.68083786964417
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment6.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9247583412277405
#  Precision: 0.9493254496149192
#  Time: 130.35385584831238
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment7.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9301056866277843
#  Precision: 0.9524469964727049
#  Time: 131.7564299106598
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment8.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9312590128093836
#  Precision: 0.9531705129417538
#  Time: 130.32481360435486
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment9.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9309325645719609
#  Precision: 0.952378314206569
#  Time: 136.44820380210876
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment10.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9301315413716529
#  Precision: 0.9533672038431513
#  Time: 131.0485599040985
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment11.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9255897285950317
#  Precision: 0.9502909726634814
#  Time: 132.5074484348297
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment12.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9316288287273937
#  Precision: 0.9516861195733031
#  Time: 132.35838913917542
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment13.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9298266747778514
#  Precision: 0.9522201941421451
#  Time: 132.06267094612122
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment14.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9274592435518506
#  Precision: 0.9506698808909907
#  Time: 131.82289743423462
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment15.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9289866375574024
#  Precision: 0.9518623445400344
#  Time: 129.5587875843048
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment16.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9267939950498333
#  Precision: 0.9502516443214633
#  Time: 133.69359946250916
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment17.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9271479529922517
#  Precision: 0.9507500653506697
#  Time: 134.24173665046692
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment18.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9277126795823678
#  Precision: 0.9504573586462932
#  Time: 132.04440593719482
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment19.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9298012325240613
#  Precision: 0.9518162815995799
#  Time: 130.61771845817566
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment20.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9273522850753455
#  Precision: 0.9516656688017038
#  Time: 130.6073660850525
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment21.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9258066227677569
#  Precision: 0.9505665075098401
#  Time: 132.85157823562622
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment22.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9267868595131197
#  Precision: 0.9507132949616897
#  Time: 130.81647610664368
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment23.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9297370704033808
#  Precision: 0.952033448586143
#  Time: 129.24092864990234
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment24.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9284834998891501
#  Precision: 0.9517861579825759
#  Time: 129.66257190704346
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment25.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9330966294505583
#  Precision: 0.9547778125074415
#  Time: 129.5780439376831
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment26.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9300293357514983
#  Precision: 0.9525178206603347
#  Time: 129.27667665481567
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment27.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9293227948494586
#  Precision: 0.9510691958507258
#  Time: 128.235990524292
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment28.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9288685078755835
#  Precision: 0.9513273777438475
#  Time: 127.9575514793396
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment29.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9291281124432984
#  Precision: 0.9514509482875515
#  Time: 126.51386499404907
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment30.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9291849614327152
#  Precision: 0.9516271867779701
#  Time: 128.19983386993408
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment31.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9306951333373757
#  Precision: 0.9531718180698098
#  Time: 127.692538022995
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment32.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9289284438370314
#  Precision: 0.9518408753820099
#  Time: 127.4267270565033
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment33.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.932512902456891
#  Precision: 0.9535715549434669
#  Time: 126.70210433006287
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment34.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9325102423436776
#  Precision: 0.9537666525341653
#  Time: 127.7836127281189
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment35.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9312471373070212
#  Precision: 0.9528924502493148
#  Time: 129.65253329277039
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment36.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9311798357444661
#  Precision: 0.952997270094432
#  Time: 130.0236999988556
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment37.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9268616171204666
#  Precision: 0.9502799241104154
#  Time: 126.61190438270569
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment38.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9341836084702653
#  Precision: 0.9544166883314698
#  Time: 128.8077850341797
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment39.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9281986985669527
#  Precision: 0.951639665986306
#  Time: 126.92991161346436
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment40.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9316866625186655
#  Precision: 0.9526094684627034
#  Time: 128.52199959754944
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment41.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.928511872723462
#  Precision: 0.9507931662838006
#  Time: 126.73275446891785
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment42.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9285900517301166
#  Precision: 0.9518711227735307
#  Time: 126.61430144309998
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment43.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9296588385991034
#  Precision: 0.9516526724063459
#  Time: 125.67516565322876
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment44.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9304329873415256
#  Precision: 0.9520729057534489
#  Time: 127.5428056716919
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment45.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9294888587196317
#  Precision: 0.9515311646182735
#  Time: 126.98328876495361
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9291535201386831
#  Precision: 0.9519839205082272
#  Time: 126.42061805725098
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9280324406302448
#  Precision: 0.9507714272209538
#  Time: 127.69569540023804
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-3/cols_set_2/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9323093432047466
#  Precision: 0.9527436579675539
#  Time: 128.5208055973053
# ===========================

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
for i in range(len(experiments)):
    for d in list(experiments[i].keys()):
        experiments[i][d] = str(experiments[i][d])

# %%
# experiments

# %%
cols = ['experiment_filter', 'undersampling_method', 'filename', 'experiment_id', 'n_covid', 'n_not_covid', 'model_name', 'params', 'model_AUC_ROC', 'model_AUC_PR', 'model_covid_precision', 'model_covid_recall', 'model_covid_f1', 'model_not_covid_precision', 'model_not_covid_recall', 'model_not_covid_f1', 'model_avg_precision', 'model_avg_recall', 'model_avg_f1', 'model_avg_acc', 'model_TP', 'model_TN', 'model_FN', 'model_FP', 'model_time_exec', 'model_col_set']

# %%
intermed_results = spark.createDataFrame(data=experiments).select(cols)
intermed_results.toPandas()
# Out:
# /usr/lib/spark/python/pyspark/sql/session.py:346: UserWarning: inferring schema from dict is deprecated,please use pyspark.sql.Row instead
#   warnings.warn("inferring schema from dict is deprecated,"

# %%
intermed_results.write.parquet('gs://ai-covid19-datalake/trusted/intermed_results/STRSAMP/GBT_experiments-AG-ds3-cs2.parquet', mode='overwrite')

# %%
print('finished')
# Out:
# finished

# %%
intermed_results.show()
# Out:
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# |experiment_filter|undersampling_method|            filename|experiment_id|n_covid|n_not_covid|model_name|              params|     model_AUC_ROC|      model_AUC_PR|model_covid_precision|model_covid_recall|    model_covid_f1|model_not_covid_precision|model_not_covid_recall|model_not_covid_f1|model_avg_precision|  model_avg_recall|      model_avg_f1|     model_avg_acc|model_TP|model_TN|model_FN|model_FP|   model_time_exec|model_col_set|
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|            0|  76008|      44538|       GBT|{'maxIter': 20, '...|0.9203104102211102|0.9079510001445159|   0.9275459659138612|0.9708260105448154|0.9486926280537546|       0.9455469903231097|     0.869794809897405| 0.906090373280943| 0.9365464781184855|0.9203104102211102|0.9273915006673488|0.9336406041759218|   22096|   11530|     664|    1726|27.704296588897705|   cols_set_2|
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|            1|  76098|      44538|       GBT|{'maxIter': 20, '...|0.9196156681676722|0.9045204802118015|   0.9277919471505623|0.9684881284916201|0.9477033462170877|       0.9415668501133053|    0.8707432078437243| 0.904771163043901| 0.9346793986319338|0.9196156681676722|0.9262372546304944|0.9324842169106498|   22190|   11634|     722|    1727|19.893548727035522|   cols_set_2|
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|            2|  76542|      44538|       GBT|{'maxIter': 20, '...|0.9207435618893842|0.9086499315745207|    0.928311107429802|   0.9716081491114|0.9494662826160623|       0.9464300318966222|    0.8698789746673683|0.9065413239326282| 0.9373705696632122|0.9207435618893842|0.9280038032743452|0.9344018915129354|   22415|   11572|     655|    1731| 19.63073468208313|   cols_set_2|
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|            3|  75793|      44538|       GBT|{'maxIter': 20, '...|0.9208883729112135|0.9089844588185542|   0.9267235939931856|0.9700158506516379|0.9478756588146715|       0.9456200590912721|    0.8717608951707891|0.9071896426245835| 0.9361718265422289|0.9208883729112135|0.9275326507196275|0.9332433325986335|   22031|   11842|     681|    1742|20.760419607162476|   cols_set_2|
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|            4|  74465|      44538|       GBT|{'maxIter': 20, '...| 0.922246294229571|0.9111622879972517|   0.9269058100509959|0.9701199762784545|0.9480206847360912|       0.9468646061491036|    0.8743726121806877|0.9091758840940958| 0.9368852081000498| 0.922246294229571|0.9285982844150935|0.9338814856818827|   21266|   11672|     655|    1677|18.910874366760254|   cols_set_2|
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|            5|  74906|      44538|       GBT|{'maxIter': 20, '...|0.9227148535000137|0.9109964089728464|   0.9293326566861203|0.9716572338167669|0.9500237776144569|       0.9474934469200524|    0.8737724731832603|0.9091409258822605| 0.9384130518030864|0.9227148535000136|0.9295823517483587|0.9355162603893569|   21975|   11567|     641|    1671|20.753438234329224|   cols_set_2|
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|            6|  75869|      44538|       GBT|{'maxIter': 20, '...|0.9219166405366165| 0.907892142645365|   0.9294700724361418|0.9697692919649961|0.9491921354876387|       0.9441176470588235|    0.8740639891082369|0.9077412513255567| 0.9367938597474826|0.9219166405366165|0.9284666934065977| 0.934471503891539|   21942|   11556|     684|    1665|18.979822635650635|   cols_set_2|
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|            7|  75764|      44538|       GBT|{'maxIter': 20, '...|0.9213550739514778|0.9087619485118874|   0.9280040348001513| 0.970250911807356|0.9486573576799141|         0.94538120209762|    0.8724592360955997| 0.907457600867343| 0.9366926184488856|0.9213550739514779|0.9280574792736285|0.9339560075163037|   22080|   11718|     677|    1713|18.656402349472046|   cols_set_2|
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|            8|  75929|      44538|       GBT|{'maxIter': 20, '...|0.9201075801274464| 0.906899063392371|   0.9275520483546004| 0.970018875378605|0.9483102671387189|       0.9442630977639954|    0.8701962848762879|0.9057179758130797| 0.9359075730592978|0.9201075801274464|0.9270141214758993|0.9332280059870282|   22098|   11571|     683|    1726| 18.51894187927246|   cols_set_2|
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|            9|  75880|      44538|       GBT|{'maxIter': 20, '...|  0.92106061561078|0.9071052088747619|   0.9281434599156119|0.9690308370044053|0.9481465517241379|       0.9433931878573154|    0.8730903942171547|0.9068813375648269| 0.9357683238864636|  0.92106061561078|0.9275139446444824|0.9333868601013318|   21997|   11716|     703|    1703| 19.39965009689331|   cols_set_2|
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|           10|  76773|      44538|       GBT|{'maxIter': 20, '...|0.9218988612853622|0.9062865310938698|   0.9313692946058091|0.9701344167350996|0.9503567118995702|        0.943029103800808|    0.8736633058356248|0.9070219261726339| 0.9371991992033085|0.9218988612853622|0.9286893190361021|0.9352728477186784|   22446|   11438|     691|    1654|18.427087545394897|   cols_set_2|
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|           11|  75938|      44538|       GBT|{'maxIter': 20, '...|0.9202831023286421|0.9060444751625383|   0.9280590541329552| 0.969249531774032|0.9482071713147411|       0.9430001614726304|    0.8713166728832525|0.9057423132100346| 0.9355296078027928|0.9202831023286422|0.9269747422623879|0.9331481685183148|   22253|   11680|     706|    1725|18.760917901992798|   cols_set_2|
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|           12|  74219|      44538|       GBT|{'maxIter': 20, '...|0.9228851308775954| 0.909918501643018|   0.9289999143028537|0.9696766402790823|0.9489025537781474|        0.945296111021462|    0.8760936214761086|0.9093802150036869| 0.9371480126621579|0.9228851308775954|0.9291413843909171|0.9346524124034479|   21681|   11716|     678|    1657|  18.4181489944458|   cols_set_2|
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|           13|  75346|      44538|       GBT|{'maxIter': 20, '...|0.9192717696281465|0.9039140256990719|   0.9273050395633224|0.9678915290168713|0.9471636952998379|       0.9408510292083638|    0.8706520102394217|0.9043913502522192| 0.9340780343858431|0.9192717696281465|0.9257775227760285|0.9319396503730097|   21915|   11564|     727|    1718| 19.11789631843567|   cols_set_2|
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|           14|  75248|      44538|       GBT|{'maxIter': 20, '...|0.9181965484606316|0.9052421834975578|   0.9255002307143756| 0.969546493232554|0.9470114819186608|       0.9434516523867809|    0.8668466036887089|0.9035283085218615| 0.9344759415505782|0.9181965484606315|0.9252698952202612|0.9315952789937386|   22063|   11562|     693|    1776|18.903894424438477|   cols_set_2|
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|           15|  74762|      44538|       GBT|{'maxIter': 20, '...|0.9191317999889479|0.9041613354212248|   0.9263983050847457|0.9673893805309735|0.9464502164502164|       0.9408127208480566|    0.8708742194469223|0.9044935145151327| 0.9336055129664012|0.9191317999889479|0.9254718654826746|0.9313769000332852|   21863|   11715|     737|    1737|20.233166456222534|   cols_set_2|
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|           16|  75621|      44538|       GBT|{'maxIter': 20, '...|0.9212466125117311| 0.906715145154714|   0.9288592881686676|0.9690210656753407|0.9485152374970217|       0.9429828133908935|    0.8734721593481213|0.9068974971603149| 0.9359210507797806| 0.921246612511731|0.9277063673286683|0.9336959553695955|   21896|   11577|     700|    1677|18.760483026504517|   cols_set_2|
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|           17|  75031|      44538|       GBT|{'maxIter': 20, '...|0.9197746267210647| 0.906929402448953|   0.9265434691306174|0.9695864281633191| 0.947576401864141|        0.944162026950698|    0.8699628252788104|0.9055450218627868| 0.9353527480406576|0.9197746267210647| 0.926560711863464| 0.932574648509792|   22061|   11701|     692|    1749|   19.266437292099|   cols_set_2|
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|           18|  75151|      44538|       GBT|{'maxIter': 20, '...|0.9199777844661613|0.9063017108509221|   0.9275203440570056|0.9695447132971925|0.9480670602939276|       0.9435319114161967|      0.87041085563513|0.9054976080307425| 0.9355261277366012|0.9199777844661612|0.9267823341623351|0.9329699059909885|   21998|   11546|     691|    1719| 18.64596438407898|   cols_set_2|
# |             ds-3|       03-STRSAMP-AG|gs://ai-covid19-d...|           19|  75145|      44538|       GBT|{'maxIter': 20, '...|0.9224699057653261|0.9083672721904958|   0.9289610500298304|0.9685861548031636|0.9483598712259637|       0.9435393707075547|    0.8763536567274886|0.9087063528687895| 0.9362502103686925|0.9224699057653261|0.9285331120473765|0.9340335667444704|   21799|   11815|     707|    1667|18.815521478652954|   cols_set_2|
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# only showing top 20 rows
