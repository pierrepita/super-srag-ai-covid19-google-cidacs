# %%
import pandas as pd
import pyspark.sql.functions as F
from datetime import datetime
from pyspark.sql.types import *
from pyspark import StorageLevel

import numpy as np
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", 1000)
pd.set_option("mode.chained_assignment", None)

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import GBTClassifier
from pyspark.ml.feature import IndexToString, StringIndexer, VectorIndexer
# from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import OneHotEncoderEstimator, StringIndexer, VectorAssembler

from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

from pyspark.sql import Row
from pyspark.ml.linalg import Vectors

# %%
# !pip install scikit-plot

# %%
import sklearn
import scikitplot as skplt
from sklearn.metrics import classification_report, confusion_matrix, precision_score

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
result_schema = StructType([
                    StructField('experiment_filter', StringType(), True),
                    StructField('undersampling_method', StringType(), True),
                    StructField('undersampling_column', StringType(), True),
                    StructField('filename', StringType(), True),
                    StructField('experiment_id', StringType(), True),
                    StructField('n_covid', IntegerType(), True),
                    StructField('n_not_covid', IntegerType(), True),
                    StructField('model_name', StringType(), True),
                    StructField('model_seed', StringType(), True),
                    StructField('model_maxIter', IntegerType(), True),
                    StructField('model_maxDepth', IntegerType(), True),
                    StructField('model_maxBins', IntegerType(), True),
                    StructField('model_minInstancesPerNode', IntegerType(), True),
                    StructField('model_minInfoGain', FloatType(), True),
                    StructField('model_featureSubsetStrategy', StringType(), True),
                    StructField('model_n_estimators', IntegerType(), True),
                    StructField('model_learning_rate', FloatType(), True),
                    StructField('model_impurity', StringType(), True),
                    StructField('model_AUC_ROC', StringType(), True),
                    StructField('model_AUC_PR', StringType(), True),
                    StructField('model_covid_precision', StringType(), True),
                    StructField('model_covid_recall', StringType(), True),
                    StructField('model_covid_f1', StringType(), True),
                    StructField('model_not_covid_precision', StringType(), True),
                    StructField('model_not_covid_recall', StringType(), True),
                    StructField('model_not_covid_f1', StringType(), True),
                    StructField('model_avg_precision', StringType(), True),
                    StructField('model_avg_recall', StringType(), True),
                    StructField('model_avg_f1', StringType(), True),
                    StructField('model_avg_acc', StringType(), True),
                    StructField('model_TP', StringType(), True),
                    StructField('model_TN', StringType(), True),
                    StructField('model_FN', StringType(), True),
                    StructField('model_FP', StringType(), True),
                    StructField('model_time_exec', StringType(), True),
                    StructField('model_col_set', StringType(), True)
                          ])

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# undersamp_col = ['03-STRSAMP-AG', '04-STRSAMP-EW'] 
# dfs = ['ds-1', 'ds-2', 'ds-3']
# cols_sets = ['cols_set_1', 'cols_set_2', 'cols_set_3']

undersamp_col = ['02-KMODES']
dfs = ['ds-3']
cols_sets = ['cols_set_2']

# %%
# lists of params
model_maxIter = [20, 50, 100] 
model_maxDepth = [3, 5, 7] 
model_maxBins = [32, 64] 
# model_learningRate = [0.01, 0.1, 0.5]
# model_loss = ['logLoss', 'leastSquaresError', 'leastAbsoluteError']



list_of_param_dicts = []

for maxIter in model_maxIter:
    for maxDepth in model_maxDepth:
        for maxBins in model_maxBins: 
            params_dict = {}
            params_dict['maxIter'] = maxIter
            params_dict['maxDepth'] = maxDepth
            params_dict['maxBins'] = maxBins
            list_of_param_dicts.append(params_dict)

print("There is {} set of params.".format(len(list_of_param_dicts)))
# list_of_param_dicts
# Out:
# There is 18 set of params.

# %%
prefix = 'gs://ai-covid19-datalake/trusted/experiment_map/'

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# filename = 'gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment0.parquet'
# df = spark.read.parquet(filename)
# df.limit(2).toPandas()

# %%
# params_dict = {'maxIter': 100,
#                'maxDepth': 3,
#                'maxBins': 32,
#                'learningRate': 0.5,
#                'loss': 'leastAbsoluteError'}
# cols = 'cols_set_1'
# experiment_filter = 'ds-1'
# undersampling_method = '03-STRSAMP-AG', 
# experiment_id = 0

# %%
# run_gbt(df, params_dict, cols, filename, experiment_filter, undersampling_method, experiment_id)

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
def run_gbt(exp_df, params_dict, cols, filename, experiment_filter, 
            undersampling_method, experiment_id):
    import time
    start_time = time.time()
    
    n_covid = exp_df.filter(F.col('CLASSI_FIN') == 1.0).count()
    n_not_covid = exp_df.filter(F.col('CLASSI_FIN') == 0.0).count()
    
    
    id_cols = ['NU_NOTIFIC', 'CLASSI_FIN']

    labelIndexer = StringIndexer(inputCol="CLASSI_FIN", outputCol="indexedLabel").fit(exp_df)    
    
    input_cols = [x for x in exp_df.columns if x not in id_cols]
    assembler = VectorAssembler(inputCols = input_cols, outputCol= 'features')
    exp_df = assembler.transform(exp_df)
    
    # Automatically identify categorical features, and index them.
    # Set maxCategories so features with > 4 distinct values are treated as continuous.
    featureIndexer = VectorIndexer(inputCol="features", outputCol="indexedFeatures", maxCategories=30).fit(exp_df)
    
    # Split the data into training and test sets (30% held out for testing)
    (trainingData, testData) = exp_df.randomSplit([0.7, 0.3])
    trainingData = trainingData.persist(StorageLevel.MEMORY_ONLY)
    testData = testData.persist(StorageLevel.MEMORY_ONLY)
    
    # Train a RandomForest model.
    gbt = GBTClassifier(labelCol = "indexedLabel", featuresCol = "indexedFeatures",
                       maxIter = params_dict['maxIter'],
                       maxDepth = params_dict['maxDepth'],
                       maxBins = params_dict['maxBins'])
    
    # Convert indexed labels back to original labels.
    labelConverter = IndexToString(inputCol="prediction", outputCol="predictedLabel",
                               labels=labelIndexer.labels)

    # Chain indexers and forest in a Pipeline
    pipeline = Pipeline(stages=[labelIndexer, featureIndexer, gbt, labelConverter])

    # Train model.  This also runs the indexers.
    model = pipeline.fit(trainingData)
    
    # Make predictions.
    predictions = model.transform(testData)    
    
    
    pred = predictions.select(['CLASSI_FIN', 'predictedLabel'])\
                  .withColumn('predictedLabel', F.col('predictedLabel').cast('double'))\
                  .withColumn('predictedLabel', F.when(F.col('predictedLabel') == 1.0, 'covid').otherwise('n-covid'))\
                  .withColumn('CLASSI_FIN', F.when(F.col('CLASSI_FIN') == 1.0, 'covid').otherwise('n-covid'))\
                  .toPandas()

    y_true = pred['CLASSI_FIN'].tolist()
    y_pred = pred['predictedLabel'].tolist()
    
    report = classification_report(y_true, y_pred, output_dict=True)
    
    
    evaluator_ROC = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderROC")
    accuracy_ROC = evaluator_ROC.evaluate(predictions)


    
    evaluator_PR = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderPR")
    accuracy_PR = evaluator_PR.evaluate(predictions)
    
    conf_matrix = confusion_matrix(y_true, y_pred)

    result_dict = {}
    
    result_dict['experiment_filter'] = experiment_filter
    result_dict['undersampling_method'] = undersampling_method
    result_dict['filename'] = filename
    result_dict['experiment_id'] = experiment_id
    result_dict['n_covid'] = n_covid
    result_dict['n_not_covid'] = n_not_covid
    result_dict['model_name'] = 'GBT'
    result_dict['params'] = params_dict
    result_dict['model_AUC_ROC'] = accuracy_ROC
    result_dict['model_AUC_PR'] = accuracy_PR
    result_dict['model_covid_precision'] = report['covid']['precision']
    result_dict['model_covid_recall'] = report['covid']['recall']
    result_dict['model_covid_f1'] = report['covid']['f1-score']
    result_dict['model_not_covid_precision'] = report['n-covid']['precision']
    result_dict['model_not_covid_recall'] = report['n-covid']['recall']
    result_dict['model_not_covid_f1'] = report['n-covid']['f1-score']
    result_dict['model_avg_precision'] = report['macro avg']['precision']
    result_dict['model_avg_recall'] = report['macro avg']['recall']
    result_dict['model_avg_f1'] = report['macro avg']['f1-score']
    result_dict['model_avg_acc'] = report['accuracy']
    result_dict['model_TP'] = conf_matrix[0][0]
    result_dict['model_TN'] = conf_matrix[1][1]
    result_dict['model_FN'] = conf_matrix[0][1]
    result_dict['model_FP'] = conf_matrix[1][0]
    result_dict['model_time_exec'] = time.time() - start_time
    result_dict['model_col_set'] = cols
    
    return result_dict

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %% [markdown]
# # Running GBT on 10 samples for each experiment
# ### 3x col sets -> ['cols_set_1', 'cols_set_2', 'cols_set_3']
# ### 3x model_maxIter -> [100, 200, 300]
# ### 3x model_maxDepth -> [5, 10, 15]
# ### 3x model_maxBins -> [16, 32, 64]
# Total: 10 * 3 * 3 * 3 * 3 = 810

# %%
experiments = []

# %% [markdown]
# ### Datasets: strat_samp_lab_agegrp

# %%
for uc in undersamp_col: 
    for ds in dfs:
        for col_set in cols_sets:
            for params_dict in list_of_param_dicts: 
                for id_exp in range(50):
                    filename = prefix + uc + '/' + ds + '/' + col_set + '/' + 'experiment' + str(id_exp) + '.parquet'
                    exp_dataframe = spark.read.parquet(filename)
#                     if 'SG_UF_NOT' in exp_dataframe.columns:
#                         exp_dataframe = exp_dataframe.withColumn('SG_UF_NOT', F.col('SG_UF_NOT').cast('float'))
                    print('read {}'.format(filename))
                    
                    undersampling_method = uc
                    experiment_filter = ds
                    experiment_id = id_exp

                    try:                     
                        model = run_gbt(exp_dataframe, params_dict, col_set, filename, experiment_filter, undersampling_method, experiment_id)
                        experiments.append(model)

                        print("Parameters ==> {}\n Results: \n AUC_PR: {} \n Precision: {} \n Time: {}".format(str(params_dict), str(model['model_AUC_PR']), str(model['model_avg_precision']), str(model['model_time_exec'])))
                        print('=========================== \n')
                    except:
                        print('=========== W A R N I N G =========== \n')
                        print('Something wrong with the exp: {}, {}, {}'.format(filename, params_dict, col_set))
# Out:
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9308477327167839
#  Precision: 0.9297698319163815
#  Time: 52.453635454177856
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9307570933028291
#  Precision: 0.9296546986582098
#  Time: 42.1927490234375
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8910742562831765
#  Precision: 0.9295892758275315
#  Time: 40.59894561767578
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9328376922686006
#  Precision: 0.9313694300609969
#  Time: 42.64921569824219
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9325354428981197
#  Precision: 0.9292175189764879
#  Time: 40.2602379322052
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8905586513591662
#  Precision: 0.9278967369467405
#  Time: 40.40925145149231
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8926974172751823
#  Precision: 0.9309525890957835
#  Time: 39.79506969451904
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9311971732445201
#  Precision: 0.9316227580279682
#  Time: 40.710269927978516
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.887092427392059
#  Precision: 0.9264755162973031
#  Time: 39.44875955581665
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9351047953629215
#  Precision: 0.9335966650476717
#  Time: 39.82371520996094
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8903269837277148
#  Precision: 0.9281717105039411
#  Time: 39.460352659225464
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8907461785517597
#  Precision: 0.9277711784090473
#  Time: 38.937506914138794
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8883471704691029
#  Precision: 0.9290719652590267
#  Time: 39.743866205215454
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9347442443418962
#  Precision: 0.9301315199473732
#  Time: 39.63273549079895
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8850847124458517
#  Precision: 0.9275657567602492
#  Time: 39.64300203323364
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9331903636660797
#  Precision: 0.9306461359150453
#  Time: 41.57361674308777
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9284322023370621
#  Precision: 0.9294470250931577
#  Time: 42.11671805381775
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8901347094802468
#  Precision: 0.9291692991784166
#  Time: 44.00028085708618
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8886917438819079
#  Precision: 0.9288384340718425
#  Time: 39.62014675140381
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8906949343429875
#  Precision: 0.9261613180517362
#  Time: 40.141361474990845
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9309483386532549
#  Precision: 0.9302701686203222
#  Time: 39.11544847488403
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9283179899622988
#  Precision: 0.9283622727903215
#  Time: 40.2001097202301
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8891554959459885
#  Precision: 0.9281088607015602
#  Time: 40.805845975875854
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9284756896585327
#  Precision: 0.935097947797972
#  Time: 43.78189277648926
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8844414935809515
#  Precision: 0.9264296593856085
#  Time: 39.47406053543091
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9329767739407198
#  Precision: 0.9316086876438987
#  Time: 39.79072022438049
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8853489943070395
#  Precision: 0.9276704719624731
#  Time: 39.149110555648804
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8884041990263721
#  Precision: 0.9276713778470955
#  Time: 38.66251277923584
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9329926874394455
#  Precision: 0.932693725542364
#  Time: 41.74034118652344
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.883698967059933
#  Precision: 0.9261365439252649
#  Time: 41.707967042922974
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.890126046495436
#  Precision: 0.9304832407494585
#  Time: 41.092397689819336
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9307972405736297
#  Precision: 0.9323764654628247
#  Time: 40.319496393203735
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8883083976207636
#  Precision: 0.9285000332173196
#  Time: 39.63095712661743
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8939200982514566
#  Precision: 0.9306753261863957
#  Time: 40.26224112510681
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8902514464498417
#  Precision: 0.9290555666490095
#  Time: 41.380311250686646
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8912615838454669
#  Precision: 0.9297120278968447
#  Time: 42.2330846786499
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9372509398628055
#  Precision: 0.933923048506545
#  Time: 44.932905197143555
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.89242284122668
#  Precision: 0.9293216598579617
#  Time: 39.80176615715027
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8831353222880813
#  Precision: 0.9247697139900215
#  Time: 41.44617414474487
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.931252987226719
#  Precision: 0.9318376705251338
#  Time: 41.11948561668396
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8834998982515684
#  Precision: 0.9257556224856471
#  Time: 40.850802183151245
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9245052608623665
#  Precision: 0.9278091053643212
#  Time: 40.57650327682495
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8925031029280757
#  Precision: 0.9306904489287492
#  Time: 39.85797929763794
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9311293311185963
#  Precision: 0.9267976526956104
#  Time: 40.32024526596069
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.88883672223905
#  Precision: 0.9283309466284448
#  Time: 40.361493825912476
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9318787658212928
#  Precision: 0.9285417888230385
#  Time: 40.493163108825684
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.889988734906273
#  Precision: 0.9283971413458003
#  Time: 39.06309795379639
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8848854339244518
#  Precision: 0.9269987684088645
#  Time: 43.084978103637695
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8896529505095317
#  Precision: 0.9278211560019293
#  Time: 40.2219614982605
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8870035982394435
#  Precision: 0.9270203556471048
#  Time: 40.08600616455078
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9259763615006047
#  Precision: 0.9269755566746914
#  Time: 38.97794532775879
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9306231553376343
#  Precision: 0.9267740096752612
#  Time: 38.441330671310425
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.890304090184429
#  Precision: 0.9292205289539457
#  Time: 40.67614960670471
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9366398751755167
#  Precision: 0.9314738317912479
#  Time: 41.2962532043457
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9343795173720816
#  Precision: 0.9315349859513442
#  Time: 40.17280960083008
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8825375526061977
#  Precision: 0.9260927299251962
#  Time: 37.23493528366089
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8912431070579895
#  Precision: 0.929754626635318
#  Time: 37.50605773925781
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9277916723817029
#  Precision: 0.9306832927457178
#  Time: 38.740830421447754
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8867601354927015
#  Precision: 0.9259396535817859
#  Time: 38.415261030197144
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9309586964628909
#  Precision: 0.9286696295091517
#  Time: 40.147220849990845
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8910351380134351
#  Precision: 0.927899368592632
#  Time: 40.624995708465576
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8915044951135334
#  Precision: 0.9281435737235377
#  Time: 41.340327978134155
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8858443458408239
#  Precision: 0.9288293938549228
#  Time: 40.67167258262634
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9345962369296321
#  Precision: 0.9298489824310938
#  Time: 40.340740442276
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8875051516750739
#  Precision: 0.9280837708187251
#  Time: 38.79378795623779
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9308808135406625
#  Precision: 0.9283166075173799
#  Time: 38.86695837974548
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9290764417012476
#  Precision: 0.9309849746012486
#  Time: 40.100632190704346
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8843441885304766
#  Precision: 0.925304005629642
#  Time: 38.32866549491882
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8896336795618894
#  Precision: 0.9295957173035762
#  Time: 38.79033899307251
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8930160933384685
#  Precision: 0.9293824671634772
#  Time: 39.0723876953125
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9326408605962726
#  Precision: 0.9314975734204003
#  Time: 38.955965757369995
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.928694092953752
#  Precision: 0.9308482451498985
#  Time: 40.82478928565979
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8916795308869718
#  Precision: 0.9303542224735997
#  Time: 39.488970041275024
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9335885871552463
#  Precision: 0.9352745680186557
#  Time: 39.25099968910217
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8862111062262371
#  Precision: 0.9271776377613952
#  Time: 40.54150700569153
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9328398057999462
#  Precision: 0.9308719749308582
#  Time: 41.68997883796692
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8824755969856275
#  Precision: 0.9259013094811974
#  Time: 936.2937595844269
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8841050613292009
#  Precision: 0.9254917128388663
#  Time: 39.772082567214966
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9360458247752861
#  Precision: 0.9334624210101145
#  Time: 39.22925090789795
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8868620177817864
#  Precision: 0.9284707326307408
#  Time: 38.871941804885864
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8861168482217961
#  Precision: 0.9269500241319731
#  Time: 38.55993175506592
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9339806734960768
#  Precision: 0.9316424864302092
#  Time: 39.48073220252991
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8875217711571535
#  Precision: 0.9286631474699151
#  Time: 38.72695565223694
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8917914674962211
#  Precision: 0.931148396811927
#  Time: 39.24308180809021
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8899269149594946
#  Precision: 0.9286071077263394
#  Time: 39.786219120025635
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8922613353465292
#  Precision: 0.9291278103224854
#  Time: 39.287739753723145
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9327390414914126
#  Precision: 0.9305822362705007
#  Time: 38.5668203830719
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8892118441701956
#  Precision: 0.9280036195503596
#  Time: 41.048901319503784
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8799444404596131
#  Precision: 0.9230588180527084
#  Time: 39.04178762435913
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9310688339198337
#  Precision: 0.9354858271660893
#  Time: 39.45300793647766
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8838190993131079
#  Precision: 0.9258263688649642
#  Time: 39.42904210090637
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9293185205280552
#  Precision: 0.9314331445323561
#  Time: 38.72594118118286
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.89666930103269
#  Precision: 0.932582285033554
#  Time: 37.14552307128906
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9314349430860158
#  Precision: 0.9286290624751325
#  Time: 37.98942995071411
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8948778850146806
#  Precision: 0.931640694880082
#  Time: 38.69369459152222
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9323047856362398
#  Precision: 0.9302072911479361
#  Time: 39.82146906852722
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8892187531149082
#  Precision: 0.9271039328452393
#  Time: 38.968576431274414
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.883628655649991
#  Precision: 0.9263307009255068
#  Time: 39.24436664581299
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8875047351939205
#  Precision: 0.9279004031638186
#  Time: 39.99219369888306
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8869588740508811
#  Precision: 0.9271760529306841
#  Time: 38.89162087440491
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9359620942771318
#  Precision: 0.936772032576686
#  Time: 43.11945366859436
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9350010462767563
#  Precision: 0.9331482335327681
#  Time: 44.31140422821045
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9062621471004598
#  Precision: 0.9382423862108185
#  Time: 46.34133577346802
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9382150526303992
#  Precision: 0.9349528511728445
#  Time: 44.22919964790344
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9410987546599132
#  Precision: 0.9365026432884551
#  Time: 43.2200882434845
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8940099753300144
#  Precision: 0.9320431256667674
#  Time: 42.79373335838318
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8975952307975892
#  Precision: 0.9351660564024724
#  Time: 43.07627868652344
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9337026025046808
#  Precision: 0.9370397772514321
#  Time: 41.9307963848114
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8990347245106591
#  Precision: 0.9329930207291905
#  Time: 42.354145526885986
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9392673641115487
#  Precision: 0.9376074056582879
#  Time: 43.008854389190674
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9067698153709979
#  Precision: 0.9382628680021208
#  Time: 41.76219964027405
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9030793791197484
#  Precision: 0.9359251700253275
#  Time: 43.335981369018555
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.896272960890428
#  Precision: 0.9341657069853847
#  Time: 41.32502579689026
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9401689999090312
#  Precision: 0.935744240815759
#  Time: 42.686326026916504
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8899246302675653
#  Precision: 0.9305509660919271
#  Time: 41.46726393699646
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9371975042659195
#  Precision: 0.9352536355184332
#  Time: 41.473464488983154
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9363412960342471
#  Precision: 0.9382377483356383
#  Time: 40.064268827438354
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8900186456052339
#  Precision: 0.9300137171652243
#  Time: 40.420013427734375
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8990839058455892
#  Precision: 0.9354360957915087
#  Time: 42.25214385986328
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9021326251584804
#  Precision: 0.935484701185233
#  Time: 43.69262886047363
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9360992969248536
#  Precision: 0.9358052096245084
#  Time: 42.16285490989685
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9357218247152285
#  Precision: 0.9350725060559331
#  Time: 41.573944330215454
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9008738478590503
#  Precision: 0.9355832015697606
#  Time: 42.662978649139404
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9360642004488139
#  Precision: 0.9413711049701403
#  Time: 42.40745973587036
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8998125889169932
#  Precision: 0.934226777725043
#  Time: 42.174020290374756
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9362194014045974
#  Precision: 0.9340187993205107
#  Time: 41.348737478256226
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8920121844292119
#  Precision: 0.9321952317500609
#  Time: 41.16879439353943
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8932292929089876
#  Precision: 0.93066576768395
#  Time: 41.21437931060791
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9357719704428998
#  Precision: 0.9374989240505147
#  Time: 42.08473539352417
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8932842712052432
#  Precision: 0.9313536119951948
#  Time: 39.81616520881653
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8940322479487773
#  Precision: 0.9313808215598479
#  Time: 39.62507629394531
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9360788477757055
#  Precision: 0.9369510940718573
#  Time: 41.27842116355896
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9020521999689549
#  Precision: 0.9364049313261349
#  Time: 41.220802783966064
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9061778878122245
#  Precision: 0.937481526217801
#  Time: 41.767876863479614
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9043727239615034
#  Precision: 0.9365705852959398
#  Time: 40.70339298248291
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9047868711138343
#  Precision: 0.9370766431621949
#  Time: 41.94204878807068
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9394510448290623
#  Precision: 0.9353162703523781
#  Time: 42.102030515670776
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8969789636232197
#  Precision: 0.9336226958371433
#  Time: 41.70630860328674
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.891863749031954
#  Precision: 0.9306872378104123
#  Time: 41.057180404663086
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9318288993289358
#  Precision: 0.936123211179238
#  Time: 42.55161166191101
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8867720496359168
#  Precision: 0.9284975351140463
#  Time: 43.34550857543945
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9342412889965716
#  Precision: 0.9379650267012856
#  Time: 40.90234684944153
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9037885597679624
#  Precision: 0.9364800625789195
#  Time: 41.40688943862915
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9354884117179859
#  Precision: 0.9335012574095125
#  Time: 43.04188561439514
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8988077037470108
#  Precision: 0.9340243364260785
#  Time: 41.60824227333069
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9349925371128727
#  Precision: 0.9337297616876057
#  Time: 41.96363925933838
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8945752767973076
#  Precision: 0.933108197539454
#  Time: 1090.4495508670807
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8941660983435179
#  Precision: 0.9326482693745639
#  Time: 40.94212603569031
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8962490792932103
#  Precision: 0.9338870756191627
#  Time: 40.54224371910095
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8956283875099389
#  Precision: 0.9348381679744733
#  Time: 41.319297313690186
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9324719717570888
#  Precision: 0.9344710883716314
#  Time: 40.53368926048279
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9390003423315996
#  Precision: 0.9356794895889107
#  Time: 41.22960066795349
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9019177753852705
#  Precision: 0.9354710457566341
#  Time: 40.37261891365051
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9348020915912444
#  Precision: 0.9332157913231192
#  Time: 41.44565677642822
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9372555385351006
#  Precision: 0.934127986161998
#  Time: 41.534276247024536
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8956057430385064
#  Precision: 0.9322746702570607
#  Time: 40.80789804458618
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8999631929371524
#  Precision: 0.9351137420299563
#  Time: 40.596471071243286
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9339383074642893
#  Precision: 0.9366495172988072
#  Time: 42.570128202438354
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8996334734137472
#  Precision: 0.9332778553920802
#  Time: 46.204127073287964
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.935972729000986
#  Precision: 0.934979575797188
#  Time: 42.92736744880676
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.897588326103333
#  Precision: 0.9329366502827368
#  Time: 43.052512407302856
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8984138562648221
#  Precision: 0.9335093671952132
#  Time: 43.80605387687683
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8916955659593931
#  Precision: 0.9318392096691018
#  Time: 44.425010204315186
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9353846736237512
#  Precision: 0.9332961275455107
#  Time: 42.6154465675354
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8899376374386524
#  Precision: 0.9306846828129268
#  Time: 42.71872687339783
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9333489296307459
#  Precision: 0.9355770100957325
#  Time: 41.41434049606323
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9314653502167116
# ...
#  Precision: 0.9469072372579719
#  Time: 159.31063413619995
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment44.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9212772259928362
#  Precision: 0.9463602318873954
#  Time: 162.8841302394867
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment45.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9399513676977521
#  Precision: 0.9417415873847885
#  Time: 160.7151644229889
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.914315758428558
#  Precision: 0.9430646956046238
#  Time: 164.9619243144989
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9090261916270274
#  Precision: 0.9400980279180056
#  Time: 157.1562476158142
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment48.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9087555744035678
#  Precision: 0.9416234183268376
#  Time: 160.28871059417725
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9082649773772173
#  Precision: 0.9407739465182774
#  Time: 162.03884434700012
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment0.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9406359074286227
#  Precision: 0.9440794496464942
#  Time: 159.96757459640503
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment1.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9444392944745864
#  Precision: 0.9428644986887158
#  Time: 160.31185913085938
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment2.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9156457051369956
#  Precision: 0.944686960377912
#  Time: 160.37565326690674
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment3.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9438888039585487
#  Precision: 0.9427143809605164
#  Time: 162.29696369171143
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment4.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.910635903293025
#  Precision: 0.9423726340480595
#  Time: 165.58153104782104
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment6.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9101225371198541
#  Precision: 0.9424236257263416
#  Time: 163.68012499809265
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment7.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9409724528974397
#  Precision: 0.9453307865353032
#  Time: 166.0581569671631
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment8.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9123357047649896
#  Precision: 0.9409880174693939
#  Time: 160.82459163665771
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment9.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9434470655575729
#  Precision: 0.9441427978027908
#  Time: 166.66594243049622
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment10.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9154552208578798
#  Precision: 0.9434827004181191
#  Time: 165.59794759750366
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment11.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9151713986782982
#  Precision: 0.9425730796257479
#  Time: 163.322518825531
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment12.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9099611044754836
#  Precision: 0.9416472903159886
#  Time: 161.3677716255188
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment13.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9463890405318861
#  Precision: 0.9447992511318618
#  Time: 161.0294919013977
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment14.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9102664869723924
#  Precision: 0.9420659756894175
#  Time: 161.15937900543213
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment15.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.942283272771143
#  Precision: 0.9447199124254266
#  Time: 166.33395290374756
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment16.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9445324259992026
#  Precision: 0.9471361181740299
#  Time: 163.6749587059021
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment17.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.910740348640653
#  Precision: 0.9416707218406113
#  Time: 162.55739545822144
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment18.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9138314219062977
#  Precision: 0.944866624938171
#  Time: 163.63682627677917
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment19.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.917378770976757
#  Precision: 0.9438881391285039
#  Time: 160.36163878440857
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment20.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9434063162744944
#  Precision: 0.9454196200520422
#  Time: 160.38728761672974
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment21.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9423795882939974
#  Precision: 0.9443806141011348
#  Time: 165.31441140174866
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment22.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9128188310280438
#  Precision: 0.9424264342583815
#  Time: 161.8026099205017
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment23.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.940066570609704
#  Precision: 0.9478744331015928
#  Time: 161.99099493026733
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment24.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9107859426436707
#  Precision: 0.9422260444621926
#  Time: 162.49677395820618
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment25.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9437068462278199
#  Precision: 0.9435480994082412
#  Time: 162.52729630470276
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment26.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.908970804522254
#  Precision: 0.9409954776219747
#  Time: 161.47610330581665
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment27.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9124733103395946
#  Precision: 0.9418445256704009
#  Time: 157.6619691848755
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment28.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9435793757017129
#  Precision: 0.945788415319558
#  Time: 159.06227684020996
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment29.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9081010216346448
#  Precision: 0.9406374253003473
#  Time: 162.43394780158997
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment30.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9157198239384603
#  Precision: 0.9434421620010729
#  Time: 158.37416124343872
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment31.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9431819856726502
#  Precision: 0.9455803672719554
#  Time: 160.11206340789795
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment32.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9151668538385226
#  Precision: 0.9439397693148149
#  Time: 159.2406804561615
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment33.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9231241537887592
#  Precision: 0.9470233761130402
#  Time: 158.97031807899475
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment34.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9164642862591066
#  Precision: 0.9439767024439811
#  Time: 160.99477577209473
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment35.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9182804690153601
#  Precision: 0.945567394324388
#  Time: 162.4197554588318
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment36.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9478363581731338
#  Precision: 0.9472995716024863
#  Time: 159.46527981758118
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment37.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9165756312994364
#  Precision: 0.9444707959910092
#  Time: 160.7394425868988
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment38.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9083968701814215
#  Precision: 0.9407624232252076
#  Time: 157.65651559829712
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment39.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9426947766029743
#  Precision: 0.9481102471891154
#  Time: 164.74029445648193
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment40.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.90942235281117
#  Precision: 0.9411616000487599
#  Time: 158.6179280281067
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment41.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9386237595281911
#  Precision: 0.9448813969319855
#  Time: 163.39305782318115
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment42.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9144859761371161
#  Precision: 0.9433482221907226
#  Time: 160.47693991661072
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment43.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9446505198456812
#  Precision: 0.9452126098022563
#  Time: 162.0094871520996
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment44.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9147584729919158
#  Precision: 0.9435786421805386
#  Time: 160.77957606315613
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment45.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9376950431623312
#  Precision: 0.9410107911471799
#  Time: 163.6423077583313
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9131468885697172
#  Precision: 0.9427010929389403
#  Time: 160.47418808937073
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.914851034169003
#  Precision: 0.9433233799860263
#  Time: 158.66685938835144
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment48.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9115841442649869
#  Precision: 0.9426780420744207
#  Time: 158.79962682724
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-3/cols_set_2/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9107942463828024
#  Precision: 0.9417062313598988
#  Time: 162.21731233596802
# ===========================

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
for i in range(len(experiments)):
    for d in list(experiments[i].keys()):
        experiments[i][d] = str(experiments[i][d])

# %%
# experiments

# %%
cols = ['experiment_filter', 'undersampling_method', 'filename', 'experiment_id', 'n_covid', 'n_not_covid', 'model_name', 'params', 'model_AUC_ROC', 'model_AUC_PR', 'model_covid_precision', 'model_covid_recall', 'model_covid_f1', 'model_not_covid_precision', 'model_not_covid_recall', 'model_not_covid_f1', 'model_avg_precision', 'model_avg_recall', 'model_avg_f1', 'model_avg_acc', 'model_TP', 'model_TN', 'model_FN', 'model_FP', 'model_time_exec', 'model_col_set']

# %%
intermed_results = spark.createDataFrame(data=experiments).select(cols)
intermed_results.toPandas()
# Out:
# /usr/lib/spark/python/pyspark/sql/session.py:346: UserWarning: inferring schema from dict is deprecated,please use pyspark.sql.Row instead
#   warnings.warn("inferring schema from dict is deprecated,"

# %%
intermed_results.write.parquet('gs://ai-covid19-datalake/trusted/intermed_results/KMODES/GBT_experiments-kmodes-ds3-cs2.parquet', mode='overwrite')

# %%
df = spark.read.parquet('gs://ai-covid19-datalake/trusted/intermed_results/KMODES/GBT_experiments-kmodes-ds3-cs2.parquet')
df.limit(2).toPandas()
# Out:
#   experiment_filter undersampling_method  \
# 0              ds-3            02-KMODES
# 1              ds-3            02-KMODES
#
#                                             filename experiment_id n_covid  \
# 0  gs://ai-covid19-datalake/trusted/experiment_ma...            34   43338
# 1  gs://ai-covid19-datalake/trusted/experiment_ma...            35   43787
#
#   n_not_covid model_name                                          params  \
# 0       44538        GBT  {'maxIter': 100, 'maxDepth': 5, 'maxBins': 64}
# 1       44538        GBT  {'maxIter': 100, 'maxDepth': 5, 'maxBins': 64}
#
#         model_AUC_ROC        model_AUC_PR model_covid_precision  \
# 0  0.9409241983367467  0.9130637795455521    0.9206153399608156
# 1   0.941182838568824  0.9115894579340814    0.9190445073694911
#
#    model_covid_recall      model_covid_f1 model_not_covid_precision  \
# 0  0.9642775708748195  0.9419407528398543        0.9628399746995573
# 1  0.9650072425097203  0.9414652287095574        0.9642411966344656
#
#   model_not_covid_recall  model_not_covid_f1 model_avg_precision  \
# 0     0.9175708257986739  0.9396604938271605  0.9417276573301865
# 1     0.9173584346279277  0.9402157398966879  0.9416428520019784
#
#      model_avg_recall        model_avg_f1       model_avg_acc model_TP  \
# 0  0.9409241983367467  0.9408006233335074   0.940822581255439    12687
# 1  0.9411828385688239  0.9408404843031226  0.9408470818144237    12658
#
#   model_TN model_FN model_FP     model_time_exec model_col_set
# 0    12178      470     1094  101.87886595726013    cols_set_2
# 1    12377      459     1115  103.98189854621887    cols_set_2

# %%
print('finished')
# Out:
# finished

# %%
intermed_results.show()
# Out:
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# |experiment_filter|undersampling_method|            filename|experiment_id|n_covid|n_not_covid|model_name|              params|     model_AUC_ROC|      model_AUC_PR|model_covid_precision|model_covid_recall|    model_covid_f1|model_not_covid_precision|model_not_covid_recall|model_not_covid_f1|model_avg_precision|  model_avg_recall|      model_avg_f1|     model_avg_acc|model_TP|model_TN|model_FN|model_FP|   model_time_exec|model_col_set|
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|            0|  47370|      44538|       GBT|{'maxIter': 20, '...|0.9258178019574914|0.9308477327167839|    0.902423094507217| 0.962655890754546| 0.931566882416397|        0.957116569325546|     0.888979713160437|0.9217907227615966| 0.9297698319163815|0.9258178019574915|0.9266788025889967|0.9270046745774901|   13817|   11963|     536|    1494|52.453635454177856|   cols_set_2|
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|            1|  45428|      44538|       GBT|{'maxIter': 20, '...| 0.927437589902445|0.9307570933028291|   0.9046730264067468|0.9584737073385089| 0.930796586059744|       0.9546363709096728|    0.8964014724663812| 0.924602867105773| 0.9296546986582098|0.9274375899024451|0.9276997265827585|0.9278323753013166|   13087|   11932|     567|    1379|  42.1927490234375|   cols_set_2|
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|            2|  43889|      44538|       GBT|{'maxIter': 20, '...|0.9278559996267676|0.8910742562831765|   0.8985352673492605|0.9628924108503505|0.9296012946888332|       0.9606432843058025|    0.8928195884031846|0.9254905014014325| 0.9295892758275315|0.9278559996267676|0.9275458980451329|0.9276042060670248|   12637|   11887|     487|    1427| 40.59894561767578|   cols_set_2|
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|            3|  44844|      44538|       GBT|{'maxIter': 20, '...|0.9292688560784514|0.9328376922686006|   0.9065250803409249|0.9597633136094674|0.9323848530574118|       0.9562137797810689|    0.8987743985474353|0.9266047890180173| 0.9313694300609969|0.9292688560784514|0.9294948210377145|0.9296132844640587|   12976|   11880|     544|    1338| 42.64921569824219|   cols_set_2|
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|            4|  45306|      44538|       GBT|{'maxIter': 20, '...|0.9269529067194832|0.9325354428981197|   0.9013586579786497|0.9604816073275225|0.9299814046631384|        0.957076379974326|     0.893424206111444|0.9241555624418966| 0.9292175189764879|0.9269529067194833|0.9270684835525175|0.9271848270732614|   13003|   11929|     535|    1423|  40.2602379322052|   cols_set_2|
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|            5|  40933|      44538|       GBT|{'maxIter': 20, '...|0.9282463333473149|0.8905586513591662|   0.8999158313566455|0.9552469135802469|0.9267562349789212|       0.9558776425368354|    0.9012457531143828|0.9277581315820155| 0.9278967369467405|0.9282463333473149|0.9272571832804684|0.9272606330946511|   11761|   11937|     551|    1308| 40.40925145149231|   cols_set_2|
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|            6|  41230|      44538|       GBT|{'maxIter': 20, '...|0.9311597197508072|0.8926974172751823|   0.9009334537789823|0.9606678439556912|0.9298422810970399|       0.9609717244125846|    0.9016515955459233|0.9303670573719927| 0.9309525890957835|0.9311597197508072|0.9301046692345163|0.9301056542435853|   11968|   12065|     490|    1316| 39.79506969451904|   cols_set_2|
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|            7|  49019|      44538|       GBT|{'maxIter': 20, '...|0.9273003381911585|0.9311971732445201|   0.9060065666645207|0.9634421852536456|0.9338420703384208|       0.9572389493914157|    0.8911584911286715|0.9230175276040459| 0.9316227580279682|0.9273003381911585|0.9284297989712333|0.9288390849719853|   14073|   11954|     534|    1460|40.710269927978516|   cols_set_2|
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|            8|  43171|      44538|       GBT|{'maxIter': 20, '...|0.9255766870245007| 0.887092427392059|   0.8954328660211013|0.9588330882921923|0.9260491013041366|       0.9575181665735047|     0.892320285756809|0.9237702707908015| 0.9264755162973031|0.9255766870245006| 0.924909686047469|0.9249269754561663|   12391|   11991|     532|    1447| 39.44875955581665|   cols_set_2|
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|            9|  46213|      44538|       GBT|{'maxIter': 20, '...|0.9303984285819561|0.9351047953629215|    0.907691268823013|0.9640679911066485|0.9350306065664997|       0.9595020612723304|    0.8967288660572638|0.9270540456107467| 0.9335966650476717|0.9303984285819562|0.9310423260886231|0.9312729948491538|   13442|   11870|     501|    1367| 39.82371520996094|   cols_set_2|
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|           10|  43831|      44538|       GBT|{'maxIter': 20, '...|0.9269704592515374|0.8903269837277148|   0.8984994950223633|0.9596270899144772|0.9280578219887485|       0.9578439259855189|    0.8943138285885976|0.9249893174843647| 0.9281717105039411|0.9269704592515374|0.9265235697365566|0.9265556062680663|   12455|   11906|     524|    1407|39.460352659225464|   cols_set_2|
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|           11|  44116|      44538|       GBT|{'maxIter': 20, '...|0.9260179100422802|0.8907461785517597|   0.8988914777942526|0.9593097731896617|0.9281183932346724|        0.956650879023842|    0.8927260468948985|0.9235836627140975| 0.9277711784090473|0.9260179100422801| 0.925851027974385|0.9259203606311044|   12731|   11917|     540|    1432|38.937506914138794|   cols_set_2|
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|           12|  38418|      44538|       GBT|{'maxIter': 20, '...|0.9311788806121085|0.8883471704691029|   0.8976186619147902|0.9571601312834687|0.9264337067380036|        0.960525268603263|    0.9051976299407485|0.9320410842536103| 0.9290719652590267|0.9311788806121086| 0.929237395495807|0.9293484805909036|   11082|   12069|     496|    1264|39.743866205215454|   cols_set_2|
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|           13|  44698|      44538|       GBT|{'maxIter': 20, '...|  0.92807199412717|0.9347442443418962|   0.9011827279725663|0.9619751979680263|0.9305871725383921|       0.9590803119221802|    0.8941687902863139| 0.925487762305574| 0.9301315199473732|0.9280719941271701| 0.928037467421983| 0.928127806046094|   12877|   11930|     509|    1412| 39.63273549079895|   cols_set_2|
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|           14|  40620|      44538|       GBT|{'maxIter': 20, '...|0.9284845480302031|0.8850847124458517|   0.8933353737852935|0.9605891064670068|0.9257423779883439|        0.961796139735205|    0.8963799895933993|0.9279365934361895| 0.9275657567602492|0.9284845480302031|0.9268394857122667|0.9268559378294997|   11675|   12059|     479|    1394| 39.64300203323364|   cols_set_2|
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|           15|  46738|      44538|       GBT|{'maxIter': 20, '...|0.9272585496680891|0.9331903636660797|    0.902518656716418| 0.963371266002845|0.9319526627218935|       0.9587736151136728|    0.8911458333333333|0.9237235847601419| 0.9306461359150453|0.9272585496680892|0.9278381237410177|0.9280727272727273|   13545|   11977|     515|    1463| 41.57361674308777|   cols_set_2|
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|           16|  48764|      44538|       GBT|{'maxIter': 20, '...|0.9253926020264612|0.9284322023370621|   0.9043376471353319| 0.960889994472084|0.9317565077557036|       0.9545564030509835|    0.8898952095808383|0.9210923881464265| 0.9294470250931577|0.9253926020264611| 0.926424447951065|0.9268108651911469|   13906|   11889|     566|    1471| 42.11671805381775|   cols_set_2|
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|           17|  39800|      44538|       GBT|{'maxIter': 20, '...|0.9301733318589491|0.8901347094802468|   0.8991255465334166|  0.95759188425079|0.9274381895788032|       0.9592130518234165|    0.9027547794671082|0.9301279565723148| 0.9291692991784166|0.9301733318589491|0.9287830730755591|0.9288084702907712|   11516|   11994|     510|    1292| 44.00028085708618|   cols_set_2|
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|           18|  41608|      44538|       GBT|{'maxIter': 20, '...|0.9288636936224078|0.8886917438819079|   0.8968027619333534|0.9608394982309424|0.9277173913043479|       0.9608741062103318|    0.8968878890138733|0.9277790706694592| 0.9288384340718425|0.9288636936224078|0.9277482309869036|0.9277482441504016|   11949|   11960|     487|    1375| 39.62014675140381|   cols_set_2|
# |             ds-3|           02-KMODES|gs://ai-covid19-d...|           19|  43650|      44538|       GBT|{'maxIter': 20, '...|0.9245463012753103|0.8906949343429875|   0.8995667305916614|0.9556326869388063|0.9267525245133909|        0.952755905511811|    0.8934599156118144|0.9221556886227544| 0.9261613180517362|0.9245463012753103|0.9244541065680727|0.9245240339302545|   12665|   11858|     588|    1414|40.141361474990845|   cols_set_2|
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# only showing top 20 rows
