# %%
import pandas as pd
import pyspark.sql.functions as F
from datetime import datetime
from pyspark.sql.types import *
from pyspark import StorageLevel

import numpy as np
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", 1000)
pd.set_option("mode.chained_assignment", None)

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import GBTClassifier
from pyspark.ml.feature import IndexToString, StringIndexer, VectorIndexer
# from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import OneHotEncoderEstimator, StringIndexer, VectorAssembler

from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

from pyspark.sql import Row
from pyspark.ml.linalg import Vectors

# %%
# !pip install scikit-plot

# %%
import sklearn
import scikitplot as skplt
from sklearn.metrics import classification_report, confusion_matrix, precision_score

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
result_schema = StructType([
                    StructField('experiment_filter', StringType(), True),
                    StructField('undersampling_method', StringType(), True),
                    StructField('undersampling_column', StringType(), True),
                    StructField('filename', StringType(), True),
                    StructField('experiment_id', StringType(), True),
                    StructField('n_covid', IntegerType(), True),
                    StructField('n_not_covid', IntegerType(), True),
                    StructField('model_name', StringType(), True),
                    StructField('model_seed', StringType(), True),
                    StructField('model_maxIter', IntegerType(), True),
                    StructField('model_maxDepth', IntegerType(), True),
                    StructField('model_maxBins', IntegerType(), True),
                    StructField('model_minInstancesPerNode', IntegerType(), True),
                    StructField('model_minInfoGain', FloatType(), True),
                    StructField('model_featureSubsetStrategy', StringType(), True),
                    StructField('model_n_estimators', IntegerType(), True),
                    StructField('model_learning_rate', FloatType(), True),
                    StructField('model_impurity', StringType(), True),
                    StructField('model_AUC_ROC', StringType(), True),
                    StructField('model_AUC_PR', StringType(), True),
                    StructField('model_covid_precision', StringType(), True),
                    StructField('model_covid_recall', StringType(), True),
                    StructField('model_covid_f1', StringType(), True),
                    StructField('model_not_covid_precision', StringType(), True),
                    StructField('model_not_covid_recall', StringType(), True),
                    StructField('model_not_covid_f1', StringType(), True),
                    StructField('model_avg_precision', StringType(), True),
                    StructField('model_avg_recall', StringType(), True),
                    StructField('model_avg_f1', StringType(), True),
                    StructField('model_avg_acc', StringType(), True),
                    StructField('model_TP', StringType(), True),
                    StructField('model_TN', StringType(), True),
                    StructField('model_FN', StringType(), True),
                    StructField('model_FP', StringType(), True),
                    StructField('model_time_exec', StringType(), True),
                    StructField('model_col_set', StringType(), True)
                          ])

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# undersamp_col = ['03-STRSAMP-AG', '04-STRSAMP-EW'] 
# dfs = ['ds-1', 'ds-2', 'ds-3']
# cols_sets = ['cols_set_1', 'cols_set_2', 'cols_set_3']

undersamp_col = ['02-KMODES']
dfs = ['ds-2']
cols_sets = ['cols_set_3']

# %%
# lists of params
model_maxIter = [20, 50, 100] 
model_maxDepth = [3, 5, 7] 
model_maxBins = [32, 64] 
# model_learningRate = [0.01, 0.1, 0.5]
# model_loss = ['logLoss', 'leastSquaresError', 'leastAbsoluteError']



list_of_param_dicts = []

for maxIter in model_maxIter:
    for maxDepth in model_maxDepth:
        for maxBins in model_maxBins: 
            params_dict = {}
            params_dict['maxIter'] = maxIter
            params_dict['maxDepth'] = maxDepth
            params_dict['maxBins'] = maxBins
            list_of_param_dicts.append(params_dict)

print("There is {} set of params.".format(len(list_of_param_dicts)))
# list_of_param_dicts
# Out:
# There is 18 set of params.

# %%
prefix = 'gs://ai-covid19-datalake/trusted/experiment_map/'

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# filename = 'gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment0.parquet'
# df = spark.read.parquet(filename)
# df.limit(2).toPandas()

# %%
# params_dict = {'maxIter': 100,
#                'maxDepth': 3,
#                'maxBins': 32,
#                'learningRate': 0.5,
#                'loss': 'leastAbsoluteError'}
# cols = 'cols_set_1'
# experiment_filter = 'ds-1'
# undersampling_method = '03-STRSAMP-AG', 
# experiment_id = 0

# %%
# run_gbt(df, params_dict, cols, filename, experiment_filter, undersampling_method, experiment_id)

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
def run_gbt(exp_df, params_dict, cols, filename, experiment_filter, 
            undersampling_method, experiment_id):
    import time
    start_time = time.time()
    
    n_covid = exp_df.filter(F.col('CLASSI_FIN') == 1.0).count()
    n_not_covid = exp_df.filter(F.col('CLASSI_FIN') == 0.0).count()
    
    
    id_cols = ['NU_NOTIFIC', 'CLASSI_FIN']

    labelIndexer = StringIndexer(inputCol="CLASSI_FIN", outputCol="indexedLabel").fit(exp_df)    
    
    input_cols = [x for x in exp_df.columns if x not in id_cols]
    assembler = VectorAssembler(inputCols = input_cols, outputCol= 'features')
    exp_df = assembler.transform(exp_df)
    
    # Automatically identify categorical features, and index them.
    # Set maxCategories so features with > 4 distinct values are treated as continuous.
    featureIndexer = VectorIndexer(inputCol="features", outputCol="indexedFeatures", maxCategories=30).fit(exp_df)
    
    # Split the data into training and test sets (30% held out for testing)
    (trainingData, testData) = exp_df.randomSplit([0.7, 0.3])
    trainingData = trainingData.persist(StorageLevel.MEMORY_ONLY)
    testData = testData.persist(StorageLevel.MEMORY_ONLY)
    
    # Train a RandomForest model.
    gbt = GBTClassifier(labelCol = "indexedLabel", featuresCol = "indexedFeatures",
                       maxIter = params_dict['maxIter'],
                       maxDepth = params_dict['maxDepth'],
                       maxBins = params_dict['maxBins'])
    
    # Convert indexed labels back to original labels.
    labelConverter = IndexToString(inputCol="prediction", outputCol="predictedLabel",
                               labels=labelIndexer.labels)

    # Chain indexers and forest in a Pipeline
    pipeline = Pipeline(stages=[labelIndexer, featureIndexer, gbt, labelConverter])

    # Train model.  This also runs the indexers.
    model = pipeline.fit(trainingData)
    
    # Make predictions.
    predictions = model.transform(testData)    
    
    
    pred = predictions.select(['CLASSI_FIN', 'predictedLabel'])\
                  .withColumn('predictedLabel', F.col('predictedLabel').cast('double'))\
                  .withColumn('predictedLabel', F.when(F.col('predictedLabel') == 1.0, 'covid').otherwise('n-covid'))\
                  .withColumn('CLASSI_FIN', F.when(F.col('CLASSI_FIN') == 1.0, 'covid').otherwise('n-covid'))\
                  .toPandas()

    y_true = pred['CLASSI_FIN'].tolist()
    y_pred = pred['predictedLabel'].tolist()
    
    report = classification_report(y_true, y_pred, output_dict=True)
    
    
    evaluator_ROC = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderROC")
    accuracy_ROC = evaluator_ROC.evaluate(predictions)


    
    evaluator_PR = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderPR")
    accuracy_PR = evaluator_PR.evaluate(predictions)
    
    conf_matrix = confusion_matrix(y_true, y_pred)

    result_dict = {}
    
    result_dict['experiment_filter'] = experiment_filter
    result_dict['undersampling_method'] = undersampling_method
    result_dict['filename'] = filename
    result_dict['experiment_id'] = experiment_id
    result_dict['n_covid'] = n_covid
    result_dict['n_not_covid'] = n_not_covid
    result_dict['model_name'] = 'GBT'
    result_dict['params'] = params_dict
    result_dict['model_AUC_ROC'] = accuracy_ROC
    result_dict['model_AUC_PR'] = accuracy_PR
    result_dict['model_covid_precision'] = report['covid']['precision']
    result_dict['model_covid_recall'] = report['covid']['recall']
    result_dict['model_covid_f1'] = report['covid']['f1-score']
    result_dict['model_not_covid_precision'] = report['n-covid']['precision']
    result_dict['model_not_covid_recall'] = report['n-covid']['recall']
    result_dict['model_not_covid_f1'] = report['n-covid']['f1-score']
    result_dict['model_avg_precision'] = report['macro avg']['precision']
    result_dict['model_avg_recall'] = report['macro avg']['recall']
    result_dict['model_avg_f1'] = report['macro avg']['f1-score']
    result_dict['model_avg_acc'] = report['accuracy']
    result_dict['model_TP'] = conf_matrix[0][0]
    result_dict['model_TN'] = conf_matrix[1][1]
    result_dict['model_FN'] = conf_matrix[0][1]
    result_dict['model_FP'] = conf_matrix[1][0]
    result_dict['model_time_exec'] = time.time() - start_time
    result_dict['model_col_set'] = cols
    
    return result_dict

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %% [markdown]
# # Running GBT on 10 samples for each experiment
# ### 3x col sets -> ['cols_set_1', 'cols_set_2', 'cols_set_3']
# ### 3x model_maxIter -> [100, 200, 300]
# ### 3x model_maxDepth -> [5, 10, 15]
# ### 3x model_maxBins -> [16, 32, 64]
# Total: 10 * 3 * 3 * 3 * 3 = 810

# %%
experiments = []

# %% [markdown]
# ### Datasets: strat_samp_lab_agegrp

# %%
for uc in undersamp_col: 
    for ds in dfs:
        for col_set in cols_sets:
            for params_dict in list_of_param_dicts: 
                for id_exp in range(50):
                    filename = prefix + uc + '/' + ds + '/' + col_set + '/' + 'experiment' + str(id_exp) + '.parquet'
                    exp_dataframe = spark.read.parquet(filename)
#                     if 'SG_UF_NOT' in exp_dataframe.columns:
#                         exp_dataframe = exp_dataframe.withColumn('SG_UF_NOT', F.col('SG_UF_NOT').cast('float'))
                    print('read {}'.format(filename))
                    
                    undersampling_method = uc
                    experiment_filter = ds
                    experiment_id = id_exp

                    try:                     
                        model = run_gbt(exp_dataframe, params_dict, col_set, filename, experiment_filter, undersampling_method, experiment_id)
                        experiments.append(model)

                        print("Parameters ==> {}\n Results: \n AUC_PR: {} \n Precision: {} \n Time: {}".format(str(params_dict), str(model['model_AUC_PR']), str(model['model_avg_precision']), str(model['model_time_exec'])))
                        print('=========================== \n')
                    except:
                        print('=========== W A R N I N G =========== \n')
                        print('Something wrong with the exp: {}, {}, {}'.format(filename, params_dict, col_set))
# Out:
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8505502077031721
#  Precision: 0.9105860446056778
#  Time: 41.46422266960144
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8465516406295701
#  Precision: 0.9088388402857347
#  Time: 28.389264345169067
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8514086174611258
#  Precision: 0.910973350675419
#  Time: 27.054616451263428
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8359674851835959
#  Precision: 0.9051635915257368
#  Time: 25.23535132408142
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8495312886784019
#  Precision: 0.9094271167774477
#  Time: 25.133219718933105
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8325398224993548
#  Precision: 0.9039745144282172
#  Time: 25.749501705169678
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8334919509299106
#  Precision: 0.903275888077736
#  Time: 23.54803490638733
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8600538646337825
#  Precision: 0.9146749129972747
#  Time: 24.98399519920349
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8475606025751107
#  Precision: 0.9099621251534666
#  Time: 25.25086259841919
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.865196342172409
#  Precision: 0.9159760374959504
#  Time: 23.99194836616516
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.851823387914443
#  Precision: 0.9108410286128633
#  Time: 23.68980360031128
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8405221983743851
#  Precision: 0.906151458913045
#  Time: 23.723393440246582
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8321525791813509
#  Precision: 0.9037677599895095
#  Time: 25.142306804656982
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8473278955506701
#  Precision: 0.908405532378294
#  Time: 23.953820943832397
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8410609037794002
#  Precision: 0.9070633726990349
#  Time: 25.131107091903687
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8559495993438647
#  Precision: 0.9122237556919074
#  Time: 24.62631344795227
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8548177267679088
#  Precision: 0.9105772913030306
#  Time: 25.298471689224243
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8335033526492173
#  Precision: 0.9031430037338473
#  Time: 25.017157316207886
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8458935255144177
#  Precision: 0.909186383146103
#  Time: 24.008692502975464
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8497485899041545
#  Precision: 0.9094202788215504
#  Time: 24.91522765159607
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8432271286598644
#  Precision: 0.9062743241993483
#  Time: 24.47401785850525
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8657627047001584
#  Precision: 0.9166267720806156
#  Time: 24.07029676437378
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8404299530587357
#  Precision: 0.9051784208544273
#  Time: 24.866239309310913
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8539213758168914
#  Precision: 0.9120694623519878
#  Time: 25.626384973526
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8335958138660439
#  Precision: 0.9039845311388154
#  Time: 23.959739446640015
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.850052371449395
#  Precision: 0.9098451968243852
#  Time: 23.91820192337036
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8365944226306856
#  Precision: 0.9033939354607134
#  Time: 24.10357904434204
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8394734032346316
#  Precision: 0.9050050861505314
#  Time: 24.07392954826355
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8539768633250959
#  Precision: 0.9118810810495799
#  Time: 25.531336545944214
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8426331233054578
#  Precision: 0.9078053722338024
#  Time: 24.522461891174316
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8410674312414529
#  Precision: 0.9065471383037371
#  Time: 24.628018617630005
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8585780966052552
#  Precision: 0.9124993550323957
#  Time: 24.57016110420227
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8420875199218141
#  Precision: 0.9075246613513318
#  Time: 23.919134855270386
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8541588955632679
#  Precision: 0.9124051532638797
#  Time: 23.581772327423096
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8490759042338109
#  Precision: 0.910679788114481
#  Time: 23.267258644104004
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8438464194886123
#  Precision: 0.9072029141962055
#  Time: 23.69058871269226
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8576177458550814
#  Precision: 0.9144259795157137
#  Time: 24.011050939559937
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8425492912909017
#  Precision: 0.9077575564727045
#  Time: 26.296510219573975
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8416021092321987
#  Precision: 0.9073962367563814
#  Time: 23.51343274116516
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8614051193635224
#  Precision: 0.914099005660536
#  Time: 28.008398294448853
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8273520177951118
#  Precision: 0.9011650254425204
#  Time: 25.211676836013794
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8665032740908157
#  Precision: 0.9163154144775609
#  Time: 24.022997856140137
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8436248812079645
#  Precision: 0.9084065495095242
#  Time: 23.716556072235107
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8520625781501767
#  Precision: 0.9117816831405592
#  Time: 23.60109853744507
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8402284336882307
#  Precision: 0.9063932527062163
#  Time: 23.509541034698486
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8472198522075058
#  Precision: 0.9084852245894077
#  Time: 22.803741455078125
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.851310702557061
#  Precision: 0.9117709109068645
#  Time: 22.805901527404785
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8390639747681354
#  Precision: 0.905935231130562
#  Time: 23.480790376663208
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.819220505185079
#  Precision: 0.8972910172360897
#  Time: 23.774733304977417
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8461735130054872
#  Precision: 0.9090320209995816
#  Time: 24.509549617767334
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8505996109056501
#  Precision: 0.909243937199707
#  Time: 23.630808353424072
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8475343162405156
#  Precision: 0.909617426430346
#  Time: 23.79283595085144
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.846448387753141
#  Precision: 0.9090806115624002
#  Time: 24.63052535057068
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8402020424062492
#  Precision: 0.9075290912524712
#  Time: 24.550241470336914
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.851363968324447
#  Precision: 0.909799897895154
#  Time: 23.598784685134888
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8378978790946178
#  Precision: 0.9055517117089195
#  Time: 22.880918264389038
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.839876492531633
#  Precision: 0.9069924491502936
#  Time: 23.183496236801147
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8646992086936273
#  Precision: 0.9148579047193335
#  Time: 23.914539575576782
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8468972225624903
#  Precision: 0.9084205314817868
#  Time: 24.464649200439453
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8628870290805857
#  Precision: 0.9147995963240605
#  Time: 26.068564653396606
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8462661789070358
#  Precision: 0.9080215650031291
#  Time: 25.067591667175293
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8415657141858376
#  Precision: 0.9056680967733419
#  Time: 24.492136240005493
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8312501847715003
#  Precision: 0.9024669276800286
#  Time: 24.112573862075806
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.851300232729266
#  Precision: 0.9116520201023156
#  Time: 24.45094633102417
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.834550373929677
#  Precision: 0.9031879688524458
#  Time: 23.854827642440796
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8552680542881472
#  Precision: 0.9118582170685494
#  Time: 23.68352246284485
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8592569955203424
#  Precision: 0.9145527047772866
#  Time: 23.76227307319641
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8381447763926038
#  Precision: 0.905790719046314
#  Time: 23.566946983337402
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8439199592427047
#  Precision: 0.9075338927152956
#  Time: 24.243576288223267
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8512822049461138
#  Precision: 0.9101472791782197
#  Time: 24.26825475692749
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8496240538689369
#  Precision: 0.9092399114929356
#  Time: 24.572608470916748
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8677531441429402
#  Precision: 0.9176789311288552
#  Time: 23.437182426452637
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8386362748926349
#  Precision: 0.9054297968911779
#  Time: 23.977130889892578
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8588976339205581
#  Precision: 0.9130884946659525
#  Time: 23.44831609725952
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8283557146582325
#  Precision: 0.9005168124817102
#  Time: 23.872979879379272
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8566234208183874
#  Precision: 0.9134588980995026
#  Time: 23.944445371627808
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.847753323266025
#  Precision: 0.9087384754622603
#  Time: 23.72241735458374
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8469003770481002
#  Precision: 0.9091947226291912
#  Time: 22.244922161102295
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8529173649365012
#  Precision: 0.9122135418649384
#  Time: 24.768083572387695
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8373128210669525
#  Precision: 0.904495007652453
#  Time: 23.099489450454712
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8386654492543472
#  Precision: 0.9038521277708715
#  Time: 22.87464427947998
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8539706197518412
#  Precision: 0.9111500760840732
#  Time: 24.803229808807373
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8404217030223575
#  Precision: 0.9067087435885038
#  Time: 22.661816120147705
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8561146636515877
#  Precision: 0.912966260858063
#  Time: 24.274526357650757
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8538878501997267
#  Precision: 0.9120151948871935
#  Time: 23.756483554840088
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8455474182790671
#  Precision: 0.9080354421901813
#  Time: 23.607239723205566
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8544818502351329
#  Precision: 0.9115687349088087
#  Time: 23.871739387512207
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8399395024161987
#  Precision: 0.9049946219332353
#  Time: 23.833844423294067
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8370755294747062
#  Precision: 0.9051632590188381
#  Time: 24.467915773391724
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8628285517431473
#  Precision: 0.9149147732642464
#  Time: 26.075445413589478
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8359888970798449
#  Precision: 0.9042688600329329
#  Time: 23.930701971054077
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8669329285794758
#  Precision: 0.9165265519735797
#  Time: 24.815246105194092
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8427615871079572
#  Precision: 0.9078999603589675
#  Time: 24.58987045288086
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8497934789257395
#  Precision: 0.9100248830165378
#  Time: 23.42319941520691
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.835793545782169
#  Precision: 0.9048108281475377
#  Time: 22.57433819770813
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8568459033925184
#  Precision: 0.9137310454135572
#  Time: 23.367262363433838
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8510129320693669
#  Precision: 0.9103150617922522
#  Time: 23.263643264770508
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8397387407140009
#  Precision: 0.90658757814041
#  Time: 23.750582218170166
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8210454028789511
#  Precision: 0.8991585033316782
#  Time: 23.314424753189087
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8494499488946676
#  Precision: 0.9104185256287134
#  Time: 24.38986587524414
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8614757118654196
#  Precision: 0.9159166452887126
#  Time: 27.59314751625061
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.853946312196254
#  Precision: 0.9121162674292389
#  Time: 28.126909971237183
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.851744121112753
#  Precision: 0.912156266115436
#  Time: 27.89299464225769
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.846938778003764
#  Precision: 0.9108275282841757
#  Time: 28.662508010864258
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8632711765485644
#  Precision: 0.9171361451579232
#  Time: 27.734217643737793
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8497010413362766
#  Precision: 0.9125450901616063
#  Time: 27.80613136291504
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8387794496446837
#  Precision: 0.9075252122211177
#  Time: 27.17965078353882
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8684566872321271
#  Precision: 0.9179155234668898
#  Time: 27.53743052482605
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8537601956613811
#  Precision: 0.9139169641867042
#  Time: 27.182921648025513
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.870759592122429
#  Precision: 0.9196659893582113
#  Time: 27.063817262649536
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8522052170763093
#  Precision: 0.9124949964564051
#  Time: 27.04040765762329
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8500374010561517
#  Precision: 0.9110061240288931
#  Time: 27.985088348388672
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8331615758859281
#  Precision: 0.9046917889237809
#  Time: 26.867597341537476
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8564786907079724
#  Precision: 0.9141835282161694
#  Time: 27.17651629447937
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8378544744345376
#  Precision: 0.9068452088055483
#  Time: 27.62944269180298
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.857048113219832
#  Precision: 0.91351410862726
#  Time: 26.777437210083008
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.861900575444482
#  Precision: 0.9156796040527244
#  Time: 26.726135730743408
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8455354635529913
#  Precision: 0.9104970768639389
#  Time: 27.099125146865845
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8443211664768779
#  Precision: 0.9078576892478116
#  Time: 28.416131496429443
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8592283072480936
#  Precision: 0.9154651987572056
#  Time: 26.27413511276245
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8538450060926137
#  Precision: 0.9125380166629316
#  Time: 29.786142349243164
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8724113138712958
#  Precision: 0.9201769423032062
#  Time: 28.43343162536621
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8499774574778262
#  Precision: 0.9111112093339597
#  Time: 30.12677240371704
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8577041552880531
#  Precision: 0.9135835897353917
#  Time: 28.92524266242981
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8417448671396839
#  Precision: 0.9091274892025218
#  Time: 32.37424445152283
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8512924245632881
#  Precision: 0.9113970090692032
#  Time: 29.5518741607666
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.846438110465229
#  Precision: 0.9085713196552054
#  Time: 29.56304931640625
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8617535951126649
#  Precision: 0.9172616052274836
#  Time: 29.313310861587524
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8458553766296983
#  Precision: 0.9100787356184541
#  Time: 31.194688081741333
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8520285553852399
#  Precision: 0.9128533294216317
#  Time: 31.689589738845825
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8691763637383133
#  Precision: 0.9195641689713775
#  Time: 35.841997385025024
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8423343629321713
#  Precision: 0.9078711052015949
#  Time: 28.64687728881836
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8561859440305982
#  Precision: 0.9120627651238278
#  Time: 29.661799430847168
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8639134536007074
#  Precision: 0.9178418447267577
#  Time: 30.608602285385132
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8491569119592935
#  Precision: 0.909764881709366
#  Time: 28.28691267967224
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8653421326706922
#  Precision: 0.9175052493635948
#  Time: 29.693263053894043
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8539794293197643
#  Precision: 0.9136583214896792
#  Time: 29.79996919631958
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8482225586542151
#  Precision: 0.9118011334972005
#  Time: 29.033549070358276
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.865844646104294
#  Precision: 0.9181644276324967
#  Time: 30.057460069656372
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8425329090738725
#  Precision: 0.9089837424090199
#  Time: 31.010411977767944
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8706324967806762
#  Precision: 0.9179797210649587
#  Time: 29.571955680847168
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8496050353782135
#  Precision: 0.9111307745179611
#  Time: 29.35838270187378
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8545715418321087
#  Precision: 0.9140428421248767
#  Time: 28.182971239089966
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8452466789627061
#  Precision: 0.9103978779932524
#  Time: 27.252359867095947
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8577821685493077
#  Precision: 0.9143818853196441
#  Time: 28.702518224716187
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.853755750114483
#  Precision: 0.9126494448128466
#  Time: 27.588019371032715
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.84759085367619
#  Precision: 0.9112571542165409
#  Time: 26.560413599014282
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8371463527880091
#  Precision: 0.9072198334143344
#  Time: 28.31279754638672
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8549373234705534
#  Precision: 0.9138856748994073
#  Time: 28.592353343963623
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8566886929492304
#  Precision: 0.9137792063090406
#  Time: 28.316177368164062
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.85499802226407
#  Precision: 0.9136191027358708
#  Time: 29.54263710975647
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8490277916143498
#  Precision: 0.9111375804441247
#  Time: 28.378194332122803
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8432630736795518
#  Precision: 0.9090254913676923
#  Time: 27.69115447998047
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8580694359197282
#  Precision: 0.9140856904996476
#  Time: 28.594942092895508
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8470140675124981
#  Precision: 0.9094669384841567
#  Time: 29.199708700180054
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8407892547048198
#  Precision: 0.9077705009985562
#  Time: 27.17580246925354
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8673241572352752
#  Precision: 0.918886559049212
#  Time: 29.115649938583374
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8547268280675732
#  Precision: 0.9128810043491845
#  Time: 27.2454674243927
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8682683362737038
#  Precision: 0.9182977522012722
#  Time: 32.25822854042053
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8491746880762271
#  Precision: 0.9112646550063681
#  Time: 29.471172094345093
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8509050609210813
#  Precision: 0.9127040214318412
#  Time: 30.968149662017822
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8386696357576325
#  Precision: 0.9067283003382578
#  Time: 30.038974046707153
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8580361480321235
#  Precision: 0.9160182669938801
#  Time: 28.50193428993225
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8449102563506175
#  Precision: 0.90941016650948
#  Time: 27.270334720611572
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8579811442058908
#  Precision: 0.9128636162592972
#  Time: 29.4636812210083
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8575732537391283
#  Precision: 0.914438796337907
#  Time: 28.508094549179077
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
# ...
#  Precision: 0.9145182404094079
#  Time: 153.48279809951782
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment45.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8668243257197462
#  Precision: 0.9174242666465691
#  Time: 147.93712615966797
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8688117099548494
#  Precision: 0.9186427844491196
#  Time: 149.15901708602905
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8506083203974704
#  Precision: 0.9114064563466553
#  Time: 150.65722584724426
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8481715922260344
#  Precision: 0.9123639108550012
#  Time: 149.33200550079346
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.8642139404635291
#  Precision: 0.9172546327132216
#  Time: 150.18289875984192
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8670161668348236
#  Precision: 0.9170362780442742
#  Time: 152.14086055755615
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8666133697264865
#  Precision: 0.9180640485573947
#  Time: 150.84897708892822
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8669548471333357
#  Precision: 0.9181125902390015
#  Time: 162.79065084457397
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8502390740098804
#  Precision: 0.9099972512475292
#  Time: 165.4586431980133
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8654804825176975
#  Precision: 0.9172190255988073
#  Time: 154.3797688484192
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8584115017010366
#  Precision: 0.9140679131911401
#  Time: 155.48852038383484
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8553618536761497
#  Precision: 0.9137488920418307
#  Time: 153.15335416793823
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8774689809332151
#  Precision: 0.9230624839067343
#  Time: 156.01547074317932
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8642094537620519
#  Precision: 0.9178909938408377
#  Time: 159.29186034202576
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8756571433287719
#  Precision: 0.9218030458128987
#  Time: 155.4703574180603
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8656912066458684
#  Precision: 0.9171572877156939
#  Time: 163.1720311641693
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8573341112635384
#  Precision: 0.9145070038803609
#  Time: 162.06165146827698
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8485218729494944
#  Precision: 0.9117639109448317
#  Time: 161.88047194480896
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8604135663832546
#  Precision: 0.9153131464843727
#  Time: 153.07748579978943
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8498083499099195
#  Precision: 0.9122799274593131
#  Time: 156.7364513874054
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8682805270864218
#  Precision: 0.9172696325392309
#  Time: 162.9741072654724
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment16.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8717952925219714
#  Precision: 0.9202388785159483
#  Time: 161.1325969696045
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8539152782983739
#  Precision: 0.9135728420807969
#  Time: 163.26817107200623
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment18.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8586260189908144
#  Precision: 0.9137832889801512
#  Time: 160.3151457309723
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment19.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8668062490524231
#  Precision: 0.9181577096557196
#  Time: 158.87867903709412
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment20.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8605673698072828
#  Precision: 0.9155889202214774
#  Time: 155.96658539772034
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment21.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8746525555435386
#  Precision: 0.9205177638776629
#  Time: 152.05251336097717
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment22.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8589111062844247
#  Precision: 0.9162094952924648
#  Time: 154.03717255592346
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment23.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8677429964935423
#  Precision: 0.9184748565157449
#  Time: 155.71092104911804
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment24.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.856556627126456
#  Precision: 0.914610570433812
#  Time: 153.01634693145752
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment25.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8714285555661464
#  Precision: 0.9192586708183478
#  Time: 154.74214220046997
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment26.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.858811163736858
#  Precision: 0.9160452982816034
#  Time: 150.02695155143738
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment27.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.856757444689273
#  Precision: 0.9143663967669868
#  Time: 154.89507508277893
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment28.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8654306104995497
#  Precision: 0.9175206027074315
#  Time: 151.45869183540344
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment29.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8643093108579495
#  Precision: 0.9177398424839638
#  Time: 146.89124369621277
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment30.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8574189555373193
#  Precision: 0.9151049979418677
#  Time: 154.6946291923523
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment31.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8764549117371582
#  Precision: 0.9203585069392115
#  Time: 162.70185160636902
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment32.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8615793395250071
#  Precision: 0.9169616967209984
#  Time: 156.3665144443512
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment33.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8703321583477867
#  Precision: 0.9200804162113905
#  Time: 164.7157220840454
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment34.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8734648628235174
#  Precision: 0.9219116753824469
#  Time: 160.90152788162231
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment35.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8677969855117639
#  Precision: 0.9199450152982045
#  Time: 153.54860711097717
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment36.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8688366469809061
#  Precision: 0.9195262404957497
#  Time: 153.7107231616974
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment37.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8574112360223012
#  Precision: 0.9145243885504697
#  Time: 161.892107963562
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment38.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8572862292407076
#  Precision: 0.9147185327140717
#  Time: 161.37263369560242
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment39.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8755515446233852
#  Precision: 0.9211618825767875
#  Time: 159.84142780303955
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment40.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8538797335185513
#  Precision: 0.9133721365740906
#  Time: 159.2297809123993
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment41.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8775009051718001
#  Precision: 0.9224215656093822
#  Time: 153.08253645896912
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment42.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8543060542673709
#  Precision: 0.9132830558232093
#  Time: 154.1016561985016
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment43.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8630817170384899
#  Precision: 0.9162825425190122
#  Time: 157.50974225997925
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment44.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8611732639427219
#  Precision: 0.9171329801175895
#  Time: 164.4822289943695
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment45.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.868399050147624
#  Precision: 0.9180971134152232
#  Time: 164.26732182502747
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.862236205548572
#  Precision: 0.915491119923638
#  Time: 163.02045679092407
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8529906532918626
#  Precision: 0.9122201555943359
#  Time: 156.00293159484863
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8466284508477571
#  Precision: 0.911482924980151
#  Time: 166.175772190094
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/02-KMODES/ds-2/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.8622826853133899
#  Precision: 0.9149719427189982
#  Time: 156.12254524230957
# ===========================

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
for i in range(len(experiments)):
    for d in list(experiments[i].keys()):
        experiments[i][d] = str(experiments[i][d])

# %%
# experiments

# %%
cols = ['experiment_filter', 'undersampling_method', 'filename', 'experiment_id', 'n_covid', 'n_not_covid', 'model_name', 'params', 'model_AUC_ROC', 'model_AUC_PR', 'model_covid_precision', 'model_covid_recall', 'model_covid_f1', 'model_not_covid_precision', 'model_not_covid_recall', 'model_not_covid_f1', 'model_avg_precision', 'model_avg_recall', 'model_avg_f1', 'model_avg_acc', 'model_TP', 'model_TN', 'model_FN', 'model_FP', 'model_time_exec', 'model_col_set']

# %%
intermed_results = spark.createDataFrame(data=experiments).select(cols)
intermed_results.toPandas()
# Out:
# /usr/lib/spark/python/pyspark/sql/session.py:346: UserWarning: inferring schema from dict is deprecated,please use pyspark.sql.Row instead
#   warnings.warn("inferring schema from dict is deprecated,"

# %%
intermed_results.write.parquet('gs://ai-covid19-datalake/trusted/intermed_results/KMODES/GBT_experiments-kmodes-ds2-cs3.parquet', mode='overwrite')

# %%
df = spark.read.parquet('gs://ai-covid19-datalake/trusted/intermed_results/KMODES/GBT_experiments-kmodes-ds2-cs3.parquet')
df.limit(2).toPandas()
# Out:
#   experiment_filter undersampling_method  \
# 0              ds-2            02-KMODES
# 1              ds-2            02-KMODES
#
#                                             filename experiment_id n_covid  \
# 0  gs://ai-covid19-datalake/trusted/experiment_ma...            41   36968
# 1  gs://ai-covid19-datalake/trusted/experiment_ma...            42   29384
#
#   n_not_covid model_name                                          params  \
# 0       44538        GBT  {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
# 1       44538        GBT  {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#
#         model_AUC_ROC        model_AUC_PR model_covid_precision  \
# 0  0.9268317477990324  0.8813441660579747    0.8929398644591233
# 1  0.9250972275035864  0.8632207848885167    0.8782891288395009
#
#    model_covid_recall      model_covid_f1 model_not_covid_precision  \
# 0  0.9473923728042232  0.9193605370075959         0.954290233293792
# 1  0.9369268619995527  0.9066608949732157        0.9558996012197982
#
#   model_not_covid_recall  model_not_covid_f1 model_avg_precision  \
# 0     0.9062711227938415  0.9296610169491525  0.9236150488764576
# 1       0.91326759300762  0.9340974212034384  0.9170943650296496
#
#      model_avg_recall        model_avg_f1       model_avg_acc model_TP  \
# 0  0.9268317477990323  0.9245107769783742  0.9248621512632705    10409
# 1  0.9250972275035863   0.920379158088327  0.9227427445360086     8378
#
#   model_TN model_FN model_FP    model_time_exec model_col_set
# 0    12067      578     1248  154.7003951072693    cols_set_3
# 1    12225      564     1161  151.4044644832611    cols_set_3

# %%
print('finished')
# Out:
# finished

# %%
intermed_results.show()
# Out:
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# |experiment_filter|undersampling_method|            filename|experiment_id|n_covid|n_not_covid|model_name|              params|     model_AUC_ROC|      model_AUC_PR|model_covid_precision|model_covid_recall|    model_covid_f1|model_not_covid_precision|model_not_covid_recall|model_not_covid_f1|model_avg_precision|  model_avg_recall|      model_avg_f1|     model_avg_acc|model_TP|model_TN|model_FN|model_FP|   model_time_exec|model_col_set|
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|            0|  32065|      44538|       GBT|{'maxIter': 20, '...|  0.91909703126906|0.8505502077031721|   0.8624528301886792| 0.946474790350968|0.9025124635964263|       0.9587192590226764|    0.8917192721871519|0.9240063103620763| 0.9105860446056778|  0.91909703126906|0.9132593869792514|0.9145909012281612|    9142|   12007|     517|    1458| 41.46422266960144|   cols_set_3|
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|            1|  30946|      44538|       GBT|{'maxIter': 20, '...|0.9186289142418711|0.8465516406295701|   0.8592570520460866|0.9437111377768082|0.8995061086560957|       0.9584206285253828|    0.8935466907069342|0.9248474009564169| 0.9088388402857347|0.9186289142418711|0.9121767548062563|0.9140048046979269|    8651|   11894|     516|    1417|28.389264345169067|   cols_set_3|
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|            2|  30471|      44538|       GBT|{'maxIter': 20, '...|0.9201309601755657|0.8514086174611258|   0.8647672552166934|0.9415619879847078|0.9015321863724312|       0.9571794461341444|    0.8986999323664236|0.9270183326227666|  0.910973350675419|0.9201309601755657|0.9142752594975989|0.9161695307630665|    8620|   11959|     535|    1348|27.054616451263428|   cols_set_3|
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|            3|  28398|      44538|       GBT|{'maxIter': 20, '...|0.9184749759587122|0.8359674851835959|   0.8491314604331975|0.9429626101452727|0.8935906116000903|       0.9611957226182761|    0.8939873417721519| 0.926374141161774| 0.9051635915257368|0.9184749759587123|0.9099823763809322|0.9129672358098754|    7919|   11865|     479|    1407| 25.23535132408142|   cols_set_3|
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|            4|  32372|      44538|       GBT|{'maxIter': 20, '...|0.9178234031897669|0.8495312886784019|   0.8620393354974222|0.9437650256088638|0.9010528416745671|       0.9568148980574731|    0.8918817807706697|0.9232079928745692| 0.9094271167774477|0.9178234031897667|0.9121304172745681| 0.913526949241235|    9029|   11920|     538|    1445|25.133219718933105|   cols_set_3|
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|            5|  28944|      44538|       GBT|{'maxIter': 20, '...| 0.917930377204172|0.8325398224993548|   0.8446248308877095| 0.946914012367285|0.8928492849284929|       0.9633241979687248|    0.8889467420410592|0.9246421663442939| 0.9039745144282172| 0.917930377204172|0.9087457256363933|0.9115148762207586|    8116|   11951|     455|    1493|25.749501705169678|   cols_set_3|
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|            6|  27646|      44538|       GBT|{'maxIter': 20, '...|0.9167010896717778|0.8334919509299106|   0.8483432916892993|0.9364432186113443| 0.890218878248974|       0.9582084844661726|    0.8969589607322114|0.9265726267632481|  0.903275888077736|0.9167010896717778| 0.908395752506111|0.9120025585964271|    7809|   12152|     530|    1396| 23.54803490638733|   cols_set_3|
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|            7|  36069|      44538|       GBT|{'maxIter': 20, '...|0.9196882729961048|0.8600538646337825|   0.8701497617426821|0.9526737469722377|0.9095437160900115|       0.9592000642518673|    0.8867027990199717|0.9215277777777777| 0.9146749129972747|0.9196882729961047|0.9155357469338946|0.9159608313019048|   10226|   11943|     508|    1526| 24.98399519920349|   cols_set_3|
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|            8|  31147|      44538|       GBT|{'maxIter': 20, '...|0.9192022607692587|0.8475606025751107|   0.8587268208755496|0.9495824965648452|0.9018722080008031|       0.9611974294313838|    0.8888220249736724|0.9235940125845156| 0.9099621251534666|0.9192022607692587|0.9127331102926594|0.9140848165238409|    8984|   11816|     477|    1478| 25.25086259841919|   cols_set_3|
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|            9|  35810|      44538|       GBT|{'maxIter': 20, '...|0.9205534736138891| 0.865196342172409|   0.8764162454244379|0.9480531724332988|0.9108283139350574|       0.9555358295674629|    0.8930537747944792|0.9232388600834276| 0.9159760374959504| 0.920553473613889|0.9170335870092425|0.9174976954663538|   10056|   11841|     551|    1418| 23.99194836616516|   cols_set_3|
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|           10|  30940|      44538|       GBT|{'maxIter': 20, '...|0.9194494696387774| 0.851823387914443|   0.8647648719696233|0.9426873275313097|0.9020464124308131|       0.9569171852561034|    0.8962116117462452|0.9255700891306864| 0.9108410286128633|0.9194494696387774|0.9138082507807497|0.9154132865599649|    8882|   11994|     540|    1389| 23.68980360031128|   cols_set_3|
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|           11|  29751|      44538|       GBT|{'maxIter': 20, '...|0.9175247872859319|0.8405221983743851|   0.8541258885340476|0.9405558706749858|0.8952596911780585|       0.9581770292920425|     0.894493703896878|0.9252408477842003|  0.906151458913045|0.9175247872859319|0.9102502694811294|0.9127540924626731|    8291|   12005|     524|    1416|23.723393440246582|   cols_set_3|
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|           12|  26213|      44538|       GBT|{'maxIter': 20, '...|0.9186121451065308|0.8321525791813509|   0.8465420346369996| 0.939058524173028|0.8904035225284999|       0.9609934853420196|    0.8981657660400335|0.9285180376883434| 0.9037677599895095|0.9186121451065308|0.9094607801084216|0.9134720700985761|    7381|   11801|     479|    1338|25.142306804656982|   cols_set_3|
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|           13|  31151|      44538|       GBT|{'maxIter': 20, '...|0.9174473084531116|0.8473278955506701|   0.8603449956144625|0.9419547588561673|0.8993021952834513|       0.9564660691421255|     0.892939858050056|0.9236119160774313|  0.908405532378294|0.9174473084531116|0.9114570556804413|0.9131256316737707|    8828|   11952|     544|    1433|23.953820943832397|   cols_set_3|
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|           14|  27706|      44538|       GBT|{'maxIter': 20, '...|0.9190744863631296|0.8410609037794002|   0.8548229944787269|0.9406719085060757|0.8956950825250979|        0.959303750919343|    0.8974770642201835|0.9273610617371726| 0.9070633726990349|0.9190744863631296|0.9115280721311352|0.9143615535065661|    7896|   11739|     498|    1341|25.131107091903687|   cols_set_3|
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|           15|  33551|      44538|       GBT|{'maxIter': 20, '...|0.9186852059114267|0.8559495993438647|   0.8673913043478261|0.9474621549421193|0.9056603773584905|       0.9570562070359887|    0.8899082568807339|0.9222616217901258| 0.9122237556919074|0.9186852059114266|0.9139609995743081|0.9147618030335398|    9576|   11834|     531|    1464| 24.62631344795227|   cols_set_3|
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|           16|  33634|      44538|       GBT|{'maxIter': 20, '...|0.9168820537498243|0.8548177267679088|   0.8671418128654971|0.9434337409285217| 0.903680426605723|       0.9540127697405641|    0.8903303665711269|0.9210721392064296| 0.9105772913030306|0.9168820537498243|0.9123762829060763| 0.913239267487241|    9490|   11804|     569|    1454|25.298471689224243|   cols_set_3|
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|           17|  27910|      44538|       GBT|{'maxIter': 20, '...|0.9163398973994341|0.8335033526492173|   0.8479030355035932|0.9378336694744335|0.8906038756196486|       0.9583829719641014|    0.8948461253244345| 0.925525387329345| 0.9031430037338473| 0.916339897399434|0.9080646314744968|0.9113808524231085|    7905|   12067|     524|    1418|25.017157316207886|   cols_set_3|
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|           18|  29154|      44538|       GBT|{'maxIter': 20, '...|0.9199239741518812|0.8458935255144177|   0.8589276418532015|0.9431805190350977|0.8990845684394071|       0.9594451244390045|    0.8966674292686647|0.9269946389151688|  0.909186383146103|0.9199239741518812|0.9130396036772879|0.9152790484903934|    8250|   11758|     497|    1355|24.008692502975464|   cols_set_3|
# |             ds-2|           02-KMODES|gs://ai-covid19-d...|           19|  31063|      44538|       GBT|{'maxIter': 20, '...|0.9176823370898507|0.8497485899041545|   0.8622621462378055|0.9436575052854123|0.9011255236460909|       0.9565784114052953|    0.8917071688942891|0.9230043626930786| 0.9094202788215504|0.9176823370898507|0.9120649431695848|0.9134258440869719|    8927|   11742|     533|    1426| 24.91522765159607|   cols_set_3|
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# only showing top 20 rows
