# %%
import pandas as pd
import pyspark.sql.functions as F
from datetime import datetime
from pyspark.sql.types import *
from pyspark import StorageLevel

import numpy as np
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", 1000)
pd.set_option("mode.chained_assignment", None)

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import GBTClassifier
from pyspark.ml.feature import IndexToString, StringIndexer, VectorIndexer
# from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import OneHotEncoderEstimator, StringIndexer, VectorAssembler

from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

from pyspark.sql import Row
from pyspark.ml.linalg import Vectors

# %%
# !pip install scikit-plot

# %%
import sklearn
import scikitplot as skplt
from sklearn.metrics import classification_report, confusion_matrix, precision_score

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
result_schema = StructType([
                    StructField('experiment_filter', StringType(), True),
                    StructField('undersampling_method', StringType(), True),
                    StructField('undersampling_column', StringType(), True),
                    StructField('filename', StringType(), True),
                    StructField('experiment_id', StringType(), True),
                    StructField('n_covid', IntegerType(), True),
                    StructField('n_not_covid', IntegerType(), True),
                    StructField('model_name', StringType(), True),
                    StructField('model_seed', StringType(), True),
                    StructField('model_maxIter', IntegerType(), True),
                    StructField('model_maxDepth', IntegerType(), True),
                    StructField('model_maxBins', IntegerType(), True),
                    StructField('model_minInstancesPerNode', IntegerType(), True),
                    StructField('model_minInfoGain', FloatType(), True),
                    StructField('model_featureSubsetStrategy', StringType(), True),
                    StructField('model_n_estimators', IntegerType(), True),
                    StructField('model_learning_rate', FloatType(), True),
                    StructField('model_impurity', StringType(), True),
                    StructField('model_AUC_ROC', StringType(), True),
                    StructField('model_AUC_PR', StringType(), True),
                    StructField('model_covid_precision', StringType(), True),
                    StructField('model_covid_recall', StringType(), True),
                    StructField('model_covid_f1', StringType(), True),
                    StructField('model_not_covid_precision', StringType(), True),
                    StructField('model_not_covid_recall', StringType(), True),
                    StructField('model_not_covid_f1', StringType(), True),
                    StructField('model_avg_precision', StringType(), True),
                    StructField('model_avg_recall', StringType(), True),
                    StructField('model_avg_f1', StringType(), True),
                    StructField('model_avg_acc', StringType(), True),
                    StructField('model_TP', StringType(), True),
                    StructField('model_TN', StringType(), True),
                    StructField('model_FN', StringType(), True),
                    StructField('model_FP', StringType(), True),
                    StructField('model_time_exec', StringType(), True),
                    StructField('model_col_set', StringType(), True)
                          ])

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# undersamp_col = ['03-STRSAMP-AG', '04-STRSAMP-EW'] 
# dfs = ['ds-1', 'ds-2', 'ds-3']
# cols_sets = ['cols_set_1', 'cols_set_2', 'cols_set_3']

undersamp_col = ['04-STRSAMP-EW']
dfs = ['ds-2']
cols_sets = ['cols_set_3']

# %%
# lists of params
model_maxIter = [20, 50, 100] 
model_maxDepth = [3, 5, 7] 
model_maxBins = [32, 64] 
# model_learningRate = [0.01, 0.1, 0.5]
# model_loss = ['logLoss', 'leastSquaresError', 'leastAbsoluteError']



list_of_param_dicts = []

for maxIter in model_maxIter:
    for maxDepth in model_maxDepth:
        for maxBins in model_maxBins: 
            params_dict = {}
            params_dict['maxIter'] = maxIter
            params_dict['maxDepth'] = maxDepth
            params_dict['maxBins'] = maxBins
            list_of_param_dicts.append(params_dict)

print("There is {} set of params.".format(len(list_of_param_dicts)))
# list_of_param_dicts
# Out:
# There is 18 set of params.

# %%
prefix = 'gs://ai-covid19-datalake/trusted/experiment_map/'

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
# filename = 'gs://ai-covid19-datalake/trusted/experiment_map/03-STRSAMP-AG/ds-1/cols_set_1/experiment0.parquet'
# df = spark.read.parquet(filename)
# df.limit(2).toPandas()

# %%
# params_dict = {'maxIter': 100,
#                'maxDepth': 3,
#                'maxBins': 32,
#                'learningRate': 0.5,
#                'loss': 'leastAbsoluteError'}
# cols = 'cols_set_1'
# experiment_filter = 'ds-1'
# undersampling_method = '03-STRSAMP-AG', 
# experiment_id = 0

# %%
# run_gbt(df, params_dict, cols, filename, experiment_filter, undersampling_method, experiment_id)

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
def run_gbt(exp_df, params_dict, cols, filename, experiment_filter, 
            undersampling_method, experiment_id):
    import time
    start_time = time.time()
    
    n_covid = exp_df.filter(F.col('CLASSI_FIN') == 1.0).count()
    n_not_covid = exp_df.filter(F.col('CLASSI_FIN') == 0.0).count()
    
    
    id_cols = ['NU_NOTIFIC', 'CLASSI_FIN']

    labelIndexer = StringIndexer(inputCol="CLASSI_FIN", outputCol="indexedLabel").fit(exp_df)    
    
    input_cols = [x for x in exp_df.columns if x not in id_cols]
    assembler = VectorAssembler(inputCols = input_cols, outputCol= 'features')
    exp_df = assembler.transform(exp_df)
    
    # Automatically identify categorical features, and index them.
    # Set maxCategories so features with > 4 distinct values are treated as continuous.
    featureIndexer = VectorIndexer(inputCol="features", outputCol="indexedFeatures", maxCategories=30).fit(exp_df)
    
    # Split the data into training and test sets (30% held out for testing)
    (trainingData, testData) = exp_df.randomSplit([0.7, 0.3])
    trainingData = trainingData.persist(StorageLevel.MEMORY_ONLY)
    testData = testData.persist(StorageLevel.MEMORY_ONLY)
    
    # Train a RandomForest model.
    gbt = GBTClassifier(labelCol = "indexedLabel", featuresCol = "indexedFeatures",
                       maxIter = params_dict['maxIter'],
                       maxDepth = params_dict['maxDepth'],
                       maxBins = params_dict['maxBins'])
    
    # Convert indexed labels back to original labels.
    labelConverter = IndexToString(inputCol="prediction", outputCol="predictedLabel",
                               labels=labelIndexer.labels)

    # Chain indexers and forest in a Pipeline
    pipeline = Pipeline(stages=[labelIndexer, featureIndexer, gbt, labelConverter])

    # Train model.  This also runs the indexers.
    model = pipeline.fit(trainingData)
    
    # Make predictions.
    predictions = model.transform(testData)    
    
    
    pred = predictions.select(['CLASSI_FIN', 'predictedLabel'])\
                  .withColumn('predictedLabel', F.col('predictedLabel').cast('double'))\
                  .withColumn('predictedLabel', F.when(F.col('predictedLabel') == 1.0, 'covid').otherwise('n-covid'))\
                  .withColumn('CLASSI_FIN', F.when(F.col('CLASSI_FIN') == 1.0, 'covid').otherwise('n-covid'))\
                  .toPandas()

    y_true = pred['CLASSI_FIN'].tolist()
    y_pred = pred['predictedLabel'].tolist()
    
    report = classification_report(y_true, y_pred, output_dict=True)
    
    
    evaluator_ROC = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderROC")
    accuracy_ROC = evaluator_ROC.evaluate(predictions)


    
    evaluator_PR = BinaryClassificationEvaluator(labelCol="indexedLabel", rawPredictionCol="prediction", metricName="areaUnderPR")
    accuracy_PR = evaluator_PR.evaluate(predictions)
    
    conf_matrix = confusion_matrix(y_true, y_pred)

    result_dict = {}
    
    result_dict['experiment_filter'] = experiment_filter
    result_dict['undersampling_method'] = undersampling_method
    result_dict['filename'] = filename
    result_dict['experiment_id'] = experiment_id
    result_dict['n_covid'] = n_covid
    result_dict['n_not_covid'] = n_not_covid
    result_dict['model_name'] = 'GBT'
    result_dict['params'] = params_dict
    result_dict['model_AUC_ROC'] = accuracy_ROC
    result_dict['model_AUC_PR'] = accuracy_PR
    result_dict['model_covid_precision'] = report['covid']['precision']
    result_dict['model_covid_recall'] = report['covid']['recall']
    result_dict['model_covid_f1'] = report['covid']['f1-score']
    result_dict['model_not_covid_precision'] = report['n-covid']['precision']
    result_dict['model_not_covid_recall'] = report['n-covid']['recall']
    result_dict['model_not_covid_f1'] = report['n-covid']['f1-score']
    result_dict['model_avg_precision'] = report['macro avg']['precision']
    result_dict['model_avg_recall'] = report['macro avg']['recall']
    result_dict['model_avg_f1'] = report['macro avg']['f1-score']
    result_dict['model_avg_acc'] = report['accuracy']
    result_dict['model_TP'] = conf_matrix[0][0]
    result_dict['model_TN'] = conf_matrix[1][1]
    result_dict['model_FN'] = conf_matrix[0][1]
    result_dict['model_FP'] = conf_matrix[1][0]
    result_dict['model_time_exec'] = time.time() - start_time
    result_dict['model_col_set'] = cols
    
    return result_dict

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %% [markdown]
# # Running GBT on 10 samples for each experiment
# ### 3x col sets -> ['cols_set_1', 'cols_set_2', 'cols_set_3']
# ### 3x model_maxIter -> [100, 200, 300]
# ### 3x model_maxDepth -> [5, 10, 15]
# ### 3x model_maxBins -> [16, 32, 64]
# Total: 10 * 3 * 3 * 3 * 3 = 810

# %%
experiments = []

# %% [markdown]
# ### Datasets: strat_samp_lab_agegrp

# %%
for uc in undersamp_col: 
    for ds in dfs:
        for col_set in cols_sets:
            for params_dict in list_of_param_dicts: 
                for id_exp in range(50):
                    filename = prefix + uc + '/' + ds + '/' + col_set + '/' + 'experiment' + str(id_exp) + '.parquet'
                    exp_dataframe = spark.read.parquet(filename)
#                     if 'SG_UF_NOT' in exp_dataframe.columns:
#                         exp_dataframe = exp_dataframe.withColumn('SG_UF_NOT', F.col('SG_UF_NOT').cast('float'))
                    print('read {}'.format(filename))
                    
                    undersampling_method = uc
                    experiment_filter = ds
                    experiment_id = id_exp

                    try:                     
                        model = run_gbt(exp_dataframe, params_dict, col_set, filename, experiment_filter, undersampling_method, experiment_id)
                        experiments.append(model)

                        print("Parameters ==> {}\n Results: \n AUC_PR: {} \n Precision: {} \n Time: {}".format(str(params_dict), str(model['model_AUC_PR']), str(model['model_avg_precision']), str(model['model_time_exec'])))
                        print('=========================== \n')
                    except:
                        print('=========== W A R N I N G =========== \n')
                        print('Something wrong with the exp: {}, {}, {}'.format(filename, params_dict, col_set))
# Out:
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.915595324497113
#  Precision: 0.925422918787518
#  Time: 26.11881923675537
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9175969130918951
#  Precision: 0.9249786834295501
#  Time: 15.510443687438965
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9189051037158987
#  Precision: 0.9272963668730219
#  Time: 14.964608430862427
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9221740707715611
#  Precision: 0.9266523003091443
#  Time: 13.695220232009888
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9165757081648644
#  Precision: 0.923959871478476
#  Time: 15.157051086425781
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9209055225485867
#  Precision: 0.926320201233716
#  Time: 12.91630744934082
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9197552271833211
#  Precision: 0.9263459313294808
#  Time: 12.947561025619507
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9152073006666026
#  Precision: 0.9249921496821717
#  Time: 13.201907634735107
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9233159696331703
#  Precision: 0.9268717912931288
#  Time: 12.81569528579712
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9178248575248926
#  Precision: 0.9281242997524305
#  Time: 12.644547939300537
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9194439908207891
#  Precision: 0.9252000515259096
#  Time: 12.786217451095581
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9163259927710692
#  Precision: 0.9259669313097996
#  Time: 12.70435094833374
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9173267341563385
#  Precision: 0.923564222664005
#  Time: 12.891528606414795
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9198556306320812
#  Precision: 0.9256596811701545
#  Time: 13.819063663482666
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9145683983479005
#  Precision: 0.9243922837301721
#  Time: 12.830574989318848
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9181546113186847
#  Precision: 0.9256203363579835
#  Time: 21.98294472694397
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9174887457922779
#  Precision: 0.9245892253913643
#  Time: 12.306756496429443
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9192227325942338
#  Precision: 0.9278244451581574
#  Time: 13.838562250137329
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.917554384231346
#  Precision: 0.9229943604187847
#  Time: 12.352733373641968
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9148520122704197
#  Precision: 0.9243566483923717
#  Time: 12.40332555770874
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9185919588104781
#  Precision: 0.9243415000434216
#  Time: 12.394972324371338
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9175574186570308
#  Precision: 0.9258104641050204
#  Time: 13.395314455032349
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9205234799536953
#  Precision: 0.9268431882720993
#  Time: 12.579327583312988
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9200399355666745
#  Precision: 0.9248855745259882
#  Time: 12.738784313201904
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9227581754858416
#  Precision: 0.9282296826578497
#  Time: 12.6811044216156
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.917866672176425
#  Precision: 0.9257198511450806
#  Time: 13.171200513839722
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9223501721798206
#  Precision: 0.9255465315578579
#  Time: 13.184033155441284
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9180118858870274
#  Precision: 0.9248194420481446
#  Time: 12.44285273551941
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9190648341163308
#  Precision: 0.9246909960482288
#  Time: 12.429792404174805
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9227291621198523
#  Precision: 0.9262822407713747
#  Time: 12.100436449050903
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9197289834136579
#  Precision: 0.926651160780699
#  Time: 14.22754955291748
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9176280587727027
#  Precision: 0.9259064287991592
#  Time: 14.471999645233154
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9194992744582599
#  Precision: 0.925260787996139
#  Time: 12.801737785339355
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9234527575231909
#  Precision: 0.9288301285541665
#  Time: 12.3828706741333
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.920730859900175
#  Precision: 0.927684211494803
#  Time: 13.07155466079712
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9213719126045224
#  Precision: 0.9263690660064882
#  Time: 12.560124158859253
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9188467809521967
#  Precision: 0.925095456995333
#  Time: 12.745115756988525
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.918426623680462
#  Precision: 0.9232813142200289
#  Time: 12.522678136825562
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9189756484294704
#  Precision: 0.9249600638718545
#  Time: 12.24786901473999
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9190284430263008
#  Precision: 0.9251428672442917
#  Time: 12.402988195419312
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9213199040714439
#  Precision: 0.9251604723323901
#  Time: 12.351912498474121
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9176260607282936
#  Precision: 0.9260933767873671
#  Time: 12.465346097946167
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9145512510533894
#  Precision: 0.9253827845412834
#  Time: 13.328950643539429
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.917478960728935
#  Precision: 0.9245221709591187
#  Time: 12.270230531692505
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9196404883502267
#  Precision: 0.9259400004576719
#  Time: 13.165596008300781
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9168273936509219
#  Precision: 0.9241823009462216
#  Time: 12.449880123138428
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9152176666922537
#  Precision: 0.923349352392705
#  Time: 12.79542589187622
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9209855378186445
#  Precision: 0.9253966699979075
#  Time: 12.802125215530396
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9193591133576976
#  Precision: 0.927273170030156
#  Time: 12.292447566986084
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9185588759318333
#  Precision: 0.9251984265627671
#  Time: 12.561107397079468
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9168184401134766
#  Precision: 0.9254580650316695
#  Time: 12.95038628578186
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9181996404579086
#  Precision: 0.9257749215529931
#  Time: 12.19400954246521
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.918969821045034
#  Precision: 0.9261987304944013
#  Time: 12.27356219291687
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9211413774356609
#  Precision: 0.9282958580900291
#  Time: 12.943024635314941
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9179109740845371
#  Precision: 0.925008040875779
#  Time: 12.128179550170898
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9223326532911125
#  Precision: 0.9268395611242806
#  Time: 12.390848398208618
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9196151521320897
#  Precision: 0.9277998588260845
#  Time: 15.213690757751465
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.917727072075954
#  Precision: 0.9253137985968665
#  Time: 12.385655164718628
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.924045622648602
#  Precision: 0.928377901677603
#  Time: 11.781197309494019
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9203921030375637
#  Precision: 0.9276772410964567
#  Time: 12.040411233901978
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9173056025294003
#  Precision: 0.9258122719751218
#  Time: 11.936841249465942
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9161143991586693
#  Precision: 0.9251148005496188
#  Time: 11.9222092628479
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9172209633921056
#  Precision: 0.925177411967163
#  Time: 12.020120620727539
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9176239677470162
#  Precision: 0.9247468788080828
#  Time: 12.652068614959717
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9155736954026013
#  Precision: 0.9248671905497378
#  Time: 12.733354806900024
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.918522264600363
#  Precision: 0.926565768088508
#  Time: 12.30277156829834
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.916182749298742
#  Precision: 0.9243918390053523
#  Time: 12.418057918548584
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9202982580138561
#  Precision: 0.9255371648957356
#  Time: 12.109680652618408
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9179698004495631
#  Precision: 0.9241119579749846
#  Time: 12.799158334732056
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9163562635549651
#  Precision: 0.9230555734723721
#  Time: 12.3893723487854
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9180978849955586
#  Precision: 0.9254094343559516
#  Time: 12.351017236709595
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.914445756881202
#  Precision: 0.9234009021632417
#  Time: 12.575309753417969
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9164932356693279
#  Precision: 0.9230707652363253
#  Time: 12.53295373916626
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9190637460583307
#  Precision: 0.9259518076707043
#  Time: 12.430519104003906
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9185348455573896
#  Precision: 0.9242970122442888
#  Time: 12.471083164215088
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9164246642087718
#  Precision: 0.9238967170101822
#  Time: 12.12572717666626
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9206401886767915
#  Precision: 0.9270848692598319
#  Time: 12.667641878128052
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9198793569921118
#  Precision: 0.9255469748876295
#  Time: 12.76247239112854
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9175886233843156
#  Precision: 0.9255810018557117
#  Time: 13.148872375488281
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9125240536210315
#  Precision: 0.9225513932232545
#  Time: 12.749439001083374
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9169292710889988
#  Precision: 0.9247789262837963
#  Time: 12.70809268951416
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.917642800867628
#  Precision: 0.9249526027316834
#  Time: 12.237125635147095
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.917260053716104
#  Precision: 0.9241102189835553
#  Time: 12.892696857452393
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9164878886851019
#  Precision: 0.9250882168798908
#  Time: 12.550904273986816
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9182501163077985
#  Precision: 0.9271393788197758
#  Time: 14.618141412734985
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9174639401871344
#  Precision: 0.9249942035579113
#  Time: 12.761044025421143
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9192633607948821
#  Precision: 0.924385363229507
#  Time: 12.798795938491821
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.916212059195195
#  Precision: 0.923577747370909
#  Time: 12.605657815933228
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9210284929759277
#  Precision: 0.9262378557799166
#  Time: 12.382825374603271
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9191241355543782
#  Precision: 0.9250082158041069
#  Time: 12.597013473510742
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9163117860306699
#  Precision: 0.92489163555587
#  Time: 15.970953226089478
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9220087174055074
#  Precision: 0.9256357760159344
#  Time: 12.193201541900635
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9167512588222001
#  Precision: 0.9251671416712159
#  Time: 14.290136337280273
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9182486599465303
#  Precision: 0.9247725093832428
#  Time: 13.972806692123413
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9197213628258778
#  Precision: 0.9241977135754355
#  Time: 13.01670789718628
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9157015153977119
#  Precision: 0.924228049595957
#  Time: 12.106269121170044
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9193508521606516
#  Precision: 0.9261537610230839
#  Time: 12.69070816040039
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9177432369979526
#  Precision: 0.9247459391940016
#  Time: 13.012587070465088
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.916188063918648
#  Precision: 0.9238461296887505
#  Time: 12.58013129234314
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 3, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9157016148200137
#  Precision: 0.9240174857551156
#  Time: 12.603516101837158
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.920436323783753
#  Precision: 0.9305888190080213
#  Time: 16.20459485054016
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9159323736369462
#  Precision: 0.9259505233919736
#  Time: 16.787633419036865
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.917189935820653
#  Precision: 0.927532990630461
#  Time: 16.275673389434814
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.920163059262003
#  Precision: 0.9286995850948534
#  Time: 15.615489721298218
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9201667992857396
#  Precision: 0.9280471422416761
#  Time: 16.57680583000183
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9173640738957771
#  Precision: 0.9283361553693719
#  Time: 15.729720115661621
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9161606291782126
#  Precision: 0.9276511592789152
#  Time: 15.622644186019897
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9157085920195496
#  Precision: 0.926720720826866
#  Time: 15.941505193710327
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9199214283782831
#  Precision: 0.9288431824274118
#  Time: 22.10808563232422
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9204113475930422
#  Precision: 0.9292605277095962
#  Time: 15.566986322402954
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9183791096866346
#  Precision: 0.9276452932470858
#  Time: 18.336873531341553
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9177217134863201
#  Precision: 0.9261519236632847
#  Time: 15.326995134353638
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9184867215672972
#  Precision: 0.9265091230458673
#  Time: 15.511296272277832
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9182056671575711
#  Precision: 0.9267883554789931
#  Time: 16.842609405517578
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9143281483307846
#  Precision: 0.9261631334098617
#  Time: 15.381603240966797
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9205356454647521
#  Precision: 0.9270322887730578
#  Time: 15.694262266159058
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment16.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9181030892531085
#  Precision: 0.9272550368167791
#  Time: 15.712554931640625
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9175612359113509
#  Precision: 0.9267487947393417
#  Time: 16.235169410705566
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment18.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9186717453352135
#  Precision: 0.9275741111356168
#  Time: 15.794488430023193
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment19.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9209345549235044
#  Precision: 0.9281616334556002
#  Time: 15.646991968154907
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment20.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9185812872307861
#  Precision: 0.9281497558556036
#  Time: 16.397427082061768
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment21.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9187386414201293
#  Precision: 0.9286593091662878
#  Time: 15.584775924682617
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment22.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9166580574240824
#  Precision: 0.9271744427894915
#  Time: 17.18828010559082
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment23.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9167962972392264
#  Precision: 0.9258441940438794
#  Time: 15.307629108428955
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment24.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9160310219777822
#  Precision: 0.927609726483799
#  Time: 16.31743860244751
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment25.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9187371354413704
#  Precision: 0.9288183723428641
#  Time: 16.082829236984253
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment26.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.916309658086392
#  Precision: 0.9261201903545175
#  Time: 16.011404514312744
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment27.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9173025621985056
#  Precision: 0.9286390829544604
#  Time: 15.679853677749634
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment28.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9205371788784635
#  Precision: 0.9282469758189077
#  Time: 16.001428604125977
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment29.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.920232431367094
#  Precision: 0.9284832946856904
#  Time: 15.738093614578247
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment30.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9153410737241878
#  Precision: 0.9262904351608936
#  Time: 15.16516375541687
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment31.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9159890563784853
#  Precision: 0.9264706689434989
#  Time: 15.751749753952026
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment32.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9176048107073254
#  Precision: 0.9269773391962126
#  Time: 15.546667337417603
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment33.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9163584766553146
#  Precision: 0.9265940578551954
#  Time: 15.374580383300781
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment34.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9187064895244175
#  Precision: 0.9268276553685153
#  Time: 15.349638223648071
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment35.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9172345403028428
#  Precision: 0.9281889040884714
#  Time: 16.72626042366028
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment36.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9159822993525852
#  Precision: 0.9263275850632486
#  Time: 16.42714524269104
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment37.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9140942085664149
#  Precision: 0.9238768469756167
#  Time: 15.526309967041016
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment38.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9212626060625968
#  Precision: 0.9283581389628
#  Time: 14.729964017868042
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment39.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9170730930837647
#  Precision: 0.9283977082835353
#  Time: 15.407367706298828
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment40.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9172365254158431
#  Precision: 0.9270628846299237
#  Time: 15.488203763961792
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment41.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9178567005885118
#  Precision: 0.928682581732118
#  Time: 16.313996076583862
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment42.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9155906735408635
#  Precision: 0.9275790367963166
#  Time: 15.653674840927124
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment43.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9205540630572747
#  Precision: 0.9282305154031278
#  Time: 15.872995853424072
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment44.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9146516784909594
#  Precision: 0.925887018357301
#  Time: 15.73415732383728
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment45.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9170379151496761
#  Precision: 0.9266323679733355
#  Time: 15.050064325332642
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9197805291771816
#  Precision: 0.9277455582905264
#  Time: 14.893261432647705
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9186818989294537
#  Precision: 0.9260525385676805
#  Time: 14.795919179916382
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9201193588411628
#  Precision: 0.9291343115326416
#  Time: 16.376569509506226
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9167643958499585
#  Precision: 0.9265065591688122
#  Time: 15.251793384552002
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9171122602064237
#  Precision: 0.9272902169479329
#  Time: 15.259997844696045
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9173422049773541
#  Precision: 0.9279182839389283
#  Time: 15.297879934310913
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9215909379900641
#  Precision: 0.9302874519789966
#  Time: 15.96919322013855
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9194362230168796
#  Precision: 0.9284568327736312
#  Time: 15.136084079742432
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9190772648843026
#  Precision: 0.927721213998477
#  Time: 15.165514707565308
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9178009802357666
#  Precision: 0.9261346378806543
#  Time: 15.082533836364746
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9190164935834171
#  Precision: 0.9286084971848186
#  Time: 15.600088357925415
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.918261920529832
#  Precision: 0.9278826571987173
#  Time: 15.918477773666382
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9206657982752269
#  Precision: 0.9299535535853765
#  Time: 15.37785029411316
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9207369676930578
#  Precision: 0.9294767061923864
#  Time: 15.392348527908325
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.919503948933811
#  Precision: 0.928170457930674
#  Time: 15.386937618255615
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9165396188632726
#  Precision: 0.9272552021142813
#  Time: 15.401280403137207
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9182625131169058
#  Precision: 0.9263367014358903
#  Time: 15.260161876678467
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 20, 'maxDepth': 5, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9165884722238813
#  Precision: 0.9275970196170891
#  Time: 15.621917247772217
# ===========================
#
# ...
#  Results:
#  AUC_PR: 0.9233843284411558
#  Precision: 0.9305052033399303
#  Time: 120.60589814186096
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9235604894674695
#  Precision: 0.9316851439064425
#  Time: 120.52438879013062
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9227619458961297
#  Precision: 0.9308756511160898
#  Time: 122.74178266525269
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9207687997765568
#  Precision: 0.9294417578115604
#  Time: 122.7989752292633
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 32}
#  Results:
#  AUC_PR: 0.9203409997203724
#  Precision: 0.9293237799062375
#  Time: 124.78846096992493
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment0.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9240004479329573
#  Precision: 0.9323463127643067
#  Time: 123.05401659011841
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment1.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9233935434162048
#  Precision: 0.9316655920959525
#  Time: 119.98395729064941
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment2.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9243973215742386
#  Precision: 0.9326138631535403
#  Time: 123.56613326072693
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment3.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9216446701744139
#  Precision: 0.9302983127854554
#  Time: 120.48421859741211
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment4.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9197052643296503
#  Precision: 0.9296189972255597
#  Time: 120.78335404396057
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment5.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9238401408808277
#  Precision: 0.9307269245050693
#  Time: 122.82532620429993
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment6.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9212087400763613
#  Precision: 0.9296426980437762
#  Time: 121.73197555541992
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment7.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.922132615118888
#  Precision: 0.9315368809718425
#  Time: 122.02982687950134
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment8.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9236108458267536
#  Precision: 0.9334834530222895
#  Time: 122.80508613586426
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment9.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9240432305334195
#  Precision: 0.9331303235226991
#  Time: 122.27866983413696
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment10.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9218395926393756
#  Precision: 0.9311628528211877
#  Time: 127.794269323349
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment11.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9220815878149451
#  Precision: 0.9311136063081014
#  Time: 121.76351022720337
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment12.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.924264522739507
#  Precision: 0.9321320614031223
#  Time: 122.11421585083008
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment13.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9183731979955647
#  Precision: 0.928453249713291
#  Time: 122.34186458587646
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment14.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9211583298269735
#  Precision: 0.9312850424055699
#  Time: 122.5757372379303
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment15.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.924326574997201
#  Precision: 0.9312790648548002
#  Time: 121.70778036117554
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment16.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9234489118895999
#  Precision: 0.9311006375946744
#  Time: 123.63703322410583
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment17.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9217202490364194
#  Precision: 0.9309087678810494
#  Time: 124.05892395973206
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment18.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.920325232249035
#  Precision: 0.9292678067378289
#  Time: 124.94362568855286
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment19.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9229129871165223
#  Precision: 0.9315841818606652
#  Time: 121.5786201953888
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment20.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.921394636078543
#  Precision: 0.9307152262956488
#  Time: 123.18070578575134
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment21.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9215128640088107
#  Precision: 0.930790373047163
#  Time: 123.91714406013489
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment22.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9205644381415026
#  Precision: 0.9302579388084311
#  Time: 124.37670493125916
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment23.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9210476230654406
#  Precision: 0.9307756807716017
#  Time: 122.44751787185669
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment24.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9242688654602067
#  Precision: 0.9326250208727683
#  Time: 124.02748227119446
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment25.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9225491054257079
#  Precision: 0.9332024033562814
#  Time: 123.04265260696411
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment26.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9265644427576623
#  Precision: 0.9334705619928604
#  Time: 123.21108889579773
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment27.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9192722265308065
#  Precision: 0.9287546033287153
#  Time: 124.01705169677734
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment28.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9247231756143287
#  Precision: 0.9331512623206366
#  Time: 122.0637903213501
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment29.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9252324776372092
#  Precision: 0.9331165459517631
#  Time: 140.510662317276
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment30.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.921262237383953
#  Precision: 0.9311387210306836
#  Time: 123.31442618370056
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment31.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9193373267314899
#  Precision: 0.9291834362667799
#  Time: 121.85932874679565
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment32.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9211715449995319
#  Precision: 0.9309542370661206
#  Time: 122.47331714630127
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment33.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9218211283607705
#  Precision: 0.9309518688049667
#  Time: 123.00353264808655
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment34.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9228646598406179
#  Precision: 0.9321306699610488
#  Time: 123.71919751167297
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment35.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9159321524028308
#  Precision: 0.9268366163094848
#  Time: 125.56073093414307
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment36.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9147343938335057
#  Precision: 0.9267422023612701
#  Time: 125.77292823791504
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment37.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9222392636458794
#  Precision: 0.9321648445731767
#  Time: 123.26316833496094
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment38.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9216164085250443
#  Precision: 0.9308456777489038
#  Time: 127.07922387123108
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment39.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9210611105478114
#  Precision: 0.930948462188963
#  Time: 124.98786902427673
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment40.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9220713080205714
#  Precision: 0.9309449869192572
#  Time: 121.81149411201477
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment41.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9248290826452107
#  Precision: 0.9324119208963157
#  Time: 129.30061411857605
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment42.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9181049019846994
#  Precision: 0.9290139223818978
#  Time: 123.53339004516602
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment43.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9195429614473698
#  Precision: 0.9288613288611094
#  Time: 125.79015040397644
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment44.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9173849213606202
#  Precision: 0.9273007496685693
#  Time: 127.73134255409241
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment45.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9199446499838828
#  Precision: 0.9304543737343434
#  Time: 125.40819001197815
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment46.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9253837243613717
#  Precision: 0.9329320700584511
#  Time: 123.00590634346008
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment47.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9193256198936681
#  Precision: 0.9293289680766866
#  Time: 120.70885610580444
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment48.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9212653882086712
#  Precision: 0.9312395858578058
#  Time: 123.29042291641235
# ===========================
#
# read gs://ai-covid19-datalake/trusted/experiment_map/04-STRSAMP-EW/ds-2/cols_set_3/experiment49.parquet
# Parameters ==> {'maxIter': 100, 'maxDepth': 7, 'maxBins': 64}
#  Results:
#  AUC_PR: 0.9214222584820531
#  Precision: 0.9314218288611256
#  Time: 124.9844000339508
# ===========================

# %% [markdown]
# <hr />
# <hr />
# <hr />

# %%
for i in range(len(experiments)):
    for d in list(experiments[i].keys()):
        experiments[i][d] = str(experiments[i][d])

# %%
# experiments

# %%
cols = ['experiment_filter', 'undersampling_method', 'filename', 'experiment_id', 'n_covid', 'n_not_covid', 'model_name', 'params', 'model_AUC_ROC', 'model_AUC_PR', 'model_covid_precision', 'model_covid_recall', 'model_covid_f1', 'model_not_covid_precision', 'model_not_covid_recall', 'model_not_covid_f1', 'model_avg_precision', 'model_avg_recall', 'model_avg_f1', 'model_avg_acc', 'model_TP', 'model_TN', 'model_FN', 'model_FP', 'model_time_exec', 'model_col_set']

# %%
intermed_results = spark.createDataFrame(data=experiments).select(cols)
intermed_results.toPandas()
# Out:
# /usr/lib/spark/python/pyspark/sql/session.py:346: UserWarning: inferring schema from dict is deprecated,please use pyspark.sql.Row instead
#   warnings.warn("inferring schema from dict is deprecated,"

# %%
intermed_results.write.parquet('gs://ai-covid19-datalake/trusted/intermed_results/STRSAMP/GBT_experiments-EW-ds2-cs3.parquet', mode='overwrite')

# %%
df = spark.read.parquet('gs://ai-covid19-datalake/trusted/intermed_results/STRSAMP/GBT_experiments-EW-ds2-cs3.parquet')
df.limit(2).toPandas()
# Out:
#   experiment_filter undersampling_method  \
# 0              ds-2        04-STRSAMP-EW
# 1              ds-2        04-STRSAMP-EW
#
#                                             filename experiment_id n_covid  \
# 0  gs://ai-covid19-datalake/trusted/experiment_ma...            34   53070
# 1  gs://ai-covid19-datalake/trusted/experiment_ma...            35   52769
#
#   n_not_covid model_name                                          params  \
# 0       44538        GBT  {'maxIter': 100, 'maxDepth': 5, 'maxBins': 64}
# 1       44538        GBT  {'maxIter': 100, 'maxDepth': 5, 'maxBins': 64}
#
#         model_AUC_ROC        model_AUC_PR model_covid_precision  \
# 0  0.9267895328803827  0.9233686352834001    0.9144230769230769
# 1  0.9270786658531358  0.9207498902446805    0.9173312229865466
#
#    model_covid_recall      model_covid_f1 model_not_covid_precision  \
# 0  0.9596972563859981    0.93651330973996        0.9494221940794682
# 1  0.9570049536390194  0.9367482050166288        0.9459394713726743
#
#   model_not_covid_recall  model_not_covid_f1 model_avg_precision  \
# 0     0.8938818093747671  0.9208152611983265  0.9319226355012725
# 1     0.8971523780672523   0.920900221557119  0.9316353471796104
#
#      model_avg_recall        model_avg_f1       model_avg_acc model_TP  \
# 0  0.9267895328803826  0.9286642854691433  0.9295279087244654    15216
# 1  0.9270786658531358  0.9288242132868739  0.9297063903281519    15069
#
#   model_TN model_FN model_FP    model_time_exec model_col_set
# 0    11995      639     1424  65.29870009422302    cols_set_3
# 1    11846      677     1358  65.50185322761536    cols_set_3

# %%
print('finished')
# Out:
# finished

# %%
intermed_results.show()
# Out:
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# |experiment_filter|undersampling_method|            filename|experiment_id|n_covid|n_not_covid|model_name|              params|     model_AUC_ROC|      model_AUC_PR|model_covid_precision|model_covid_recall|    model_covid_f1|model_not_covid_precision|model_not_covid_recall|model_not_covid_f1|model_avg_precision|  model_avg_recall|      model_avg_f1|     model_avg_acc|model_TP|model_TN|model_FN|model_FP|   model_time_exec|model_col_set|
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|            0|  53203|      44538|       GBT|{'maxIter': 20, '...| 0.918495457624014| 0.915595324497113|   0.9054133395960545| 0.958064115308151|0.9309949287611688|       0.9454324979789814|    0.8789267999398768| 0.910967440411279|  0.925422918787518|0.9184954576240139|0.9209811845862239|0.9222501870621046|   15421|   11695|     675|    1611| 26.11881923675537|   cols_set_3|
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|            1|  53038|      44538|       GBT|{'maxIter': 20, '...|0.9171470224131691|0.9175969130918951|   0.9011235955056179|0.9607212659983607|0.9299685697720546|       0.9488337713534822|    0.8735727788279773|0.9096492264084092| 0.9249786834295501| 0.917147022413169|0.9198088980902319|0.9210960599601182|   15238|   11553|     623|    1672|15.510443687438965|   cols_set_3|
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|            2|  53459|      44538|       GBT|{'maxIter': 20, '...|0.9202066952448188|0.9189051037158987|    0.905999528524281|0.9603923283563441|0.9324033358605003|       0.9485932052217627|    0.8800210621332932|0.9130214227182268| 0.9272963668730219|0.9202066952448187|0.9227123792893636|0.9239275110064503|   15373|   11699|     634|    1595|14.964608430862427|   cols_set_3|
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|            3|  52952|      44538|       GBT|{'maxIter': 20, '...|0.9194212749699702|0.9221740707715611|   0.9007475083056479|0.9625943067266849|0.9306445186797021|       0.9525570923126407|    0.8762482432132555|0.9128106337892508| 0.9266523003091443|0.9194212749699702|0.9217275762344764|0.9227434111702854|   15183|   11846|     590|    1673|13.695220232009888|   cols_set_3|
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|            4|  52087|      44538|       GBT|{'maxIter': 20, '...|     0.91743941908|0.9165757081648644|   0.9014781297134238|0.9576977310601205|0.9287379183889113|       0.9464416132435284|    0.8771811070998796|0.9104961161637848|  0.923959871478476|     0.91743941908| 0.919617017276348|0.9206519482317116|   14942|   11663|     660|    1633|15.157051086425781|   cols_set_3|
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|            5|  52315|      44538|       GBT|{'maxIter': 20, '...| 0.918354198501027|0.9209055225485867|   0.9004857244402322|0.9630051944761181|0.9306967062568876|       0.9521546780271998|    0.8737032025259359|0.9112435314411165|  0.926320201233716|0.9183541985010271| 0.920970118849002|0.9221672167216721|   15202|   11622|     584|    1680| 12.91630744934082|   cols_set_3|
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|            6|  53153|      44538|       GBT|{'maxIter': 20, '...|0.9194733198857866|0.9197552271833211|   0.9031316980233389|0.9604280106369507|0.9308990487879718|       0.9495601646356226|    0.8785186291346225|0.9126590133416072| 0.9263459313294808|0.9194733198857866|0.9217790310647895|0.9228423613252476|   15169|   11766|     625|    1627|12.947561025619507|   cols_set_3|
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|            7|  53255|      44538|       GBT|{'maxIter': 20, '...| 0.917735973737842|0.9152073006666026|   0.9044260271557044|0.9583930239800685|0.9306277972662393|        0.945558272208639|    0.8770789234956153|0.9100321593850497| 0.9249921496821717|0.9177359737378419|0.9203299783256444|0.9216610319980876|   15387|   11602|     668|    1626|13.201907634735107|   cols_set_3|
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|            8|  53062|      44538|       GBT|{'maxIter': 20, '...|0.9185080389159435|0.9233159696331703|    0.898651817116061|0.9651850919163939|0.9307309373482273|       0.9550917654701965|    0.8718309859154929|0.9115640985893659| 0.9268717912931288|0.9185080389159435|0.9211475179687967|0.9223122489276231|   15331|   11761|     553|    1729| 12.81569528579712|   cols_set_3|
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|            9|  53148|      44538|       GBT|{'maxIter': 20, '...|0.9223190771439519|0.9178248575248926|   0.9106910039113429|0.9575051405071967| 0.933511526896091|        0.945557595593518|     0.887133013780707|0.9154140422736582| 0.9281242997524305|0.9223190771439518|0.9244627845848745|0.9255467501105404|   15367|   11845|     682|    1507|12.644547939300537|   cols_set_3|
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|           10|  53539|      44538|       GBT|{'maxIter': 20, '...|0.9165974080724958|0.9194439908207891|   0.8987120461565359|0.9630901823632276|0.9297880678906273|       0.9516880568952832|    0.8701046337817638|0.9090696130871042| 0.9252000515259096|0.9165974080724957|0.9194288404888658| 0.920760751224823|   15421|   11642|     591|    1738|12.786217451095581|   cols_set_3|
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|           11|  53003|      44538|       GBT|{'maxIter': 20, '...|0.9202852123494629|0.9163259927710692|   0.9074805505685218|0.9561160151324086|0.9311636475284005|       0.9444533120510774|    0.8844544095665172| 0.913469702817445| 0.9259669313097996|0.9202852123494629|0.9223166751729228|0.9233242134062928|   15164|   11834|     696|    1546| 12.70435094833374|   cols_set_3|
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|           12|  51577|      44538|       GBT|{'maxIter': 20, '...|0.9172748554020307|0.9173267341563385|     0.90002435460302| 0.957693553611921|0.9279638406729652|       0.9471040907249899|    0.8768561571921404|0.9106273608785389|  0.923564222664005|0.9172748554020307| 0.919295600775752|0.9202266328339532|   14782|   11692|     653|    1642|12.891528606414795|   cols_set_3|
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|           13|  52510|      44538|       GBT|{'maxIter': 20, '...|0.9190969260314951|0.9198556306320812|   0.9018001315710783|0.9598956012476924|0.9299414122725871|       0.9495192307692307|     0.878298250815298|0.9125211766517789| 0.9256596811701545|0.9190969260314952| 0.921231294462183|0.9221944453957056|   15079|   11850|     630|    1642|13.819063663482666|   cols_set_3|
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|           14|  52884|      44538|       GBT|{'maxIter': 20, '...|0.9180813093979417|0.9145683983479005|   0.9049139613269469|0.9561984503874031|0.9298496126386145|       0.9438706061333973|    0.8799641684084801|0.9107977593200696| 0.9243922837301721|0.9180813093979416| 0.920323685979342|0.9214625850340136|   15303|   11788|     701|    1608|12.830574989318848|   cols_set_3|
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|           15|  52068|      44538|       GBT|{'maxIter': 20, '...|0.9189152103039275|0.9181546113186847|   0.9033928571428571|0.9591127401415571|0.9304193231976459|       0.9478478155731098|    0.8787176804662981|0.9119745618116954| 0.9256203363579835|0.9189152103039275|0.9211969425046707|0.9222762446072725|   15177|   11759|     647|    1623| 21.98294472694397|   cols_set_3|
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|           16|  52872|      44538|       GBT|{'maxIter': 20, '...|0.9170013288754228|0.9174887457922779|   0.9006287829817241|0.9602155253430236|0.9294681302686639|       0.9485496678010047|     0.873787132407822|0.9096348096348096| 0.9245892253913643|0.9170013288754228|0.9195514699517368|0.9207738683197657|   15326|   11707|     635|    1691|12.306756496429443|   cols_set_3|
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|           17|  52377|      44538|       GBT|{'maxIter': 20, '...|0.9221052526776178|0.9192227325942338|   0.9086141419012599|0.9580499586855654|0.9326774333271457|        0.947034748415055|    0.8861605466696704|0.9155869345953914| 0.9278244451581574|0.9221052526776179|0.9241321839612686|0.9250946643717728|   15073|   11801|     660|    1516|13.838562250137329|   cols_set_3|
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|           18|  52304|      44538|       GBT|{'maxIter': 20, '...|0.9153442834222835| 0.917554384231346|   0.8967551622418879|0.9602888086642599|0.9274351710612334|       0.9492335585956816|    0.8703997581803068|0.9081089604604408| 0.9229943604187847|0.9153442834222834| 0.917772065760837| 0.918907636110628|   14896|   11518|     616|    1715|12.352733373641968|   cols_set_3|
# |             ds-2|       04-STRSAMP-EW|gs://ai-covid19-d...|           19|  52485|      44538|       GBT|{'maxIter': 20, '...|0.9173694724233161|0.9148520122704197|    0.903673517599811|0.9576292402052823|0.9298693406259496|       0.9450397791849326|    0.8771097046413502|0.9098085189527159| 0.9243566483923717|0.9173694724233162|0.9198389297893328|0.9210940170940171|   15301|   11641|     677|    1631| 12.40332555770874|   cols_set_3|
# +-----------------+--------------------+--------------------+-------------+-------+-----------+----------+--------------------+------------------+------------------+---------------------+------------------+------------------+-------------------------+----------------------+------------------+-------------------+------------------+------------------+------------------+--------+--------+--------+--------+------------------+-------------+
# only showing top 20 rows
