# %%
import pandas as pd
import pyspark.sql.functions as F
from datetime import datetime
from pyspark.sql.types import *
from pyspark import StorageLevel

# %%
dict_results = [
    {'col1': 9827, 'col2':892346},    
    {'col1': 564654, 'col2':234234}
]

# %%
schema = StructType([
            StructField('col1', IntegerType(), True),
            StructField('col2', IntegerType(), True)
                    ])

# %%
df = spark.createDataFrame(data=dict_results, schema=schema)

# %%
df.show()
# Out:
# +------+------+
# |  col1|  col2|
# +------+------+
# |  9827|892346|
# |564654|234234|
# +------+------+
